# %%
# User-defined indicators
from bs4 import BeautifulSoup
import requests
import os
import wget
import time
base_path = "C:\\Users\\10235555\\Documents\\Dataportal Data\\Userdefined indicators"
import urllib.request
import logging
from selenium.webdriver.support.ui import Select
import datetime
from Hashing.HashScrapedData import _hashing
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import ElementNotInteractableException, NoSuchElementException
from selenium.common.exceptions import ElementClickInterceptedException
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from webdriver_manager.firefox import GeckoDriverManager
from selenium.webdriver.firefox.options import Options
from bs4 import BeautifulSoup
import time
import os
from RequestInferSchemaToJsonAPI.main import TriggerInferShemaToJsonAPI

# %%
chrome_options = webdriver.ChromeOptions()
base_path = "C:\\Users\\10235555\\Documents\\Dataportal Data\\Userdefined indicators" # local, gets current working directory
prefs = {'download.default_directory' : base_path}#, "profile.content_settings.exceptions.automatic_downloads.*.setting" : 1}
chrome_options.add_experimental_option('prefs', prefs)
# chrome_options.add_argument('--user-agent="Mozilla/5.0 (Windows Phone 10.0; Android 4.2.1; Microsoft; Lumia 640 XL LTE) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.135 Mobile Safari/537.36 Edge/12.10166"')
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)
driver.maximize_window()

# %%
url_1 = 'https://di.unfccc.int/indicators_annex1'
url_2 = 'https://di.unfccc.int/indicators_non_annex1'
driver.get(url_1)

# %%
content = driver.find_element(By.CLASS_NAME,'PageContent')
topic = content.find_element(By.TAG_NAME,'h1').text
top = topic.split(' - ')[1]
indicator_boxes = content.find_element(By.CLASS_NAME,'indicator-box')
# party
party = indicator_boxes.find_elements(By.CLASS_NAME,'indicators-column')[0]
party_visible = party.find_element(By.CLASS_NAME,'ddlb')
driver.execute_script("arguments[0].style.display = 'block';", party_visible)
time.sleep(1)
filter_box_1 = party.find_element(By.CLASS_NAME,'ddlbFilterBox')
driver.execute_script("arguments[0].style.display = 'block';", filter_box_1)
Select_all_part = filter_box_1.find_element(By.CLASS_NAME,"ddlbButton")
Select_all_part.click()
# year
year = indicator_boxes.find_elements(By.CLASS_NAME,'indicators-column')[1]
year_visible = year.find_element(By.CLASS_NAME,'ddlb')
driver.execute_script("arguments[0].style.display = 'block';", year_visible)
time.sleep(1)
filter_box_2 = year.find_element(By.CLASS_NAME,'ddlbFilterBox')
driver.execute_script("arguments[0].style.display = 'block';", filter_box_2)
Select_all_year = filter_box_2.find_element(By.CLASS_NAME,"ddlbButton")
Select_all_year.click()
filters = content.find_element(By.CLASS_NAME,'filters').find_elements(By.CLASS_NAME,'indicator-box')
# A
A = filters[0]
tap = A.find_element(By.CLASS_NAME,'tab').find_elements(By.CLASS_NAME,'radio')
for radio in tap:
    radio.find_element(By.TAG_NAME,'input').click()
    time.sleep(3)
    content_a = A.find_element(By.CLASS_NAME,'tabcontent').find_elements(By.CLASS_NAME,'indicators-column')
    # category
    category = content_a[0]
    classification = content_a[1]
    filter_box_1a = category.find_element(By.CLASS_NAME,'ddlbFilterBox.ddlbFilterBoxSingle')
    driver.execute_script("arguments[0].style.display = 'block';", filter_box_1a)
    time.sleep(1)
    list_category = category.find_element(By.CLASS_NAME,'ddlbCheckContainer').find_elements(By.TAG_NAME,'p')
    driver.execute_script('arguments[0].scrollIntoView(true);', classification)
    time.sleep(1)
    for categ in list_category:
        # categ.click()
        WebDriverWait(driver, 10).until(EC.element_to_be_clickable((categ)))
        driver.execute_script("arguments[0].click()", categ)
        time.sleep(2)
        t_1a = categ.text
        # classification
        classification = content_a[1]
        gas = content_a[2]
        filter_box_2a = classification.find_element(By.CLASS_NAME,'ddlbFilterBox.ddlbFilterBoxSingle')
        driver.execute_script("arguments[0].style.display = 'block';", filter_box_2a)
        time.sleep(1)
        list_classification = classification.find_element(By.CLASS_NAME,'ddlbCheckContainer').find_elements(By.TAG_NAME,'p')
        driver.execute_script('arguments[0].scrollIntoView(true);', gas)
        time.sleep(1)
        for classif in list_classification:
            # classif.click()
            WebDriverWait(driver, 10).until(EC.element_to_be_clickable((classif)))
            driver.execute_script("arguments[0].click()", classif)
            time.sleep(2)
            t_2a = classif.text
            # Gas
            Gas = content_a[2]
            unit = content_a[3]
            filter_box_3a = Gas.find_element(By.CLASS_NAME,'ddlbFilterBox.ddlbFilterBoxSingle')
            driver.execute_script("arguments[0].style.display = 'block';", filter_box_3a)
            time.sleep(1)
            list_gas = Gas.find_element(By.CLASS_NAME,'ddlbCheckContainer').find_elements(By.TAG_NAME,'p')
            driver.execute_script('arguments[0].scrollIntoView(true);', unit)
            time.sleep(1)
            for gas in list_gas:
                # gas.click()
                # gas.click()
                WebDriverWait(driver, 10).until(EC.element_to_be_clickable((gas)))
                driver.execute_script("arguments[0].click()", gas)
                time.sleep(2)
                t_3a = gas.text
                # unit 
                unit = content_a[3]
                filter_box_4a = unit.find_element(By.CLASS_NAME,'ddlbFilterBox.ddlbFilterBoxSingle')
                driver.execute_script("arguments[0].style.display = 'block';", filter_box_4a)
                time.sleep(1)
                list_unit = unit.find_element(By.CLASS_NAME,'ddlbCheckContainer').find_elements(By.TAG_NAME,'p')
                # driver.execute_script('arguments[0].scrollIntoView(true);', unit)
                time.sleep(1)
                for unt in list_unit:
                    # unt.click()
                    WebDriverWait(driver, 10).until(EC.element_to_be_clickable((unt)))
                    driver.execute_script("arguments[0].click()", unt)
                    time.sleep(2)
                    t_4a = unt.text
                    ind_ua = list_unit.index(unt)

                    # B
                    B = filters[1]
                    tap_b = B.find_element(By.CLASS_NAME,'tab').find_elements(By.CLASS_NAME,'radio')
                    for radio_b in tap_b:
                        radio_bs = radio_b.find_element(By.TAG_NAME,'input')
                        WebDriverWait(driver, 10).until(EC.element_to_be_clickable((radio_bs)))
                        driver.execute_script("arguments[0].click()", radio_bs)
                        # radio_b.find_element(By.TAG_NAME,'input').click()
                        time.sleep(3)
                        content_b = B.find_element(By.CLASS_NAME,'tabcontent').find_elements(By.CLASS_NAME,'indicators-column')
                        # category
                        category_b = content_b[0]
                        classification_b = content_b[1]
                        filter_box_1b = category_b.find_element(By.CLASS_NAME,'ddlbFilterBox.ddlbFilterBoxSingle')
                        driver.execute_script("arguments[0].style.display = 'block';", filter_box_1b)
                        time.sleep(1)
                        list_category_b = category_b.find_element(By.CLASS_NAME,'ddlbCheckContainer').find_elements(By.TAG_NAME,'p')
                        driver.execute_script('arguments[0].scrollIntoView(true);', classification_b)
                        time.sleep(1)
                        for categ_b in list_category_b:
                            # categ.click()
                            WebDriverWait(driver, 10).until(EC.element_to_be_clickable((categ_b)))
                            driver.execute_script("arguments[0].click()", categ_b)
                            time.sleep(2)
                            t_1b = categ_b.text
                            # classification
                            classification_b = content_b[1]
                            gas_b = content_b[2]
                            filter_box_2b = classification_b.find_element(By.CLASS_NAME,'ddlbFilterBox.ddlbFilterBoxSingle')
                            driver.execute_script("arguments[0].style.display = 'block';", filter_box_2b)
                            time.sleep(1)
                            list_classification_b = classification_b.find_element(By.CLASS_NAME,'ddlbCheckContainer').find_elements(By.TAG_NAME,'p')
                            driver.execute_script('arguments[0].scrollIntoView(true);', gas_b)
                            time.sleep(1)
                            for classif_b in list_classification_b:
                                # classif.click()
                                WebDriverWait(driver, 10).until(EC.element_to_be_clickable((classif_b)))
                                driver.execute_script("arguments[0].click()", classif_b)
                                time.sleep(2)
                                t_2b = classif_b.text
                                # Gas
                                Gas_b = content_b[2]
                                unit_b = content_b[3]
                                filter_box_3b = Gas_b.find_element(By.CLASS_NAME,'ddlbFilterBox.ddlbFilterBoxSingle')
                                driver.execute_script("arguments[0].style.display = 'block';", filter_box_3b)
                                time.sleep(1)
                                list_gas_b = Gas_b.find_element(By.CLASS_NAME,'ddlbCheckContainer').find_elements(By.TAG_NAME,'p')
                                driver.execute_script('arguments[0].scrollIntoView(true);', unit_b)
                                time.sleep(1)
                                for gas_b in list_gas_b:
                                    # gas.click()
                                    # gas.click()
                                    WebDriverWait(driver, 10).until(EC.element_to_be_clickable((gas_b)))
                                    driver.execute_script("arguments[0].click()", gas_b)
                                    time.sleep(2)
                                    t_3b = gas_b.text
                                    # unit 
                                    unit = content_b[3]
                                    filter_box_4b = unit.find_element(By.CLASS_NAME,'ddlbFilterBox.ddlbFilterBoxSingle')
                                    driver.execute_script("arguments[0].style.display = 'block';", filter_box_4b)
                                    time.sleep(1)
                                    list_unit_b = unit_b.find_element(By.CLASS_NAME,'ddlbCheckContainer').find_elements(By.TAG_NAME,'p')
                                    # driver.execute_script('arguments[0].scrollIntoView(true);', unit)
                                    time.sleep(1)
                                    for unt_b in list_unit_b:
                                        # unt.click()
                                        WebDriverWait(driver, 10).until(EC.element_to_be_clickable((unt_b)))
                                        driver.execute_script("arguments[0].click()", unt_b)
                                        time.sleep(4)
                                        t_4b = unt_b.text
                                        topic = 'Annual greenhouse gas (GHG) Indicators Numerator ('+ t_1a + ' ' + t_2a + ' ' + t_3a + ' ' + t_4a  + '), Denominator(' + t_1b + ' ' + t_2b + ' ' + t_3b + ' ' + t_4b  + ')'
                                        title_a = t_1a + ' ' + t_2a + ' ' + t_3a + ' ' + t_4a
                                        title_b = t_1b + ' ' + t_2b + ' ' + t_3b + ' ' + t_4b 
                                        ind_ub = list_unit_b.index(unt_b)
                                        if title_a == title_b:
                                            pass
                                        else:
                                            if t_2a == 'Total for category':
                                                t_2a = ''
                                            if t_2b == 'Total for category':
                                                t_2b = ''
                                            title = t_1a + ' ' + t_2a + ' ' + t_3a + str(ind_ua) + ' ON ' + t_1b + ' ' + t_2b + ' ' + t_3b + str(ind_ub)
                                            title = title.replace('.','').replace('/','').replace(':',' ').replace('₂','2').replace('₆','6').replace('₃','3').replace('₄','4')
                                            Unit = t_4a + '/' + t_4b
                                            table = driver.find_element(By.CLASS_NAME,'dataTable.no-footer')
                                            head = []
                                            thead = table.find_element(By.TAG_NAME,'thead').find_elements(By.TAG_NAME,'th')
                                            for th in thead:
                                                driver.execute_script("return arguments[0].scrollIntoView(true);", th)
                                                head.append(th.text)
                                            table_body = driver.find_element(By.CLASS_NAME,'dataTables_scrollBody').find_element(By.TAG_NAME,'table')#tbody
                                            rows = table_body.find_elements(By.TAG_NAME,'tr')
                                            l = []
                                            for tr in rows[1:]:
                                                cells = tr.find_elements(By.TAG_NAME,'td')
                                                cells_text = [cell.text for cell in cells]
                                                l.append(cells_text)
                                            df = pd.DataFrame(l,columns=head) 
                                            Units = [Unit]*len(df.index)
                                            df.insert(1,'Unit',Units)
                                            df.to_excel(f'{base_path}\\{title}.xlsx',index = False)
                                            notes = driver.find_element(By.CLASS_NAME,'disclaimer-notes').text
                                            
                                        unit_b = content_b[3]
                                        filter_box_4b = unit_b.find_element(By.CLASS_NAME,'ddlbFilterBox.ddlbFilterBoxSingle')
                                        driver.execute_script("arguments[0].style.display = 'block';", filter_box_4b)
                                        time.sleep(1)
                                        list_unit_b = unit_b.find_element(By.CLASS_NAME,'ddlbCheckContainer').find_elements(By.TAG_NAME,'p')

                                    Gas_b = content_b[2]
                                    unit_b = content_b[3]
                                    filter_box_3b = Gas_b.find_element(By.CLASS_NAME,'ddlbFilterBox.ddlbFilterBoxSingle')
                                    driver.execute_script("arguments[0].style.display = 'block';", filter_box_3b)
                                    time.sleep(1)
                                    list_gas_b = Gas_b.find_element(By.CLASS_NAME,'ddlbCheckContainer').find_elements(By.TAG_NAME,'p')
                                    driver.execute_script('arguments[0].scrollIntoView(true);', unit_b)
                                    time.sleep(1)

                                classification_b = content_b[1]
                                filter_box_2b = classification.find_element(By.CLASS_NAME,'ddlbFilterBox.ddlbFilterBoxSingle')
                                driver.execute_script("arguments[0].style.display = 'block';", filter_box_2b)
                                time.sleep(1)
                                driver.execute_script('arguments[0].scrollTop = arguments[0].scrollHeight', category_b)
                                driver.implicitly_wait(1)
                                # driver.execute_script('arguments[0].scrollIntoView(true);', category)
                                time.sleep(1)
                                list_classification_b = classification_b.find_element(By.CLASS_NAME,'ddlbCheckContainer').find_elements(By.TAG_NAME,'p')
                                driver.execute_script('arguments[0].scrollIntoView(true);', gas_b)
                                time.sleep(1)
                                
                            category_b = content_b[0]
                            classification_b = content_b[1]
                            filter_box_1b = category_b.find_element(By.CLASS_NAME,'ddlbFilterBox.ddlbFilterBoxSingle')
                            driver.execute_script("arguments[0].style.display = 'block';", filter_box_1b)
                            time.sleep(1)
                            driver.execute_script('arguments[0].scrollTop = arguments[0].scrollHeight', tap_b)
                            driver.implicitly_wait(1)
                            # driver.execute_script('arguments[0].scrollIntoView(true);', tap)
                            time.sleep(1)
                            list_category_b = category_b.find_element(By.CLASS_NAME,'ddlbCheckContainer').find_elements(By.TAG_NAME,'p')
                            driver.execute_script('arguments[0].scrollIntoView(true);', classification_b)
                            time.sleep(1)

                    unit = content_a[3]
                    filter_box_4a = unit.find_element(By.CLASS_NAME,'ddlbFilterBox.ddlbFilterBoxSingle')
                    driver.execute_script("arguments[0].style.display = 'block';", filter_box_4a)
                    time.sleep(1)
                    list_unit = unit.find_element(By.CLASS_NAME,'ddlbCheckContainer').find_elements(By.TAG_NAME,'p')

                Gas = content_a[2]
                unit = content_a[3]
                filter_box_3a = Gas.find_element(By.CLASS_NAME,'ddlbFilterBox.ddlbFilterBoxSingle')
                driver.execute_script("arguments[0].style.display = 'block';", filter_box_3a)
                time.sleep(1)
                list_gas = Gas.find_element(By.CLASS_NAME,'ddlbCheckContainer').find_elements(By.TAG_NAME,'p')
                driver.execute_script('arguments[0].scrollIntoView(true);', unit)
                time.sleep(1)

            classification = content_a[1]
            filter_box_2a = classification.find_element(By.CLASS_NAME,'ddlbFilterBox.ddlbFilterBoxSingle')
            driver.execute_script("arguments[0].style.display = 'block';", filter_box_2a)
            time.sleep(1)
            driver.execute_script('arguments[0].scrollTop = arguments[0].scrollHeight', category)
            driver.implicitly_wait(1)
            # driver.execute_script('arguments[0].scrollIntoView(true);', category)
            time.sleep(1)
            list_classification = classification.find_element(By.CLASS_NAME,'ddlbCheckContainer').find_elements(By.TAG_NAME,'p')
            driver.execute_script('arguments[0].scrollIntoView(true);', gas)
            time.sleep(1)
            
        category = content_a[0]
        classification = content_a[1]
        filter_box_1a = category.find_element(By.CLASS_NAME,'ddlbFilterBox.ddlbFilterBoxSingle')
        driver.execute_script("arguments[0].style.display = 'block';", filter_box_1a)
        time.sleep(1)
        driver.execute_script('arguments[0].scrollTop = arguments[0].scrollHeight', tap)
        driver.implicitly_wait(1)
        # driver.execute_script('arguments[0].scrollIntoView(true);', tap)
        time.sleep(1)
        list_category = category.find_element(By.CLASS_NAME,'ddlbCheckContainer').find_elements(By.TAG_NAME,'p')
        driver.execute_script('arguments[0].scrollIntoView(true);', classification)
        time.sleep(1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\10235555\Documents\DataportalCrawlers\UN_Data\UNFCCC\User-defined indicators.ipynb Cell 4 in 1
#     <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/UNFCCC/User-defined%20indicators.ipynb#W3sZmlsZQ%3D%3D?line=144'>145</a> WebDriverWait(driver, 10).until(EC.element_to_be_clickable((gas_b)))
#     <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/UNFCCC/User-defined%20indicators.ipynb#W3sZmlsZQ%3D%3D?line=145'>146</a> driver.execute_script("arguments[0].click()", gas_b)
# --> <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/UNFCCC/User-defined%20indicators.ipynb#W3sZmlsZQ%3D%3D?line=146'>147</a> time.sleep(2)
# ...

# %%
table = driver.find_element(By.CLASS_NAME,'dataTable.no-footer')
head = []
# thead = table.find_element(By.TAG_NAME,'thead').find_elements(By.TAG_NAME,'th')
# for th in thead:
#     head.append(th.text)
table_body = driver.find_element(By.CLASS_NAME,'dataTables_scrollBody').find_element(By.TAG_NAME,'table')#tbody
thead = table.find_element(By.TAG_NAME,'thead').find_elements(By.TAG_NAME,'th')
for th in thead:
    driver.execute_script("return arguments[0].scrollIntoView(true);", th)
    # time.sleep(1)
    head.append(th.text)
# rows = table_body.find_elements(By.TAG_NAME,'tr')
# l = []
# for tr in rows[1:]:
#     cells = tr.find_elements(By.TAG_NAME,'td')
#     cells_text = [cell.text for cell in cells]
#     l.append(cells_text)
# df = pd.DataFrame(l,columns=head) 
# df.to_excel(f'{base_path}\\{title}.xlsx',index = False)
# notes = driver.find_element(By.CLASS_NAME,'disclaimer-notes').text
head
# Out:
# ['Party',
#  'Base year',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2017',
#  '2018',
#  '2019',
#  'Last Inventory Year (2020)']

# %%
notes = driver.find_element(By.CLASS_NAME,'disclaimer-notes').text
notes
# Out:
# 'Note 1: The reporting and review requirements for GHG inventories are different for Annex I and non-Annex I Parties. The definition format of data for emissions/removals from the forestry sector is different for Annex I and non-Annex I Parties.\nNote 2: Base year data in the data interface relate to the base year under the Climate Change Convention (UNFCCC). The base year under the Convention is defined slightly different than the base year under the Kyoto Protocol. An exception is made for European Union (KP) whereby the base year under the Kyoto Protocol is displayed.\nNote 3: – means "No data available"\nNote 4: Data displayed on the data interface are "as received" from Parties. The publication of Party submissions on this website does not imply the expression of any opinion whatsoever on the part of the UNFCCC or the Secretariat of the United Nations concerning the legal status of any country, territory, city or area or of its authorities, or concerning the delimitation of its 
# ...
