# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import ElementNotInteractableException, NoSuchElementException
from selenium.common.exceptions import ElementClickInterceptedException
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from webdriver_manager.firefox import GeckoDriverManager
from selenium.webdriver.firefox.options import Options
from bs4 import BeautifulSoup
import shutil
import time
import os
import pandas as pd
from pyshadow.main import Shadow
from py7zr import unpack_7zarchive
from RequestInferSchemaToJsonAPI.main import TriggerInferShemaToJsonAPI
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\UNOPS'

# %%
chrome_options = webdriver.ChromeOptions()
base_path = "C:\\Users\\10235555\\Documents\\Dataportal Data\\UNOPS" # local, gets current working directory
prefs = {'download.default_directory' : base_path}#, "profile.content_settings.exceptions.automatic_downloads.*.setting" : 1}
chrome_options.add_experimental_option('prefs', prefs)
chrome_options.add_argument('--user-agent="Mozilla/5.0 (Windows Phone 10.0; Android 4.2.1; Microsoft; Lumia 640 XL LTE) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.135 Mobile Safari/537.36 Edge/12.10166"')
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)
driver.maximize_window()

# %%
driver.get('https://data.unops.org/index.htm#SegmentCode=ORG&FocusCode=DATA_PROJECTS&EntityCode=ORG_CODE&EntityValue=UNOPS##SectionCode=OVERVIEW')
time.sleep(2)
driver.refresh()
time.sleep(2)

# %%
update = driver.find_element(By.ID,'tbtext-1062').text.split(': ')[1]
# Out:
# '06-Mar-2023'

# %%
i = ['23210-001']
url = f'https://data.unops.org/index.htm#SegmentCode=ORG&FocusCode=DATA_PROJECTS&EntityCode=PROJECT_ID&EntityValue={i[0]}##SectionCode=OVERVIEW'
driver.get(url)
time.sleep(1)
driver.refresh()
time.sleep(2)

# %%
.find_element(By.ID,'Workspace-TabPanel-1046-body').find_element(By.CLASS_NAME,'x-table-layout-cell')

# %%
driver.find_elements(By.CLASS_NAME,'x-tab.x-box-item.x-tab-default.x-noicon.x-tab-noicon.x-tab-default-noicon.x-top.x-tab-top.x-tab-default-top')[6].click()

# %%
data = driver.find_elements(By.CLASS_NAME,'x-toolbar-text.x-box-item.x-toolbar-item.x-toolbar-text-default')[2].text
# Out:
# 'of 0'

# %%
driver.find_element(By.ID,'button-1039').click()

# %%
summary = []
title = driver.find_element(By.TAG_NAME,'thead').text
table_summary = driver.find_element(By.CLASS_NAME,'summary')
rows = table_summary.find_elements(By.TAG_NAME,'tr')
for row in rows:
    summary.append(row.text)
#     cells = row.find_elements(By.TAG_NAME,'td')
#     cells_text = [cell.text for cell in cells]
#     cells_summary.append(cells_text)
# cells_summary

# %%
summary
# Out:
# ['Partner(s):\nUNMAS',
#  'Funding Source(s):\nUN VTF',
#  'Countries of Delivery:\nLibya',
#  'Sector(s):\n152 Conflict prevention and resolution, peace and security',
#  'Project Duration: 01-Aug-2022 to 16-Jun-2023',
#  'Total Funded Amount: US$ 1,007,714',
#  'Total Delivery: US$ 3,517']

# %%
projects_id = []
from selenium.common.exceptions import TimeoutException
table = driver.find_element(By.TAG_NAME,'tbody')
dataset = table.find_elements(By.CLASS_NAME,'x-grid-cell.x-grid-cell-gridcolumn-1078')
for i in range(77):
    for x in dataset:
        data_dataset = x.find_element(By.TAG_NAME,'div').find_element(By.TAG_NAME,'a').get_attribute('onclick')
        data_dataset = data_dataset.split(", '")[-1].split("')")[0]
        if data_dataset in projects_id:
            pass
        else:
            print(data_dataset)
            projects_id.append(data_dataset)
        
    next_table = driver.find_element(By.ID,'button-1096')
    next_table.click()
    time.sleep(7)
    timeout = 15
    try:
        element_present = EC.presence_of_element_located((By.XPATH,'/html/body/table/tbody/tr/td/div/div/table/tbody/tr[6]/td/div/div[1]/div/table/tbody/tr[2]/td/div/div/div[1]/div[2]/div/div[1]/table/tbody/tr/td/div/div/table/tbody/tr[2]/td/div/div[2]/div/div/table/tbody/tr/td/div/div[2]/div/table/tbody/tr[2]/td[2]'))
        WebDriverWait(driver, timeout).until(element_present)
    except TimeoutException:
        print("Timed out waiting for page to load next table")
    table = driver.find_element(By.TAG_NAME,'tbody')
    dataset = table.find_elements(By.CLASS_NAME,'x-grid-cell.x-grid-cell-gridcolumn-1078')
# Out:
# 22288-001
# 22091-001
# 22020-001
# 21891-004
# 21509-001
# 22335-001
# 11903-013
# 11295-025
# 21385-009
# 20429-002
# 21940-001
# 22278-001
# 21759-001
# 20119-001
# 22280-001
# 23161-004
# 23161-005
# 23161-006
# 23161-007
# 23105-001
# 22994-001
# 22988-001
# 22938-001
# 22893-001
# 23303-001
# 22787-001
# 22790-001
# 22791-001
# 22791-002
# 22792-001
# 23866-001
# 23867-001
# 23868-001
# 23827-001
# 23829-001
# 23829-002
# 23829-003
# 23829-004
# 69213
# 72855
# 76963
# 78847
# 10175-001
# 10175-002
# 10175-003
# 10175-004
# 10175-005
# 10175-006
# 10175-007
# 10175-008
# 10175-009
# 69191
# 69214
# 69215
# 69216
# 69217
# 69218
# 69420
# 76426
# 76428
# 62026
# 70927
# 72551
# 62788
# 61792
# 58896
# 55793

# %%
from selenium.common.exceptions import TimeoutException
for i in projects_id:
    url = f'https://data.unops.org/index.htm#SegmentCode=ORG&FocusCode=DATA_PROJECTS&EntityCode=PROJECT_ID&EntityValue={i}##SectionCode=OVERVIEW'
    driver.get(url)
    time.sleep(2)
    driver.refresh()
    time.sleep(4)
    timeout = 15
    try:
        element_present = EC.presence_of_element_located((By.CLASS_NAME,'x-box-inner.x-horizontal-box-overflow-body'))
        WebDriverWait(driver, timeout).until(element_present)
    except TimeoutException:
        print("Timed out waiting for page to load dataset")
    driver.find_elements(By.CLASS_NAME,'x-box-inner.x-horizontal-box-overflow-body')[2].find_elements(By.CLASS_NAME,'x-tab.x-box-item.x-tab-default.x-noicon.x-tab-noicon.x-tab-default-noicon.x-top.x-tab-top.x-tab-default-top')[1].click()
    time.sleep(2)
    data = driver.find_elements(By.CLASS_NAME,'x-toolbar-text.x-box-item.x-toolbar-item.x-toolbar-text-default')[2].text
    if '0' in data :
        continue
    else:
        summary = []
        title = driver.find_element(By.TAG_NAME,'thead').text.replace(':','').replace('/',',')
        print(title)
        table_summary = driver.find_element(By.CLASS_NAME,'summary')
        rows = table_summary.find_elements(By.TAG_NAME,'tr')
        for row in rows:
            summary.append(row.text)
        source = summary[0].replace('\n',' ') + ', ' + summary[1].replace('\n',' ')
        description = summary[2].replace('\n',' ') + ', ' + summary[3].replace('\n',' ') + ', ' + summary[5].replace('\n',' ') + ', ' + summary[6].replace('\n',' ')
        created = summary[4].split(': ')[1].split(' to')[0]
        last_update = summary[4].split(' to')[1]
        # print(source,description,created,last_update)
        driver.find_element(By.ID,'button-1039').click()
        def latest_download_file():
            path = base_path
            os.chdir(path)
            files = sorted(os.listdir(os.getcwd()), key=os.path.getmtime)
            newest = files[-1]

            return newest

        fileends = "crdownload"
        while "crdownload" == fileends:
            time.sleep(10) 
            newest_file = latest_download_file()
            if "crdownload" in newest_file:
                fileends = "crdownload"
                # time.sleep(5)
            else:
                fileends = "None"
        time.sleep(1)
        latest_download_file() 
        # file = max([base_path + "\\" + f for f in os.listdir(base_path)],key=os.path.getctime)
        time.sleep(1)
        os.rename(f'{base_path}\\Download.csv',f'{base_path}\\{title}.csv')
        time.sleep(1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\10235555\Documents\DataportalCrawlers\UN_Data\UNOPS.ipynb Cell 13 in 2
#       <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/UNOPS.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> from selenium.common.exceptions import TimeoutException
# ----> <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/UNOPS.ipynb#X15sZmlsZQ%3D%3D?line=1'>2</a> for i in projects_id:
#       <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/UNOPS.ipynb#X15sZmlsZQ%3D%3D?line=2'>3</a>     url = f'https://data.unops.org/index.htm#SegmentCode=ORG&FocusCode=DATA_PROJECTS&EntityCode=PROJECT_ID&EntityValue={i}##SectionCode=OVERVIEW'
#       <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/UNOPS.ipynb#X15sZmlsZQ%3D%3D?line=3'>4</a>     driver.get(url)
#
# NameError: name 'projects_id' is not defined

# %%
import datetime
date = '06-Mar-2023'
update = datetime.datetime.strptime(update, "%d-%b-%Y").strftime('%Y-%m-%d')
update
# Out:
# '2023-03-06'

# %%
title = 'Acquisition de véhicules de moyen châssis (04) à 6 roues pour les dépôts régionaux et central et d un camion frigorifique dans le cadre du Projet de renforcement de l état deépa préparation du système et de riposte d urgence au COVID 19 (PREPSRU COVID-19)'
import textwrap
title_file = textwrap.shorten(title, width=150).replace('[','').replace(']','')
title_file
# Out:
# 'Acquisition de véhicules de moyen châssis (04) à 6 roues pour les dépôts régionaux et central et d un camion frigorifique dans le cadre du ...'

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import ElementNotInteractableException, NoSuchElementException
from selenium.common.exceptions import ElementClickInterceptedException
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from webdriver_manager.firefox import GeckoDriverManager
from selenium.webdriver.firefox.options import Options
from bs4 import BeautifulSoup
import shutil
import time
import os
import pandas as pd
from pyshadow.main import Shadow
from py7zr import unpack_7zarchive
from RequestInferSchemaToJsonAPI.main import TriggerInferShemaToJsonAPI
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\UNOPS'

chrome_options = webdriver.ChromeOptions()
base_path = "C:\\Users\\10235555\\Documents\\Dataportal Data\\UNOPS" # local, gets current working directory
prefs = {'download.default_directory' : base_path}#, "profile.content_settings.exceptions.automatic_downloads.*.setting" : 1}
chrome_options.add_experimental_option('prefs', prefs)
chrome_options.add_argument('--user-agent="Mozilla/5.0 (Windows Phone 10.0; Android 4.2.1; Microsoft; Lumia 640 XL LTE) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.135 Mobile Safari/537.36 Edge/12.10166"')
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)
driver.maximize_window()

driver.get('https://data.unops.org/index.htm#SegmentCode=ORG&FocusCode=DATA_PROJECTS&EntityCode=ORG_CODE&EntityValue=UNOPS##SectionCode=OVERVIEW')
time.sleep(2)
driver.refresh()
time.sleep(3)

projects_id = []
from selenium.common.exceptions import TimeoutException
table = driver.find_element(By.TAG_NAME,'tbody')
dataset = table.find_elements(By.CLASS_NAME,'x-grid-cell.x-grid-cell-gridcolumn-1078')
for j in range(77):
    for x in dataset:
        data_dataset = x.find_element(By.TAG_NAME,'div').find_element(By.TAG_NAME,'a').get_attribute('onclick')
        data_dataset = data_dataset.split(", '")[-1].split("')")[0]
        if data_dataset in projects_id:
            pass
        else:
            projects_id.append(data_dataset)
        
    next_table = driver.find_element(By.ID,'button-1096')
    next_table.click()
    time.sleep(6)
    timeout = 15
    try:
        element_present = EC.presence_of_element_located((By.XPATH,'/html/body/table/tbody/tr/td/div/div/table/tbody/tr[6]/td/div/div[1]/div/table/tbody/tr[2]/td/div/div/div[1]/div[2]/div/div[1]/table/tbody/tr/td/div/div/table/tbody/tr[2]/td/div/div[2]/div/div/table/tbody/tr/td/div/div[2]/div/table/tbody/tr[2]/td[2]'))
        WebDriverWait(driver, timeout).until(element_present)
    except TimeoutException:
        print("Timed out waiting for page to load next table")
    table = driver.find_element(By.TAG_NAME,'tbody')
    dataset = table.find_elements(By.CLASS_NAME,'x-grid-cell.x-grid-cell-gridcolumn-1078')


from selenium.common.exceptions import TimeoutException
for i in projects_id:
    url = f'https://data.unops.org/index.htm#SegmentCode=ORG&FocusCode=DATA_PROJECTS&EntityCode=PROJECT_ID&EntityValue={i}##SectionCode=OVERVIEW'
    driver.get(url)
    time.sleep(2)
    driver.refresh()
    time.sleep(4)
    timeout = 15
    try:
        element_present = EC.presence_of_element_located((By.CLASS_NAME,'x-box-inner.x-horizontal-box-overflow-body'))
        WebDriverWait(driver, timeout).until(element_present)
    except TimeoutException:
        print("Timed out waiting for page to load dataset")
    driver.find_elements(By.CLASS_NAME,'x-box-inner.x-horizontal-box-overflow-body')[2].find_elements(By.CLASS_NAME,'x-tab.x-box-item.x-tab-default.x-noicon.x-tab-noicon.x-tab-default-noicon.x-top.x-tab-top.x-tab-default-top')[1].click()
    time.sleep(2)
    data = driver.find_elements(By.CLASS_NAME,'x-toolbar-text.x-box-item.x-toolbar-item.x-toolbar-text-default')[2].text
    if '0' in data :
        continue
    else:
        summary = []
        title = driver.find_element(By.TAG_NAME,'thead').text.replace(':','').replace('/',',')
        print(title)
        table_summary = driver.find_element(By.CLASS_NAME,'summary')
        rows = table_summary.find_elements(By.TAG_NAME,'tr')
        for row in rows:
            summary.append(row.text)
        source = summary[0].replace('\n',' ') + ', ' + summary[1].replace('\n',' ')
        description = summary[2].replace('\n',' ') + ', ' + summary[3].replace('\n',' ') + ', ' + summary[5].replace('\n',' ') + ', ' + summary[6].replace('\n',' ')
        created = summary[4].split(': ')[1].split(' to')[0]
        last_update = summary[4].split(' to')[1]
        # print(source,description,created,last_update)
        driver.find_element(By.ID,'button-1039').click()
        def latest_download_file():
            path = base_path
            os.chdir(path)
            files = sorted(os.listdir(os.getcwd()), key=os.path.getmtime)
            newest = files[-1]

            return newest

        fileends = "crdownload"
        while "crdownload" == fileends:
            time.sleep(10) 
            newest_file = latest_download_file()
            if "crdownload" in newest_file:
                fileends = "crdownload"
                # time.sleep(5)
            else:
                fileends = "None"
        time.sleep(1)
        latest_download_file() 
        # file = max([base_path + "\\" + f for f in os.listdir(base_path)],key=os.path.getctime)
        time.sleep(1)
        os.rename(f'{base_path}\\Download.csv',f'{base_path}\\{title}.csv')
        time.sleep(1)
        
        # driver.back()
        # time.sleep(2)
        # driver.refresh()
        # time.sleep(3)
        # try:
        #     element_present = EC.presence_of_element_located((By.XPATH,'/html/body/table/tbody/tr/td/div/div/table/tbody/tr[6]/td/div/div[1]/div/table/tbody/tr[2]/td/div/div/div[1]/div[2]/div/div[1]/table/tbody/tr/td/div/div/table/tbody/tr[2]/td/div/div[2]/div/div/table/tbody/tr/td/div/div[2]/div/table/tbody/tr[2]/td[2]'))
        #     WebDriverWait(driver, timeout).until(element_present)
        # except TimeoutException:
        #     print("Timed out waiting for page to load next table")
        # table = driver.find_element(By.ID,'ext-gen1369').find_element(By.TAG_NAME,'tbody')
        # dataset = table.find_elements(By.CLASS_NAME,'x-grid-cell.x-grid-cell-gridcolumn-1078')
# Out:
# Supporting UKs Zimbabwe’s proposed approach to Security, Justice and the Rule of Law
# Implementation of the Maputo Accord for Peace and Reconciliation
# Nexus Response Mechanism
# Plan de mobilité, d’entretien et de réparation de routes rurales dans les Départements du Sud-Est, des Nippes et du Sud (PARR)
# Canada
# OQ EC support 2020-2021
# VAT for Construction of KSFH by Government of Sri Lanka
# Non-lethal support for the Somalia National Army
# Support to Explosive Hazards Assessment in Syria (Unearmarked VTF)
# Construction of Gaalkacyo-Garowe Road
# Appui au projet de développement de Ourghla en Algérie
# Apoyo a las acciones sociales y preparación a emergencias de instituciones del Estado de Paraguay
# UNGSC FA 05 - Technical Support for IOT Implementation and Technology Centres Technical Support Services
# Support to Community Violence Reduction Activities in Bangui - Phase 6
# Humanitarian Mine Action in Syria
# Phase II Yemen Integrated Urban Services Emergency Project (YIUSEP)
# Support to Afghanistan Mine Action UNMAS Programme (FCDO 2021-22)
# Procurement support to UNODC Egypt
# Engagement
# 22790 Mine Action in Support of UNMISS AB 21-22
# 22791 Mine Action in Support of MONUSCO 21-22 (Core)
# 22791 Mine Action in Support of MONUSCO 21-22 (SALW,Programmatic)
# 22792 Mine Action in Support of UNISFA 2021-22
# Support to Maritime COVID Response and Law Enforcement in South-East Asia
# OCT SPs
# STBP USAID amd 20
# Project d’Urgence de Rétablissement des Infrastructures et de la Connectivité (PURIC)
# Acquisition de véhicules au profit du projet REDE en Guinée-Bissau
# 23243 Humanitarian Mine Action for Syria (Unearmarked 2022)
# Phase II Yemen Emergency Electricity Access Project (RY-EEAP-II)
# WB- 3R FOR CONFLICT-AFFECTED COMMUNITIES (Tigray)
# UN Global Pulse Finland 2023
# Alliance of Civilizations
# Acquisition de materiel informatique et réalisation d'impressions pour le Ministère de la Santé Publique (CAGF)
# Uzbekistan COVID-19 Emergency Project
# Acquisition de motos au profit du FSRP
# Acquisition de véhicules au profit du FSRP
# Acquisition d'incinérateurs et d'équipements de chaîne de froid (Projet COVID-19 Niger)
# Construction of PSA sites
# Germany’s Support to Humanitarian Mine Action in Afghanistan for Stabilization, Resilience-Building, and Reconciliation
# AHF- 2023 Contribution
# Acquisition de véhicules
# Support to the UN-led humanitarian mine action coordination in Afghanistan
# Acquisition de matériel avec le reliquat du projet KOICA 21209-001 Procurement of Agricultural Equipment for the CIPA (Saint Louis) and PDIDCVR (Podor) projects
# FCDO 2022-23 Core funding for OQ
# IT Equipment of the PHASAO Project
# Additional Financing Yemen Human Capital Protection Project
# Procurement of Vehicles for MoH
# Acquisition d'équipements informatiques au profit du Projet d'Appui à la Promotion des Filières Agricoles (PAPFA) - Burkina Faso
# Vehicles Procurement
# 23637 Support to Community Violence Reduction Activities in Bangui - Phase 7
# Support to Community Violence Reduction (CVR) Programme in multiple field locations in CAR throughout FY 2022-2023
# Establishment of multiple PSA Oxygen Plants for the Ministry of Health in Zambia
# Emergency Locust Response Project
# 23205 Humanitarian Mine Action in Support of At-risk Populations, including Returnees, Refugees, Internally Displaced Persons (IDPs) and Host Communities in Afghanistan
# Procurement of Medical Waste Incinerators
# RFQ_021_22_STI-OI Medicines
# Acquisition d'équipements informatiques et de matériels de laboratoire au profit du Projet pour la résilience et la compétitivité de l’agriculture (PReCA)
# Licitación servicios comerciales
# Explosive hazard management capacity development in retaken areas of Iraq, VTF - Canada 2022
# IDA CRL - Cash for Work Project
# STBP UNF 2022-2023
# SGP-OP6 ARAB STATES (Francophone)
# SGP-OP6 ASIA
# SGP-OP6 PACIFIC
# SGP-OP6 LATIN AMERICA
# SGP-OP6 CARIBBEAN
# SGP-OP6 EUROPE & CIS
# Sustain & Equitable Access to
# Support to Election Supply Chain Logistics for upcoming presidential, parlimentary and local government elections
# Estudios, diseños y constricción del Puente Binacional sobre el Río Sixaola Costa Rica
# Estudios, diseños y constricción del Puente Binacional sobre el Río Sixaola Panamá
# Modernisation and Improvement of Policing Project
# STBP IH Diagnostics
# Climate & Clean Air Coalition
# Projet de rénovation de centres santé au profit du PNLSH en Guinée, financé par le Fonds Mondial
# MIP - BB
# African Climate Mobility Initiative (ACMI)
# Caribbean Climate Mobility Initiative (CCMI)
# LIRA II
# Project 23119-001 Emergency Procurement for the DGDA
# Construction of Faculty of Mathematics and Natural Sciences
# Crossline demining in South Kordofan, Sudan
# Aprimoramento da Infraestrutura Hospitalar da Secretaria de Estado da Saúde de Rondônia
# The Kenyan Assistive Technology Centre of Excellence Design and Construction - Phase 2
# Grants Management
# Yemen Human Capital Protection Project
# Mozambique Northern Crisis Recovery Project
# MSP - OP7 Bolivia
# STBP Global Fund SI SSL SSC
# 22971 Improved access to water and sanitation services in KP and Sindh
# ATscale-Global Partnership for Assistive Technology - Pooled Fund
# Procurement of144 Motorcycles
# Protection of civilians in Syria through Explosive Ordnance Assessment Support in Rural Damascus (OCHA 2021)
# KOICA Sudan - procurement of medical supplies
# Provision of victim assistance services in Farah, Kunar and Uruzgan provinces
# Procurement of Mobile Vans
# Support to Community Violence Reduction (CVR) Program in 7 Field locations in CAR throughout FY 2021-2022
# 22968 KOICA Potable Water Supply Project in Rural Areas - Phase 2
# RBM Gates Data Initiative
# Mine Action support to Security Institutions in Burkina Faso in addressing the impact of improvised explosive devices (IEDs) and other explosive ordnance (Canada 2022)
# Mitigation of the Threat Posed by Explosive Hazards in Gaza (VTF)
# Ministry of Defense (Denmark) Contribution Afghanistan 2021
# 22710 Asistencia Técnica al Ministerio de la Salud en supervisión de adqusiciones para atención al COVID - 19
# Digitalización, preservación y puesta en valor del acervo documental Nacional de Instituciones del Estado Paraguayo
# Mejora de la calidad de vida de poblaciones rurales a través de infraestructura vial (Empedrados) y la instalación de sistemas de agua potable
# WACA ResIP
# Asistencia a ELECTROPERÚ en la contratación de intervenciones prioritarias en las Centrales Hidroeléctricas de Restitución y Santiago Antúnez de Mayolo
# Renovation of the Sumerian Gallery at the Iraq Museum in Baghdad
# Provision of Financial and Management Services for CVF & V20
# GOJUST 2
# DPKO SSR
# Explosive Threat Mitigation Enabling Safe and Dignified Returns in Retaken Areas, Iraq (New Zealand 2020-2022)
# Riposte au COVID-19 en Tunisie. Aménagement des structures sanitaires désignées pour la prise en charge des cas COVID +
# Asistencia al IHSS en el suministro de medicamentos y material médico y en su fortalecimiento institucional para la optimización de la cadena de abastecimiento de medicamentos y material médico quirúrgico.
# Technical Assistance for Somalia Crisis Recovery Project (SCRP)
# Renforcement de capacité des structures sanitaires pour la préparation et riposte au COVID- 19 au Tchad
# MoF- Advanced JAVA EE traning
# OICT FA-04 - Technology Solutions Services for the Field
# RBM USAID Pooled Fund
# MSP OP7 - Ecuador
# Projet d’Appui pour l’Agriculture Familiale, Résilience et Marché en Haute et Moyenne Guinée - (AgriFARM)
# Projet d'amélioration de l'accès aux zones rurales des régions de Oio, Quinara et Tombali
# ZEAT BEAD Feeder Road Program
# Elaboração de projetos básicos e executivos para a construção de hospitais universitários federais
# Estudios previos, diseño y construcción de los puentes sobre el río Virilla en Rutas Nacionales 32 y 147 y río Pirro en la Ruta Nacional 3
# STBP Flexible Funding
# Support to UNOG-ICTS
# Provision of equipment and ser
# HR workpackage- Short-term UK
# The Global Fund LFA Services
# Service Support for Digital Information Branch
# Reconstruction of Bridges & Canals in Kalam SWAT Pakistan
# International Aid and Transpar
# HR TransactionalSupport to OQR
# AR, AFCO, Cost Recovery UNOCA Office Space and Common Services Project
# AR, AFCO, Herat Multi Agency Compound (HMAC) Project
# AR, AFCO, Transportation Project
# EIF - West Africa Activities -2
# EIF - Central Africa Activities
# SGP-OP5 AFRICA (Anglophone)
# SGP-OP5 ARAB STATES (Anglophone)
# SGP-OP5 ARAB STATES (Francophone)
# SGP-OP5 ASIA
# SGP-OP5 LATIN AMERICA
# SGP-OP5 CARIBBEAN
# SGP-OP5 EUROPE & CIS
# EIF - Executive Secretariat
# EIF - West Africa Activities - 1
# EIF - East Africa Activities
# EIF - Southern Africa Activities
# EIF - Asia Activities
# EIF - The Pacific Activities
# EIF - Inter-Regional Activities
# UN Water - Technical Advisory Unit (TAU)
# UN Water Inter-Agency Trust Fund (IATF)
# EIF - Trust Fund Manager
# Livelihood and Food Security Trust Fund (LIFT)
# UN Global Marketplace
# Memorandum de acuerdo entre el Gobierno Nacional del Perú y el PNUD acerca de servicios de gestión y otros servicios de apoyo que han de ser proporcionados por la UNOPS con respecto al proyecto "Apoyo a la Gestión del IPD" financiados con recursos propio
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\10235555\Documents\DataportalCrawlers\UN_Data\UNOPS.ipynb Cell 14 in 1
#     <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/UNOPS.ipynb#X16sZmlsZQ%3D%3D?line=111'>112</a> # file = max([base_path + "\\" + f for f in os.listdir(base_path)],key=os.path.getctime)
#     <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/UNOPS.ipynb#X16sZmlsZQ%3D%3D?line=112'>113</a> time.sleep(1)
# --> <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/UNOPS.ipynb#X16sZmlsZQ%3D%3D?line=113'>114</a> os.rename(f'{base_path}\\Download.csv',f'{base_path}\\{title}.csv')
#     <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/UNOPS.ipynb#X16sZmlsZQ%3D%3D?line=114'>115</a> time.sleep(1)
#     <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/UNOPS.ipynb#X16sZmlsZQ%3D%3D?line=116'>117</a> # driver.back()
#     <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/UNOPS.ipynb#X16sZmlsZQ%3D%3D?line=117'>118</a> # time.sleep(2)
#     <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/UNOPS.ipynb#X16sZmlsZQ%3D%3D?line=118'>119</a> # driver.refresh()
#    (...)
#     <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/UNOPS.ipynb#X16sZmlsZQ%3D%3D?line=125'>126</a> # table = driver.find_element(By.ID,'ext-gen1369').find_element(By.TAG_NAME,'tbody')
#     <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/UNOPS.ipynb#X16sZmlsZQ%3D%3D?line=126'>127</a> # dataset = table.find_elements(By.CLASS_NAME,'x-grid-cell.x-grid-cell-gridcolumn-1078')
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'C:\\Users\\10235555\\Documents\\Dataportal Data\\UNOPS\\Download.csv' -> 'C:\\Users\\10235555\\Documents\\Dataportal Data\\UNOPS\\Memorandum de acuerdo entre el Gobierno Nacional del Perú y el PNUD acerca de servicios de gestión y otros servicios de apoyo que han de ser proporcionados por la UNOPS con respecto al proyecto "Apoyo a la Gestión del IPD" financiados con recursos propio.csv'

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import ElementNotInteractableException, NoSuchElementException
from selenium.common.exceptions import ElementClickInterceptedException
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from webdriver_manager.firefox import GeckoDriverManager
from selenium.webdriver.firefox.options import Options
from bs4 import BeautifulSoup
import shutil
import time
import os
import pandas as pd
from pyshadow.main import Shadow
from py7zr import unpack_7zarchive
from RequestInferSchemaToJsonAPI.main import TriggerInferShemaToJsonAPI
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\UNOPS'

chrome_options = webdriver.ChromeOptions()
base_path = "C:\\Users\\10235555\\Documents\\Dataportal Data\\UNOPS" # local, gets current working directory
prefs = {'download.default_directory' : base_path}#, "profile.content_settings.exceptions.automatic_downloads.*.setting" : 1}
chrome_options.add_experimental_option('prefs', prefs)
chrome_options.add_argument('--user-agent="Mozilla/5.0 (Windows Phone 10.0; Android 4.2.1; Microsoft; Lumia 640 XL LTE) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.135 Mobile Safari/537.36 Edge/12.10166"')
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)
driver.maximize_window()

for i in range(77):
    for x in dataset:
        data_dataset = x.find_element(By.TAG_NAME,'div').find_element(By.TAG_NAME,'a').get_attribute('onclick')
        data_dataset = data_dataset.split(", '")[-1].split("')")[0]
        if data_dataset in projects_id:
            pass
        else:
            print(data_dataset)
            projects_id.append(data_dataset)
    next_table = driver.find_element(By.ID,'button-1096')
    next_table.click()
    time.sleep(7)
    timeout = 15
    try:
        element_present = EC.presence_of_element_located((By.XPATH,'/html/body/table/tbody/tr/td/div/div/table/tbody/tr[6]/td/div/div[1]/div/table/tbody/tr[2]/td/div/div/div[1]/div[2]/div/div[1]/table/tbody/tr/td/div/div/table/tbody/tr[2]/td/div/div[2]/div/div/table/tbody/tr/td/div/div[2]/div/table/tbody/tr[2]/td[2]'))
        WebDriverWait(driver, timeout).until(element_present)
    except TimeoutException:
        print("Timed out waiting for page to load next table")
    table = driver.find_element(By.TAG_NAME,'tbody')
    dataset = table.find_elements(By.CLASS_NAME,'x-grid-cell.x-grid-cell-gridcolumn-1078')

for i in projects_id:
    url = f'https://data.unops.org/index.htm#SegmentCode=ORG&FocusCode=DATA_PROJECTS&EntityCode=PROJECT_ID&EntityValue={i}##SectionCode=OVERVIEW'
    driver.get(url)
    time.sleep(2)
    driver.refresh()
    time.sleep(2)
    driver.find_elements(By.CLASS_NAME,'x-box-inner.x-horizontal-box-overflow-body')[2].find_elements(By.CLASS_NAME,'x-tab.x-box-item.x-tab-default.x-noicon.x-tab-noicon.x-tab-default-noicon.x-top.x-tab-top.x-tab-default-top')[1].click()
    time.sleep(2)
    data = driver.find_elements(By.CLASS_NAME,'x-toolbar-text.x-box-item.x-toolbar-item.x-toolbar-text-default')[2].text
    if '0' in data :
        print(data)
        pass
    else:
        summary = []
        title = driver.find_element(By.TAG_NAME,'thead').text.replace(':','').replace('/',',')
        print(title)
        table_summary = driver.find_element(By.CLASS_NAME,'summary')
        rows = table_summary.find_elements(By.TAG_NAME,'tr')
        for row in rows:
            summary.append(row.text)
        source = summary[0].replace('\n',' ') + ', ' + summary[1].replace('\n',' ')
        description = summary[2].replace('\n',' ') + ', ' + summary[3].replace('\n',' ') + ', ' + summary[5].replace('\n',' ') + ', ' + summary[6].replace('\n',' ')
        created = summary[4].split(': ')[1].split(' to')[0]
        last_update = summary[4].split(' to')[1]
        print(source,description,created,last_update)
        driver.find_element(By.ID,'button-1039').click()
        def latest_download_file():
            path = base_path
            os.chdir(path)
            files = sorted(os.listdir(os.getcwd()), key=os.path.getmtime)
            newest = files[-1]

            return newest

        fileends = "crdownload"
        while "crdownload" == fileends:
            time.sleep(6) 
            newest_file = latest_download_file()
            if "crdownload" in newest_file:
                fileends = "crdownload"
                # time.sleep(5)
            else:
                fileends = "None"
        time.sleep(1)
        latest_download_file() 
        file = max([base_path + "\\" + f for f in os.listdir(base_path)],key=os.path.getctime)
        time.sleep(1)
        os.rename(file,f'{base_path}\\{title}.csv')
        time.sleep(1)
# Out:
# of 0
# of 0
# of 0
# of 0
# of 0
# of 0
# of 0
# of 0
# PRO - Local Governance for People and Nature
# Partner(s): SDC, Funding Source(s): SDC Countries of Delivery: Serbia, Sector(s): 998 Unallocated / Unspecified, Total Funded Amount: US$ 9,473,684, Total Delivery: US$ 51,777 01-Jan-2023  31-Dec-2026
# of 0
# of 0
# of 0
# of 0
# of 0
# of 0
# of 0
# of 0
# of 0
# of 0
# of 0
# of 0
# of 0
# of 0
# of 0
# of 0
# of 0
# of 0
# UNITAMS Support operationalization in 5 Darfur states
# Partner(s): UN DPO, Funding Source(s): UN DPO Countries of Delivery: Sudan, Sector(s): 998 Unallocated / Unspecified, Total Funded Amount: US$ 884,201, Total Delivery: US$ 67,036 01-Jan-2023  01-Jan-2024
# of 0
# of 0
# Supporting UKs Zimbabwe’s proposed approach to Security, Justice and the Rule of Law
# Partner(s): DFID, Funding Source(s): DFID Countries of Delivery: Zimbabwe, Sector(s): 151 Government and civil society, general, Total Funded Amount: US$ 500,000, Total Delivery: US$ 179,065 01-Jan-2020  31-Mar-2021
# Implementation of the Maputo Accord for Peace and Reconciliation
# Partner(s): Mozambique UN DPPA, Funding Source(s): DFID EC - Other FCDO Germany Global Affairs Canada Ireland Italy MoFA Finland MoFA Netherlands MoFA Norway SDC SIDA Switzerland USDOS Countries of Delivery: Mozambique, Sector(s): 152 Conflict prevention and resolution, peace and security, Total Funded Amount: US$
Sector(s): 152 Conflict prevention and resolution, peace and security, Total Funded Amount: US$ 3,701,211, Total Delivery: US$ 3,572,892 01-Jul-2021  31-Aug-2022
# Humanitarian Mine Action in Syria
# Partner(s): UNMAS, Funding Source(s): UN VTF Countries of Delivery: Syrian Arab Republic, Sector(s): 152 Conflict prevention and resolution, peace and security, Total Funded Amount: US$ 1,113,795, Total Delivery: US$ 1,036,193 01-Jul-2021  15-Dec-2022
# Phase II Yemen Integrated Urban Services Emergency Project (YIUSEP)
# Partner(s): WB, Funding Source(s): WB Countries of Delivery: Yemen, Sector(s): 160 Other social infrastructure and services, Total Funded Amount: US$ 50,000,000, Total Delivery: US$ 17,290,641 01-Jul-2021  30-Jun-2025
# Support to Afghanistan Mine Action UNMAS Programme (FCDO 2021-22)
# Partner(s): UNMAS, Funding Source(s): UN VTF Countries of Delivery: Afghanistan, Sector(s): 152 Conflict prevention and resolution, peace and security, Total Funded Amount: US$ 12,752,647, Total Delivery: US$ 12,743,244 01-Jul-2021  31-Aug-2022
# Procurement support to UNODC Egypt
# Partner(s): Tunisia, Funding Source(s): UNODC Countries of Delivery: Tunisia, Sector(s): 151 Government and civil society, general, Total Funded Amount: US$ 512,834, Total Delivery: US$ 436,931 01-Jul-2021  31-Dec-2022
# of 0
# Engagement
# Partner(s): UNMAS, Funding Source(s): UN DPO Countries of Delivery: Central African Republic, Sector(s): 152 Conflict prevention and resolution, peace and security, Total Funded Amount: US$ 5,893,238, Total Delivery: US$ 5,645,174 01-Jul-2021  30-Jun-2022
# 22790 Mine Action in Support of UNMISS AB 21-22
# Partner(s): UNMAS, Funding Source(s): UN DPO Countries of Delivery: South Sudan, Sector(s): 152 Conflict prevention and resolution, peace and security, Total Funded Amount: US$ 29,492,712, Total Delivery: US$ 29,415,778 01-Jul-2021  30-Jun-2022
# 22791 Mine Action in Support of MONUSCO 21-22 (Core)
# Partner(s): UNMAS, Funding Source(s): UN DPO Countries of Delivery: Democratic Republic of the Congo, Sector(s): 152 Conflict prevention and resolution, peace and security, Total Funded Amount: US$ 3,191,625, Total Delivery: US$ 3,171,039 01-Jul-2021  30-Jun-2022
# 22791 Mine Action in Support of MONUSCO 21-22 (SALW,Programmatic)
# Partner(s): UNMAS, Funding Source(s): UN DPO Countries of Delivery: Democratic Republic of the Congo, Sector(s): 152 Conflict prevention and resolution, peace and security, Total Funded Amount: US$ 800,000, Total Delivery: US$ 783,922 01-Jul-2021  30-Jun-2022
# 22792 Mine Action in Support of UNISFA 2021-22
# Partner(s): UNMAS, Funding Source(s): UN DPO Countries of Delivery: Sudan, Sector(s): 152 Conflict prevention and resolution, peace and security, Total Funded Amount: US$ 9,615,928, Total Delivery: US$ 9,603,911 01-Jul-2021  30-Jun-2022
# of 0
# UNGSC FA 05 - Technical Support for IOT Implementation and Technology Centres Technical Support Services
# Partner(s): UN DOS, Funding Source(s): UN DOS Countries of Delivery: United States of America, Sector(s): 220 Communication, Total Funded Amount: US$ 914,788, Total Delivery: US$ 856,090 01-Jul-2021  30-Jun-2022
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# c:\Users\10235555\Documents\DataportalCrawlers\UN_Data\UNOPS.ipynb Cell 14 in 7
#      <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/UNOPS.ipynb#X32sZmlsZQ%3D%3D?line=74'>75</a> file = max([base_path + "\\" + f for f in os.listdir(base_path)],key=os.path.getctime)
#      <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/UNOPS.ipynb#X32sZmlsZQ%3D%3D?line=75'>76</a> time.sleep(1)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/UNOPS.ipynb#X32sZmlsZQ%3D%3D?line=76'>77</a> os.rename(file,f'{base_path}\\{title}.csv')
#      <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/UNOPS.ipynb#X32sZmlsZQ%3D%3D?line=77'>78</a> time.sleep(1)
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'C:\\Users\\10235555\\Documents\\Dataportal Data\\UNOPS\\Download (5).csv' -> 'C:\\Users\\10235555\\Documents\\Dataportal Data\\UNOPS\\UNGSC FA 05 - Technical Support for IOT Implementation and Technology Centres Technical Support Services.csv'
