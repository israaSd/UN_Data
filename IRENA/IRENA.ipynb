# %%
from bs4 import BeautifulSoup
import requests
import os
import wget
import time
base_path = "C:\\Users\\10235555\\Documents\\Dataportal Data\\IRENA"
import urllib.request
import logging
import pandas as pd
from selenium.webdriver.support.ui import Select
import datetime
from re import search
# logging.basicConfig(handlers=[logging.FileHandler("C:\\Users\\10235555\\Documents\\Dataportal Data\\IPU_out.log"),
#                             logging.StreamHandler()], level=logging.INFO)
import zipfile
from zipfile import ZipFile
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import ElementNotInteractableException, NoSuchElementException
from selenium.common.exceptions import ElementClickInterceptedException
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from webdriver_manager.firefox import GeckoDriverManager
from selenium.webdriver.firefox.options import Options
from bs4 import BeautifulSoup
import shutil
import time
import os
from pyshadow.main import Shadow
from py7zr import unpack_7zarchive
from RequestInferSchemaToJsonAPI.main import TriggerInferShemaToJsonAPI

chrome_options = webdriver.ChromeOptions()
# base_path = "C:\\Users\\10235555\\Documents\\Dataportal Data\\FAOSTAT TEST" # local, gets current working directory
base_path = "C:\\Users\\10235555\\Documents\\Dataportal Data\\IRENA" # local, gets current working directory
prefs = {'download.default_directory' : base_path}#, "profile.content_settings.exceptions.automatic_downloads.*.setting" : 1}
chrome_options.add_experimental_option('prefs', prefs)
# chrome_options.add_argument('--user-agent="Mozilla/5.0 (Windows Phone 10.0; Android 4.2.1; Microsoft; Lumia 640 XL LTE) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.135 Mobile Safari/537.36 Edge/12.10166"')
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)
driver.maximize_window()
# Out:
# [WDM] - Downloading: 100%|██████████| 6.78M/6.78M [00:00<00:00, 14.7MB/s]

# %%
# driver.get('https://irena.sharepoint.com/:x:/s/statistics-public/EZ8Qm-KyyWVNsKNdvPn7ypgBCy1YiyL8gHGisBM-IXBKdA?rtime=d3nouAQf20g')

# %%
url = 'https://www.irena.org/Data'
driver.get(url)

# %%
from selenium.common.exceptions import TimeoutException
timeout = 15
try:
    element_present = EC.presence_of_element_located((By.CLASS_NAME,'m-SideMenu__link'))
    WebDriverWait(driver, timeout).until(element_present)
except TimeoutException:
    print("Timed out waiting for page to load element")
view_data_by_topic = driver.find_elements(By.CLASS_NAME,'m-SideMenu__link')
time.sleep(2)
view_data_by_topic[1].click()
list_data = driver.find_element(By.CLASS_NAME,'m-SideMenu__container')
benefits = list_data.find_element(By.TAG_NAME,'ul').find_element(By.TAG_NAME,'li').find_element(By.TAG_NAME,'button')
benefits.click()
Renewable_Energy_Employment_by_Country = list_data.find_element(By.TAG_NAME,'ul').find_element(By.TAG_NAME,'li').find_element(By.CLASS_NAME,'m-SideMenu__container').find_elements(By.TAG_NAME,'li')[1]
link_renewble = Renewable_Energy_Employment_by_Country.find_element(By.TAG_NAME,'a').get_attribute('href')
driver.get(link_renewble)

# %%
content = driver.find_element(By.CLASS_NAME,'m-Iframe')#tabZoneId53
div = content.find_element(By.TAG_NAME,'iframe')
html = div.find_element(By.XPATH,'/html')
html.click()

# body = html.find_element(By.CLASS_NAME,'tundra.tableau.public.ff-IFrameSizedToWindow')

# %%
driver.switch_to.frame(div)
# html = div.find_element(By.XPATH,'/html')
# html.click()
# center = driver.find_element(By.ID,'centeringContainer')

# %%
center = driver.find_element(By.ID,'centeringContainer')
div = center.find_element(By.ID,'view6762280515476473387_7506702030957726925')
# div0 = div.find_element(By.)
# canvas = div.find_element(By.CLASS_NAME,'tabCanvas.tab-widget')
# zone8.click()
# zone40 = div.find_element(By.ID,'tabZoneId40')
# excel_div = zone40.find_element(By.CLASS_NAME,'tab-zone-margin')
# excel_div = div.find_element(By.CLASS_NAME,'tab-zone.tab-widget.tabZone-viz')
# excel_div.click()

# %%
# div = center.find_element(By.CLASS_NAME,'tvimagesContainer')

# %%
canvas = div.find_elements(By.TAG_NAME,'canvas')

# %%
canvas[1].click()

# %%
# excel_div = div.find_element(By.CLASS_NAME,'tab-zone.tab-widget.tabZone-viz')
# excel_div.click()

# %%
driver.switch_to.window(driver.window_handles[1])

# %%
driver.current_url
# Out:
# 'https://irena.sharepoint.com/:x:/s/statistics-public/EZ8Qm-KyyWVNsKNdvPn7ypgBCy1YiyL8gHGisBM-IXBKdA?rtime=XaTWEqAf20g'

# %%
page_source = driver.page_source               
soup = BeautifulSoup(page_source, 'html.parser')
# excel = requests.get("https://irena.sharepoint.com/:x:/s/statistics-public/EZ8Qm-KyyWVNsKNdvPn7ypgBCy1YiyL8gHGisBM-IXBKdA?rtime=d3nouAQf20g")
# soup = BeautifulSoup(excel.content,'html.parser')
# output = open(f'{base_path}\\test.xlsx', 'wb')
# output.write(excel.content)
# output.close()
link = soup.find('script').text.split('"FileGetUrl":"')[1].split("\\")[0]
driver.get(link)

# %%
from bs4 import BeautifulSoup
import requests
import os
import wget
import time
base_path = "C:\\Users\\10235555\\Documents\\Dataportal Data\\IRENA Test"
import urllib.request
import logging
import pandas as pd
from selenium.webdriver.support.ui import Select
import datetime
from re import search
# logging.basicConfig(handlers=[logging.FileHandler("C:\\Users\\10235555\\Documents\\Dataportal Data\\IPU_out.log"),
#                             logging.StreamHandler()], level=logging.INFO)
import zipfile
from zipfile import ZipFile
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import ElementNotInteractableException, NoSuchElementException
from selenium.common.exceptions import ElementClickInterceptedException
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from webdriver_manager.firefox import GeckoDriverManager
from selenium.webdriver.firefox.options import Options
from bs4 import BeautifulSoup
import shutil
import time
import os
from pyshadow.main import Shadow
from py7zr import unpack_7zarchive
from RequestInferSchemaToJsonAPI.main import TriggerInferShemaToJsonAPI

chrome_options = webdriver.ChromeOptions()
# base_path = "C:\\Users\\10235555\\Documents\\Dataportal Data\\FAOSTAT TEST" # local, gets current working directory
base_path = "C:\\Users\\10235555\\Documents\\Dataportal Data\\IRENA Test" # local, gets current working directory
prefs = {'download.default_directory' : base_path}#, "profile.content_settings.exceptions.automatic_downloads.*.setting" : 1}
chrome_options.add_experimental_option('prefs', prefs)
# chrome_options.add_argument('--user-agent="Mozilla/5.0 (Windows Phone 10.0; Android 4.2.1; Microsoft; Lumia 640 XL LTE) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.135 Mobile Safari/537.36 Edge/12.10166"')
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)
driver.maximize_window()

# %%
url = 'https://www.irena.org/Data'
driver.get(url)
time.sleep(1)
from selenium.common.exceptions import TimeoutException
timeout = 15
try:
    element_present = EC.presence_of_element_located((By.CLASS_NAME,'m-SideMenu__link'))
    WebDriverWait(driver, timeout).until(element_present)
except TimeoutException:
    print("Timed out waiting for page to load element")
view_data_by_topic = driver.find_elements(By.CLASS_NAME,'m-SideMenu__link')
time.sleep(2)
view_data_by_topic[1].click()
time.sleep(1)
list_data = driver.find_element(By.CLASS_NAME,'m-SideMenu__container')
tags = list_data.find_element(By.TAG_NAME,'ul').find_elements(By.TAG_NAME,'li')
for i in range(len(tags)):
    if tags[i].text == 'Costs':
        view_data_by_topic[1].click()
        list_data = driver.find_element(By.CLASS_NAME,'m-SideMenu__container')
        tags = list_data.find_element(By.TAG_NAME,'ul').find_elements(By.TAG_NAME,'li')[i].find_element(By.TAG_NAME,'button')
        tags.click()
        time.sleep(2)
        dataset = list_data.find_element(By.TAG_NAME,'ul').find_elements(By.TAG_NAME,'li')[i].find_element(By.CLASS_NAME,'m-SideMenu__container').find_elements(By.TAG_NAME,'li')[0]
        link_dataset = dataset.find_element(By.TAG_NAME,'a').get_attribute('href')
        driver.get(link_dataset)
        time.sleep(2)
        content = driver.find_element(By.CLASS_NAME,'m-Iframe')
        div = content.find_element(By.TAG_NAME,'iframe')
        html = div.find_element(By.XPATH,'/html')
        html.click()
        time.sleep(1)
        driver.switch_to.frame(div)
        center = driver.find_element(By.ID,'centeringContainer')
        div = center.find_element(By.ID,'view11151608863636357857_7506702030957726925')
        canvas = div.find_elements(By.TAG_NAME,'canvas')
        canvas[1].click()
        time.sleep(2)
        driver.switch_to.window(driver.window_handles[1])
        time.sleep(1)
        page_source = driver.page_source               
        soup = BeautifulSoup(page_source, 'html.parser')
        filename = soup.find('script').text.split('"FileName":"')[1].split('","')[0]
        link = soup.find('script').text.split('"FileGetUrl":"')[1].split("\\")[0]
        driver.get(link)
        time.sleep(1)
        driver.close()
        time.sleep(3)
        xls = pd.ExcelFile(f'{base_path}\\{filename}')
        sheets = xls.sheet_names
        df = pd.read_excel(f'{base_path}\\{filename}','Table 5.2')
        title = df.columns[0]
        desc = df.iloc[19,0]
        df = df.iloc[4:19,:]
        df.columns = ['Country','Parabolic trough collectors (2020 USD/kWh)' , 'Solar tower (2020 USD/kWh)']
        df.to_csv(f'{base_path}\\{title}.csv',index=False)
        driver.switch_to.window(driver.window_handles[0])
        time.sleep(1)
        driver.back()
        time.sleep(3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\10235555\Documents\DataportalCrawlers\UN_Data\IRENA.ipynb Cell 16 in 1
#      <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/IRENA.ipynb#X31sZmlsZQ%3D%3D?line=15'>16</a> tags = list_data.find_element(By.TAG_NAME,'ul').find_elements(By.TAG_NAME,'li')
#      <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/IRENA.ipynb#X31sZmlsZQ%3D%3D?line=16'>17</a> for i in range(len(tags)):
# ---> <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/IRENA.ipynb#X31sZmlsZQ%3D%3D?line=17'>18</a>     if tags[i].text == 'Costs':
#      <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/IRENA.ipynb#X31sZmlsZQ%3D%3D?line=18'>19</a>         view_data_by_topic[1].click()
#      <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/IRENA.ipynb#X31sZmlsZQ%3D%3D?line=19'>20</a>         list_data = driver.find_element(By.CLASS_NAME,'m-SideMenu__container')
#
# TypeError: 'WebElement' object is not subscriptable

# %%
url = 'https://www.irena.org/Data'
driver.get(url)
time.sleep(1)
from selenium.common.exceptions import TimeoutException
timeout = 15
try:
    element_present = EC.presence_of_element_located((By.CLASS_NAME,'m-SideMenu__link'))
    WebDriverWait(driver, timeout).until(element_present)
except TimeoutException:
    print("Timed out waiting for page to load element")
view_data_by_topic = driver.find_elements(By.CLASS_NAME,'m-SideMenu__link')
time.sleep(2)
view_data_by_topic[1].click()
time.sleep(1)
list_data = driver.find_element(By.CLASS_NAME,'m-SideMenu__container')
tags = list_data.find_element(By.TAG_NAME,'ul').find_elements(By.TAG_NAME,'li')
for i in range(len(tags)):
    if i in [0]:
        view_data_by_topic[1].click()
        list_data = driver.find_element(By.CLASS_NAME,'m-SideMenu__container')
        tags = list_data.find_element(By.TAG_NAME,'ul').find_elements(By.TAG_NAME,'li')[i].find_element(By.TAG_NAME,'button')
        tags.click()
        time.sleep(2)
        dataset = list_data.find_element(By.TAG_NAME,'ul').find_elements(By.TAG_NAME,'li')[i].find_element(By.CLASS_NAME,'m-SideMenu__container').find_elements(By.TAG_NAME,'li')[1]
        link_dataset = dataset.find_element(By.TAG_NAME,'a').get_attribute('href')
        driver.get(link_dataset)
        time.sleep(2)
        content = driver.find_element(By.CLASS_NAME,'m-Iframe')
        div = content.find_element(By.TAG_NAME,'iframe')
        html = div.find_element(By.XPATH,'/html')
        html.click()
        time.sleep(1)
        driver.switch_to.frame(div)
        center = driver.find_element(By.ID,'centeringContainer')
        div = center.find_element(By.ID,'view6762280515476473387_7506702030957726925')
        canvas = div.find_elements(By.TAG_NAME,'canvas')
        canvas[1].click()
        time.sleep(2)
        driver.switch_to.window(driver.window_handles[1])
        time.sleep(1)
        page_source = driver.page_source               
        soup = BeautifulSoup(page_source, 'html.parser')
        link = soup.find('script').text.split('"FileGetUrl":"')[1].split("\\")[0]
        driver.get(link)
        time.sleep(1)
        driver.close()
        driver.switch_to.window(driver.window_handles[0])
        time.sleep(1)
        driver.back()
        time.sleep(3)
        try:
            element_present = EC.presence_of_element_located((By.CLASS_NAME,'m-SideMenu__link'))
            WebDriverWait(driver, timeout).until(element_present)
        except TimeoutException:
            print("Timed out waiting for page to load element")
        view_data_by_topic = driver.find_elements(By.CLASS_NAME,'m-SideMenu__link')
        view_data_by_topic[1].click()
        time.sleep(1)
        list_data = driver.find_element(By.CLASS_NAME,'m-SideMenu__container')
        tags = list_data.find_element(By.TAG_NAME,'ul').find_elements(By.TAG_NAME,'li')
    elif tags[i].text == 'Energy Transition':
        # for j in [1,2,3]:
        #     k = ['view16206229265905950579_7506702030957726925','view10592748734926140813_7506702030957726925','view5570767731693464673_7506702030957726925']
        # timeout = 15
        # try:
        #     element_present = EC.presence_of_element_located((By.CLASS_NAME,'m-SideMenu__link'))
        #     WebDriverWait(driver, timeout).until(element_present)
        # except TimeoutException:
        #     print("Timed out waiting for page to load element")
        # view_data_by_topic = driver.find_elements(By.CLASS_NAME,'m-SideMenu__link')
        # view_data_by_topic[1].click()
        # time.sleep(1)
        list_data = driver.find_element(By.CLASS_NAME,'m-SideMenu__container')
        tags = list_data.find_element(By.TAG_NAME,'ul').find_elements(By.TAG_NAME,'li')[i].find_element(By.TAG_NAME,'button')
        tags.click()
        time.sleep(2)
        dataset = list_data.find_element(By.TAG_NAME,'ul').find_elements(By.TAG_NAME,'li')[i].find_element(By.CLASS_NAME,'m-SideMenu__container').find_elements(By.TAG_NAME,'li')[1]
        link_dataset = dataset.find_element(By.TAG_NAME,'a').get_attribute('href')
        driver.get(link_dataset)
        time.sleep(2)
        content = driver.find_element(By.CLASS_NAME,'m-Iframe')
        div = content.find_element(By.TAG_NAME,'iframe')
        html = div.find_element(By.XPATH,'/html')
        html.click()
        time.sleep(1)
        driver.switch_to.frame(div)
        center = driver.find_element(By.ID,'centeringContainer')
        div = center.find_element(By.ID,'view16206229265905950579_7506702030957726925')
        canvas = div.find_elements(By.TAG_NAME,'canvas')
        canvas[1].click()
        time.sleep(2)
        driver.switch_to.window(driver.window_handles[1])
        time.sleep(1)
        page_source = driver.page_source               
        soup = BeautifulSoup(page_source, 'html.parser')
        link = soup.find('script').text.split('"FileGetUrl":"')[1].split("\\")[0]
        driver.get(link)
        time.sleep(1)
        driver.close()
        driver.switch_to.window(driver.window_handles[0])
        time.sleep(1)
        driver.back()
        time.sleep(3)
        try:
            element_present = EC.presence_of_element_located((By.CLASS_NAME,'m-SideMenu__link'))
            WebDriverWait(driver, timeout).until(element_present)
        except TimeoutException:
            print("Timed out waiting for page to load element")
        view_data_by_topic = driver.find_elements(By.CLASS_NAME,'m-SideMenu__link')
        view_data_by_topic[1].click()
        time.sleep(1)
        list_data = driver.find_element(By.CLASS_NAME,'m-SideMenu__container')
        tags = list_data.find_element(By.TAG_NAME,'ul').find_elements(By.TAG_NAME,'li')
    elif tags[i].text == 'Finance and Investment':
        list_data = driver.find_element(By.CLASS_NAME,'m-SideMenu__container')
        tags = list_data.find_element(By.TAG_NAME,'ul').find_elements(By.TAG_NAME,'li')[i].find_element(By.TAG_NAME,'button')
        tags.click()
        time.sleep(2)
        dataset = list_data.find_element(By.TAG_NAME,'ul').find_elements(By.TAG_NAME,'li')[i].find_element(By.CLASS_NAME,'m-SideMenu__container').find_elements(By.TAG_NAME,'li')[1]
        link_dataset = dataset.find_element(By.TAG_NAME,'a').get_attribute('href')
        driver.get(link_dataset)
        time.sleep(2)
        content = driver.find_element(By.CLASS_NAME,'m-Iframe')
        div = content.find_element(By.TAG_NAME,'iframe')
        html = div.find_element(By.XPATH,'/html')
        html.click()
        time.sleep(1)
        driver.switch_to.frame(div)
        center = driver.find_element(By.ID,'centeringContainer')
        div = center.find_element(By.ID,'view7734379744678548899_7506702030957726925')
        canvas = div.find_elements(By.TAG_NAME,'canvas')
        canvas[1].click()
        time.sleep(2)
        driver.switch_to.window(driver.window_handles[1])
        time.sleep(1)
        page_source = driver.page_source               
        soup = BeautifulSoup(page_source, 'html.parser')
        link = soup.find('script').text.split('"FileGetUrl":"')[1].split("\\")[0]
        driver.get(link)
        time.sleep(1)
        driver.close()
        driver.switch_to.window(driver.window_handles[0])
        time.sleep(1)
        driver.back()
        time.sleep(3)
        try:
            element_present = EC.presence_of_element_located((By.CLASS_NAME,'m-SideMenu__link'))
            WebDriverWait(driver, timeout).until(element_present)
        except TimeoutException:
            print("Timed out waiting for page to load element")
        view_data_by_topic = driver.find_elements(By.CLASS_NAME,'m-SideMenu__link')
        view_data_by_topic[1].click()
        time.sleep(1)
        list_data = driver.find_element(By.CLASS_NAME,'m-SideMenu__container')
        tags = list_data.find_element(By.TAG_NAME,'ul').find_elements(By.TAG_NAME,'li')
    elif tags[i].text == 'Innovation and Technology':
        list_data = driver.find_element(By.CLASS_NAME,'m-SideMenu__container')
        tags = list_data.find_element(By.TAG_NAME,'ul').find_elements(By.TAG_NAME,'li')[i].find_element(By.TAG_NAME,'button')
        tags.click()
        time.sleep(2)
        dataset = list_data.find_element(By.TAG_NAME,'ul').find_elements(By.TAG_NAME,'li')[i].find_element(By.CLASS_NAME,'m-SideMenu__container').find_elements(By.TAG_NAME,'li')[1]
        link_dataset = dataset.find_element(By.TAG_NAME,'a').get_attribute('href')
        driver.get(link_dataset)
        time.sleep(2)
        content = driver.find_element(By.CLASS_NAME,'m-Iframe')
        div = content.find_element(By.TAG_NAME,'iframe')
        html = div.find_element(By.XPATH,'/html')
        html.click()
        time.sleep(1)
        driver.switch_to.frame(div)
        center = driver.find_element(By.ID,'centeringContainer')
        div = center.find_element(By.ID,'view3912306690392202374_7506702030957726925')
        canvas = div.find_elements(By.TAG_NAME,'canvas')
        canvas[1].click()
        time.sleep(2)
        driver.switch_to.window(driver.window_handles[1])
        time.sleep(1)
        page_source = driver.page_source               
        soup = BeautifulSoup(page_source, 'html.parser')
        link = soup.find('script').text.split('"FileGetUrl":"')[1].split("\\")[0]
        driver.get(link)
        time.sleep(1)
        driver.close()
        driver.switch_to.window(driver.window_handles[0])
        time.sleep(1)
        driver.back()
        time.sleep(3)
        try:
            element_present = EC.presence_of_element_located((By.CLASS_NAME,'m-SideMenu__link'))
            WebDriverWait(driver, timeout).until(element_present)
        except TimeoutException:
            print("Timed out waiting for page to load element")
        view_data_by_topic = driver.find_elements(By.CLASS_NAME,'m-SideMenu__link')
        view_data_by_topic[1].click()
        time.sleep(1)
        list_data = driver.find_element(By.CLASS_NAME,'m-SideMenu__container')
        tags = list_data.find_element(By.TAG_NAME,'ul').find_elements(By.TAG_NAME,'li')
    elif tags[i].text == 'Renewable Energy Balances':
        list_data = driver.find_element(By.CLASS_NAME,'m-SideMenu__container')
        tags = list_data.find_element(By.TAG_NAME,'ul').find_elements(By.TAG_NAME,'li')[i].find_element(By.TAG_NAME,'button')
        tags.click()
        time.sleep(2)
        dataset = list_data.find_element(By.TAG_NAME,'ul').find_elements(By.TAG_NAME,'li')[i].find_element(By.CLASS_NAME,'m-SideMenu__container').find_elements(By.TAG_NAME,'li')[1]
        link_dataset = dataset.find_element(By.TAG_NAME,'a').get_attribute('href')
        driver.get(link_dataset)
        time.sleep(2)
        content = driver.find_element(By.CLASS_NAME,'m-Iframe')
        div = content.find_element(By.TAG_NAME,'iframe')
        html = div.find_element(By.XPATH,'/html')
        html.click()
        time.sleep(1)
        driver.switch_to.frame(div)
        center = driver.find_element(By.ID,'centeringContainer')
        div = center.find_element(By.ID,'view6882849831517330334_7506702030957726925')
        canvas = div.find_elements(By.TAG_NAME,'canvas')
        canvas[1].click()
        time.sleep(2)
        driver.switch_to.window(driver.window_handles[1])
        time.sleep(1)
        page_source = driver.page_source               
        soup = BeautifulSoup(page_source, 'html.parser')
        link = soup.find('script').text.split('"FileGetUrl":"')[1].split("\\")[0]
        driver.get(link)
        time.sleep(1)
        driver.close()
        driver.switch_to.window(driver.window_handles[0])
        time.sleep(1)
        driver.back()
        time.sleep(3)
        try:
            element_present = EC.presence_of_element_located((By.CLASS_NAME,'m-SideMenu__link'))
            WebDriverWait(driver, timeout).until(element_present)
        except TimeoutException:
            print("Timed out waiting for page to load element")
        view_data_by_topic = driver.find_elements(By.CLASS_NAME,'m-SideMenu__link')
        view_data_by_topic[1].click()
        time.sleep(1)
        list_data = driver.find_element(By.CLASS_NAME,'m-SideMenu__container')
        tags = list_data.find_element(By.TAG_NAME,'ul').find_elements(By.TAG_NAME,'li')

# %%
url = 'https://www.irena.org/Data'
driver.get(url)
time.sleep(1)
from selenium.common.exceptions import TimeoutException
timeout = 15
try:
    element_present = EC.presence_of_element_located((By.CLASS_NAME,'m-SideMenu__link'))
    WebDriverWait(driver, timeout).until(element_present)
except TimeoutException:
    print("Timed out waiting for page to load element")
view_data_by_topic = driver.find_elements(By.CLASS_NAME,'m-SideMenu__link')
time.sleep(2)
view_data_by_topic[1].click()
list_data = driver.find_element(By.CLASS_NAME,'m-SideMenu__container')
tags = list_data.find_element(By.TAG_NAME,'ul').find_elements(By.TAG_NAME,'li')

# %%
for i in range(len(tags)):
    print(tags[0].text)
    # if tags[i].text == 'Costs':
    #     print(i)
# Out:
# Benefits
# Benefits
# Benefits
# Benefits
# Benefits
# Benefits
# Benefits
# Benefits
# Benefits
# Benefits
# Benefits
# Benefits
# Benefits
# Benefits
# Benefits
# Benefits
# Benefits
# Benefits
# Benefits
# Benefits
# Benefits
# Benefits
# Benefits
# Benefits
# Benefits
# Benefits
# Benefits
# Benefits
# Benefits
# Benefits
# Benefits
# Benefits

# %%
tab-tvView tvimagesNS

# %%
driver.get('https://www.irena.org/Data/View-data-by-topic/Energy-Transition/REmap-Energy-Generation-and-Capacity')
time.sleep(2)
content = driver.find_element(By.CLASS_NAME,'m-Iframe')
div = content.find_element(By.TAG_NAME,'iframe')
html = div.find_element(By.XPATH,'/html')
html.click()
time.sleep(1)
driver.switch_to.frame(div)
center = driver.find_element(By.ID,'centeringContainer')
tabs = driver.find_elements(By.CLASS_NAME,'tab-tvView.tvimagesNS')#[2].get_attribute('id')
len(tabs)
# Out:
# 4

# %%
driver.get('https://www.irena.org/Data/View-data-by-topic/Benefits/Renewable-Energy-Employment-by-Country')
time.sleep(2)
content = driver.find_element(By.CLASS_NAME,'m-Iframe')
div = content.find_element(By.TAG_NAME,'iframe')
html = div.find_element(By.XPATH,'/html')
html.click()
time.sleep(1)
driver.switch_to.frame(div)
center = driver.find_element(By.ID,'centeringContainer')
tabs = center.find_element(By.ID,'tabZoneId53').text
tabs
# Out:
# ''
