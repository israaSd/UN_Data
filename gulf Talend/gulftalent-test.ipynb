# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import ElementNotInteractableException, NoSuchElementException
from selenium.common.exceptions import ElementClickInterceptedException
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from webdriver_manager.firefox import GeckoDriverManager
from selenium.webdriver.firefox.options import Options
from bs4 import BeautifulSoup
import shutil
import time
import os
import requests
from bs4 import BeautifulSoup
import logging
import pandas as pd

# %%
types = []
url = 'https://www.gulftalent.com'
middleEast_countries = ['uae','saudi-arabia','qatar','kuwait','egypt','jordan','oman','bahrain','iraq','lebanon','libya']
for c in range(len(middleEast_countries[0:1])):
    url_middleEast = f'https://www.gulftalent.com/{middleEast_countries[c]}/jobs'
    #print(url_middleEast)
    chrome_options = webdriver.ChromeOptions()
    base_path = f"{os.getcwd()}\\downloadfolder" # local, gets current working directory
    base_path
    prefs = {'download.default_directory' : base_path}#, "profile.content_settings.exceptions.automatic_downloads.*.setting" : 1}
    chrome_options.add_experimental_option('prefs', prefs)
    driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)
    driver.maximize_window()
    driver.get(url_middleEast)
    page_source = driver.page_source               
    soup = BeautifulSoup(page_source, 'html.parser')
    links = []
    import csv
    from itertools import zip_longest
    table = soup.find('table')
    rows = table.find_all('tr')
    with open(f'jobs{middleEast_countries[c]}.csv','w',encoding='utf8',newline = '') as f:
        thewriter = csv.writer(f)
        header = ['position','location','date','img','links']
        thewriter.writerow(header)
        for row in rows[1:]:
            a = row.find('a')['href']
            l = f'{url}{a}'
            link = [f'{url}{a}']
            links.append(l)
            cells = row.find_all(['td','th'])
            cells_text = [cell.get_text(strip=True) for cell in cells] + link
            thewriter.writerow(cells_text)
            #print(cells_text)
            #chrome_options = webdriver.ChromeOptions()
        #base_path = f"{os.getcwd()}\\downloadfolder" # local, gets current working directory
        #base_path
        #prefs = {'download.default_directory' : base_path}#, "profile.content_settings.exceptions.automatic_downloads.*.setting" : 1}
        #chrome_options.add_experimental_option('prefs', prefs)
        #chrome_options.add_argument('--user-agent="Mozilla/5.0 (Windows Phone 10.0; Android 4.2.1; Microsoft; Lumia 640 XL LTE) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.135 Mobile Safari/537.36 Edge/12.10166"')
        #driver2 = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)
        #driver2.maximize_window()
        #descr = []
        #descriptions = []
        #types = []
        #try:
        #    for k in links:
        #        driver.get(k)
        #        time.sleep(5)
        #        page_source = driver.page_source                    # this is how to use beautifulsoup with selenium, you can get the hrefs or just click as shown above, up to you
        #        soup = BeautifulSoup(page_source, 'html.parser')
        #        Emp = soup.find(class_ = 'space-bottom-sm')
        #        Employment = Emp.find('span').text
        #        Employment = Employment.strip()
        #        types.append(Employment)
        #        cont = soup.find(class_= 'panel-body content-visibility-auto')
        #        for data in cont.find_all('p'):
        #            descr.append(data.get_text())
        #        #all = cont.find_all('p')#.text
        #        description = ' '.join([str(elem) for elem in descr])
        #        descriptions.append(description)
        #except:
        #    print('error')

# %%
chrome_options = webdriver.ChromeOptions()
base_path = f"{os.getcwd()}\\downloadfolder" # local, gets current working directory
base_path
prefs = {'download.default_directory' : base_path}#, "profile.content_settings.exceptions.automatic_downloads.*.setting" : 1}
chrome_options.add_experimental_option('prefs', prefs)
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)
driver.maximize_window()
driver.get(url_middleEast)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [7], line 8
#       6 driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)
#       7 driver.maximize_window()
# ----> 8 driver.get(url_middleEast)
#
# NameError: name 'url_middleEast' is not defined

# %%
chrome_options = webdriver.ChromeOptions()
base_path = f"{os.getcwd()}\\downloadfolder" # local, gets current working directory
base_path
prefs = {'download.default_directory' : base_path}#, "profile.content_settings.exceptions.automatic_downloads.*.setting" : 1}
chrome_options.add_experimental_option('prefs', prefs)
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)
driver.maximize_window()
driver.get("https://www.gulftalent.com/uae/jobs/senior-accountant-uae-national-356693")

# %%
driver.find_element(By.CLASS_NAME,'panel-body').find_element(By.TAG_NAME,'p').text
# Out:
# 'Based in Abu Dhabi, this role of Senior Accountant will be a hands-on position in a small team, responsible for ensuring that all daily transactions are transacted and recorded in a timely fashion in line with financial controls, preparing transaction documentation and recording it within the system. Also ensure that the accounting system is up to date and that daily and monthly reconciliations and checks have taken place.\n\n**As part of the interview process, candidates will be required to sit a Maths and Accountancy test. A good/high score must be achieved otherwise candidates will not proceed to the next stage.**\n\nResponsibilities:\n\nReporting to: Finance Manager\n\nInvoices and Payments:\n• Initial the payment process;\n• Update invoice tracker on daily basis;\n• Liaise with suppliers for the invoices, queries, outstanding payments and follow up on any discrepancies;\n• Liaise with bank to request the payment/receipt the bank advice/swifts and monitor the payment and transac
# ...

# %%
page_source = driver.page_source               
soup = BeautifulSoup(page_source, 'html.parser')

# %%
links = []
import csv
from itertools import zip_longest
table = soup.find('table')
rows = table.find_all('tr')
with open('gulftilent.csv','w',encoding='utf8',newline = '') as f:
    thewriter = csv.writer(f)
    header = ['position','location','date','img','links']
    thewriter.writerow(header)
    for row in rows[1:]:
        a = row.find('a')['href']
        l = f'{url}{a}'
        link = [f'{url}{a}']
        links.append(l)
        cells = row.find_all(['td','th'])
        cells_text = [cell.get_text(strip=True) for cell in cells] + link
        thewriter.writerow(cells_text)
        print(cells_text)
# Out:
# ['Student Recruitment Director – MENA RegionCharterhouse', 'Dubai', '12 Dec', '', 'https://www.gulftalent.com/uae/jobs/student-recruitment-director-mena-region-356695']
# ['AccountantAspire MENA', 'Dubai', '11 Dec', '', 'https://www.gulftalent.com/uae/jobs/accountant-356694']
# ['Senior Accountant - UAE NationalInspire Selection', 'Abu Dhabi', '11 Dec', '', 'https://www.gulftalent.com/uae/jobs/senior-accountant-uae-national-356693']
# ['Recruitment ConsultanteMagine Solutions', 'Dubai', '11 Dec', '', 'https://www.gulftalent.com/uae/jobs/recruitment-consultant-356692']
# ['Real Estate AgentRocky Real Estate', 'Dubai', '10 Dec', '', 'https://www.gulftalent.com/uae/jobs/real-estate-agent-356691']
# ['Marketing Officer – EventsRAK Properties', 'Ras Al Khaimah', '9 Dec', '', 'https://www.gulftalent.com/uae/jobs/marketing-officer-events-356690']
# ['Assistant Restaurant ManagerAccorHotels', 'Dubai', '9 Dec', '', 'https://www.gulftalent.com/uae/jobs/assistant-restaurant-manager-356688']
# ...

# %%
chrome_options = webdriver.ChromeOptions()
base_path = f"{os.getcwd()}\\downloadfolder" # local, gets current working directory
base_path
prefs = {'download.default_directory' : base_path}#, "profile.content_settings.exceptions.automatic_downloads.*.setting" : 1}
chrome_options.add_experimental_option('prefs', prefs)
#chrome_options.add_argument('--user-agent="Mozilla/5.0 (Windows Phone 10.0; Android 4.2.1; Microsoft; Lumia 640 XL LTE) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.135 Mobile Safari/537.36 Edge/12.10166"')
driver2 = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)
driver2.maximize_window()
#descr = [[] for _ in range(25)]
#job_descriptions = []
#requirements = []
#about_companies = []
types = []
try:
    for k in links[0:1]:
        driver.get(k)
        time.sleep(5)
        page_source = driver.page_source                    # this is how to use beautifulsoup with selenium, you can get the hrefs or just click as shown above, up to you
        soup = BeautifulSoup(page_source, 'html.parser')
        Emp = soup.find(class_ = 'space-bottom-sm')
        Employment = Emp.find('span').text
        Employment = Employment.strip()
        types.append(Employment)
        cont = soup.find(class_= 'panel-body content-visibility-auto')
        #for data in cont.find_all('p'):
        #    descr.append(data.get_text())
        #all = cont.find_all('p')#.text
        data = cont.find_all('p')
        job_description = data[0:1]
        requirement = data[1:2]
        about_company =  data[2:]
        for jo in job_description:
            job_descriptions = [jo.get_text(strip=True)]
            print(job_descriptions)
        #print(job_descriptions)
        for r in requirement:
            requirements = r.get_text(strip=True)
        for a in about_company:
            about_companies = a.get_text(strip=True)
        #print(data)
        #description = ' '.join([str(elem) for elem in descr])
        #for d in data:
        #    descr= d.get_text(strip=True)#.append(d.get_text().replace('\t',' ').replace('\n',' ').replace('/',';'))
        #    print([descr])
            #job_description = descr[0:1]
            #print(job_description)
except:
    print('error')
# Out:
# ["We are WSP - Join us and make your career future ready!Think bigger scale. Think higher profile. Think ground-breaking.Join WSP, and you'll be at the heart of a team of international experts all dedicated to growing and sharing their expertise and working on projects that transform society for all of us.WSP is looking for a Senior Fa?ade Consultant to join our expanding UAE team.?The role primarily involves design support of fa?ade systems from concept design through to tender documentation, including the review and technical commentary of architectural designs and preparation of technical reports, specifications, and detailed drawings. The role may also include construction stage design supervision such as the review of fa?ade-related submittals. Candidates must have a strong knowledge of fa?ade materials, systems, and performance requirements.Your new role, what's involved?* Design fa?ade systems as the fa?ade consultant on the project - taking the design through all stages - typ
# ...

# %%
job_descriptions
# Out:
# ["We are WSP - Join us and make your career future ready!Think bigger scale. Think higher profile. Think ground-breaking.Join WSP, and you'll be at the heart of a team of international experts all dedicated to growing and sharing their expertise and working on projects that transform society for all of us.WSP is looking for a Senior Fa?ade Consultant to join our expanding UAE team.?The role primarily involves design support of fa?ade systems from concept design through to tender documentation, including the review and technical commentary of architectural designs and preparation of technical reports, specifications, and detailed drawings. The role may also include construction stage design supervision such as the review of fa?ade-related submittals. Candidates must have a strong knowledge of fa?ade materials, systems, and performance requirements.Your new role, what's involved?* Design fa?ade systems as the fa?ade consultant on the project - taking the design through all stages - typ
# ...

# %%
links[0]
# Out:
# 'https://www.gulftalent.com/libya/jobs/general-services-supervisor-353702'

# %%
descriptions
# Out:
# ['The role is to manage and oversee security operations/protocols in order to protect the facilities as well as all company assets and staff. \n\n-\tProvide protection to all staff, buildings and properties according to security protocols.\n-\tKeep the premises free from all kinds of dangers.\n-\tDevelop and implement preventative measures against accidents, thefts and other risks.\n-\tOversee and coordinate staff security operations through all areas.\n-\tPlan and respond to emergencies and security alerts.\n-\tScreen visitors before allowing them to enter the premises.\n-\tTrain and schedule programs for security staff and delegate tasks to increase performance.\n-\tEvaluate, assess and analyse performance of security staff.\n-\tInitiate disciplinary measures related to security protocols wherever necessary.\n-\tMaintain all security devices and equipment in good working condition.\n-\tEnsure compliance of applicable policies and regulations while implementing security measures.\n-
# ...
