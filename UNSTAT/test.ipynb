# %%
file = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\downloadfolder\\Demographic Indicators - Indicator reference .csv'
import pandas as pd
indcs = []
df = pd.read_csv(file)
for i in range(len(df.index)):
    f = df.iloc[i].to_list()
    f = [' : '.join(map(str,f))]
    indcs.append(f[0])
indc = [' , '.join(map(str,indcs))]
indc =  'IndicatorNo : Topic : Indicator : IndicatorName : Unit'+ ' , ' + indc[0]

# %%
file = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\downloadfolder\\Notes - File , Location notes.csv'
import unidecode
import pandas as pd
notes = []
df = pd.read_csv(file)
df.iloc[:,0] = df.iloc[:,1].str.encode('ascii', 'ignore').str.decode('ascii')
for i in range(len(df.index)):
    f = df.iloc[i].to_list()
    f = [' : '.join(map(str,f))]
    notes.append(f[0])
note = [' , '.join(map(str,notes))]
note =  'Notes : Text'+ ' , ' + note[0]
note
# Out:
# 'Notes : Text , Countries and areas are grouped into eight Sustainable Development Goal (SDG) regions as defined by the United Nations Statistics Division and used for The Sustainable Development Goals Report (https://unstats.un.org/sdgs/indicators/regional-groups/).  These regions are further divided into 21 geographic subregions. : Countries and areas are grouped into eight Sustainable Development Goal (SDG) regions as defined by the United Nations Statistics Division and used for The Sustainable Development Goals Report (https://unstats.un.org/sdgs/indicators/regional-groups/).  These regions are further divided into 21 geographic subregions. , Sub-Saharan Africa refers to all of Africa except Northern Africa. : Sub-Saharan Africa refers to all of Africa except Northern Africa. , The designation more developed and less developed regions are intended for statistical purposes and do not express a judgment about the stage reached by a particular country or area in the development pro
# ...

# %%
import pandas as pd
note = []
xls = pd.ExcelFile('C:\\Users\\10235555\\Documents\\DataportalCrawlers\\UN_Data\\downloadfolder2\\File 12 Population of Urban Agglomerations with 300,000 Inhabitants or More in 2018, by country, 1950-2035 (thousands).xls')
sheets = xls.sheet_names
df = pd.read_excel('C:\\Users\\10235555\\Documents\\DataportalCrawlers\\UN_Data\\downloadfolder2\\File 12 Population of Urban Agglomerations with 300,000 Inhabitants or More in 2018, by country, 1950-2035 (thousands).xls',sheets[0])
df.iloc[14:16] = df.iloc[14:16].fillna(method='ffill', axis=1)
df.iloc[14:16] = df.iloc[14:16].fillna('')
df.columns = df.iloc[14:16].apply(lambda x: ' \n '.join(map(str,[y for y in x if y])), axis=0)
# df[16:].to_excel('test_file_title_2.xlsx',index = False)
df_2 = pd.read_excel('C:\\Users\\10235555\\Documents\\DataportalCrawlers\\UN_Data\\downloadfolder2\\File 12 Population of Urban Agglomerations with 300,000 Inhabitants or More in 2018, by country, 1950-2035 (thousands).xls',sheets[1])
for i in range(len(df_2.index)):
    f = df_2.iloc[i].to_list()
    f = [' : '.join(map(str,f))]
    note.append(f[0])
notes = [' , '.join(map(str,note))]
notes = 'Notes, ' + notes[0]
notes
# Out:
# 'Notes, (1) Refers to the Governorate of Grand Algiers. , (2) Estimate for 2014 refers to the urban population of the "municipio" of Benguela. , (3) Estimate for 2014 refers to the urban population of the "municipio" of Cabinda. , (4) Estimate for 2014 refers to the urban population of the "municipio" of Huambo. , (5) Estimate for 2014 refers to the urban population of the "municipio" of Lobito. , (6) Estimate for 2014 refers to the urban population of the province of Luanda. , (7) Estimate for 2014 refers to the urban population of the "municipio" of Lubango. , (8) Estimate for 2014 refers to the urban population of the "municipio" of Malanje. , (9) Refers to Gran Buenos Aires. Data for 2001 and 2010 refer to the urban agglomeration including Buenos Aires city, 24 districts of Gran Buenos Aires and some districts of the suburbs. , (10) Refers to Gran Córdoba. , (11) Refers to Gran Corrientes. , (12) Refers to Gran La Plata. , (13) Refers to Gran Mendoza. , (14) Refers to Gran Resist
# ...

# %%
import pandas as pd
df = pd.read_excel('C:\\Users\\10235555\\Documents\\DataportalCrawlers\\UN_Data\\downloadfolder2\\Urban-Agglomerations\\WUP1999F11-Growth_Rate_Cities.xls')
topic = df.iloc[7,0]
title = df.iloc[8,0].replace(':','')
if title=='File 10  Population of Urban Agglomerations with 750,000 Inhabitants or More in 1995 by Country, 1950-2015':
    df.columns = df.iloc[13].to_list()
else:
    df.columns = df.iloc[12].to_list()
df[13:].to_excel(f'C:\\Users\\10235555\\Documents\\DataportalCrawlers\\UN_Data\\{title}.xlsx',index = False)

# %%
'C:\Users\10235555\Documents\DataportalCrawlers\UN_Data\downloadfolder2\Urban-Rural-Areas'
'C:\Users\10235555\Documents\DataportalCrawlers\UN_Data\downloadfolder2\WUP2003_DOCUMENTATION'
'C:\Users\10235555\Documents\DataportalCrawlers\UN_Data\downloadfolder2\WUP2005_DOCUMENTATION'
'C:\Users\10235555\Documents\DataportalCrawlers\UN_Data\downloadfolder2\WUP2007_DOCUMENTATION'
# like previous for file start with 'WUP'


'C:\Users\10235555\Documents\DataportalCrawlers\UN_Data\downloadfolder2\WUP2003_EXCEL_DATA_SETS'
'C:\Users\10235555\Documents\DataportalCrawlers\UN_Data\downloadfolder2\WUP2005_EXCEL_DATA_SETS'
'C:\Users\10235555\Documents\DataportalCrawlers\UN_Data\downloadfolder2\WUP2007_XLS_CD_FILES'
'C:\Users\10235555\Documents\DataportalCrawlers\UN_Data\downloadfolder2\WUP2011_XLS_CD_FILES'
# LIKE previous BUT -1 for index (start line 13 not 14)

'C:\Users\10235555\Documents\DataportalCrawlers\UN_Data\downloadfolder2\WUP2009_XLS_CD_FILES'
# LIKE previous BUT -3 for index (start line 11 not 14)

'C:\Users\10235555\Documents\DataportalCrawlers\UN_Data\downloadfolder2\WUP2011_DOCUMENTATION'
# LIKE previous BUT -2 for index (start line 12 not 14)

'C:\Users\10235555\Documents\DataportalCrawlers\UN_Data\downloadfolder2\WUP2009_DOCUMENTATION'
# from line 10 in file

'C:\Users\10235555\Documents\DataportalCrawlers\UN_Data\downloadfolder2\WUP2014_DOCUMENTATION'
'C:\Users\10235555\Documents\DataportalCrawlers\UN_Data\downloadfolder2\WUP2014_XLS_CD_FILES'
# from line 16-17 oin file

# %%
import pandas as pd
note = []
df = pd.read_csv('C:\\Users\\10235555\\Documents\\Dataportal Data\\downloadfolder\\Notes - File , Location notes.csv')
for i in range(len(df.index)):
    f = df.iloc[i].to_list()
    f = [' : '.join(map(str,f))]
    note.append(f[0])
notes = [' , '.join(map(str,note))]
notes = 'Notes, ' + notes[0]
notes
# Out:
# 'Notes, a : Countries and areas are grouped into eight Sustainable Development Goal (SDG) regions as defined by the United Nations Statistics Division and used for The Sustainable Development Goals Report (https://unstats.un.org/sdgs/indicators/regional-groups/).  These regions are further divided into 21 geographic subregions. , b : Sub-Saharan Africa refers to all of Africa except Northern Africa. , c : The designation “more developed” and “less developed” regions are intended for statistical purposes and do not express a judgment about the stage reached by a particular country or area in the development process. , d : More developed regions comprise Europe, Northern America, Australia/New Zealand and Japan. , e : Less developed regions comprise all regions of Africa, Asia (except Japan), Latin America and the Caribbean plus Melanesia, Micronesia and Polynesia. , f : The group of least developed countries includes 46 countries:  32 in Sub-Saharan Africa, 2 in Northern Africa and We
# ...

# %%
import pandas as pd
df = pd.read_excel('C:\\Users\\10235555\\Downloads\\WUP2018-F01-Total_Urban_Rural-1.xls')
df.iloc[14:16] = df.iloc[14:16].fillna(method='ffill', axis=1)
df.iloc[14:16] = df.iloc[14:16].fillna('')
df.columns = df.iloc[14:16].apply(lambda x: ' \n\n '.join(map(str,[y for y in x if y])), axis=0)
df[16:].columns
# Out:
# Index(['Index', 'Region, subregion, country or area', 'Note', 'Country\ncode',
#        'Population of Urban and Rural Areas at Mid-Year (thousands) and Percentage Urban, 2018 \n\n Urban',
#        'Population of Urban and Rural Areas at Mid-Year (thousands) and Percentage Urban, 2018 \n\n Rural',
#        'Population of Urban and Rural Areas at Mid-Year (thousands) and Percentage Urban, 2018 \n\n Total',
#        'Population of Urban and Rural Areas at Mid-Year (thousands) and Percentage Urban, 2018 \n\n Percentage urban'],
#       dtype='object')

# %%
colum = []
import pandas as pd
from unidecode import unidecode
df = pd.read_excel('C:\\Users\\10235555\\Documents\\DataportalCrawlers\\UN_Data\\UNStat_demogrphic_yearbook\\Table 9 - Live births and crude birth rates, by urban or rural residence 2017-2021.xls')
df.iloc[2:4] = df.iloc[2:4].fillna(method='ffill', axis=1)
df.iloc[2:4] = df.iloc[2:4].fillna('')
df.columns = df.iloc[2:4].apply(lambda x: ' \n '.join(map(str,[y for y in x if y])), axis=0)
df = df.iloc[4:]
df = df.loc[:,~df.columns.duplicated()].copy()
list = df.columns.to_list()
for col in list:
    colum.append(unidecode(col.replace('\n',' \n ')))
df.columns = colum
df.iloc[:,0] = df.iloc[:,0].str.encode('ascii', 'ignore').str.decode('ascii')
df.to_excel('test_table1.xlsx',index=False)
df.columns
# Out:
# Index(['Continent, country or area, and urban/rural residence \n Continent, pays ou zone et residence, urbaine/rurale',
#        'Co-dea', 'Number \n Nombre  \n  \n  2017',
#        'Number \n Nombre  \n  \n  2018', 'Number \n Nombre  \n  \n  2019',
#        'Number \n Nombre  \n  \n  2020', 'Number \n Nombre  \n  \n  2021',
#        'Rate \n Taux  \n  \n  2017', 'Rate \n Taux  \n  \n  2018',
#        'Rate \n Taux  \n  \n  2019', 'Rate \n Taux  \n  \n  2020',
#        'Rate \n Taux  \n  \n  2021'],
#       dtype='object')

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\10235555\\Documents\\DataportalCrawlers\\UN_Data'

# %%
import pandas as pd
from unidecode import unidecode
footnot = []
df = pd.read_csv('C:\\Users\\10235555\\Documents\\DataportalCrawlers\\UN_Data\\downloadfolder\\Population 5 to 24 years of age by school attendance  sex and urban rural residence.csv')
ind = df.iloc[:,1].index[df.iloc[:,1]== 'Footnote'].to_list()
footnotes = df.iloc[ind[0]:]
footnotes = footnotes.iloc[:,0:2]
for i in range(len(footnotes.index)):
    f = footnotes.iloc[i].to_list()
    f = [' : '.join(map(str,f))]
    footnot.append(f[0])
footnot = [' , '.join(map(str,footnot))]
df = df.iloc[:ind[0]]
df.iloc[:,0] = df.iloc[:,0].str.encode('ascii', 'ignore').str.decode('ascii')
# df.to_csv('test_popcensus.csv')
description = footnot[0]
description
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_26768\1318681888.py:4: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('C:\\Users\\10235555\\Documents\\DataportalCrawlers\\UN_Data\\downloadfolder\\Population 5 to 24 years of age by school attendance  sex and urban rural residence.csv')
# ...

# %%
colum = []
df = pd.read_excel('C:\\Users\\10235555\\Documents\\DataportalCrawlers\\UN_Data\\UNStat_demogrphic_yearbook\\Table 1 - Population, rate of increase, birth and death rates, surface area and density for the world, major areas and regions selected years.xls')
df.iloc[2:4] = df.iloc[2:4].fillna(method='ffill', axis=1)
df.iloc[2:4] = df.iloc[2:4].fillna('')
df.columns = df.iloc[2:4].apply(lambda x: ' \n\n '.join(map(str,[y for y in x if y])), axis=0)
df = df.iloc[4:]
df = df.loc[:,~df.columns.duplicated()].copy()
list = df.columns.to_list()
for col in list:
    colum.append(unidecode(col))
df.columns = colum
df.iloc[:,0] = df.iloc[:,0].str.encode('ascii', 'ignore').str.decode('ascii')
df.to_excel('test_table1.xlsx',index=False)

# %%
colum = []
import pandas as pd
from unidecode import unidecode
df = pd.read_excel('C:\\Users\\10235555\\Documents\\DataportalCrawlers\\UN_Data\\UNStat_demogrphic_yearbook\\Table 3 - Population by sex, annual rate of population increase, surface area and density.xls')
df.iloc[2:4] = df.iloc[2:4].fillna(method='ffill', axis=1)
df.iloc[2:4] = df.iloc[2:4].fillna('')
df.columns = df.iloc[2:4].apply(lambda x: ' \n\n '.join(map(str,[y for y in x if y])), axis=0)
df = df.iloc[4:]
df = df.loc[:,~df.columns.duplicated()].copy()
list = df.columns.to_list()
for col in list:
    colum.append(unidecode(col))
df.columns = colum
df.iloc[:,0] = df.iloc[:,0].str.encode('ascii', 'ignore').str.decode('ascii')
df.rename(columns={df.columns[5]: df.columns[5].replace(' \n\n Female\nFeminin','')},inplace=True)
df.rename(columns={df.columns[10]: df.columns[10].replace(' \n\n 2021','')},inplace=True)
df.to_excel('test_table3.xlsx',index=False)

# %%
colum = []
import pandas as pd
from unidecode import unidecode
df = pd.read_excel('C:\\Users\\10235555\\Documents\\DataportalCrawlers\\UN_Data\\UNStat_demogrphic_yearbook\\Table 4 - Vital statistics summary and life expectancy at birth 2017-2021.xls')
df.iloc[2:4] = df.iloc[2:4].fillna(method='ffill', axis=1)
df.iloc[2:4] = df.iloc[2:4].fillna('')
df.columns = df.iloc[2:4].apply(lambda x: ' \n\n '.join(map(str,[y for y in x if y])), axis=0)
df = df.iloc[4:]
df = df.loc[:,~df.columns.duplicated()].copy()
list = df.columns.to_list()
for col in list:
    colum.append(unidecode(col))
df.columns = colum
df.iloc[:,0] = df.iloc[:,0].str.encode('ascii', 'ignore').str.decode('ascii')
df.rename(columns={df.columns[7]: df.columns[7].replace(' \n\n Crude death rate\nTaux brut de mortalite','')},inplace=True)
df.rename(columns={df.columns[13]: df.columns[13].replace(' \n\n Femaleb\nFemininb','')},inplace=True)
df.to_excel('test_table4.xlsx',index=False)

# %%
colum = []
import pandas as pd
from unidecode import unidecode
df = pd.read_excel('C:\\Users\\10235555\\Documents\\DataportalCrawlers\\UN_Data\\UNStat_demogrphic_yearbook\\Table 10 - Live births by age of mother and sex of child, general and age-specific fertility rates latest available year, 2012-2021.xls')
df.iloc[2:4] = df.iloc[2:4].fillna(method='ffill', axis=1)
df.iloc[2:4] = df.iloc[2:4].fillna('')
df.columns = df.iloc[2:4].apply(lambda x: ' \n\n '.join(map(str,[y for y in x if y])), axis=0)
df = df.iloc[4:]
df = df.loc[:,~df.columns.duplicated()].copy()
list = df.columns.to_list()
for col in list:
    colum.append(unidecode(col))
df.columns = colum
df.iloc[:,0] = df.iloc[:,0].str.encode('ascii', 'ignore').str.decode('ascii')
df.rename(columns={df.columns[4]: df.columns[4].replace(' \n\n Female\nFeminin','')},inplace=True)
df.to_excel('test_table10.xlsx',index=False)

# %%
colum = []
import pandas as pd
from unidecode import unidecode
df = pd.read_excel('C:\\Users\\10235555\\Documents\\DataportalCrawlers\\UN_Data\\UNStat_demogrphic_yearbook\\Table 11 - Live births and live birth rates by age of father latest available year, 2012-2021.xls')
df.iloc[2:4] = df.iloc[2:4].fillna(method='ffill', axis=1)
df.iloc[2:4] = df.iloc[2:4].fillna('')
df.columns = df.iloc[2:4].apply(lambda x: ' \n\n '.join(map(str,[y for y in x if y])), axis=0)
df = df.iloc[4:]
df = df.loc[:,~df.columns.duplicated()].copy()
list = df.columns.to_list()
for col in list:
    colum.append(unidecode(col))
df.columns = colum
df.iloc[:,0] = df.iloc[:,0].str.encode('ascii', 'ignore').str.decode('ascii')
df.rename(columns={df.columns[2]: df.columns[2].replace(' \n\n Both sexes\nLes deux sexes','')},inplace=True)
df.to_excel('test_table11.xlsx',index=False)

# %%
colum = []
import pandas as pd
from unidecode import unidecode
df = pd.read_excel('C:\\Users\\10235555\\Documents\\DataportalCrawlers\\UN_Data\\UNStat_demogrphic_yearbook\\Table 20 - Death and death rates by cause and sex 2016 - 2020.xls')
df.iloc[2:6] = df.iloc[2:6].fillna(method='ffill', axis=1)
df.iloc[2:6] = df.iloc[2:6].fillna('')
df.columns = df.iloc[2:6].apply(lambda x: ' \n\n '.join(map(str,[y for y in x if y])), axis=0)
df = df.iloc[7:]
df = df.loc[:,~df.columns.duplicated()].copy()
list = df.columns.to_list()
for col in list:
    colum.append(unidecode(col))
df.columns = colum
df.iloc[:,0] = df.iloc[:,0].str.encode('ascii', 'ignore').str.decode('ascii')
df.to_excel('test_table20.xlsx',index=False)

# %%
colum = []
import pandas as pd
from unidecode import unidecode
df = pd.read_excel('C:\\Users\\10235555\\Documents\\DataportalCrawlers\\UN_Data\\UNStat_demogrphic_yearbook\\Table 2 - Estimates of population and its percentage distribution, by age and sex and sex ratio for all ages for the world, major areas and regions 2021.xls')
df.iloc[2:5] = df.iloc[2:5].fillna(method='ffill', axis=1)
df.iloc[2:5] = df.iloc[2:5].fillna('')
df.columns = df.iloc[2:5].apply(lambda x: ' \n\n '.join(map(str,[y for y in x if y])), axis=0)
df = df.iloc[5:]
df = df.loc[:,~df.columns.duplicated()].copy()
df.rename(columns={df.columns[13]: df.columns[13].replace(' \n\n Female\nFéminin \n\n 65+','')},inplace=True)
list = df.columns.to_list()
for col in list:
    colum.append(unidecode(col))
df.columns = colum
df.iloc[:,0] = df.iloc[:,0].str.encode('ascii', 'ignore').str.decode('ascii')
df.to_excel('test_table2.xlsx',index=False)

# %%
colum = []
import pandas as pd
from unidecode import unidecode
df = pd.read_excel('C:\\Users\\10235555\\Documents\\DataportalCrawlers\\UN_Data\\UNStat_demogrphic_yearbook\\Table 6 - Total and urban population by sex 2012-2021.xls')
df.iloc[2:5] = df.iloc[2:5].fillna(method='ffill', axis=1)
df.iloc[2:5] = df.iloc[2:5].fillna('')
df.columns = df.iloc[2:5].apply(lambda x: ' \n\n '.join(map(str,[y for y in x if y])), axis=0)
df = df.iloc[4:]
df = df.loc[:,~df.columns.duplicated()].copy()
df.rename(columns={df.columns[5]: df.columns[5].replace(' \n\n Percent P.100','')},inplace=True)
df.rename(columns={df.columns[8]: df.columns[8].replace(' \n\n Percent P.100',' ')},inplace=True)
list = df.columns.to_list()
for col in list:
    colum.append(unidecode(col))
df.columns = colum
df.iloc[:,0] = df.iloc[:,0].str.encode('ascii', 'ignore').str.decode('ascii')
df.to_excel('test_table6.xlsx',index=False)

# %%
colum = []
import pandas as pd
from unidecode import unidecode
df = pd.read_excel('C:\\Users\\10235555\\Documents\\DataportalCrawlers\\UN_Data\\UNStat_demogrphic_yearbook\\Table 8 - Population of capital cities and cities of 100 000 or more inhabitants latest available year, 2002-2021.xls')
df.iloc[2:5] = df.iloc[2:5].fillna(method='ffill', axis=1)
df.iloc[2:5] = df.iloc[2:5].fillna('')
df.columns = df.iloc[2:5].apply(lambda x: ' \n '.join(map(str,[y for y in x if y])), axis=0)
df = df.iloc[5:]
df = df.loc[:,~df.columns.duplicated()].copy()
list = df.columns.to_list()
for col in list:
    colum.append(unidecode(col))
df.columns = colum
df.rename(columns={df.columns[4]: df.columns[4].replace('\n Population',' ')},inplace=True)
df.rename(columns={df.columns[8]: df.columns[8].replace('\n Population',' ')},inplace=True)
df.iloc[:,0] = df.iloc[:,0].str.encode('ascii', 'ignore').str.decode('ascii')
df.to_excel('test_table8.xlsx',index=False)

# %%
colum = []
import pandas as pd
from unidecode import unidecode
df = pd.read_excel('C:\\Users\\10235555\\Documents\\DataportalCrawlers\\UN_Data\\UNStat_demogrphic_yearbook\\Table 17 - Maternal deaths and maternal mortality ratios 2011-2020.xls')
df.columns = df.iloc[2]
df = df[4:]
df = df.loc[:, df.columns.notna()]
df.iloc[:,0] = df.iloc[:,0].str.encode('ascii', 'ignore').str.decode('ascii')
df.to_excel('test_table17.xlsx',index=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [28], line 10
#       8 list = df.columns.to_list()
#       9 for col in list:
# ---> 10     colum.append(unidecode(col))
#      11 df.columns = colum
#      12 df.iloc[:,0] = df.iloc[:,0].str.encode('ascii', 'ignore').str.decode('ascii')
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\unidecode\__init__.py:60, in unidecode_expect_ascii(string, errors, replace_str)
#      36 """Transliterate an Unicode object into an ASCII string
#      37
#      38 >>> unidecode("\u5317\u4EB0")
#    (...)
#      56 ASCII!
#      57 """
#      59 try:
# ---> 60     bytestring = string.encode('ASCII')
#      61 except UnicodeEncodeError:
#      62     pass
#
# AttributeError: 'int' object has no attribute 'encode'

# %%
import pandas as pd
import numpy as np
import numpy as np
df = pd.read_excel('\\\\10.30.31.77\\data_collection_dump\\RawData\\UNStat_Env\\Fresh groundwater abstracted XLS.xlsx')
# with open("C:\\Users\\10235555\\Documents\\DataportalCrawlers\\UN_Data\\test_excel_E.xlsx",'w',encoding = 'utf-8') as f :
#     df.to_excel(f,index = False)
# ind = df.iloc[:,0].index[df.iloc[:,0] =='nan'].to_list()
# df = df.iloc[:ind[0]]
index3 = df.iloc[:,0].index[df.iloc[:,0] == 'Footnote number'].tolist()
# Out:
#      Unnamed: 0        CountryID  \
# 110         110              887
# 111         111              894
# 112         112              716
# 113         113              NaN
# 114         114  Footnote number
# 115         115                1
# 116         116                2
# 117         117                3
# 118         118                4
# 119         119                5
# 120         120                6
# 121         121                7
# 122         122                8
# 123         123                9
# 124         124               10
# 125         125               11
# 126         126               12
# 127         127               13
# 128         128               14
# 129         129               15
# 130         130               16
# 131         131               17
# 132         132               18
# 133         133               19
# 134         134               20
# 135         135               21
# 136         136               22
# ...

# %%
colum = []
import pandas as pd
from unidecode import unidecode
df = pd.read_excel('C:\\Users\\10235555\\Documents\\DataportalCrawlers\\UN_Data\\UNStat_demogrphic_yearbook\\Table 8 - Population of capital cities and cities of 100 000 or more inhabitants latest available year, 2002-2021.xls')
df.iloc[2:5] = df.iloc[2:5].fillna(method='ffill', axis=1)
df.iloc[2:5] = df.iloc[2:5].fillna('')
df.columns = df.iloc[2:5].apply(lambda x: ' \n '.join(map(str,[y for y in x if y])), axis=0)
df = df.iloc[5:]
df = df.loc[:,~df.columns.duplicated()].copy()
list = df.columns.to_list()
for col in list:
    colum.append(unidecode(col))
df.columns = colum
df.rename(columns={df.columns[4]: df.columns[4].replace('\n Population',' ')},inplace=True)
df.rename(columns={df.columns[8]: df.columns[8].replace('\n Population',' ')},inplace=True)
df.columns
# df.columns[4] = df.columns[4].replace('\n Population',' ')
# df.to_excel('test_table8.xlsx',index=False)
# Out:
# Index(['Continent, country or area, date, code and city\nContinent, pays ou zone, date, code et ville',
#        'City proper\nVille proprement dite \n Population \n Both sexes\nLes deux sexes',
#        'City proper\nVille proprement dite \n Population \n Male\nMasculin',
#        'City proper\nVille proprement dite \n Population \n Female\nFeminin',
#        'City proper\nVille proprement dite   \n Surface area\nSuperficie (km2)',
#        'Urban agglomeration\nAgglomeration urbaine \n Population \n Both sexes\nLes deux sexes',
#        'Urban agglomeration\nAgglomeration urbaine \n Population \n Male\nMasculin',
#        'Urban agglomeration\nAgglomeration urbaine \n Population \n Female\nFeminin',
#        'Urban agglomeration\nAgglomeration urbaine   \n Surface area\nSuperficie (km2)'],
#       dtype='object')

# %%
import pandas as pd
import numpy as np
df = pd.read_excel('\\\\10.30.31.77\\data_collection_dump\\RawData\\UNStat_Env\\Proportion of population in coastal zones (LECZ).xls')
b = df.iloc[35:,1:]
column = ['Country', 'Urban - 1990', 'Rural - 1990',' Total - 1990', 'Urban - 1995','Rural - 1995',' Total - 1995','Urban - 2000','Rural - 2000',' Total - 2000']
b.set_axis(column, axis=1,inplace=True)
b.to_excel('test_lecz.xlsx',index = False)
# header1 = b.iloc[0, :].values.tolist()

# #b.columns = [b.columns[i-1] if None in b.columns[i] else b.columns[i] for i in range(len(b.columns)) ]
# header2 = b.iloc[1, :].values.tolist()
# header3 = b.iloc[2, :].values.tolist()
# header = zip(header1,header2,header3)
# b.set_axis(header, axis=1,inplace=True)
#b.columns = [' '.join(b.columns[i]) for i in range(len(b.columns))]
b.head()
#column = ['Country', 'Urban - 1990', 'Rural - 1990',' Total - 1990', 'Urban - 1995','Rural - 1995',' Total - 1995','Urban - 2000','Rural - 2000',' Total - 2000']
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_4764\1435642537.py:6: FutureWarning: DataFrame.set_axis 'inplace' keyword is deprecated and will be removed in a future version. Use `obj = obj.set_axis(..., copy=False)` instead
#   b.set_axis(column, axis=1,inplace=True)
#            Country Urban - 1990 Rural - 1990  Total - 1990 Urban - 1995  \
# 35    Afghanistan1            0            0             0            0
# 36         Albania    11.113795     8.128178      9.099972    10.475542
# 37         Algeria     5.851422     1.547665      3.737483     5.851422
# 38  American Samoa     5.847475    37.604369     10.331037     5.738278
# 39        Andorra1            0            0             0            0
#
#    Rural - 1995  Total - 1995 Urban - 2000 Rural - 2000  Total - 2000
# 35            0             0            0            0             0
# 36     9.289446      9.739686    10.272006     10.05229      10.14283
# ...

# %%
import xlrd
sheet = xlrd.open_workbook('\\\\10.30.31.77\\data_collection_dump\\RawData\\UNStat_Env\\Proportion of population in coastal zones (LECZ).xls')
del sheet.charts[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [29], line 3
#       1 import xlrd
#       2 sheet = xlrd.open_workbook('\\\\10.30.31.77\\data_collection_dump\\RawData\\UNStat_Env\\Proportion of population in coastal zones (LECZ).xls')
# ----> 3 del sheet_charts[0]
#
# NameError: name 'sheet_charts' is not defined

# %%
import xlwings as xw
ws = xw.Book('\\\\10.30.31.77\\data_collection_dump\\RawData\\UNStat_Env\\Proportion of population in coastal zones (LECZ).xls').sheets['Sheet1']

# %%
import pandas as pd
df = pd.read_excel('C:\\Users\\10235555\\Documents\\DataportalCrawlers\\UN_Data\\UNStat_demogrphic_yearbook\\Table 2 - Estimates of population and its percentage distribution, by age and sex and sex ratio for all ages for the world, major areas and regions 2021.xls')
df.iloc[2:5] = df.iloc[2:5].fillna(method='ffill', axis=1)
df.iloc[2:5] = df.iloc[2:5].fillna('')
df.columns = df.iloc[2:5].apply(lambda x: ' \n\n '.join(map(str,[y for y in x if y])), axis=0)
df = df.iloc[5:]
df = df.loc[:,~df.columns.duplicated()].copy()
df.rename(columns={df.columns[13]: df.columns[13].replace(' \n\n Female\nFéminin \n\n 65+','')},inplace=True)
df.columns
# df.to_excel('test_table2.xlsx',index=False)
# Out:
# Index(['Major areas and regions\nGrandes régions et régions',
#        'Population (millions) \n\n Both sexes\nLes deux sexes \n\n All ages - Tous âges',
#        'Population (millions) \n\n Both sexes\nLes deux sexes \n\n 0-14',
#        'Population (millions) \n\n Both sexes\nLes deux sexes \n\n 15-64',
#        'Population (millions) \n\n Both sexes\nLes deux sexes \n\n 65+',
#        'Population (millions) \n\n Male\nMasculin \n\n All ages - Tous âges',
#        'Population (millions) \n\n Male\nMasculin \n\n 0-14',
#        'Population (millions) \n\n Male\nMasculin \n\n 15-64',
#        'Population (millions) \n\n Male\nMasculin \n\n 65+',
#        'Population (millions) \n\n Female\nFéminin \n\n All ages - Tous âges',
#        'Population (millions) \n\n Female\nFéminin \n\n 0-14',
#        'Population (millions) \n\n Female\nFéminin \n\n 15-64',
#        'Population (millions) \n\n Female\nFéminin \n\n 65+',
#        'Sex ratio\nRapport de masculinité¹'],
# ...

# %%
import pandas as pd
df = pd.read_excel('C:\\Users\\10235555\\Documents\\DataportalCrawlers\\UN_Data\\UNStat_demogrphic_yearbook\\Table 6 - Total and urban population by sex 2012-2021.xls')
df.iloc[2:5] = df.iloc[2:5].fillna(method='ffill', axis=1)
df.iloc[2:5] = df.iloc[2:5].fillna('')
df.columns = df.iloc[2:5].apply(lambda x: ' \n\n '.join(map(str,[y for y in x if y])), axis=0)
# df.columns = df.iloc[3:5].apply(lambda x: ' \n\n '.join(map(str,[y for y in x if y])), axis=0)
df = df.iloc[4:]
df = df.loc[:,~df.columns.duplicated()].copy()
df.rename(columns={df.columns[5]: df.columns[5].replace(' \n\n Percent P.100','')},inplace=True)
df.rename(columns={df.columns[8]: df.columns[8].replace(' \n\n Percent P.100',' ')},inplace=True)
df.columns
# df.to_excel('test_table6.xlsx',index=False)
# Out:
# Index(['Continent, country or area, and date Continent, pays ou zone et date',
#        'Codea', 'Both sexes Les deux sexes \n\n Total',
#        'Both sexes Les deux sexes \n\n Urban Urbaine \n\n Number Nombre',
#        'Both sexes Les deux sexes \n\n Urban Urbaine \n\n Percent P.100',
#        'Male Masculin \n\n Total',
#        'Male Masculin \n\n Urban Urbaine \n\n Number Nombre',
#        'Male Masculin \n\n Urban Urbaine \n\n Percent P.100',
#        'Female Féminin \n\n Total ',
#        'Female Féminin \n\n Urban Urbaine \n\n Number Nombre',
#        'Female Féminin \n\n Urban Urbaine \n\n Percent P.100'],
#       dtype='object')

# %%
import pandas as pd
df = pd.read_excel('C:\\Users\\10235555\\Documents\\DataportalCrawlers\\UN_Data\\UNStat_demogrphic_yearbook\\Table 20 - Death and death rates by cause and sex 2016 - 2020.xls')
df.iloc[2:6] = df.iloc[2:6].fillna(method='ffill', axis=1)
df.iloc[2:6] = df.iloc[2:6].fillna('')
df.columns = df.iloc[2:6].apply(lambda x: ' \n\n '.join(map(str,[y for y in x if y])), axis=0)
df = df.iloc[7:]
df = df.loc[:,~df.columns.duplicated()].copy()
df.to_excel('test_table20.xlsx',index=False)

# %%
import pandas as pd
df = pd.read_excel('C:\\Users\\10235555\\Documents\\DataportalCrawlers\\UN_Data\\UNStat_demogrphic_yearbook\\Table 17 - Maternal deaths and maternal mortality ratios 2011-2020.xls')
df.columns = df.iloc[2]
df = df[4:]
df = df.loc[:, df.columns.notna()]
df.head()
# Out:
# 2 Continent and country or area Continent et pays ou zone Co-dea      2011  \
# 4                                   AFRICA - AFRIQUE         NaN       NaN
# 5                                         Cabo Verde         NaN       NaN
# 6                                    Number - Nombre           C         5
# 7                                        Rate - Taux           C  46.04052
# 8                                     Egypt - Égypte         NaN       NaN
#
# 2     2012 2013 2014 2015 2016 2017 2018 2019 2020
# 4      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 5      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 6        1  ...  ...  ...  ...  ...  ...  ...  ...
# 7  9.87069  ...  ...  ...  ...  ...  ...  ...  ...
# 8      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN

# %%
colum = []
import pandas as pd
from unidecode import unidecode
df = pd.read_excel('C:\\Users\\10235555\\Documents\\DataportalCrawlers\\UN_Data\\UNStat_demogrphic_yearbook\\Table 10 - Live births by age of mother and sex of child, general and age-specific fertility rates latest available year, 2012-2021.xls')
df.iloc[2:4] = df.iloc[2:4].fillna(method='ffill', axis=1)
df.iloc[2:4] = df.iloc[2:4].fillna('')
df.columns = df.iloc[2:4].apply(lambda x: ' \n\n '.join(map(str,[y for y in x if y])), axis=0)
df = df.iloc[4:]
df = df.loc[:,~df.columns.duplicated()].copy()
list = df.columns.to_list()
for col in list:
    colum.append(unidecode(col))
df.columns = colum
df.to_excel('test_table10.xlsx',index=False)

# %%
import pandas as pd
df = pd.read_excel('C:\\Users\\10235555\\Documents\\DataportalCrawlers\\UN_Data\\UNStat_demogrphic_yearbook\\Table 3 - Population by sex, annual rate of population increase, surface area and density.xls')
df.iloc[2:4] = df.iloc[2:4].fillna(method='ffill', axis=1)
df.iloc[2:4] = df.iloc[2:4].fillna('')
df.columns = df.iloc[2:4].apply(lambda x: ' \n\n '.join(map(str,[y for y in x if y])), axis=0)
df = df.iloc[4:]
df = df.loc[:,~df.columns.duplicated()].copy()
df.to_excel('test_table3_nondup.xlsx',index=False)

# %%
import pandas as pd
df = pd.read_excel('C:\\Users\\10235555\\Documents\\DataportalCrawlers\\UN_Data\\downloadfolder\\Meteorological disasters XLS.xlsx')
#with open("C:\\Users\\10235555\\Documents\\DataportalCrawlers\\UN_Data\\test_excel.xlsx",'w',encoding='utf-8') as f :
#df.to_excel('test_excel.xlsx',index = False)
header2 = df.loc[0, :].values.tolist()
df.columns = [df.columns[i-1] if 'Unnamed' in df.columns[i] else df.columns[i] for i in range(len(df.columns)) ]
df.columns = [df.columns[i-2] if 'Unnamed' in df.columns[i] else df.columns[i] for i in range(len(df.columns)) ]
df.columns = zip(['' if 'Unnamed' in df.columns[i] else df.columns[i] for i in range(len(df.columns)) ],header2)
df = df.iloc[1:].reset_index(drop=True)
df.columns = [' '.join(df.columns[i]) for i in range(len(df.columns))]
df.rename(columns={df.columns[0]: 'CountryID'},inplace=True)
df.to_excel('Meteorological disasters_mergeHeaders.xlsx',index=False)

# %%
import pandas as pd
import numpy as np
df = pd.read_excel('C:\\Users\\10235555\\Documents\\DataportalCrawlers\\UN_Data\\downloadfolder\\CO2 emissions XLS.xlsx')
nan_value = float("NaN")
df.replace("", nan_value, inplace=True)
df.dropna(how='all', axis=1, inplace=True)
header2 = df.loc[0, :].values.tolist()
header2 = [str(elem).replace('nan','/') for elem in header2]
header = zip(df.columns,header2)
df.set_axis(header, axis=1,inplace=True)
df = df.iloc[1:,:]
df.columns = [' '.join(df.columns[i]) for i in range(len(df.columns))]
df.head()
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_9484\2348475359.py:14: FutureWarning: DataFrame.set_axis 'inplace' keyword is deprecated and will be removed in a future version. Use `obj = obj.set_axis(..., copy=False)` instead
#   df.set_axis(header, axis=1,inplace=True)
#      Country / CO2 emissions  mio. tonnes  % change since 1990 %  \
# 1  Afghanistan                       12.25              357.6712
# 2      Albania                        4.67              -37.6589
# 3      Algeria                      121.76              54.26761
# 4      Andorra                        0.49                   ...
# 5       Angola                       29.71                 570.7
#
#   CO2 emissions per capita tonnes CO2 emissions per km2 tonnes
# 1                         0.42526                     18.76562
# 2                        1.617493                       162.38
# 3                        3.316038                     51.12034
# ...

# %%
import pandas as pd
xls = pd.ExcelFile('C:\\Users\\10235555\\Downloads\\Meteorological disasters.xlsx')
sheets = xls.sheet_names
df = pd.read_excel('C:\\Users\\10235555\\Downloads\\Meteorological disasters.xlsx',sheets[1])
dfdesc = pd.read_excel('C:\\Users\\10235555\\Downloads\\Meteorological disasters.xlsx',sheets[0])
index1 = dfdesc['Unnamed: 0'].index[dfdesc['Unnamed: 0'] == 'Definitions & Technical notes:'].tolist()
description = dfdesc.iloc[(indx+1 for indx in index1),0].tolist()
description
# Out:
# ['Meteorological disasters are defined as hazards caused by short-lived, micro- to meso-scale extreme weather and atmospheric conditions that last from minutes to days. They include extreme temperature, fog, and storm.']

# %%
import pandas as pd
import numpy as np
df = pd.read_excel('C:\\Users\\10235555\\Documents\\DataportalCrawlers\\UN_Data\\downloadfolder\\Actual evapotranspiration XLS.xlsx')
nan_value = float("NaN")
df.replace("", nan_value, inplace=True)
df.dropna(how='all', axis=1, inplace=True)
df.to_excel('test_sheet2.xlsx')

# %%
import pandas as pd
df = pd.read_excel(rf"C:\Users\10235555\Documents\DataportalCrawlers\UN_Data\test_env\Greenhouse gas emissions by sector (absolute values) XLS.xlsx")
index1 = df['Unnamed: 0'].index[df['Unnamed: 0'] == 'Definitions & Technical notes:'].tolist()
description1 = df.iloc[(indx+2 for indx in index1),0].to_string()
description2 = df.iloc[(indx+3 for indx in index1),0].to_string()
description3 = df.iloc[(indx+4 for indx in index1),0].to_string()
description4 = df.iloc[(indx+5 for indx in index1),0].to_string()
description = description1.replace('   ','') + description2.replace('   ','')  + description3.replace('   ','')  + description4.replace('   ','')
index3 = df['Unnamed: 0'].index[df['Unnamed: 0'] == 'Sources:'].tolist()
source1 = df.iloc[(indx+2 for indx in index1),0].to_string()
source2 = df.iloc[(indx+3 for indx in index1),0].to_string()
source3 = df.iloc[(indx+4 for indx in index1),0].to_string()
source4 = df.iloc[(indx+5 for indx in index1),0].to_string()
source = source1.replace('   ','') + source2.replace('   ','') + source3.replace('   ','') + source4.replace('   ','')
BodyDict["JsonDetails"]["description"] = description
BodyDict["JsonDetails"]["additional_data_sources"] = source
if df['Unnamed: 0'].str.contains('Data Quality:').any():
    index2 = df['Unnamed: 0'].index[df['Unnamed: 0'] == 'Data Quality: '].tolist()
    limitations = df.iloc[(ind+2 for ind in index2),0].to_string()
    BodyDict["JsonDetails"]["limitations"] = limitations
source
# Out:
# '211 GHG from Energy: all emissions related to the ...212 GHG from Energy, of which: from Transport: emi...213 GHG from Industrial Processes: emissions from ...214 GHG from Agriculture: all emissions from enter...'
