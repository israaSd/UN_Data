# %%
import pandas as pd
file = r'\\10.30.31.77\data_collection_dump\RawData\DESA_part_3\International Migrant Stock International Migrant Stock 2020 Total, destination.xlsx'
notes = []
xls = pd.ExcelFile(file)
sheets = xls.sheet_names
df_data = pd.read_excel(file,sheets[2])
df_data.iloc[6:10] = df_data.iloc[6:10].fillna(method='ffill', axis=1)
df_data.iloc[6:10] = df_data.iloc[6:10].fillna('')
df_data.columns = df_data.iloc[6:10].apply(lambda x: ' '.join(map(str,[y for y in x if y])), axis=0)
df_data.columns
# df_data = pd.read_excel(file,sheets[2])
# title = df_data.iloc[1,5].replace(':','')
# df_data.iloc[8:10] = df_data.iloc[8:10].fillna(method='ffill', axis=1)
# df_data.iloc[8:10] = df_data.iloc[8:10].fillna('')
# df_data.columns = df_data.iloc[8:10].apply(lambda x: ' '.join(map(str,[y for y in x if y])), axis=0)
# df.columns
# Out:
# Index(['', 'Region, development group, country or area', 'Notes',
#        'Location code', 'Type of data',
#        'Total population at mid-year, both sexes combined (thousands) 1990',
#        'Total population at mid-year, both sexes combined (thousands) 1995.0',
#        'Total population at mid-year, both sexes combined (thousands) 2000.0',
#        'Total population at mid-year, both sexes combined (thousands) 2005.0',
#        'Total population at mid-year, both sexes combined (thousands) 2010.0',
#        'Total population at mid-year, both sexes combined (thousands) 2015.0',
#        'Total population at mid-year, both sexes combined (thousands) 2020.0',
#        'Total population at mid-year, males (thousands) 1990',
#        'Total population at mid-year, males (thousands) 1995',
#        'Total population at mid-year, males (thousands) 2000',
#        'Total population at mid-year, males (thousands) 2005',
#        'Total population at mid-year, males (thousands) 2010',
#        'Total population at mid-year, males (thousands) 2015',
#        'Total population at mid-year, males (thousands) 2020',
#        'Total population at mid-year, females (thousands) 1990',
#        'Total population at mid-year, females (thousands) 1995',
#        'Total population at mid-year, females (thousands) 2000',
#        'Total population at mid-year, females (thousands) 2005',
#        'Total population at mid-year, females (thousands) 2010',
#        'Total population at mid-year, females (thousands) 2015',
#        'Total population at mid-year, females (thousands) 2020'],
#       dtype='object')

# %%
import pandas as pd
definitions = []
sources = []
footnotes = []
file = 'C:\\Users\\10235555\\Documents\\DataportalCrawlers\\UN_Data\\download_test\\Household Size and Composition Country profiles Dataset.xlsx'
xls = pd.ExcelFile(file)
sheets = xls.sheet_names
df_def = pd.read_excel(file,sheets[0])
for i in range(len(df_def.index)):
    f = df_def.iloc[i].to_list()
    f = [' : '.join(map(str,f))]
    definitions.append(f[0])
definition = [' , '.join(map(str,definitions))]
definition = f'{sheets[0]}, ' + definition[0]
# definition
df_source = pd.read_excel(file,sheets[1])
for i in range(len(df_source.index)):
    f = df_source.iloc[i].to_list()
    f = [' : '.join(map(str,f))]
    sources.append(f[0])
source = [' ,\n '.join(map(str,sources))]
# source
df_data = pd.read_excel(file,sheets[2])
df_data[3:]
df_data.iloc[2:4] = df_data.iloc[2:4].fillna(method='ffill', axis=1)
df_data.iloc[2:4] = df_data.iloc[2:4].fillna('')
df_data.columns = df_data.iloc[2:4].apply(lambda x: ' \n '.join(map(str,[y for y in x if y])), axis=0)
df_data = df_data[4:]
df_data.rename(columns={df_data.columns[9]: df_data.columns[9].replace('Households by size\n(percentage ) \n ','')},inplace=True)
df_footnote = pd.read_excel(file,sheets[3])
for i in range(len(df_footnote.index)):
    f = df_footnote.iloc[i].to_list()
    f = [' : '.join(map(str,f))]
    footnotes.append(f[0])
footnote = [' , '.join(map(str,footnotes))]
footnote = f'{sheets[3]}, ' + footnote[0]
footnote
# Out:
# 'Footnote, **For some IPUMS samples, the detail of the household relationship codes is insufficient to identify the full set of household types , ***As with the basic household types described above, for some IPUMS-I extracts, the detail of the household relationship codes is insufficient to identify the several types of intergenerational households. For example, some IPUMS-I samples do not specifically identify grandchildren of the head of household, instead grouping these in the “other relative” category. Some other IPUMS-I samples group parents and grandparents of the head into a single category. In these instances, it is not possible to identify all the potential multi-generation, three-generation and skip-generation households and thus those indicators are not estimated from those samples.                                                                                                                                                                                                                                                                                                                                                    The data compiled in the DYB are tabulations reported by countries’ national statistical offices. It is not possible to obtain estimates of extended family, non-relative households or the intergenerational household types from this source.  For more details, please see United Nations, Department of Economic and Social Affairs, Population Division (2019). Patterns and trends in household size and composition: Evidence from a United Nations dataset. (ST/ESA/SER.A/433).\n , *****For some MICS samples, the detail of the household relationship codes is insufficient to identify the full set of household types , ***** The sample weights were not  provided in datasets for the following MICS surveys  Azerbaijan 2000 MICS, Bosnia and Herzegovina 2000 MICS ,Burundi 2000 MICS , Lesotho 2000 MICS, South Sudan 2000 MICS2, Taijikistan 2000 MICS2, Trinidad and Tobago 2000 MICS2, Uzbekistan 2000 MICS2 '

# %%
import pandas as pd
note = []
file = 'C:\\Users\\10235555\\Documents\\DataportalCrawlers\\UN_Data\\download_test\\International Migrant StockInternational Migrant Stock 2020  Age and sex.xlsx'
xls = pd.ExcelFile(file)
sheets = xls.sheet_names
df = pd.read_excel(file,sheets[1])
df[6:].head(4)
# Out:
#   Unnamed: 0 Unnamed: 1                                  Unnamed: 2  \
# 6        NaN        NaN                                         NaN
# 7        NaN        NaN                                         NaN
# 8        NaN        NaN                                         NaN
# 9      Index       Year  Region, development group, country or area
#
#   Unnamed: 3     Unnamed: 4    Unnamed: 5  \
# 6        NaN            NaN           NaN
# 7        NaN            NaN           NaN
# 8        NaN            NaN           NaN
# 9      Notes  Location code  Type of data
#
#                                           Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 6  International migrant stock at mid-year by age...        NaN        NaN
# 7                                                NaN        NaN        NaN
# 8                                                NaN        NaN        NaN
# 9                                                0-4        5-9      10-14
#
#   Unnamed: 9  ... Unnamed: 47 Unnamed: 48 Unnamed: 49 Unnamed: 50 Unnamed: 51  \
# 6        NaN  ...         NaN         NaN         NaN         NaN         NaN
# 7        NaN  ...         NaN         NaN         NaN         NaN         NaN
# 8        NaN  ...         NaN         NaN         NaN         NaN         NaN
# 9      15-19  ...       35-39       40-44       45-49       50-54       55-59
#
#   Unnamed: 52 Unnamed: 53 Unnamed: 54 Unnamed: 55 Unnamed: 56
# 6         NaN         NaN         NaN         NaN         NaN
# 7         NaN         NaN         NaN         NaN         NaN
# 8         NaN         NaN         NaN         NaN         NaN
# 9       60-64       65-69       70-74         75+       Total
#
# [4 rows x 57 columns]

# %%
import pandas as pd
note = []
file = 'C:\\Users\\10235555\\Documents\\DataportalCrawlers\\UN_Data\\download_test\\International Migrant Stock International Migrant Stock 2020 Destination and origin.xlsx'
xls = pd.ExcelFile(file)
sheets = xls.sheet_names
df_data = pd.read_excel(file,sheets[2])
title = df_data.iloc[1,4].replace(':','')
df_data.iloc[6:10] = df_data.iloc[6:10].fillna(method='ffill', axis=1)
df_data.iloc[6:10] = df_data.iloc[6:10].fillna('')
df_data.columns = df_data.iloc[6:10].apply(lambda x: ' '.join(map(str,[y for y in x if y])), axis=0)
df_data = df_data[10:] 
df_data.columns
# Out:
# Index(['Index', 'Region, development group of destination Index',
#        'Region, development group of destination Notes of destination',
#        'Region, development group of destination Location code of destination',
#        'International migrant stock at mid-year by major area or region of origin, 2020 WORLD 900',
#        'International migrant stock at mid-year by major area or region of origin, 2020   Sub-Saharan Africa 947',
#        'International migrant stock at mid-year by major area or region of origin, 2020   Northern Africa and Western Asia 1833',
#        'International migrant stock at mid-year by major area or region of origin, 2020   Central and Southern Asia 921',
#        'International migrant stock at mid-year by major area or region of origin, 2020   Eastern and South-Eastern Asia 1832',
#        'International migrant stock at mid-year by major area or region of origin, 2020   Latin America and the Caribbean 1830',
#        'International migrant stock at mid-year by major area or region of origin, 2020   Oceania (excluding Australia and New Zealand) 1835',
#        'International migrant stock at mid-year by major area or region of origin, 2020   Australia and New Zealand 927',
#        'International migrant stock at mid-year by major area or region of origin, 2020   Europe and Northern America 1829',
#        'International migrant stock at mid-year by major area or region of origin, 2020   Developed regions 901',
#        'International migrant stock at mid-year by major area or region of origin, 2020   Less developed regions 902',
#        'International migrant stock at mid-year by major area or region of origin, 2020  Less developed regions, excluding least developed countries 934',
#        'International migrant stock at mid-year by major area or region of origin, 2020  Less developed regions, excluding China 948',
#        'International migrant stock at mid-year by major area or region of origin, 2020   Least developed countries 941',
#        'International migrant stock at mid-year by major area or region of origin, 2020   Land-locked Developing Countries (LLDC) 1636',
#        'International migrant stock at mid-year by major area or region of origin, 2020   Small island developing States (SIDS) 1637',
#        'International migrant stock at mid-year by major area or region of origin, 2020   High-income countries 1503',
#        'International migrant stock at mid-year by major area or region of origin, 2020   Middle-income countries 1517',
#        'International migrant stock at mid-year by major area or region of origin, 2020  Upper-middle-income countries 1502',
#        'International migrant stock at mid-year by major area or region of origin, 2020  Lower-middle-income countries 1501',
#        'International migrant stock at mid-year by major area or region of origin, 2020   Low-income countries 1500',
#        'International migrant stock at mid-year by major area or region of origin, 2020  AFRICA 903',
#        'International migrant stock at mid-year by major area or region of origin, 2020   Eastern Africa 910',
#        'International migrant stock at mid-year by major area or region of origin, 2020   Middle Africa 911',
#        'International migrant stock at mid-year by major area or region of origin, 2020   Northern Africa 912',
#        'International migrant stock at mid-year by major area or region of origin, 2020   Southern Africa 913',
#        'International migrant stock at mid-year by major area or region of origin, 2020   Western Africa 914',
#        'International migrant stock at mid-year by major area or region of origin, 2020  ASIA 935',
#        'International migrant stock at mid-year by major area or region of origin, 2020   Central Asia 5500',
#        'International migrant stock at mid-year by major area or region of origin, 2020   Eastern Asia 906',
#        'International migrant stock at mid-year by major area or region of origin, 2020   South-Eastern Asia 920',
#        'International migrant stock at mid-year by major area or region of origin, 2020   Southern Asia 5501',
#        'International migrant stock at mid-year by major area or region of origin, 2020   Western Asia 922',
#        'International migrant stock at mid-year by major area or region of origin, 2020  EUROPE 908',
#        'International migrant stock at mid-year by major area or region of origin, 2020   Eastern Europe 923',
#        'International migrant stock at mid-year by major area or region of origin, 2020   Northern Europe 924',
#        'International migrant stock at mid-year by major area or region of origin, 2020   Southern Europe 925',
#        'International migrant stock at mid-year by major area or region of origin, 2020   Western Europe 926',
#        'International migrant stock at mid-year by major area or region of origin, 2020  LATIN AMERICA AND THE CARIBBEAN 904',
#        'International migrant stock at mid-year by major area or region of origin, 2020   Caribbean 915',
#        'International migrant stock at mid-year by major area or region of origin, 2020   Central America 916',
#        'International migrant stock at mid-year by major area or region of origin, 2020   South America 931',
#        'International migrant stock at mid-year by major area or region of origin, 2020  NORTHERN AMERICA 905',
#        'International migrant stock at mid-year by major area or region of origin, 2020  OCEANIA  909',
#        'International migrant stock at mid-year by major area or region of origin, 2020   Australia and New Zealand 927',
#        'International migrant stock at mid-year by major area or region of origin, 2020   Melanesia 928',
#        'International migrant stock at mid-year by major area or region of origin, 2020   Micronesia 954',
#        'International migrant stock at mid-year by major area or region of origin, 2020   Polynesia* 957',
#        'International migrant stock at mid-year by major area or region of origin, 2020 OTHER 2003'],
#       dtype='object')

# %%
import pandas as pd
note = []
file = 'C:\\Users\\10235555\\Documents\\DataportalCrawlers\\UN_Data\\download_test\\International Migrant Stock International Migrant Stock 2020 Destination and origin.xlsx'
xls = pd.ExcelFile(file)
sheets = xls.sheet_names
for sheet in sheets:
    
    if sheet=='Table of contents':
        print(sheet)    
    elif sheet=='Notes':
        df_note = pd.read_excel(file,sheet)
        df_note = df_note.iloc[10:,0:2]
        for i in range(len(df_note.index)):
            f = df_note.iloc[i].to_list()
            f = [' : '.join(map(str,f))]
            note.append(f[0])
    else:
        df_data = pd.read_excel(file,sheet)
        title = df_data.iloc[1,4].replace(':','')
        df_data.iloc[6:10] = df_data.iloc[6:10].fillna(method='ffill', axis=1)
        df_data.iloc[6:10] = df_data.iloc[6:10].fillna('')
        df_data.columns = df_data.iloc[6:10].apply(lambda x: ' \n '.join(map(str,[y for y in x if y])), axis=0)
        df_data = df_data[10:] 
        # # df_data.to_excel(f'{title}.xlsx',index=False)
        # print(title)

notes = [' , '.join(map(str,note))]
notes = 'Notes, ' + notes[0]
df_data.head()
# Out:
# Table of contents
#    Index Region, development group, country or area Notes Location code  \
# 10     1                                      WORLD   NaN           900
# 11     2                         Sub-Saharan Africa   NaN           947
# 12     3           Northern Africa and Western Asia   NaN          1833
# 13     4                  Central and Southern Asia   NaN           921
# 14     5             Eastern and South-Eastern Asia   NaN          1832
#
#    Type of data  \
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
#
#    Female migrants as a percentage of the international migrant stock \n 1990  \
# 10                                          49.300336
# 11                                          46.938726
# 12                                          46.044025
# 13                                          45.168914
# 14                                          49.813587
#
#    Female migrants as a percentage of the international migrant stock \n 1995  \
# 10                                          49.419361
# 11                                          47.372065
# 12                                          45.602838
# 13                                          44.814336
# 14                                          50.384653
#
#    Female migrants as a percentage of the international migrant stock \n 2000  \
# 10                                          49.362387
# 11                                          47.265842
# 12                                          44.763198
# 13                                          44.399177
# 14                                          51.026055
#
#    Female migrants as a percentage of the international migrant stock \n 2005  \
# 10                                          48.986838
# 11                                          46.587172
# 12                                          44.680096
# 13                                          43.336753
# 14                                          51.140356
#
#    Female migrants as a percentage of the international migrant stock \n 2010  \
# 10                                          48.439118
# 11                                          47.193172
# 12                                          43.708518
# 13                                          40.499644
# 14                                          51.154523
#
#    Female migrants as a percentage of the international migrant stock \n 2015  \
# 10                                          48.282481
# 11                                          48.017364
# 12                                          44.251743
# 13                                          39.822664
# 14                                          51.284915
#
#    Female migrants as a percentage of the international migrant stock \n 2020
# 10                                          48.090938
# 11                                           47.91217
# 12                                          44.252076
# 13                                           39.07505
# 14                                          51.037631

# %%
import pandas as pd
note = []
file = f'{base_path_test}\\{title_f}'
df = pd.read_excel(file)
title = df.iloc[7,0]
df.columns = df.iloc[15,:].to_list()
df.rename(columns={df.columns[0]: 'Reporting country \n CntName'},inplace=True)
df = df[16:]
df.to_excel(f'{base_path_test}\\{title}.xlsx',index=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [1], line 4
#       2 note = []
#       3 file = 'C:\\Users\\10235555\\Documents\\DataportalCrawlers\\UN_Data\\download_test\\International Migration FlowsDataset (by citizenship, by residence and by birth)Dataset (by citizenship, by residence and by birth).xlsx'
# ----> 4 df = pd.read_excel(file)
#       5 title = df.iloc[7,0]
#       6 df.columns = df.iloc[15,:].to_list()
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\excel\_base.py:482, in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     480 if not isinstance(io, ExcelFile):
#     481     should_close = True
# --> 482     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     483 elif engine and engine != io.engine:
#     484     raise ValueError(
#     485         "Engine should not be specified when passing "
#     486         "an ExcelFile - ExcelFile already has the engine set"
#     487     )
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\excel\_base.py:1652, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options)
#    1650     ext = "xls"
#    1651 else:
# -> 1652     ext = inspect_excel_format(
#    1653         content_or_path=path_or_buffer, storage_options=storage_options
#    1654     )
#    1655     if ext is None:
#    1656         raise ValueError(
#    1657             "Excel file format cannot be determined, you must specify "
#    1658             "an engine manually."
#    1659         )
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\excel\_base.py:1525, in inspect_excel_format(content_or_path, storage_options)
#    1522 if isinstance(content_or_path, bytes):
#    1523     content_or_path = BytesIO(content_or_path)
# -> 1525 with get_handle(
#    1526     content_or_path, "rb", storage_options=storage_options, is_text=False
#    1527 ) as handle:
#    1528     stream = handle.handle
#    1529     stream.seek(0)
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\common.py:865, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     856         handle = open(
#     857             handle,
#     858             ioargs.mode,
#    (...)
#     861             newline="",
#     862         )
#     863     else:
#     864         # Binary mode
# --> 865         handle = open(handle, ioargs.mode)
#     866     handles.append(handle)
#     868 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\10235555\\Documents\\DataportalCrawlers\\UN_Data\\download_test\\International Migration FlowsDataset (by citizenship, by residence and by birth)Dataset (by citizenship, by residence and by birth).xlsx'

# %%
import pandas as pd
definitions = []
sources = []
footnotes = []
file = 'C:\\Users\\10235555\\Documents\\DataportalCrawlers\\UN_Data\\download_test\\Living Arrangements of Older Persons Older persons in household living arrangements Dataset.xlsx'
xls = pd.ExcelFile(file)
sheets = xls.sheet_names

df_info_note = pd.read_excel(file,sheets[0])
info_note = df_info_note.iloc[3,1]
df_def = pd.read_excel(file,sheets[1])
for i in range(len(df_def.index)):
    f = df_def.iloc[i].to_list()
    f = [' : '.join(map(str,f))]
    definitions.append(f[0])
definition = [' ,\n '.join(map(str,definitions))][0]
df_source = pd.read_excel(file,sheets[2])
for i in range(len(df_source.index)):
    f = df_source.iloc[i].to_list()
    f = [' : '.join(map(str,f))]
    sources.append(f[0])
source = [' ,\n '.join(map(str,sources))][0]
df_footnote = pd.read_excel(file,sheets[4])
# df_footnote = df_footnote.iloc[:,0]
for i in range(len(df_footnote.index)):
    f = df_footnote.iloc[i].to_list()
    footnotes.append(f[0])
footnote = [' ,\n '.join(map(str,footnotes))][0]
df_data = pd.read_excel(file,sheets[3])
title = df_data.iloc[1,0].split('\n\n\nCopyright')[0]
df_data.iloc[2:4] = df_data.iloc[2:4].fillna(method='ffill', axis=1)
df_data.iloc[2:4] = df_data.iloc[2:4].fillna('')
df_data.columns = df_data.iloc[2:4].apply(lambda x: ' \n '.join(map(str,[y for y in x if y])), axis=0)
df_data = df_data[4:]
df_data.to_excel(f'{title}.xlsx',index=False)

# %%
import pandas as pd
exp_notes = []
notes = []
file = 'C:\\Users\\10235555\\Documents\\DataportalCrawlers\\UN_Data\\download_test\\SDG Indicator 10.7.2 on Migration Policies Country data.xlsx'
xls = pd.ExcelFile(file)
sheets = xls.sheet_names
for sheet in sheets:
    if 'contents' in sheet:
        print(sheet)
    elif 'notes' in sheet:
        df_exp_note = pd.read_excel(file,sheet)
        df_exp_note = df_exp_note[11:]
        for i in range(len(df_exp_note.index)):
            f = df_exp_note.iloc[i].to_list()
            f = [' : '.join(map(str,f))]
            exp_notes.append(f[0])
        exp_note = [' ,\n '.join(map(str,exp_notes))][0]
    else:
        df_data = pd.read_excel(file,sheet)
        title = df_data.iloc[5,3]#.replace(':','')
        print(title)
        # df_data.iloc[10:13] = df_data.iloc[10:13].fillna(method='ffill', axis=1)
        # df_data.iloc[10:13] = df_data.iloc[10:13].fillna('')
        # df_data.columns = df_data.iloc[10:13].apply(lambda x: ' \n '.join(map(str,[y for y in x if y])), axis=0)
        # ind = df_data.iloc[:,0].index[df_data.iloc[:,0]== 'Notes: '].to_list()
        # df_note = df_data[ind[0]:]
        # for i in range(len(df_note.index)):
        #     f = df_note.iloc[i].to_list()
        #     notes.append(f[0])
        # note = [' ,\n '.join(map(str,notes))][0]
        # df_data = df_data.iloc[13:,1:]
# Out:
# Table of contents
# Table 1: SDG indicator 10.7.2. by country and domain ordered by SDG region and subregion, 2021
# Table 2: SDG indicator 10.7.2. by country and domain sub-category ordered by SDG region and subregion, 2021

# %%
import pandas as pd
info_notes = []
descriptions = []
file = 'C:\\Users\\10235555\\Documents\\DataportalCrawlers\\UN_Data\\download_test\\World Contraceptive UseData portal Dataset.xlsx'
xls = pd.ExcelFile(file)
sheets = xls.sheet_names
df_info_note =  pd.read_excel(file,sheets[0])
info_note = df_info_note.iloc[6,1]
df_desc = pd.read_excel(file,sheets[1])
df_desc = df_desc.iloc[:,1:]
for i in range(len(df_desc.index)):
    f = df_desc.iloc[i].to_list()
    f = [' : '.join(map(str,f))]
    descriptions.append(f[0])
description = [' ,\n '.join(map(str,descriptions))][0]
# for last 2 sheet
for sheet in sheets[2:4]:
    df_data = pd.read_excel(file,sheets[3])
    title = df_data.iloc[1,4]
    df_data.iloc[6:8] = df_data.iloc[6:8].fillna(method='ffill', axis=1)
    df_data.iloc[6:8] = df_data.iloc[6:8].fillna('')
    df_data.columns = df_data.iloc[6:8].apply(lambda x: ' \n '.join(map(str,[y for y in x if y])), axis=0)
    df_data = df_data[8:]

# %%
import pandas as pd
info_notes = []
descriptions = []
file = 'C:\\Users\\10235555\\Documents\\DataportalCrawlers\\UN_Data\\download_test\\World Marriage Data Dataset.xlsx'
xls = pd.ExcelFile(file)
sheets = xls.sheet_names
df_info_note =  pd.read_excel(file,sheets[0])
info_note = df_info_note.iloc[4,1]
df_desc = pd.read_excel(file,sheets[1])
df_desc = df_desc.iloc[:,1:]
for i in range(len(df_desc.index)):
    f = df_desc.iloc[i].to_list()
    f = [' : '.join(map(str,f))]
    descriptions.append(f[0])
description = [' ,\n '.join(map(str,descriptions))][0]
for sheet in sheets[2:]:
    df_data = pd.read_excel(file,sheet)
    title = df_data.columns[0]
    title = title.replace('  \n','').replace(' \n','').replace('\n','')
    df_data.columns = df_data.iloc[1].to_list()
    df_data = df_data[2:]
    df_data.to_excel(f'{title}.xlsx',index=False)

# %%
file = 'C:\\Users\\10235555\\Documents\\DataportalCrawlers\\UN_Data\\download_test\\World Population Policies International migration  Country data.xlsx'
import pandas as pd
notes = []

xls = pd.ExcelFile(file)
sheets = xls.sheet_names
for sheet in sheets:
    df = pd.read_excel(file,sheet)
    title = df.iloc[1,4].replace(':','')
    df.iloc[5:9] = df.iloc[5:9].fillna(method='ffill', axis=1)
    df.iloc[5:9] = df.iloc[5:9].fillna('')
    df.columns = df.iloc[5:9].apply(lambda x: ' \n '.join(map(str,[y for y in x if y])), axis=0)

    ind = df.iloc[:,0].index[df.iloc[:,0]== 'Notes: '].to_list()
    df_note = df[ind[0]:]
    for i in range(len(df_note.index)):
        f = df_note.iloc[i,0:2].to_list()
        f = [' : '.join(map(str,f))]
        notes.append(f[0])
    note = [' ,\n '.join(map(str,notes))][0]
    df = df.iloc[9:,1:]
# Out:
# 'Notes:  : nan ,\n The designations employed in this publication and the material presented in it do not imply the expression of any opinion whatsoever on the part of the Secretariat of the United Nations concerning the legal status of any country, territory, city or area or of its authorities, or concerning the delimitation of its frontiers or boundaries.\n\n\n\n\n : nan ,\n In this table, data for countries or areas have been aggregated in six continental regions: Africa, Asia, Europe, Latin America and the Caribbean, Northern America, and Oceania. Further information on continental regions is available from https://unstats.un.org/unsd/methodology/m49/. Countries or areas are also grouped into geographic regions based on the classification being used to track progress towards the Sustainable Development Goals of the United Nations (see: https://unstats.un.org/sdgs/indicators/regional-groups/).   : nan ,\n — : Indicates that a country did not respond to the Inquiry. ,\n ..  : Indicates that a country did not provide information for the subcategory.'

# %%
file = 'C:\\Users\\10235555\\Documents\\DataportalCrawlers\\UN_Data\\download_test\\World Population Policies Reproductive health  Global and regional data.xlsx'
import pandas as pd
notes = []

xls = pd.ExcelFile(file)
sheets = xls.sheet_names
df = pd.read_excel(file,sheets[0])
title = df.iloc[1,4].replace(':','')
df.iloc[6:10] = df.iloc[6:10].fillna(method='ffill', axis=1)
df.iloc[6:10] = df.iloc[6:10].fillna('')
df.columns = df.iloc[6:10].apply(lambda x: ' \n '.join(map(str,[y for y in x if y])), axis=0)
ind = df.iloc[:,0].index[df.iloc[:,0]== 'Notes: '].to_list()
df_note = df[ind[0]:]
for i in range(len(df_note.index)):
    f = df_note.iloc[i,0:2].to_list()
    f = [' : '.join(map(str,f))]
    notes.append(f[0])
note = [' ,\n '.join(map(str,notes))][0]
df = df.iloc[10:,1:]

# %%
import os
import shutil
base_path = 'C:\\Users\\10235555\\Documents\\DataportalCrawlers\\UN_Data\\download_test'
for zipfile in os.listdir(base_path):
            if zipfile.endswith(".zip"):
                filename = zipfile.split(".zip")[0]
                shutil.unpack_archive(f"{base_path}\{zipfile}", base_path)
                print(zipfile)
                # os.remove(f"{base_path}\\{zipfile}")
# Out:
# Family Planning IndicatorsDatasetDataset.zip

# %%
'C:\Users\10235555\Documents\DataportalCrawlers\UN_Data\downloadfolder2\Urban-Rural-Areas'
'C:\Users\10235555\Documents\DataportalCrawlers\UN_Data\downloadfolder2\WUP2003_DOCUMENTATION'
'C:\Users\10235555\Documents\DataportalCrawlers\UN_Data\downloadfolder2\WUP2005_DOCUMENTATION'
'C:\Users\10235555\Documents\DataportalCrawlers\UN_Data\downloadfolder2\WUP2007_DOCUMENTATION'
# like previous for file start with 'WUP'


'C:\Users\10235555\Documents\DataportalCrawlers\UN_Data\downloadfolder2\WUP2003_EXCEL_DATA_SETS'
'C:\Users\10235555\Documents\DataportalCrawlers\UN_Data\downloadfolder2\WUP2005_EXCEL_DATA_SETS'
'C:\Users\10235555\Documents\DataportalCrawlers\UN_Data\downloadfolder2\WUP2007_XLS_CD_FILES'
'C:\Users\10235555\Documents\DataportalCrawlers\UN_Data\downloadfolder2\WUP2011_XLS_CD_FILES'
# LIKE previous BUT -1 for index (start line 13 not 14)

'C:\Users\10235555\Documents\DataportalCrawlers\UN_Data\downloadfolder2\WUP2009_XLS_CD_FILES'
# LIKE previous BUT -3 for index (start line 11 not 14)

'C:\Users\10235555\Documents\DataportalCrawlers\UN_Data\downloadfolder2\WUP2011_DOCUMENTATION'
# LIKE previous BUT -2 for index (start line 12 not 14)

'C:\Users\10235555\Documents\DataportalCrawlers\UN_Data\downloadfolder2\WUP2009_DOCUMENTATION'
# from line 10 in file

'C:\Users\10235555\Documents\DataportalCrawlers\UN_Data\downloadfolder2\WUP2014_DOCUMENTATION'
'C:\Users\10235555\Documents\DataportalCrawlers\UN_Data\downloadfolder2\WUP2014_XLS_CD_FILES'
# from line 16-17 oin file

# %%
base_path_2 = 'C:\\Users\\10235555\\Documents\\DataportalCrawlers\\UN_Data\\downloadfolder2'
# from zipfile import ZipFile
# for file in base_path_2:
for folders in os.listdir(base_path_2):
    if folders.startswith("WUP2"):
        for files in os.listdir(f'{base_path_2}\\{folders}'):
            if files.endswith('xls'):
                print(files)
                shutil.move(f'{base_path_2}\\{folders}\\{files}',f'{base_path_2}\\{files}')
    # if folders.startswith('Urban'):
    #     for files in os.listdir(f'{base_path_2}\\{folders}'):
    #         if files.endswith('XLS'):
    #             shutil.move(f'{base_path_2}\\{folders}\\{files}',f'{base_path_2}\\{files}')
    #         if files.endswith('xls'):
    #             print(files)
    #             shutil.move(f'{base_path_2}\\{folders}\\{files}',f'{base_path_2}\\{files}')

        

        # shutil.move(f'{base_path_2}\\{folders}',f'{base_path_2}')
# Out:
# WUP2003-A-DESCRIPTION.xls
# WUP2003-B-DESCRIPTION.xls
# WUP2003F1-Total_Population.xls
# WUP2003F10-Cities_Over_750K.xls
# WUP2003F11-Growth_Rate_Cities.xls
# WUP2003F12-Percentage_Urban_in_Cities.xls
# WUP2003F13-Percentage_Total_in_Cities.xls
# WUP2003F14-30_Largest_Cities.xls
# WUP2003F15-Capital_Cities.xls
# WUP2003F16-City_Size_Class.xls
# WUP2003F2-Urban_Population.xls
# WUP2003F3-Rural_Population.xls
# WUP2003F4-Proportion_Urban.xls
# WUP2003F5-Total_Growth_Rate.xls
# WUP2003F6-Urban_Growth_Rate.xls
# WUP2003F7-Rural_Growth_Rate.xls
# WUP2003F8-Urbanization_Rate.xls
# WUP2003F9-Rate_Proportion_Rural.xls
# WUP2005-A-DESCRIPTION.xls
# WUP2005-B-DESCRIPTION.xls
# WUP2005F1-Total_Population.xls
# WUP2005F10-Cities_Over_750K.xls
# WUP2005F11-Growth_Rate_Cities.xls
# WUP2005F12-Percentage_Urban_in_Cities.xls
# WUP2005F13-Percentage_Total_in_Cities.xls
# WUP2005F14-30_Largest_Cities.xls
# WUP2005F15-Capital_Cities.xls
# WUP2005F16-City_Size_Class.xls
# WUP2005F2-Urban_Population.xls
# WUP2005F21-Total_Population_Annual.xls
# WUP2005F22-Urban_Population_Annual.xls
# WUP2005F23-Rural_Population_Annual.xls
# WUP2005F24-Proportion_Urban_Annual.xls
# WUP2005F25-Cities_Over_750K_Annual.xls
# WUP2005F3-Rural_Population.xls
# WUP2005F4-Proportion_Urban.xls
# WUP2005F5-Total_Growth_Rate.xls
# WUP2005F6-Urban_Growth_Rate.xls
# WUP2005F7-Rural_Growth_Rate.xls
# WUP2005F8-Urbanization_Rate.xls
# WUP2005F9-Rate_Proportion_Rural.xls
# WPP2007-F00-Locations.xls
# WUP2007-F01-Total_Urban_Rural.xls
# WUP2007-F02-Proportion_Urban.xls
# WUP2007-F03-Urban_Population.xls
# WUP2007-F04-Rural_Population.xls
# WUP2007-F05-Total_Population.xls
# WUP2007-F06-Urban_Growth_Rate.xls
# WUP2007-F07-Rural_Growth_Rate.xls
# WUP2007-F08-Total_Growth_Rate.xls
# WUP2007-F09-Urbanization_Rate.xls
# WUP2007-F10-Rate_Proportion_Rural.xls
# WUP2007-F11a-30_Largest_Cities.xls
# WUP2007-F11b-30_Largest_Cities_in_2007_by_time.xls
# WUP2007-F12-Cities_Over_750K.xls
# WUP2007-F13-Capital_Cities.xls
# WUP2007-F14-Growth_Rate_Cities.xls
# WUP2007-F15-Percentage_Urban_in_Cities.xls
# WUP2007-F16-Percentage_Total_in_Cities.xls
# WUP2007-F17a-City_Size_Class.xls
# WUP2007-F17b-City_Size_Class-Number.xls
# WUP2007-F17c-City_Size_Class-Percentage.xls
# WUP2007-F17d-City_Size_Class-Population.xls
# WUP2007-F18-Total_Population_Annual.xls
# WUP2007-F19-Urban_Population_Annual.xls
# WUP2007-F20-Rural_Population_Annual.xls
# WUP2007-F21-Proportion_Urban_Annual.xls
# WUP2007-F22-Cities_Over_750K_Annual.xls
# WUP2009-DataSource-UrbanAgglomeration-and-CapitalCities.xls
# WUP2009-DataSource-UrbanPopulation.xls
# WUP2009-F01-Total_Urban_Rural.xls
# WUP2009-F02-Proportion_Urban.xls
# WUP2009-F03-Urban_Population.xls
# WUP2009-F04-Rural_Population.xls
# WUP2009-F05-Total_Population.xls
# WUP2009-F06-Urban_Growth_Rate.xls
# WUP2009-F07-Rural_Growth_Rate.xls
# WUP2009-F08-Total_Growth_Rate.xls
# WUP2009-F09-Urbanization_Rate.xls
# WUP2009-F10-Rate_Proportion_Rural.xls
# WUP2009-F11a-30_Largest_Cities.xls
# WUP2009-F11b-30_Largest_Cities_in_2009_by_time.xls
# WUP2009-F12-Cities_Over_750K.xls
# WUP2009-F13-Capital_Cities.xls
# WUP2009-F14-Growth_Rate_Cities.xls
# WUP2009-F15-Percentage_Urban_in_Cities.xls
# WUP2009-F16-Percentage_Total_in_Cities.xls
# WUP2009-F17a-City_Size_Class.xls
# WUP2009-F17b-City_Size_Class-Number.xls
# WUP2009-F17c-City_Size_Class-Percentage.xls
# WUP2009-F17d-City_Size_Class-Population.xls
# WUP2009-F18-Total_Population_Annual.xls
# WUP2009-F19-Urban_Population_Annual.xls
# WUP2009-F20-Rural_Population_Annual.xls
# WUP2009-F21-Proportion_Urban_Annual.xls
# WUP2009-F22-Cities_Over_750K_Annual.xls
# WUP2009-F23-Largest_City_in_2009_Annual.xls
# WUP2011-DataSource-UrbanAgglomeration-and-CapitalCities.xls
# WUP2011-DataSource-UrbanPopulation.xls
# WUP2011-F01-Total_Urban_Rural.xls
# WUP2011-F02-Proportion_Urban.xls
# WUP2011-F03-Urban_Population.xls
# WUP2011-F04-Rural_Population.xls
# WUP2011-F05-Total_Population.xls
# WUP2011-F06-Urban_Growth_Rate.xls
# WUP2011-F07-Rural_Growth_Rate.xls
# WUP2011-F08-Total_Growth_Rate.xls
# WUP2011-F09-Urbanization_Rate.xls
# WUP2011-F10-Rate_Proportion_Rural.xls
# WUP2011-F11a-30_Largest_Cities.xls
# WUP2011-F11b-30_Largest_Cities_in_2011_by_time.xls
# WUP2011-F12-Cities_Over_750K.xls
# WUP2011-F13-Capital_Cities.xls
# WUP2011-F14-Growth_Rate_Cities.xls
# WUP2011-F15-Percentage_Urban_in_Cities.xls
# WUP2011-F16-Percentage_Total_in_Cities.xls
# WUP2011-F17a-City_Size_Class.xls
# WUP2011-F17b-City_Size_Class-Number.xls
# WUP2011-F17c-City_Size_Class-Percentage.xls
# WUP2011-F17d-City_Size_Class-Population.xls
# WUP2011-F18-Total_Population_Annual.xls
# WUP2011-F19-Urban_Population_Annual.xls
# WUP2011-F20-Rural_Population_Annual.xls
# WUP2011-F21-Proportion_Urban_Annual.xls
# WUP2011-F22-Cities_Over_750K_Annual.xls
# WUP2011-F23-City_Risk_Natural-Disasters.xls
# WUP2014-DataSource-UrbanAgglomeration-and-CapitalCities.xls
# WUP2014-DataSource-UrbanPopulation.xls
# WUP2014-F00-Locations.xls
# WUP2014-F01-Total_Urban_Rural.xls
# WUP2014-F02-Proportion_Urban.xls
# WUP2014-F03-Urban_Population.xls
# WUP2014-F04-Rural_Population.xls
# WUP2014-F05-Total_Population.xls
# WUP2014-F06-Urban_Growth_Rate.xls
# WUP2014-F07-Rural_Growth_Rate.xls
# WUP2014-F08-Total_Growth_Rate.xls
# WUP2014-F09-Urbanization_Rate.xls
# WUP2014-F10-Rate_Proportion_Rural.xls
# WUP2014-F11a-30_Largest_Cities.xls
# WUP2014-F11b-30_Largest_Cities_in_2014_by_time.xls
# WUP2014-F12-Cities_Over_300K.xls
# WUP2014-F13-Capital_Cities.xls
# WUP2014-F14-Growth_Rate_Cities.xls
# WUP2014-F15-Percentage_Urban_in_Cities.xls
# WUP2014-F16-Percentage_Total_in_Cities.xls
# WUP2014-F17a-City_Size_Class.xls
# WUP2014-F17b-City_Size_Class-Number.xls
# WUP2014-F17c-City_Size_Class-Percentage.xls
# WUP2014-F17d-City_Size_Class-Population.xls
# WUP2014-F18-Total_Population_Annual.xls
# WUP2014-F19-Urban_Population_Annual.xls
# WUP2014-F20-Rural_Population_Annual.xls
# WUP2014-F21-Proportion_Urban_Annual.xls
# WUP2014-F22-Cities_Over_300K_Annual.xls

# %%
path = 'C:\\Users\\10235555\\Documents\\DataportalCrawlers\\UN_Data\\downloadfolder2'
file = f'{path}\\WUP1999F5-Growth_Rate.xls'
import pandas as pd
notes = []

xls = pd.ExcelFile(file)
sheets = xls.sheet_names
data = pd.read_excel(file,sheets[0])
title = data.iloc[8,0] 
data.columns = data.iloc[12].to_list()
data = data[13:]
data_note = pd.read_excel(file,sheets[1])
for i in range(len(data_note.index)):
    f = data_note.iloc[i].to_list()
    notes.append(f[0])
note = [' ,\n '.join(map(str,notes))][0]
# fi source in note
# ma bekhod desciption dataset
# Out:
# '(a) The more developed regions comprise all regions of Europe, Northern America, Australia/New Zealand and Japan. ,\n (b) The less developed regions comprise all regions of Africa, Asia (excluding Japan), Latin America and the Caribbean, Melanesia, Micronesia and Polynesia. ,\n (c) The least developed countries, as defined by the United Nations General Assembly in 1998, include 48 countries: 33 in Africa, 9 in Asia, 1 in Latin America and 5 in Oceania.  These countries are also included in the less developed regions. ,\n (1) Included Agalega, Rodrigues and St. Brandon. ,\n (2) Including Ascension and Tristan da Cunha. ,\n (3) For statistical purposes, the data for China do not include Hong Kong Special Administrative Region (SAR) of China ,\n (4) As of 1 July 1997, Hong Kong became a Special Administrative Region (SAR) of China. ,\n (5) Refers to the Vatican City State. ,\n (6) The former Yugoslav Republic of Macedonia. ,\n (7) Including Christmas Island, Cocos (Keeling) Islands and Norfolk Island. ,\n Source:  Population Division of the Department of Economic and Social Affairs of the United Nations Secretariat, World Urbanization Prospects: The 1999 Revision. Part 1: Urban and Rural Areas  (POP/DB/WUP/Rev.1999/1/F5), data set in digital form.'

# %%
path = ''
file = f'C:\\Users\\10235555\\Documents\\DataportalCrawlers\\UN_Data\\downloadfolder2\\WUP1999F10-Cities_Over_750K.xls'
import pandas as pd
notes = []

xls = pd.ExcelFile(file)
sheets = xls.sheet_names
data = pd.read_excel(file,sheets[0])
title = data.iloc[8,0] + + ' ' + data.iloc[9,0]
data.columns = data.iloc[13].to_list()
data = data[14:]
data_note = pd.read_excel(file,sheets[1])
for i in range(len(data_note.index)):
    f = data_note.iloc[i].to_list()
    notes.append(f[0])
note = [' ,\n '.join(map(str,notes))][0]

# %%
path = 'C:\\Users\\10235555\\Documents\\DataportalCrawlers\\UN_Data\\downloadfolder2'
file = f'{path}\\WUP2003F1-Total_Population.xls'
import pandas as pd
notes = []

xls = pd.ExcelFile(file)
sheets = xls.sheet_names
data = pd.read_excel(file,sheets[0])
title = data.iloc[7,0] 
data.columns = data.iloc[11].to_list()
data = data[12:]
data_note = pd.read_excel(file,sheets[1])
for i in range(len(data_note.index)):
    f = data_note.iloc[i].to_list()
    notes.append(f[0])
note = [' ,\n '.join(map(str,notes))][0]
### for WUP2005 the same if len(sheets)=2 , if len(sheets)>2 do for loop and if sheet=='Notes' like data_note and else for all sheet like data
# Out:
# ---------------------------------------------------------------------------
# FormulaError                              Traceback (most recent call last)
# Cell In [1], line 6
#       3 import pandas as pd
#       4 notes = []
# ----> 6 xls = pd.ExcelFile(file)
#       7 sheets = xls.sheet_names
#       8 data = pd.read_excel(file,sheets[0])
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\excel\_base.py:1695, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options)
#    1692 self.engine = engine
#    1693 self.storage_options = storage_options
# -> 1695 self._reader = self._engines[engine](self._io, storage_options=storage_options)
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\excel\_xlrd.py:35, in XlrdReader.__init__(self, filepath_or_buffer, storage_options)
#      33 err_msg = "Install xlrd >= 1.0.0 for Excel support"
#      34 import_optional_dependency("xlrd", extra=err_msg)
# ---> 35 super().__init__(filepath_or_buffer, storage_options=storage_options)
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\excel\_base.py:545, in BaseExcelReader.__init__(self, filepath_or_buffer, storage_options)
#     543 self.handles.handle.seek(0)
#     544 try:
# --> 545     self.book = self.load_workbook(self.handles.handle)
#     546 except Exception:
#     547     self.close()
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\excel\_xlrd.py:48, in XlrdReader.load_workbook(self, filepath_or_buffer)
#      46 if hasattr(filepath_or_buffer, "read"):
#      47     data = filepath_or_buffer.read()
# ---> 48     return open_workbook(file_contents=data)
#      49 else:
#      50     return open_workbook(filepath_or_buffer)
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\xlrd\__init__.py:172, in open_workbook(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows, ignore_workbook_corruption)
#     169 if file_format and file_format != 'xls':
#     170     raise XLRDError(FILE_FORMAT_DESCRIPTIONS[file_format]+'; not supported')
# --> 172 bk = open_workbook_xls(
#     173     filename=filename,
#     174     logfile=logfile,
#     175     verbosity=verbosity,
#     176     use_mmap=use_mmap,
#     177     file_contents=file_contents,
#     178     encoding_override=encoding_override,
#     179     formatting_info=formatting_info,
#     180     on_demand=on_demand,
#     181     ragged_rows=ragged_rows,
#     182     ignore_workbook_corruption=ignore_workbook_corruption,
#     183 )
#     185 return bk
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\xlrd\book.py:104, in open_workbook_xls(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows, ignore_workbook_corruption)
#     102         bk.on_demand = on_demand = False
#     103 else:
# --> 104     bk.parse_globals()
#     105     bk._sheet_list = [None for sh in bk._sheet_names]
#     106     if not on_demand:
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\xlrd\book.py:1251, in Book.parse_globals(self)
#    1249 elif rc ==  XL_EOF:
#    1250     self.xf_epilogue()
# -> 1251     self.names_epilogue()
#    1252     self.palette_epilogue()
#    1253     if not self.encoding:
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\xlrd\book.py:1045, in Book.names_epilogue(self)
#    1043     if nobj.macro or nobj.binary: continue
#    1044     if nobj.evaluated: continue
# -> 1045     evaluate_name_formula(self, nobj, namex, blah=blah)
#    1047 if self.verbosity >= 2:
#    1048     print("---------- name object dump ----------", file=f)
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\xlrd\formula.py:1196, in evaluate_name_formula(bk, nobj, namex, blah, level)
#    1190     # res = get_cell_addr(data, pos+1, bv, reldelta=1)
#    1191     # # note *ALL* tRefN usage has signed offset for relative addresses
#    1192     # any_rel = 1
#    1193     # if blah: print >> bk.logfile, "   ", res
#    1194     # spush(res)
#    1195 elif opcode == 0x0D: #tAreaN
# -> 1196     not_in_name_formula(op, oname)
#    1197     # res = get_cell_range_addr(data, pos+1, bv, reldelta=1)
#    1198     # # note *ALL* tAreaN usage has signed offset for relative addresses
#    1199     # any_rel = 1
#    1200     # if blah: print >> bk.logfile, "   ", res
#    1201 elif opcode == 0x1A: # tRef3d
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\xlrd\formula.py:826, in evaluate_name_formula.<locals>.not_in_name_formula(op_arg, oname_arg)
#     823 def not_in_name_formula(op_arg, oname_arg):
#     824     msg = "ERROR *** Token 0x%02x (%s) found in NAME formula" \
#     825           % (op_arg, oname_arg)
# --> 826     raise FormulaError(msg)
#
# FormulaError: ERROR *** Token 0x2d (AreaN) found in NAME formula

# %%
path = 'C:\\Users\\10235555\\Documents\\DataportalCrawlers\\UN_Data\\downloadfolder2'
file = f'{path}\\WUP2003F1-Total_Population.xls'
import pandas as pd
notes = []

xls = pd.ExcelFile(file)
sheets = xls.sheet_names

# %%
path = 'C:\\Users\\10235555\\Documents\\DataportalCrawlers\\UN_Data\\downloadfolder2'
file = f'{path}\\WUP2007-F02-Proportion_Urban.xls'
import pandas as pd
import openpyxl
import xlrd
notes = []

# xls = pd.ExcelFile(file)
# sheets = xls.sheet_names
data = pd.read_excel(file,engine = 'xlrd')
data.head()
# title = data.iloc[7,0] 
# title
# data.columns = data.iloc[11].to_list()
# data = data[12:]
# data_note = pd.read_excel(file,sheets[1])
# for i in range(len(data_note.index)):
#     f = data_note.iloc[i].to_list()
#     notes.append(f[0])
# note = [' ,\n '.join(map(str,notes))][0]
# Out:
# ---------------------------------------------------------------------------
# FormulaError                              Traceback (most recent call last)
# Cell In [2], line 10
#       6 notes = []
#       8 # xls = pd.ExcelFile(file)
#       9 # sheets = xls.sheet_names
# ---> 10 data = pd.read_excel(file,engine = 'xlrd')
#      11 data.head()
#      12 # title = data.iloc[7,0]
#      13 # title
#      14 # data.columns = data.iloc[11].to_list()
#    (...)
#      19 #     notes.append(f[0])
#      20 # note = [' ,\n '.join(map(str,notes))][0]
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\excel\_base.py:482, in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     480 if not isinstance(io, ExcelFile):
#     481     should_close = True
# --> 482     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     483 elif engine and engine != io.engine:
#     484     raise ValueError(
#     485         "Engine should not be specified when passing "
#     486         "an ExcelFile - ExcelFile already has the engine set"
#     487     )
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\excel\_base.py:1695, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options)
#    1692 self.engine = engine
#    1693 self.storage_options = storage_options
# -> 1695 self._reader = self._engines[engine](self._io, storage_options=storage_options)
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\excel\_xlrd.py:35, in XlrdReader.__init__(self, filepath_or_buffer, storage_options)
#      33 err_msg = "Install xlrd >= 1.0.0 for Excel support"
#      34 import_optional_dependency("xlrd", extra=err_msg)
# ---> 35 super().__init__(filepath_or_buffer, storage_options=storage_options)
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\excel\_base.py:545, in BaseExcelReader.__init__(self, filepath_or_buffer, storage_options)
#     543 self.handles.handle.seek(0)
#     544 try:
# --> 545     self.book = self.load_workbook(self.handles.handle)
#     546 except Exception:
#     547     self.close()
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\excel\_xlrd.py:48, in XlrdReader.load_workbook(self, filepath_or_buffer)
#      46 if hasattr(filepath_or_buffer, "read"):
#      47     data = filepath_or_buffer.read()
# ---> 48     return open_workbook(file_contents=data)
#      49 else:
#      50     return open_workbook(filepath_or_buffer)
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\xlrd\__init__.py:172, in open_workbook(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows, ignore_workbook_corruption)
#     169 if file_format and file_format != 'xls':
#     170     raise XLRDError(FILE_FORMAT_DESCRIPTIONS[file_format]+'; not supported')
# --> 172 bk = open_workbook_xls(
#     173     filename=filename,
#     174     logfile=logfile,
#     175     verbosity=verbosity,
#     176     use_mmap=use_mmap,
#     177     file_contents=file_contents,
#     178     encoding_override=encoding_override,
#     179     formatting_info=formatting_info,
#     180     on_demand=on_demand,
#     181     ragged_rows=ragged_rows,
#     182     ignore_workbook_corruption=ignore_workbook_corruption,
#     183 )
#     185 return bk
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\xlrd\book.py:104, in open_workbook_xls(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows, ignore_workbook_corruption)
#     102         bk.on_demand = on_demand = False
#     103 else:
# --> 104     bk.parse_globals()
#     105     bk._sheet_list = [None for sh in bk._sheet_names]
#     106     if not on_demand:
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\xlrd\book.py:1251, in Book.parse_globals(self)
#    1249 elif rc ==  XL_EOF:
#    1250     self.xf_epilogue()
# -> 1251     self.names_epilogue()
#    1252     self.palette_epilogue()
#    1253     if not self.encoding:
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\xlrd\book.py:1045, in Book.names_epilogue(self)
#    1043     if nobj.macro or nobj.binary: continue
#    1044     if nobj.evaluated: continue
# -> 1045     evaluate_name_formula(self, nobj, namex, blah=blah)
#    1047 if self.verbosity >= 2:
#    1048     print("---------- name object dump ----------", file=f)
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\xlrd\formula.py:1196, in evaluate_name_formula(bk, nobj, namex, blah, level)
#    1190     # res = get_cell_addr(data, pos+1, bv, reldelta=1)
#    1191     # # note *ALL* tRefN usage has signed offset for relative addresses
#    1192     # any_rel = 1
#    1193     # if blah: print >> bk.logfile, "   ", res
#    1194     # spush(res)
#    1195 elif opcode == 0x0D: #tAreaN
# -> 1196     not_in_name_formula(op, oname)
#    1197     # res = get_cell_range_addr(data, pos+1, bv, reldelta=1)
#    1198     # # note *ALL* tAreaN usage has signed offset for relative addresses
#    1199     # any_rel = 1
#    1200     # if blah: print >> bk.logfile, "   ", res
#    1201 elif opcode == 0x1A: # tRef3d
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\xlrd\formula.py:826, in evaluate_name_formula.<locals>.not_in_name_formula(op_arg, oname_arg)
#     823 def not_in_name_formula(op_arg, oname_arg):
#     824     msg = "ERROR *** Token 0x%02x (%s) found in NAME formula" \
#     825           % (op_arg, oname_arg)
# --> 826     raise FormulaError(msg)
#
# FormulaError: ERROR *** Token 0x2d (AreaN) found in NAME formula

# %%
path = r"C:\Users\10235555\Documents\DataportalCrawlers\UN_Data\WUP2007-F01-Total_Urban_Rural.xls"
df = pd.read_excel(path, engine= "xlrd")
# Out:
# ---------------------------------------------------------------------------
# FormulaError                              Traceback (most recent call last)
# Cell In [5], line 2
#       1 path = r"C:\Users\10235555\Documents\DataportalCrawlers\UN_Data\WUP2007-F01-Total_Urban_Rural.xls"
# ----> 2 df = pd.read_excel(path, engine= "xlrd")
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\excel\_base.py:482, in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     480 if not isinstance(io, ExcelFile):
#     481     should_close = True
# --> 482     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     483 elif engine and engine != io.engine:
#     484     raise ValueError(
#     485         "Engine should not be specified when passing "
#     486         "an ExcelFile - ExcelFile already has the engine set"
#     487     )
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\excel\_base.py:1695, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options)
#    1692 self.engine = engine
#    1693 self.storage_options = storage_options
# -> 1695 self._reader = self._engines[engine](self._io, storage_options=storage_options)
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\excel\_xlrd.py:35, in XlrdReader.__init__(self, filepath_or_buffer, storage_options)
#      33 err_msg = "Install xlrd >= 1.0.0 for Excel support"
#      34 import_optional_dependency("xlrd", extra=err_msg)
# ---> 35 super().__init__(filepath_or_buffer, storage_options=storage_options)
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\excel\_base.py:545, in BaseExcelReader.__init__(self, filepath_or_buffer, storage_options)
#     543 self.handles.handle.seek(0)
#     544 try:
# --> 545     self.book = self.load_workbook(self.handles.handle)
#     546 except Exception:
#     547     self.close()
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\excel\_xlrd.py:48, in XlrdReader.load_workbook(self, filepath_or_buffer)
#      46 if hasattr(filepath_or_buffer, "read"):
#      47     data = filepath_or_buffer.read()
# ---> 48     return open_workbook(file_contents=data)
#      49 else:
#      50     return open_workbook(filepath_or_buffer)
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\xlrd\__init__.py:172, in open_workbook(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows, ignore_workbook_corruption)
#     169 if file_format and file_format != 'xls':
#     170     raise XLRDError(FILE_FORMAT_DESCRIPTIONS[file_format]+'; not supported')
# --> 172 bk = open_workbook_xls(
#     173     filename=filename,
#     174     logfile=logfile,
#     175     verbosity=verbosity,
#     176     use_mmap=use_mmap,
#     177     file_contents=file_contents,
#     178     encoding_override=encoding_override,
#     179     formatting_info=formatting_info,
#     180     on_demand=on_demand,
#     181     ragged_rows=ragged_rows,
#     182     ignore_workbook_corruption=ignore_workbook_corruption,
#     183 )
#     185 return bk
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\xlrd\book.py:104, in open_workbook_xls(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows, ignore_workbook_corruption)
#     102         bk.on_demand = on_demand = False
#     103 else:
# --> 104     bk.parse_globals()
#     105     bk._sheet_list = [None for sh in bk._sheet_names]
#     106     if not on_demand:
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\xlrd\book.py:1251, in Book.parse_globals(self)
#    1249 elif rc ==  XL_EOF:
#    1250     self.xf_epilogue()
# -> 1251     self.names_epilogue()
#    1252     self.palette_epilogue()
#    1253     if not self.encoding:
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\xlrd\book.py:1045, in Book.names_epilogue(self)
#    1043     if nobj.macro or nobj.binary: continue
#    1044     if nobj.evaluated: continue
# -> 1045     evaluate_name_formula(self, nobj, namex, blah=blah)
#    1047 if self.verbosity >= 2:
#    1048     print("---------- name object dump ----------", file=f)
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\xlrd\formula.py:1196, in evaluate_name_formula(bk, nobj, namex, blah, level)
#    1190     # res = get_cell_addr(data, pos+1, bv, reldelta=1)
#    1191     # # note *ALL* tRefN usage has signed offset for relative addresses
#    1192     # any_rel = 1
#    1193     # if blah: print >> bk.logfile, "   ", res
#    1194     # spush(res)
#    1195 elif opcode == 0x0D: #tAreaN
# -> 1196     not_in_name_formula(op, oname)
#    1197     # res = get_cell_range_addr(data, pos+1, bv, reldelta=1)
#    1198     # # note *ALL* tAreaN usage has signed offset for relative addresses
#    1199     # any_rel = 1
#    1200     # if blah: print >> bk.logfile, "   ", res
#    1201 elif opcode == 0x1A: # tRef3d
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\xlrd\formula.py:826, in evaluate_name_formula.<locals>.not_in_name_formula(op_arg, oname_arg)
#     823 def not_in_name_formula(op_arg, oname_arg):
#     824     msg = "ERROR *** Token 0x%02x (%s) found in NAME formula" \
#     825           % (op_arg, oname_arg)
# --> 826     raise FormulaError(msg)
#
# FormulaError: ERROR *** Token 0x2d (AreaN) found in NAME formula

# %%
path = 'C:\\Users\\10235555\\Documents\\DataportalCrawlers\\UN_Data\\downloadfolder2'
file = f'{path}\\WUP2009-DataSource-UrbanAgglomeration-and-CapitalCities.xls'
import pandas as pd
notes = []
xls = pd.ExcelFile(file,engine = 'xlrd')
sheets = xls.sheet_names
data = pd.read_excel(file,engine='xlrd')
title = data.iloc[7,0]
# Out:
# ---------------------------------------------------------------------------
# XLRDError                                 Traceback (most recent call last)
# Cell In [6], line 6
#       3 import pandas as pd
#       4 notes = []
# ----> 6 xls = pd.ExcelFile(file,engine = 'xlrd')
#       7 sheets = xls.sheet_names
#       8 data = pd.read_excel(file,engine='xlrd')
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\excel\_base.py:1695, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options)
#    1692 self.engine = engine
#    1693 self.storage_options = storage_options
# -> 1695 self._reader = self._engines[engine](self._io, storage_options=storage_options)
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\excel\_xlrd.py:35, in XlrdReader.__init__(self, filepath_or_buffer, storage_options)
#      33 err_msg = "Install xlrd >= 1.0.0 for Excel support"
#      34 import_optional_dependency("xlrd", extra=err_msg)
# ---> 35 super().__init__(filepath_or_buffer, storage_options=storage_options)
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\excel\_base.py:545, in BaseExcelReader.__init__(self, filepath_or_buffer, storage_options)
#     543 self.handles.handle.seek(0)
#     544 try:
# --> 545     self.book = self.load_workbook(self.handles.handle)
#     546 except Exception:
#     547     self.close()
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\excel\_xlrd.py:48, in XlrdReader.load_workbook(self, filepath_or_buffer)
#      46 if hasattr(filepath_or_buffer, "read"):
#      47     data = filepath_or_buffer.read()
# ---> 48     return open_workbook(file_contents=data)
#      49 else:
#      50     return open_workbook(filepath_or_buffer)
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\xlrd\__init__.py:172, in open_workbook(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows, ignore_workbook_corruption)
#     169 if file_format and file_format != 'xls':
#     170     raise XLRDError(FILE_FORMAT_DESCRIPTIONS[file_format]+'; not supported')
# --> 172 bk = open_workbook_xls(
#     173     filename=filename,
#     174     logfile=logfile,
#     175     verbosity=verbosity,
#     176     use_mmap=use_mmap,
#     177     file_contents=file_contents,
#     178     encoding_override=encoding_override,
#     179     formatting_info=formatting_info,
#     180     on_demand=on_demand,
#     181     ragged_rows=ragged_rows,
#     182     ignore_workbook_corruption=ignore_workbook_corruption,
#     183 )
#     185 return bk
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\xlrd\book.py:79, in open_workbook_xls(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows, ignore_workbook_corruption)
#      77 t1 = perf_counter()
#      78 bk.load_time_stage_1 = t1 - t0
# ---> 79 biff_version = bk.getbof(XL_WORKBOOK_GLOBALS)
#      80 if not biff_version:
#      81     raise XLRDError("Can't determine file's BIFF version")
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\xlrd\book.py:1284, in Book.getbof(self, rqd_stream)
#    1282     bof_error('Expected BOF record; met end of file')
#    1283 if opcode not in bofcodes:
# -> 1284     bof_error('Expected BOF record; found %r' % self.mem[savpos:savpos+8])
#    1285 length = self.get2bytes()
#    1286 if length == MY_EOF:
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\xlrd\book.py:1278, in Book.getbof.<locals>.bof_error(msg)
#    1277 def bof_error(msg):
# -> 1278     raise XLRDError('Unsupported format, or corrupt file: ' + msg)
#
# XLRDError: Unsupported format, or corrupt file: Expected BOF record; found b'<html xm'

# %%
import win32com


path=r'C:\Users\10235555\Documents\DataportalCrawlers\UN_Data\df4'
l = []    
for x in os.listdir(path):        
    l.append(x)    
    for i in range(len(l)):       
        current_dir = os.path.join(path, l[i])        
        if os.path.isdir(current_dir):            
            for file in os.listdir(current_dir):                
                if file.endswith('.xls'):                    
                    fname = os.path.join(current_dir, file)                    
                    excel = win32com.gencache.EnsureDispatch('Excel.Application')                    
                    wb = excel.Workbooks.Open(fname)                    
                    wb.SaveAs(fname + "x", FileFormat=51)  
                    # FileFormat = 51 is for .xlsx extension                    
                    wb.Close()  
                    # FileFormat = 56 is for .xls extension                    
                    excel.Application.Quit()

# %%
path = 'C:\\Users\\10235555\\Documents\\DataportalCrawlers\\UN_Data\\downloadfolder2'
file = f'{path}\\WUP2011-F14-Growth_Rate_Cities.xls'
import pandas as pd
notes = []

xls = pd.ExcelFile(file)
sheets = xls.sheet_names
data = pd.read_excel(file,sheets[0])
title = data.iloc[6,4] 
title
# data.columns = data.iloc[11].to_list()
# data = data[12:]
# data_note = pd.read_excel(file,sheets[1])
# for i in range(len(data_note.index)):
#     f = data_note.iloc[i].to_list()
#     notes.append(f[0])
# Out:
# 'File 14:  Average Annual Rate of Change of Urban Agglomerations with 750,000 Inhabitants or More in 2011, by Country, 1950-2025 (per cent)'

# %%
path = 'C:\\Users\\10235555\\Documents\\DataportalCrawlers\\UN_Data\\downloadfolder2'
file = f'{path}\\WUP2011-F01-Total_Urban_Rural.xls'
import pandas as pd
notes = []

xls = pd.ExcelFile(file)
sheets = xls.sheet_names
data = pd.read_excel(file,sheets[0])
title = data.iloc[6,3] 
data.iloc[11:13] = data.iloc[11:13].fillna(method='ffill', axis=1)
data.iloc[11:13] = data.iloc[11:13].fillna('')
data.columns = data.iloc[11:13].apply(lambda x: ' \n '.join(map(str,[y for y in x if y])), axis=0)
data = data[13:]
data_note = pd.read_excel(file,sheets[1])
for i in range(len(data_note.index)):
    f = data_note.iloc[i].to_list()
    notes.append(f[0])

# %%
path = 'C:\\Users\\10235555\\Documents\\DataportalCrawlers\\UN_Data\\downloadfolder2'
file = f'{path}\\WUP2014-F00-Locations.xls'
import pandas as pd
notes = []
xls = pd.ExcelFile(file)
sheets = xls.sheet_names
df = pd.read_excel(file,sheets[0])
title = df.iloc[8,2]
df.iloc[14:16] = df.iloc[14:16].fillna(method='ffill', axis=1)
df.iloc[14:16] = df.iloc[14:16].fillna('')
df.columns = df.iloc[14:16].apply(lambda x: ' \n '.join(map(str,[y for y in x if y])), axis=0)
# df[16:].to_excel('test_file_title_2.xlsx',index = False)
data_note = pd.read_excel(file,sheets[1])
for i in range(len(data_note.index)):
    f = data_note.iloc[i].to_list()
    notes.append(f[0])
note = [' ,\n '.join(map(str,notes))]
note = 'Notes, ' + note[0]
df = df[16:]
note
# Out:
# 'Notes, (*) Numerical Location Code (3-digit codes following ISO 3166-1 numeric standard) - see http://en.wikipedia.org/wiki/ISO_3166-1_numeric ,\n (**) ISO 3166-1 alpha-3 codes (three-letter system) for country codes - see http://en.wikipedia.org/wiki/ISO_3166-1_alpha-3 ,\n (***) ISO 3166-1 alpha-2 codes (two-letter system) for country codes - see http://en.wikipedia.org/wiki/ISO_3166-1_alpha-2 ,\n (a) More developed regions comprise Europe, Northern America, Australia/New Zealand and Japan. ,\n (b) Less developed regions comprise all regions of Africa, Asia (excluding Japan), Latin America and the Caribbean plus Melanesia, Micronesia and Polynesia. ,\n (c) The least developed countries are 49 countries, 34 in Africa, 9 in Asia, 5 in Oceania plus one in Latin America and the Caribbean. ,\n (d) Other less developed countries comprise the less developed regions excluding the least developed countries. ,\n (e) The country classification by income level is based on 2012 GNI per capita from the World Bank. ,\n (f) Sub-Saharan Africa refers to all of Africa except Northern Africa. ,\n (1) Including Agalega, Rodrigues, and Saint Brandon. ,\n (2) Including Zanzibar. ,\n (3) Including Ascension, and Tristan da Cunha. ,\n (4) For statistical purposes, the data for China do not include Hong Kong and Macao, Special Administrative Regions (SAR) of China. ,\n (5) As of 1 July 1997, Hong Kong became a Special Administrative Region (SAR) of China. ,\n (6) As of 20 December 1999, Macao became a Special Administrative Region (SAR) of China. ,\n (7) The regions Southern Asia and Central Asia are combined into South-Central Asia. ,\n (8) Including Sabah and Sarawak. ,\n (9) Including Nagorno-Karabakh. ,\n (10) Including Abkhazia and South Ossetia. ,\n (11) Including East Jerusalem. ,\n (12) Including Transnistria. ,\n (13) Refers to Guernsey, and Jersey. ,\n (14) Including Åland Islands. ,\n (15) Including Svalbard and Jan Mayen Islands. ,\n (16) Refers to the Vatican City State. ,\n (17) Including Kosovo. ,\n (18) Including Canary Islands, Ceuta and Melilla. ,\n (19) The former Yugoslav Republic of Macedonia. ,\n (20) Including Saint-Barthélemy and Saint-Martin (French part). ,\n (21) Including Christmas Island, Cocos (Keeling) Islands, and Norfolk Island. ,\n (22) Including Pitcairn.'

# %%
path = 'C:\\Users\\10235555\\Documents\\DataportalCrawlers\\UN_Data\\downloadfolder2'
file = f'{path}\\WUP2009-F01-Total_Urban_Rural.xls'     # WUP2009-F02-Proportion_Urban.xls
import pandas as pd
notes = []
xls = pd.ExcelFile(file)
sheets = xls.sheet_names
df = pd.read_excel(file,sheets[0])
title = df.iloc[5,2]
df.iloc[8:10] = df.iloc[8:10].fillna(method='ffill', axis=1)
df.iloc[8:10] = df.iloc[8:10].fillna('')
df.columns = df.iloc[8:10].apply(lambda x: ' \n '.join(map(str,[y for y in x if y])), axis=0)
df.rename(columns={df.columns[-1]: df.columns[-1].replace(' \n Total','')},inplace=True)
# df[10:].to_excel('test_file_title_2.xlsx',index = False)
data_note = pd.read_excel(file,sheets[1])
for i in range(len(data_note.index)):
    f = data_note.iloc[i].to_list()
    notes.append(f[0])
note = [' ,\n '.join(map(str,notes))]
note = 'Notes, ' + note[0]
source = note.split('\n Source:')[1]
df = df[10:]
df.to_excel(,index = False)

# %%
path = 'C:\\Users\\10235555\\Documents\\DataportalCrawlers\\UN_Data\\downloadfolder2'
file = f'{path}\\WUP2009-F17a-City_Size_Class.xls'     # WUP2009-F02-Proportion_Urban.xls
import pandas as pd
notes = []
xls = pd.ExcelFile(file)
sheets = xls.sheet_names
df = pd.read_excel(file,sheets[0])
title = df.iloc[5,2]
title = title.replace(':','')
title
# df.columns = df.iloc[9].to_list()
# df.columns
# # df[10:].to_excel('test_file_title_2.xlsx',index = False)
# data_note = pd.read_excel(file,sheets[1])
# for i in range(len(data_note.index)):
#     f = data_note.iloc[i].to_list()
#     notes.append(f[0])
# note = [' ,\n '.join(map(str,notes))]
# note = 'Notes, ' + note[0]
# source = note.split('\n Source:')[1]
# df = df[10:]
# df.to_excel(f'{base_path_2}\\{title}.xlsx',index = False)
# Out:
# 'File 17a  Urban Population (thousands), Number of Cities and Percentage of Urban Population by Size Class of Urban Settlement, Major Area, Region and Country, 1950-2025'

# %%
path = 'C:\\Users\\10235555\\Documents\\DataportalCrawlers\\UN_Data\\downloadfolder2'
file = f'{path}\\WPP2009-F00-Locations.XLS'     # WUP2009-F02-Proportion_Urban.xls
import pandas as pd
notes = []
xls = pd.ExcelFile(file)
sheets = xls.sheet_names
df = pd.read_excel(file,sheets[0])
title = df.iloc[6,3]
title = '2009' + ' ' + title
df.iloc[12:14] = df.iloc[12:14].fillna(method='ffill', axis=1)
df.iloc[12:14] = df.iloc[12:14].fillna('')
df.columns = df.iloc[12:14].apply(lambda x: ' \n '.join(map(str,[y for y in x if y])), axis=0)
df.columns
# df.rename(columns={df.columns[-1]: df.columns[-1].replace(' \n Total','')},inplace=True)
# df[10:].to_excel('test_file_title_2.xlsx',index = False)
data_note = pd.read_excel(file,sheets[1])
for i in range(len(data_note.index)):
    f = data_note.iloc[i].to_list()
    notes.append(f[0])
note = [' ,\n '.join(map(str,notes))]
note = 'Notes, ' + note[0]
source = note.split('\n Source:')[1]
df = df[14:]
title
# Out:
# 'File 0: Location list with codes, description, major area, region and development group'

# %%
path = 'C:\\Users\\10235555\\Documents\\DataportalCrawlers\\UN_Data\\downloadfolder2'
file = f'{path}\\WPP2011-F00-Locations.XLS'     # WUP2009-F02-Proportion_Urban.xls
import pandas as pd
notes = []
xls = pd.ExcelFile(file)
sheets = xls.sheet_names
df = pd.read_excel(file,sheets[0])
title = df.iloc[6,3]
title = '2011'  +' ' +title
df.iloc[12:14] = df.iloc[12:14].fillna(method='ffill', axis=1)
df.iloc[12:14] = df.iloc[12:14].fillna('')
df.columns = df.iloc[12:14].apply(lambda x: ' \n '.join(map(str,[y for y in x if y])), axis=0)
df.columns
# df.rename(columns={df.columns[-1]: df.columns[-1].replace(' \n Total','')},inplace=True)
# df[10:].to_excel('test_file_title_2.xlsx',index = False)
data_note = pd.read_excel(file,sheets[1])
for i in range(len(data_note.index)):
    f = data_note.iloc[i].to_list()
    notes.append(f[0])
note = [' ,\n '.join(map(str,notes))]
note = 'Notes, ' + note[0]
df = df[14:]
note
# Out:
# "Notes, (*) Numerical Location Code (3-digit codes following ISO 3166-1 numeric standard) - see http://en.wikipedia.org/wiki/ISO_3166-1_numeric ,\n (**) ISO 3166-1 alpha-3 codes (three-letter system) for country codes - see http://en.wikipedia.org/wiki/ISO_3166-1_alpha-3 ,\n (***) ISO 3166-1 alpha-2 codes (three-letter system) for country codes - see http://en.wikipedia.org/wiki/ISO_3166-1_alpha-2 ,\n (a) More developed regions comprise Europe, Northern America, Australia/New Zealand and Japan. ,\n (b) Less developed regions comprise all regions of Africa, Asia (excluding Japan), Latin America and the Caribbean plus Melanesia, Micronesia and Polynesia. ,\n (c) The least developed countries, as defined by the United Nations General Assembly in its resolutions (59/209, 59/210, 60/33, 62/97, 64/L.55) are 49 countries in 2011: 33 in Africa, 9 in Asia, 5 in Oceania and one in Latin America and the Caribbean. \nThe group includes 49 countries - Afghanistan, Angola, Bangladesh, Benin, Bhutan, Burkina Faso, Burundi, Cambodia, Central African Republic, Chad, Comoros, Democratic Republic of the Congo, Djibouti, Equatorial Guinea, Eritrea, Ethiopia, Gambia, Guinea, Guinea-Bissau, Haiti, Kiribati, Lao People's Democratic Republic, Lesotho, Liberia, Madagascar, Malawi, Mali, Mauritania, Mozambique, Myanmar, Nepal, Niger, Rwanda, Samoa, São Tomé and Príncipe, Senegal, Sierra Leone, Solomon Islands, Somalia, South Sudan, Sudan, Timor-Leste, Togo, Tuvalu, Uganda, United Republic of Tanzania, Vanuatu, Yemen and Zambia. These countries are also included in the less developed regions. ,\n (d) Other less developed countries comprise the less developed regions excluding the least developed countries. ,\n (e) Sub-Saharan Africa refers to all of Africa except Northern Africa. ,\n (1) Including Agalega, Rodrigues, and Saint Brandon. ,\n (2) Including Zanzibar. ,\n (3) Including Ascension, and Tristan da Cunha. ,\n (4) For statistical purposes, the data for China do not include Hong Kong and Macao, Special Administrative Regions (SAR) of China. ,\n (5) As of 1 July 1997, Hong Kong became a Special Administrative Region (SAR) of China. ,\n (6) As of 20 December 1999, Macao became a Special Administrative Region (SAR) of China. ,\n (7) The regions Southern Asia and Central Asia are combined into South-Central Asia. ,\n (8) Including Sabah and Sarawak. ,\n (9) Including Nagorno-Karabakh. ,\n (10) Including Northern-Cyprus. ,\n (11) Including Abkhazia and South Ossetia. ,\n (12) Including East Jerusalem. ,\n (13) Including Transnistria. ,\n (14) Refers to Guernsey, and Jersey. ,\n (15) Including Åland Islands. ,\n (16) Including Svalbard and Jan Mayen Islands. ,\n (17) Refers to the Vatican City State. ,\n (18) Including Kosovo. ,\n (19) Including Canary Islands, Ceuta and Melilla. ,\n (20) The former Yugoslav Republic of Macedonia. ,\n (21) Including Saint-Barthélemy and Saint-Martin (French part). ,\n (22) Refers to Curaçao, Sint Maarten (Dutch part), Bonaire, Saba and Sint Eustatius. ,\n (23) Including Christmas Island, Cocos (Keeling) Islands, and Norfolk Island. ,\n (24) Including Pitcairn."
