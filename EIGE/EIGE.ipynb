# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import ElementNotInteractableException, NoSuchElementException
from selenium.common.exceptions import ElementClickInterceptedException
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from webdriver_manager.firefox import GeckoDriverManager
from selenium.webdriver.firefox.options import Options
from bs4 import BeautifulSoup
import shutil
import time
import os
import pandas as pd
from pyshadow.main import Shadow
from py7zr import unpack_7zarchive
from RequestInferSchemaToJsonAPI.main import TriggerInferShemaToJsonAPI
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\EIGE'

# %%
chrome_options = webdriver.ChromeOptions()
base_path = "C:\\Users\\10235555\\Documents\\Dataportal Data\\EIGE" # local, gets current working directory
prefs = {'download.default_directory' : base_path}#, "profile.content_settings.exceptions.automatic_downloads.*.setting" : 1}
chrome_options.add_experimental_option('prefs', prefs)
chrome_options.add_argument('--user-agent="Mozilla/5.0 (Windows Phone 10.0; Android 4.2.1; Microsoft; Lumia 640 XL LTE) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.135 Mobile Safari/537.36 Edge/12.10166"')
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)
driver.maximize_window()

# %%
driver.get('https://eige.europa.eu/gender-statistics/dgs')

# %%
driver.find_element(By.ID,'popup-buttons').find_element(By.TAG_NAME,'button').click()

# %%
content = driver.find_element(By.CLASS_NAME,'tree')
top = content.find_element(By.CLASS_NAME,'title')
top.click()

# %%
header = driver.find_element(By.CLASS_NAME ,'theme.theme_eige_covid').find_element(By.TAG_NAME,'div')
header.click()

# %%
pop = driver.find_element(By.CLASS_NAME,'theme.theme_eige_covid.expanded').find_element(By.TAG_NAME,'li')
pop.find_element(By.TAG_NAME,'div').click()

# %%
child = pop.find_element(By.TAG_NAME,'li')
child.find_element(By.TAG_NAME,'div').click()

# %%
dataset = child.find_element(By.TAG_NAME,'li')
dataset.find_element(By.TAG_NAME,'a').click()

# %%
export = driver.find_element(By.CLASS_NAME,'button.export.small')
export.click()

# %%
csv = driver.find_element(By.CLASS_NAME,'csv')
csv.click()

# %%
metadata = driver.find_element(By.CLASS_NAME,'chart.metadata').find_element(By.TAG_NAME,'a') 
metadata.click()

# %%
summary = []
source_name = driver.find_elements(By.TAG_NAME,'td')[1].text
source_url = driver.find_elements(By.TAG_NAME,'td')[2].text
limitation = driver.find_elements(By.TAG_NAME,'td')[3].text
rows_description = driver.find_elements(By.TAG_NAME,'tr')[4:7]
for row in rows_description:
    summary.append(row.text)
summary = [' \n\n '.join(map(str,summary))][0]
description = driver.find_element(By.CLASS_NAME,'box.description').find_element(By.TAG_NAME,'div').text
# Out:
# 'This indicator shows the amount of time spent on childcare responsibilities during and before the pandemic among women and men with childcare responsibilities either in their own household or another household (e.g., grandchildren).\nChildcare responsibilities are divided according to the age of children within the household (children aged 0-11, children aged 12-17, and children aged 0-17).\nResponses are based on a set of questions regarding the number of hours per typical weekday that the respondent spends on childcare, including assistance with school tasks and home-schooling. Valid responses were grouped into the three categories:\nLess than 1 hour\nBetween 1 and 4 hours\nMore than 4 hours\nMore information on the methodological aspects of EIGE’s survey ‘Gender Equality and Socio-Economic Consequences of Covid-19 crisis’ can be obtained in the technical report.'

# %%
driver.get('https://eige.europa.eu/gender-statistics/dgs')

# %%
dataset_links = []
content = driver.find_element(By.CLASS_NAME,'tree')
tops = content.find_element(By.TAG_NAME,'ul').find_elements(By.TAG_NAME,'li')
for top in tops:
    top_more = top.find_element(By.TAG_NAME,'div')
    top_name = top_more.find_element(By.TAG_NAME,'a').text
    top_more.click()
    time.sleep(1)
    headers = top.find_element(By.TAG_NAME,'ul').find_elements(By.TAG_NAME,'li')
    for header in headers:
        header_more = header.find_element(By.TAG_NAME,'div')
        header_name = header_more.find_element(By.TAG_NAME,'a').text
        header_more.click()
        time.sleep(1)
        try:
            pops = header.find_element(By.TAG_NAME,'ul').find_elements(By.TAG_NAME,'li')
            for pop in pops:
                pop_more = pop.find_element(By.TAG_NAME,'div')
                pop_name = pop_more.find_element(By.TAG_NAME,'a').text
                pop_more.click()
                time.sleep(1)
                try:
                    childs = pop.find_element(By.TAG_NAME,'ul').find_elements(By.TAG_NAME,'li')
                    for child in childs:
                        child_more = child.find_element(By.TAG_NAME,'div')
                        child_name = child_more.find_element(By.TAG_NAME,'a').text
                        child_more.click()
                        time.sleep(1)
                        try:
                            descendants = child.find_element(By.TAG_NAME,'ul').find_elements(By.TAG_NAME,'li')
                            for descendant in descendants:
                                descendant_more = descendant.find_element(By.TAG_NAME,'div')
                                descendant_name = descendant_more.find_element(By.TAG_NAME,'a').text
                                descendant_more.click()
                                time.sleep(1)
                                try:
                                    nodes = descendant.find_element(By.TAG_NAME,'ul').find_elements(By.TAG_NAME,'li')
                                    for node in nodes:
                                        node_more = node.find_element(By.TAG_NAME,'div')
                                        node_name = node_more.find_element(By.TAG_NAME,'a').text
                                        node_more.click()
                                        time.sleep(1)
                                except:
                                    datasets = child.find_elements(By.TAG_NAME,'li')
                                    for dataset in datasets:
                                        dataset_content = dataset.find_element(By.TAG_NAME,'a')
                                        dataset_name = dataset_content.text
                                        dataset_link = dataset.find_element(By.TAG_NAME,'a').get_attribute('href')
                                        if dataset_link == 'https://eige.europa.eu/gender-statistics/dgs#':
                                            pass
                                        else:
                                            dataset_links.append(dataset_link)
                                        
                        except:
                            datasets = child.find_elements(By.TAG_NAME,'li')
                            for dataset in datasets:
                                dataset_content = dataset.find_element(By.TAG_NAME,'a')
                                dataset_name = dataset_content.text
                                dataset_link = dataset.find_element(By.TAG_NAME,'a').get_attribute('href')
                                if dataset_link == 'https://eige.europa.eu/gender-statistics/dgs#':
                                    pass
                                else:
                                    dataset_links.append(dataset_link)
                                
                except:
                    datasets = child.find_elements(By.TAG_NAME,'li')
                    for dataset in datasets:
                        dataset_content = dataset.find_element(By.TAG_NAME,'a')
                        dataset_name = dataset_content.text
                        dataset_link = dataset.find_element(By.TAG_NAME,'a').get_attribute('href')
                        if dataset_link == 'https://eige.europa.eu/gender-statistics/dgs#':
                            pass
                        else:
                            dataset_links.append(dataset_link)
        except:
            datasets = child.find_elements(By.TAG_NAME,'li')
            for dataset in datasets:
                dataset_content = dataset.find_element(By.TAG_NAME,'a')
                dataset_name = dataset_content.text
                dataset_link = dataset.find_element(By.TAG_NAME,'a').get_attribute('href')
                if dataset_link == 'https://eige.europa.eu/gender-statistics/dgs#':
                    pass
                else:
                    dataset_links.append(dataset_link)
    content = driver.find_element(By.CLASS_NAME,'tree')
    tops = content.find_element(By.TAG_NAME,'ul').find_elements(By.TAG_NAME,'li')
    # def scroll_down():
    #     scrollin = True
    #     stat=[]
    #     while scrollin:
    #         driver.find_element(By.TAG_NAME,'body').send_keys(Keys.END)
    #     stat.append(driver.find_element(By.CLASS_NAME,"lazyload").get_attribute("style"))
    #     if len(set(stat[-10:])) ==1 and list(set(stat[-10:]))[0] == 'display: none;':
    #         scrollin=False

# %%
len(dataset_links)
# Out:
# 2502

# %%
tags = driver.find_element(By.CLASS_NAME,'keywords').find_element(By.TAG_NAME,'ul').text.split('\n')
for tag in tags:
    print(tag)
# Out:
# employment rate
# employment
# parent
# labour market

# %%
periodicity = driver.find_elements(By.CLASS_NAME,'box.gray-box')[1].text.replace('\n' , " : ")
# Out:
# 'Time Periods : 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021'

# %%
title = driver.find_elements(By.ID,'page-title')[1].text
# Out:
# 'Gender Equality Index scores, domain scores and sub-domain scores'

# %%
import datetime
last_update = driver.find_elements(By.TAG_NAME,'td')[7].text
last_update = datetime.datetime.strptime(last_update, "%d.%m.%Y").strftime('%Y-%m-%d')
last_update
# Out:
# '2022-10-24'

# %%
dataset_links
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\10235555\Documents\DataportalCrawlers\UN_Data\EIGE.ipynb Cell 22 in 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/EIGE.ipynb#X31sZmlsZQ%3D%3D?line=0'>1</a> dataset_links
#
# NameError: name 'dataset_links' is not defined

# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\10235555\Documents\Dataportal Data\EIGE\eige covid chldc ben  covid chld benefits age.csv')
df = df.loc[:,~df.columns.str.startswith('_')]
df.head()
# Out:
#    time                                        geo  value    sex    age  \
# 0  2021  European Union - 27 countries (from 2020)   59.1  Women  Total
# 1  2021  European Union - 27 countries (from 2020)   68.4  Women  20-34
# 2  2021  European Union - 27 countries (from 2020)   56.7  Women  35-49
# 3  2021  European Union - 27 countries (from 2020)   46.3  Women  50-64
# 4  2021  European Union - 27 countries (from 2020)   64.4    Men  Total
#
#   age_of_children       benefits_support
# 0  0-11 years old  Any benefits/ support
# 1  0-11 years old  Any benefits/ support
# 2  0-11 years old  Any benefits/ support
# 3  0-11 years old  Any benefits/ support
# 4  0-11 years old  Any benefits/ support

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import ElementNotInteractableException, NoSuchElementException
from selenium.common.exceptions import ElementClickInterceptedException
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from webdriver_manager.firefox import GeckoDriverManager
from selenium.webdriver.firefox.options import Options
from selenium.common.exceptions import TimeoutException
from bs4 import BeautifulSoup
import shutil
import time
import os
import pandas as pd
import logging
import pandas as pd
from pyshadow.main import Shadow
from py7zr import unpack_7zarchive
from RequestInferSchemaToJsonAPI.main import TriggerInferShemaToJsonAPI
base_path = '\\\\10.30.31.77\\data_collection_dump\\RawData\\EIGE'

logging.basicConfig(handlers=[logging.FileHandler("//10.30.31.77/data_collection_dump/TACFolder/ScraperLogs/EIGE_out.log"),
                                    logging.StreamHandler()], level=logging.INFO)
chrome_options = webdriver.ChromeOptions()
base_path = "\\\\10.30.31.77\\data_collection_dump\\RawData\\EIGE" # local, gets current working directory
prefs = {'download.default_directory' : base_path}#, "profile.content_settings.exceptions.automatic_downloads.*.setting" : 1}
chrome_options.add_experimental_option('prefs', prefs)
#chrome_options.add_argument('ignore-certificate-errors')
#chrome_options.add_argument('--user-agent="Mozilla/5.0 (Windows Phone 10.0; Android 4.2.1; Microsoft; Lumia 640 XL LTE) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.135 Mobile Safari/537.36 Edge/12.10166"')
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)
driver.maximize_window()

driver.get('https://eige.europa.eu/gender-statistics/dgs') 
time.sleep(3)

driver.find_element(By.ID,'popup-buttons').find_element(By.TAG_NAME,'button').click()

dataset_links = []
content = driver.find_element(By.CLASS_NAME,'tree')
tops = content.find_element(By.TAG_NAME,'ul').find_elements(By.TAG_NAME,'li')
for top in tops[2:3]:
    top_more = top.find_element(By.TAG_NAME,'div')
    top_name = top_more.find_element(By.TAG_NAME,'a').text
    top_more.click()
    time.sleep(1)
    headers = top.find_element(By.TAG_NAME,'ul').find_elements(By.TAG_NAME,'li')
    for header in headers:
        header_more = header.find_element(By.TAG_NAME,'div')
        header_name = header_more.find_element(By.TAG_NAME,'a').text
        header_more.click()
        time.sleep(1)
        try:
            pops = header.find_element(By.TAG_NAME,'ul').find_elements(By.TAG_NAME,'li')
            for pop in pops:
                pop_more = pop.find_element(By.TAG_NAME,'div')
                pop_name = pop_more.find_element(By.TAG_NAME,'a').text
                pop_more.click()
                time.sleep(1)
                try:
                    childs = pop.find_element(By.TAG_NAME,'ul').find_elements(By.TAG_NAME,'li')
                    for child in childs:
                        child_more = child.find_element(By.TAG_NAME,'div')
                        child_name = child_more.find_element(By.TAG_NAME,'a').text
                        child_more.click()
                        time.sleep(1)
                        try:
                            descendants = child.find_element(By.TAG_NAME,'ul').find_elements(By.TAG_NAME,'li')
                            for descendant in descendants:
                                descendant_more = descendant.find_element(By.TAG_NAME,'div')
                                descendant_name = descendant_more.find_element(By.TAG_NAME,'a').text
                                descendant_more.click()
                                time.sleep(1)
                                try:
                                    nodes = descendant.find_element(By.TAG_NAME,'ul').find_elements(By.TAG_NAME,'li')
                                    for node in nodes:
                                        node_more = node.find_element(By.TAG_NAME,'div')
                                        node_name = node_more.find_element(By.TAG_NAME,'a').text
                                        node_more.click()
                                        time.sleep(1)
                                except:
                                    datasets = child.find_elements(By.CLASS_NAME,'indicator')
                                    for dataset in datasets:
                                        dataset_content = dataset.find_element(By.TAG_NAME,'a')
                                        dataset_name = dataset_content.text
                                        dataset_link = dataset.find_element(By.TAG_NAME,'a').get_attribute('href')
                                        if dataset_link == 'https://eige.europa.eu/gender-statistics/dgs#':
                                            pass
                                        elif dataset_link in dataset_links:
                                            pass
                                        else:
                                            dataset_name = dataset_name.replace('/',' ').replace(':',' ').replace('!',' ').replace('?',' ').replace('[',' ').replace(']',' ').replace("'",' ').replace('"',' ')
                                            file_exis = dataset_name +'.csv'
                                        if file_exis in os.listdir(base_path):
                                            print('the file exist')
                                        else:
                                            dataset_links.append(dataset_link)
                                        
                        except:
                            datasets = child.find_elements(By.CLASS_NAME,'indicator')
                            for dataset in datasets:
                                dataset_content = dataset.find_element(By.TAG_NAME,'a')
                                dataset_name = dataset_content.text
                                dataset_link = dataset.find_element(By.TAG_NAME,'a').get_attribute('href')
                                if dataset_link == 'https://eige.europa.eu/gender-statistics/dgs#':
                                    pass
                                elif dataset_link in dataset_links:
                                    pass
                                else:
                                    file_exis = dataset_link.split('indicator/')[1].replace('_',' ') +'.csv'
                                    if file_exis in os.listdir(base_path):
                                        print('the file exist')
                                    else:
                                        dataset_links.append(dataset_link)
                                
                except:
                    datasets = child.find_elements(By.CLASS_NAME,'indicator')
                    for dataset in datasets:
                        dataset_content = dataset.find_element(By.TAG_NAME,'a')
                        dataset_name = dataset_content.text
                        dataset_link = dataset.find_element(By.TAG_NAME,'a').get_attribute('href')
                        if dataset_link == 'https://eige.europa.eu/gender-statistics/dgs#':
                            pass
                        elif dataset_link in dataset_links:
                            pass
                        else:
                            file_exis = dataset_link.split('indicator/')[1].replace('_',' ') +'.csv'
                            if file_exis in os.listdir(base_path):
                                print('the file exist')
                            else:
                                dataset_links.append(dataset_link)
        except:
            datasets = child.find_elements(By.CLASS_NAME,'indicator')
            for dataset in datasets:
                dataset_content = dataset.find_element(By.TAG_NAME,'a')
                dataset_name = dataset_content.text
                dataset_link = dataset.find_element(By.TAG_NAME,'a').get_attribute('href')
                if dataset_link == 'https://eige.europa.eu/gender-statistics/dgs#':
                    pass
                elif dataset_link in dataset_links:
                    pass
                else:
                    file_exis = dataset_link.split('indicator/')[1].replace('_',' ') +'.csv'
                    if file_exis in os.listdir(base_path):
                        print('the file exist')
                    else:
                        dataset_links.append(dataset_link)
    content = driver.find_element(By.CLASS_NAME,'tree')
    tops = content.find_element(By.TAG_NAME,'ul').find_elements(By.TAG_NAME,'li')
# Out:
# INFO:WDM:====== WebDriver manager ======
# INFO:WDM:Get LATEST chromedriver version for google-chrome 111.0.5563
# INFO:WDM:Driver [C:\Users\10235555\.wdm\drivers\chromedriver\win32\111.0.5563\chromedriver.exe] found in cache
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist
# the file exist

# %%
import os
# os.listdir(base_path)
link = 'https://eige.europa.eu/gender-statistics/dgs/indicator/genvio_phy_oth_sur__ewcs_physviolence'
file_exis = link.split('indicator/')[1].replace('_',' ') +'.csv'
if file_exis in os.listdir(base_path):
    print('yes')
else:
    print('no')
# Out:
# yes

# %%
t='ta wrklab lab_emplrate_gen__eqls_everpaidjob'
t.replace('_',' ')
# Out:
# 'ta wrklab lab emplrate gen  eqls everpaidjob'

# %%
len(dataset_links)
# Out:
# 148

# %%
title = 'B1a. Proportion of women graduates in tertiary (ISCED levels 5-8) and vocational (ISCED levels 3-4) education and training in the fields of science, technology, engineering and mathematics (STEM) – of all graduates in the study field'
def limitString(string, limit):
    if len(string) > limit:
        return string[0:limit]
    else:
        return string
limitString(title,180)
# Out:
# 'B1a. Proportion of women graduates in tertiary (ISCED levels 5-8) and vocational (ISCED levels 3-4) education and training in the fields of science, technology, engineering and mat'
