# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import ElementNotInteractableException, NoSuchElementException
from selenium.common.exceptions import ElementClickInterceptedException
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from webdriver_manager.firefox import GeckoDriverManager
from selenium.webdriver.firefox.options import Options
from bs4 import BeautifulSoup
import shutil
import time
import os
import pandas as pd
from pyshadow.main import Shadow
from py7zr import unpack_7zarchive
from RequestInferSchemaToJsonAPI.main import TriggerInferShemaToJsonAPI
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\EIU'

chrome_options = webdriver.ChromeOptions()
base_path = "C:\\Users\\10235555\\Documents\\Dataportal Data\\EIU" # local, gets current working directory
prefs = {'download.default_directory' : base_path}#, "profile.content_settings.exceptions.automatic_downloads.*.setting" : 1}
chrome_options.add_experimental_option('prefs', prefs)
#chrome_options.add_argument('--user-agent="Mozilla/5.0 (Windows Phone 10.0; Android 4.2.1; Microsoft; Lumia 640 XL LTE) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.135 Mobile Safari/537.36 Edge/12.10166"')
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)
driver.maximize_window()

driver.get('https://viewpoint.eiu.com/data')
time.sleep(4)

iframe = driver.find_element(By.XPATH,'//*[@id="sp_message_iframe_770557"]')
driver.switch_to.frame(iframe)

driver.find_element(By.XPATH,'//*[@id="notice"]/div[4]/div[1]/button').click()

# browse_data = driver.find_element(By.CLASS_NAME,'ip_selections-wrapper')
# series = browse_data.find_element(By.CLASS_NAME,'ip-tree-wrapper-column.ip_series-data-tree-container').find_element(By.CLASS_NAME,'root').find_element(By.CLASS_NAME,'infinite-scroll-component').find_elements(By.CLASS_NAME,'node.tree')
# for serie in series:
#     print(serie.text)
#     tag = serie.text
#     input = serie.find_element(By.CLASS_NAME,'checkbox-item')
#     input.click()
#     time.sleep(1)
#     geographies = browse_data.find_element(By.CLASS_NAME,'ip-tree-wrapper-column.ip_geographies-data-tree-container').find_element(By.CLASS_NAME,'ip_data-tree-container').find_element(By.CLASS_NAME,'header').find_element(By.CLASS_NAME,'ip_select-all-button')
#     geographies.click()
#     time.sleep(1)
#     selection = browse_data.find_element(By.CLASS_NAME,'ip_selections-data-tree-container').find_element(By.CLASS_NAME,'ip_data-tree-wrapper.ip_data-tree-selection').find_element(By.CLASS_NAME,'ip_selections-buttons')
#     view_table = selection.find_element(By.CLASS_NAME,'ds-button')
#     view_table.click()
#     time.sleep(4)

#     from selenium.webdriver.common.action_chains import ActionChains
#     element = driver.find_element(By.CLASS_NAME,'ipd_data-results_series-geo-selector')
#     actions = ActionChains(driver)
#     actions.move_to_element(element).perform()
#     selector_data = driver.find_element(By.CLASS_NAME,'ipd_data-results_series-geo-selector').find_element(By.CLASS_NAME,'ipd_viewby-series-dropdown')
#     part_Series = selector_data.find_element(By.CLASS_NAME,'select-by-series__value-container.select-by-series__value-container--has-value.css-1hwfws3')
#     part_Series.click()
#     time.sleep(3)
#     categories = driver.find_elements(By.CLASS_NAME,'select-by-series__option.css-1004i92-option')#.get_attribute('innerHTML')
#     for k in range(len(categories)) :
#         title = categories[k].text
#         title = title.replace('/',' ').replace(':',' ').replace('!',' ').replace('?',' ').replace('[',' ').replace(']',' ').replace("'",' ').replace('"',' ')
#         if title == '':
#             title = driver.find_element(By.CLASS_NAME,'ip_metadata-table.ip_metadata-table-with-link-col').find_element(By.TAG_NAME,'h2').text.split('\n')[1]
#         # else:
#         categories[k].click()
#         time.sleep(5)
#         from selenium.common.exceptions import TimeoutException
#         delay = 7 # seconds
#         try:
#             myElem = WebDriverWait(driver, delay).until(EC.presence_of_element_located((By.CLASS_NAME,'ipd_data-results_series-geo-selector')))
#         except TimeoutException:
#             print("Loading took too much time!")
        
#         try:
#             download = driver.find_element(By.CLASS_NAME,'ip_download').find_element(By.CLASS_NAME,'ds-actioned-link.ds-actioned-link--download')
#             download.click()
#             time.sleep(1)
#             csv_form = driver.find_element(By.CLASS_NAME,'ds__link-list').find_element(By.CLASS_NAME,'ds-navigation-link')
#             csv_form.click()
#             time.sleep(3)
#             def latest_download_file():
#                 path = base_path
#                 os.chdir(path)
#                 files = sorted(os.listdir(os.getcwd()), key=os.path.getmtime)
#                 newest = files[-1]

#                 return newest

#             fileends = "crdownload"
#             while "crdownload" == fileends:
#                 time.sleep(4) 
#                 newest_file = latest_download_file()
#                 if "crdownload" in newest_file:
#                     fileends = "crdownload"
#                 else:
#                     fileends = "None"
#             latest_download_file() 
#             file = f'{base_path}\\table.csv'
#             file_name = tag + ' ' + title
#             print(file_name)
#             os.rename(file,f'{base_path}\\{file_name}.csv')
#             selector_data = driver.find_element(By.CLASS_NAME,'ipd_data-results_series-geo-selector').find_element(By.CLASS_NAME,'ipd_viewby-series-dropdown')
#             part_Series = selector_data.find_element(By.CLASS_NAME,'select-by-series__value-container.select-by-series__value-container--has-value.css-1hwfws3')
#             part_Series.click()
#             time.sleep(2)
#             categories = driver.find_element(By.CLASS_NAME,'select-by-series__menu.css-8plzl5-menu').find_elements(By.CLASS_NAME,'select-by-series__option.css-1004i92-option')
#         except:
#             no_data = driver.find_element(By.CLASS_NAME,'ipd_search-no-results')
#             # driver.find_elements(By.CLASS_NAME,'select-by-series__option.css-1004i92-option')[k].click()
#             # time.sleep(5)
#             from selenium.common.exceptions import TimeoutException
#             delay = 7 # seconds
#             try:
#                 myElem = WebDriverWait(driver, delay).until(EC.presence_of_element_located((By.CLASS_NAME,'ip_download')))
#             except TimeoutException:
#                 print("Loading took too much time!")
#             selector_data = driver.find_element(By.CLASS_NAME,'ipd_data-results_series-geo-selector').find_element(By.CLASS_NAME,'ipd_viewby-series-dropdown')
#             part_Series = selector_data.find_element(By.CLASS_NAME,'select-by-series__value-container.select-by-series__value-container--has-value.css-1hwfws3')
#             part_Series.click()
#             time.sleep(3)
#             categories = driver.find_element(By.CLASS_NAME,'select-by-series__menu.css-8plzl5-menu').find_elements(By.CLASS_NAME,'select-by-series__option.css-1004i92-option')

#     start_new = driver.find_element(By.CLASS_NAME,'ipd_search-container').find_element(By.CLASS_NAME,'ds-link-with-arrow-icon')
#     start_new.click()
#     time.sleep(4)
#     browse_data = driver.find_element(By.CLASS_NAME,'ip_selections-wrapper')
#     series = browse_data.find_element(By.CLASS_NAME,'ip-tree-wrapper-column ip_series-data-tree-container').find_element(By.CLASS_NAME,'root').find_element(By.CLASS_NAME,'infinite-scroll-component').find_elements(By.CLASS_NAME,'node.tree')

# %%
from selenium.webdriver.common.action_chains import ActionChains
element = driver.find_element(By.CLASS_NAME,'ipd_data-results_series-geo-selector')
actions = ActionChains(driver)
actions.move_to_element(element).perform()
selector_data = driver.find_element(By.CLASS_NAME,'ipd_data-results_series-geo-selector').find_element(By.CLASS_NAME,'ipd_viewby-series-dropdown')
part_Series = selector_data.find_element(By.CLASS_NAME,'select-by-series__value-container.select-by-series__value-container--has-value.css-1hwfws3')
part_Series.click()
time.sleep(3)
categories = driver.find_elements(By.CLASS_NAME,'select-by-series__option.css-1004i92-option')#.get_attribute('innerHTML')
for c in categories:
    print(c.text)
# Out:
# CER Emissions: Nominal spot price ($)
# CER Emissions: Real Price (Constant 2005 LCU)
# CO2 emissions: Coal (% change y/y)
# CO2 emissions: Coal (% of total)
# CO2 emissions: Coal (% of world total)
# CO2 emissions: Coal (Mt of CO2)
# CO2 emissions: Natural gas (% change y/y)
# CO2 emissions: Natural gas (% of total)
# CO2 emissions: Natural gas (% of world total)
# CO2 emissions: Natural gas (Mt of CO2)
# CO2 emissions: Oil (% change y/y)
# CO2 emissions: Oil (% of total)
# CO2 emissions: Oil (% of world total)
# CO2 emissions: Oil (Mt of CO2)
# CO2 emissions: Other (% change y/y)
# CO2 emissions: Other (% of total)
# CO2 emissions: Other (Mt of CO2)
# Coal (Australian): Index (2005=100)
# Coal (Australian): Nominal Price (LCU)
# Coal (Australian): Nominal spot price (US$)
# Coal (Australian): Real Price (Constant 2005 LCU)
# Coal (South African): Index (2005=100)
# Coal (South African): Nominal Price (LCU)
# Coal (South African): Nominal spot price ($)
# Coal (South African): Real Price (Constant 2005 LCU)
# Coal: Coal Production (ktoe)
# Coal: Gross domestic energy consumption (% change y/y)
# Coal: Gross domestic energy consumption (% of total)
# Coal: Gross domestic energy consumption (% of world total)
# Coal: Gross domestic energy consumption (ktoe)
# Coal: Net imports (% of total consumption)
# Coal: Net imports (ktoe)
# Coal: Total exports (ktoe)
# Coal: Total imports (ktoe)
# Combustible renewables and waste consumption (% change y/y)
# Combustible renewables and waste consumption (% of total)
# Combustible renewables and waste consumption (ktoe)
# Combustible renewables and waste: Gross domestic energy consumption (% of world total)
# Commercial and Public Services: Energy consumption (% of total)
# Commercial and public services: Energy consumption (ktoe)
# Crude oil and NGL production (kb/d)
# Crude oil and NGL: Exports (kb/d)
# Crude oil and NGL: Imports (kb/d)
# Crude oil and NGL: Net imports (kb/d)
# Crude oil: Net imports (% of total consumption)
# Crude refinery capacity (kb/d)
# Electricity (net imports): Gross domestic energy consumption (% of total)
# Electricity (net imports): Total primary energy supply (ktoe)
# Electricity capacity: Combustible Fuels (Mwe)
# Electricity capacity: Geothermal (Mwe)
# Electricity capacity: Hydro (Mwe)
# Electricity capacity: Nuclear (Mwe)
# Electricity capacity: Other non-hydro renewables (Mwe)
# Electricity capacity: Solar (Mwe)
# Electricity capacity: Tide/Wave/Ocean (Mwe)
# Electricity capacity: Wind (Mwe)
# Electricity generation: Coal (GWh)
# Electricity generation: Combustible Fuels (GWh)
# Electricity generation: Geothermal (GWh)
# Electricity generation: Hydro (GWh)
# Electricity generation: Natural Gas (GWh)
# Electricity generation: Nuclear (GWh)
# Electricity generation: Oil (GWh)
# Electricity generation: Other (GWh)
# Electricity generation: Other non-hydro renewables (GWh)
# Electricity generation: Solar (GWh)
# Electricity generation: Tide/Wave/Ocean (GWh)
# Electricity generation: Wind (GWh)
# Electricity sector: Energy consumption (% of total)
# Electricity: Energy consumption (ktoe)
# Electricity: Gross domestic energy consumption (% change y/y)
# Electricity: Net imports (% of total consumption)
# Electricity: Net imports (GWh)
# Electricity: Total exports (GWh)
# Electricity: Total imports (GWh)
# Energy intensity: coal consumption (Ktoe per capita)
# Energy intensity: Coal consumption (toe per US$m 2005 GDP)
# Energy intensity: natural gas consumption (Ktoe per capita)
# Energy intensity: Natural gas consumption (toe per US$m 2005 GDP)
# Energy intensity: nuclear consumption (Ktoe per capita)
# Energy intensity: Nuclear power consumption (toe per US$m 2005 GDP)
# Energy intensity: petroleum consumption (Ktoe per capita)
# Energy intensity: Petroleum consumption (toe per US$m 2005 GDP)
# Energy intensity: total energy consumption (Ktoe per capita)
# Energy intensity: Total energy consumption (toe per US$m 2005 GDP)
# Energy: Market demand (% real change pa)
# Energy: Market demand (nominal US$)
# Energy: Market demand (US$ at 2005 constant prices)
# EUA Emissions: Index (2005=100)
# EUA Emissions: Nominal Price (LCU)
# EUA Emissions: Nominal spot price ($)
# EUA Emissions: Real Price (Constant 2005 LCU)
# Gasoil: Index (2005=100)
# Gasoil: Nominal Price (LCU)
# Gasoil: Nominal spot price ($)
# Gasoil: Real Price (Constant 2005 LCU)
# Gasoline: Index (2005=100)
# Gasoline: Nominal Price (LCU)
# Gasoline: Nominal spot price ($)
# Gasoline: Real Price (Constant 2005 LCU)
# Geothermal: Gross domestic energy consumption (% of total)
# Geothermal: Gross domestic energy consumption (% of world total)
# Geothermal: Gross domestic energy consumption (ktoe)
# Gross domestic electricity consumption (GWh)
# Gross domestic energy consumption (% of 1990 level)
# Gross domestic energy consumption (ktoe)
# Gross Electricity Generation (Gwh)
# Heating Oil: Index (2005=100)
# Heating Oil: Nominal Price (LCU)
# Heating Oil: Nominal spot price ($)
# Heating Oil: Real Price (Constant 2005 LCU)
# Hydro: Gross domestic energy consumption (% of total)
# Hydro: Gross domestic energy consumption (% of world total)
# Hydro: Gross domestic energy consumption (ktoe)
# Industry: Energy consumption (% of total)
# Industry: Energy consumption (ktoe)
# Natural Gas (Europe): Index (2005=100)
# Natural Gas (Europe): Nominal Price (LCU)
# Natural Gas (Europe): Nominal spot price ($)
# Natural Gas (Europe): Real Price (Constant 2005 LCU)
# Natural Gas (Henry Hub): Index (2005=100)
# Natural Gas (Henry Hub): Nominal Price (LCU)
# Natural Gas (Henry Hub): Nominal spot price (US$)
# Natural Gas (Henry Hub): Real Price (Constant 2005 LCU)
# Natural Gas (Russia): Index (2005=100)
# Natural Gas (Russia): Nominal Price (LCU)
# Natural Gas (Russia): Nominal spot price ($)
# Natural Gas (Russia): Real Price (Constant 2005 LCU)
# Natural Gas Production (ktoe)
# Natural Gas: Gross domestic energy consumption (% change y/y)
# Natural Gas: Gross domestic energy consumption (% of total)
# Natural Gas: Gross domestic energy consumption (% of world total)
# Natural Gas: Gross domestic energy consumption (ktoe)
# Natural gas: Net imports (% of total consumption)
# Natural gas: Net imports (ktoe)
# Natural gas: Total exports (ktoe)
# Natural gas: Total imports (ktoe)
# Net maximum electrical capacity (Mwe)
# Nuclear: Gross domestic energy consumption (% change y/y)
# Nuclear: Gross domestic energy consumption (% of total)
# Nuclear: Gross domestic energy consumption (% of world total)
# Nuclear: Gross domestic energy consumption (ktoe)
# Oil (Brent): Index (2005=100)
# Oil (Brent): Nominal Price (LCU)
# Oil (Brent): Nominal spot price (US$)
# Oil (Brent): Real Price (2005 LCU)
# Oil (Dubai): Index (2005=100)
# Oil (Dubai): Nominal Price (LCU)
# Oil (Dubai): Nominal spot price (US$)
# Oil (Dubai): Real Price (Constant 2005 LCU)
# Oil (WTI): Index (2005=100)
# Oil (WTI): Nominal Price (LCU)
# Oil (WTI): Nominal spot price (US$)
# Oil (WTI): Real Price (Constant 2005 LCUl)
# Other: Energy consumption (% of total)
# Other: Energy consumption (ktoe)
# Petroleum products: Exports (kb/d)
# Petroleum products: Gross domestic consumption (% change y/y)
# Petroleum products: Gross domestic consumption (% of total)
# Petroleum products: Gross domestic consumption (ktoe)
# Petroleum Products: Gross domestic energy consumption (% of world total)
# Petroleum products: Imports (kb/d)
# Petroleum products: Net imports (kb/d)
# Residential :Energy consumption (% of total)
# Residential: Energy consumption (ktoe)
# Solar/wind/other: Gross domestic energy consumption (% of total)
# Solar/wind/other: Gross domestic energy consumption (% of world total)
# Solar/wind/other: Gross domestic energy consumption (ktoe)
# Total CO2 emissions from fuel combustion (% of 1990 level)
# Total CO2 emissions from fuel combustion (% of world total)
# Total CO2 emissions from fuel combustion (kg per US$ 2005 GDP)
# Total CO2 emissions from fuel combustion (Mt of CO2)
# Total CO2 emissions from fuel combustion (tonnes per head)
# Total gross domestic energy consumption (% of world total)
# Total number of reactors
# Transport: Energy consumption (% of total)
# Transport: Energy consumption (ktoe)
# UK Base Electricity: Index (2005=100)
# UK Base Electricity: Nominal Price (LCU)
# UK Base Electricity: Nominal spot price ($)
# UK Base Electricity: Real Price (Constant 2005 LCU)

# %%
driver.find_element(By.CSS_SELECTOR,'div.')

# %%
# library
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import ElementNotInteractableException, NoSuchElementException
from selenium.common.exceptions import ElementClickInterceptedException
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from webdriver_manager.firefox import GeckoDriverManager
from selenium.webdriver.firefox.options import Options
from bs4 import BeautifulSoup
import shutil
import time
import os
import pandas as pd
from pyshadow.main import Shadow
from py7zr import unpack_7zarchive
from RequestInferSchemaToJsonAPI.main import TriggerInferShemaToJsonAPI
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\EIU'

#driver selenium
chrome_options = webdriver.ChromeOptions()
base_path = "C:\\Users\\10235555\\Documents\\Dataportal Data\\EIU" # local, gets current working directory
prefs = {'download.default_directory' : base_path}#, "profile.content_settings.exceptions.automatic_downloads.*.setting" : 1}
chrome_options.add_experimental_option('prefs', prefs)
#chrome_options.add_argument('--user-agent="Mozilla/5.0 (Windows Phone 10.0; Android 4.2.1; Microsoft; Lumia 640 XL LTE) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.135 Mobile Safari/537.36 Edge/12.10166"')
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)
driver.maximize_window()

# source url
driver.get('https://viewpoint.eiu.com/data')
time.sleep(4)

# cookies in iframe
iframe = driver.find_element(By.XPATH,'//*[@id="sp_message_iframe_770557"]')
driver.switch_to.frame(iframe)

driver.find_element(By.XPATH,'//*[@id="notice"]/div[4]/div[1]/button').click()

# check boxes
browse_data = driver.find_element(By.CLASS_NAME,'ip_selections-wrapper')
series = browse_data.find_element(By.CLASS_NAME,'ip-tree-wrapper-column.ip_series-data-tree-container').find_element(By.CLASS_NAME,'root').find_element(By.CLASS_NAME,'infinite-scroll-component').find_elements(By.CLASS_NAME,'node.tree')
for serie in series:
    print(serie.text)
    tag = serie.text
    input = serie.find_element(By.CLASS_NAME,'checkbox-item')
    input.click()
    time.sleep(1)
    geographies = browse_data.find_element(By.CLASS_NAME,'ip-tree-wrapper-column.ip_geographies-data-tree-container').find_element(By.CLASS_NAME,'ip_data-tree-container').find_element(By.CLASS_NAME,'header').find_element(By.CLASS_NAME,'ip_select-all-button')
    geographies.click()
    time.sleep(1)
    selection = browse_data.find_element(By.CLASS_NAME,'ip_selections-data-tree-container').find_element(By.CLASS_NAME,'ip_data-tree-wrapper.ip_data-tree-selection').find_element(By.CLASS_NAME,'ip_selections-buttons')
    view_table = selection.find_element(By.CLASS_NAME,'ds-button')
    view_table.click()
    time.sleep(4)

    # select by hidden elements by click
    from selenium.webdriver.common.action_chains import ActionChains
    element = driver.find_element(By.CLASS_NAME,'ipd_data-results_series-geo-selector')
    actions = ActionChains(driver)
    actions.move_to_element(element).perform()
    selector_data = driver.find_element(By.CLASS_NAME,'ipd_data-results_series-geo-selector').find_element(By.CLASS_NAME,'ipd_viewby-series-dropdown')
    part_Series = selector_data.find_element(By.CLASS_NAME,'select-by-series__value-container.select-by-series__value-container--has-value.css-1hwfws3')
    part_Series.click()
    time.sleep(2)
    categories = driver.find_elements(By.CLASS_NAME,'select-by-series__option.css-1004i92-option')#.get_attribute('innerHTML')
    for k in range(len(categories)) :
        title = categories[k].text
        # the title direct open after view table be empty ''
        if title == '':
            title = driver.find_element(By.CLASS_NAME,'ip_metadata-table.ip_metadata-table-with-link-col').find_element(By.TAG_NAME,'h2').text.split('\n')[1]

            driver.find_element(By.CLASS_NAME,'select-by-series__option.css-1004i92-option}')[k].click()
            time.sleep(5)
            from selenium.common.exceptions import TimeoutException
            delay = 3 # seconds
            try:
                myElem = WebDriverWait(driver, delay).until(EC.presence_of_element_located((By.CLASS_NAME,'ipd_data-results_series-geo-selector')))
            except TimeoutException:
                print("Loading took too much time!")

            try:
                download = driver.find_element(By.CLASS_NAME,'ip_download').find_element(By.CLASS_NAME,'ds-actioned-link.ds-actioned-link--download')
                download.click()
                time.sleep(1)
                # table_data = driver.find_element(By.ID,'Access-To-Local-Markets-0-4--download-options')
                csv_form = driver.find_element(By.CLASS_NAME,'ds__link-list').find_element(By.CLASS_NAME,'ds-navigation-link')
                csv_form.click()
                time.sleep(3)
                def latest_download_file():
                    path = base_path
                    os.chdir(path)
                    files = sorted(os.listdir(os.getcwd()), key=os.path.getmtime)
                    newest = files[-1]

                    return newest

                fileends = "crdownload"
                while "crdownload" == fileends:
                    time.sleep(4) 
                    newest_file = latest_download_file()
                    if "crdownload" in newest_file:
                        fileends = "crdownload"
                        # time.sleep(5)
                    else:
                        fileends = "None"
                latest_download_file() 
                file = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\EIU\\table.csv'
                file_name = tag + ' ' + title
                print(file_name)
                os.rename(file,f'{base_path}\\{file_name}.csv')
                selector_data = driver.find_element(By.CLASS_NAME,'ipd_data-results_series-geo-selector').find_element(By.CLASS_NAME,'ipd_viewby-series-dropdown')
                part_Series = selector_data.find_element(By.CLASS_NAME,'select-by-series__value-container.select-by-series__value-container--has-value.css-1hwfws3')
                part_Series.click()
                time.sleep(2)
                categories = driver.find_element(By.CLASS_NAME,'select-by-series__menu.css-8plzl5-menu').find_elements(By.CLASS_NAME,'select-by-series__option.css-1004i92-option')
            except:
                driver.find_element(By.CLASS_NAME,'ipd_search-no-results').find_element(By.TAG_NAME,'h3')
                driver.find_elements(By.CLASS_NAME,'select-by-series__option.css-1004i92-option')[k].click()
                time.sleep(5)
                from selenium.common.exceptions import TimeoutException
                delay = 5 # seconds
                try:
                    myElem = WebDriverWait(driver, delay).until(EC.presence_of_element_located((By.CLASS_NAME,'ip_download')))
                except TimeoutException:
                    print("Loading took too much time!")
                selector_data = driver.find_element(By.CLASS_NAME,'ipd_data-results_series-geo-selector').find_element(By.CLASS_NAME,'ipd_viewby-series-dropdown')
                part_Series = selector_data.find_element(By.CLASS_NAME,'select-by-series__value-container.select-by-series__value-container--has-value.css-1hwfws3')
                part_Series.click()
                time.sleep(3)
                categories = driver.find_element(By.CLASS_NAME,'select-by-series__menu.css-8plzl5-menu').find_elements(By.CLASS_NAME,'select-by-series__option.css-1004i92-option')
        else:
            title = title.replace('/',' ').replace(':',' ').replace('!',' ').replace('?',' ').replace('[',' ').replace(']',' ').replace("'",' ').replace('"',' ')
            driver.find_element(By.CLASS_NAME,'select-by-series__option.css-1004i92-option}')[k].click()
            time.sleep(5)
            from selenium.common.exceptions import TimeoutException
            delay = 3 # seconds
            try:
                myElem = WebDriverWait(driver, delay).until(EC.presence_of_element_located((By.CLASS_NAME,'ipd_data-results_series-geo-selector')))
            except TimeoutException:
                print("Loading took too much time!")

            try:
                download = driver.find_element(By.CLASS_NAME,'ip_download').find_element(By.CLASS_NAME,'ds-actioned-link.ds-actioned-link--download')
                download.click()
                time.sleep(1)
                # table_data = driver.find_element(By.ID,'Access-To-Local-Markets-0-4--download-options')
                csv_form = driver.find_element(By.CLASS_NAME,'ds__link-list').find_element(By.CLASS_NAME,'ds-navigation-link')
                csv_form.click()
                time.sleep(3)
                def latest_download_file():
                    path = base_path
                    os.chdir(path)
                    files = sorted(os.listdir(os.getcwd()), key=os.path.getmtime)
                    newest = files[-1]

                    return newest

                fileends = "crdownload"
                while "crdownload" == fileends:
                    time.sleep(4) 
                    newest_file = latest_download_file()
                    if "crdownload" in newest_file:
                        fileends = "crdownload"
                        # time.sleep(5)
                    else:
                        fileends = "None"
                latest_download_file() 
                file = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\EIU\\table.csv'
                file_name = tag + ' ' + title
                print(file_name)
                os.rename(file,f'{base_path}\\{file_name}.csv')
                selector_data = driver.find_element(By.CLASS_NAME,'ipd_data-results_series-geo-selector').find_element(By.CLASS_NAME,'ipd_viewby-series-dropdown')
                part_Series = selector_data.find_element(By.CLASS_NAME,'select-by-series__value-container.select-by-series__value-container--has-value.css-1hwfws3')
                part_Series.click()
                time.sleep(2)
                categories = driver.find_element(By.CLASS_NAME,'select-by-series__menu.css-8plzl5-menu').find_elements(By.CLASS_NAME,'select-by-series__option.css-1004i92-option')
            except:
                driver.find_element(By.CLASS_NAME,'ipd_search-no-results').find_element(By.TAG_NAME,'h3')
                driver.find_elements(By.CLASS_NAME,'select-by-series__option.css-1004i92-option')[k].click()
                time.sleep(5)
                from selenium.common.exceptions import TimeoutException
                delay = 5 # seconds
                try:
                    myElem = WebDriverWait(driver, delay).until(EC.presence_of_element_located((By.CLASS_NAME,'ip_download')))
                except TimeoutException:
                    print("Loading took too much time!")
                selector_data = driver.find_element(By.CLASS_NAME,'ipd_data-results_series-geo-selector').find_element(By.CLASS_NAME,'ipd_viewby-series-dropdown')
                part_Series = selector_data.find_element(By.CLASS_NAME,'select-by-series__value-container.select-by-series__value-container--has-value.css-1hwfws3')
                part_Series.click()
                time.sleep(3)
                categories = driver.find_element(By.CLASS_NAME,'select-by-series__menu.css-8plzl5-menu').find_elements(By.CLASS_NAME,'select-by-series__option.css-1004i92-option')
    # browse new series check boxes
    start_new = driver.find_element(By.CLASS_NAME,'ipd_search-container').find_element(By.CLASS_NAME,'ds-link-with-arrow-icon')
    start_new.click()
    time.sleep(4)
    browse_data = driver.find_element(By.CLASS_NAME,'ip_selections-wrapper')
    series = browse_data.find_element(By.CLASS_NAME,'ip-tree-wrapper-column ip_series-data-tree-container').find_element(By.CLASS_NAME,'root').find_element(By.CLASS_NAME,'infinite-scroll-component').find_elements(By.CLASS_NAME,'node.tree')
# Out:
# Operational Risk
# ---------------------------------------------------------------------------
# InvalidSelectorException                  Traceback (most recent call last)
# c:\Users\10235555\Documents\DataportalCrawlers\UN_Data\EIU.ipynb Cell 3 in 7
#      <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/EIU.ipynb#X45sZmlsZQ%3D%3D?line=71'>72</a> if title == '':
#      <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/EIU.ipynb#X45sZmlsZQ%3D%3D?line=72'>73</a>     title = driver.find_element(By.CLASS_NAME,'ip_metadata-table.ip_metadata-table-with-link-col').find_element(By.TAG_NAME,'h2').text.split('\n')[1]
# ---> <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/EIU.ipynb#X45sZmlsZQ%3D%3D?line=74'>75</a>     driver.find_element(By.CLASS_NAME,'select-by-series__option.css-1004i92-option}')[k].click()
#      <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/EIU.ipynb#X45sZmlsZQ%3D%3D?line=75'>76</a>     time.sleep(5)
#      <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/EIU.ipynb#X45sZmlsZQ%3D%3D?line=76'>77</a>     from selenium.common.exceptions import TimeoutException
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\webdriver.py:861, in WebDriver.find_element(self, by, value)
#     858     by = By.CSS_SELECTOR
#     859     value = '[name="%s"]' % value
# --> 861 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\webdriver.py:444, in WebDriver.execute(self, driver_command, params)
#     442 response = self.command_executor.execute(driver_command, params)
#     443 if response:
# --> 444     self.error_handler.check_response(response)
#     445     response["value"] = self._unwrap_value(response.get("value", None))
#     446     return response
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:249, in ErrorHandler.check_response(self, response)
#     247         alert_text = value["alert"].get("text")
#     248     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 249 raise exception_class(message, screen, stacktrace)
#
# InvalidSelectorException: Message: invalid selector: An invalid or illegal selector was specified
#   (Session info: chrome=112.0.5615.138)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x0100DCE3+50899]
# 	(No symbol) [0x00F9E111]
# 	(No symbol) [0x00EA5588]
# 	(No symbol) [0x00EA7EDB]
# 	(No symbol) [0x00EA7DB0]
# 	(No symbol) [0x00EA8030]
# 	(No symbol) [0x00ED0552]
# 	(No symbol) [0x00ED0AFB]
# 	(No symbol) [0x00EFF902]
# 	(No symbol) [0x00EEB944]
# 	(No symbol) [0x00EFE01C]
# 	(No symbol) [0x00EEB6F6]
# 	(No symbol) [0x00EC7708]
# 	(No symbol) [0x00EC886D]
# 	GetHandleVerifier [0x01273EAE+2566302]
# 	GetHandleVerifier [0x012A92B1+2784417]
# 	GetHandleVerifier [0x012A327C+2759788]
# 	GetHandleVerifier [0x010A5740+672048]
# 	(No symbol) [0x00FA8872]
# 	(No symbol) [0x00FA41C8]
# 	(No symbol) [0x00FA42AB]
# 	(No symbol) [0x00F971B7]
# 	BaseThreadInitThunk [0x757D00F9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77327BBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77327B8E+238]

# %%
selector_data = driver.find_element(By.CLASS_NAME,'ipd_data-results_series-geo-selector').find_element(By.CLASS_NAME,'ipd_viewby-series-dropdown')
part_Series = selector_data.find_element(By.CLASS_NAME,'select-by-series__value-container.select-by-series__value-container--has-value.css-1hwfws3')
part_Series.click()

# %%
driver.find_element(By.CLASS_NAME,'select-by-series__option.css-1004i92-option').get_attribute('innerHTML')#.click()#select-by-series__menu.css-8plzl5-menu
# Out:
# 'Accountability Of Public Officials (0-4)'

# %%
from selenium.webdriver.common.action_chains import ActionChains
element = driver.find_element(By.CLASS_NAME,'ipd_data-results_series-geo-selector')
actions = ActionChains(driver)
actions.move_to_element(element).perform()
selector_data = driver.find_element(By.CLASS_NAME,'ipd_data-results_series-geo-selector').find_element(By.CLASS_NAME,'ipd_viewby-series-dropdown')
part_Series = selector_data.find_element(By.CLASS_NAME,'select-by-series__value-container.select-by-series__value-container--has-value.css-1hwfws3')
part_Series.click()
time.sleep(3)
categories = driver.find_elements(By.CLASS_NAME,'select-by-series__option.css-1004i92-option')#.get_attribute('innerHTML')
for k in range(len(categories)) :
    if title == '':
        title = driver.find_element(By.CLASS_NAME,'ip_metadata-table.ip_metadata-table-with-link-col').find_element(By.TAG_NAME,'h2').text.split('\n')[1]
        driver.find_elements(By.CLASS_NAME,'select-by-series__option.css-1004i92-option')[k].click()
        time.sleep(5)
        from selenium.common.exceptions import TimeoutException
        delay = 7 # seconds
        try:
            myElem = WebDriverWait(driver, delay).until(EC.presence_of_element_located((By.CLASS_NAME,'ipd_data-results_series-geo-selector')))
        except TimeoutException:
            print("Loading took too much time!")

        try:
            download = driver.find_element(By.CLASS_NAME,'ip_download').find_element(By.CLASS_NAME,'ds-actioned-link.ds-actioned-link--download')
            download.click()
            time.sleep(1)
            # table_data = driver.find_element(By.ID,'Access-To-Local-Markets-0-4--download-options')
            csv_form = driver.find_element(By.CLASS_NAME,'ds__link-list').find_element(By.CLASS_NAME,'ds-navigation-link')
            csv_form.click()
            time.sleep(3)
            def latest_download_file():
                path = base_path
                os.chdir(path)
                files = sorted(os.listdir(os.getcwd()), key=os.path.getmtime)
                newest = files[-1]

                return newest

            fileends = "crdownload"
            while "crdownload" == fileends:
                time.sleep(4) 
                newest_file = latest_download_file()
                if "crdownload" in newest_file:
                    fileends = "crdownload"
                    # time.sleep(5)
                else:
                    fileends = "None"
            latest_download_file() 
            file = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\EIU\\table.csv'
            file_name = tag + ' ' + title
            print(file_name)
            os.rename(file,f'{base_path}\\{file_name}.csv')
            selector_data = driver.find_element(By.CLASS_NAME,'ipd_data-results_series-geo-selector').find_element(By.CLASS_NAME,'ipd_viewby-series-dropdown')
            part_Series = selector_data.find_element(By.CLASS_NAME,'select-by-series__value-container.select-by-series__value-container--has-value.css-1hwfws3')
            part_Series.click()
            time.sleep(2)
            categories = driver.find_element(By.CLASS_NAME,'select-by-series__menu.css-8plzl5-menu').find_elements(By.CLASS_NAME,'select-by-series__option.css-1004i92-option')
        except:
            driver.find_element(By.CLASS_NAME,'ipd_search-no-results').find_element(By.TAG_NAME,'h3')
            driver.find_elements(By.CLASS_NAME,'select-by-series__option.css-1004i92-option')[k].click()
            time.sleep(5)
            from selenium.common.exceptions import TimeoutException
            delay = 5 # seconds
            try:
                myElem = WebDriverWait(driver, delay).until(EC.presence_of_element_located((By.CLASS_NAME,'ip_download')))
            except TimeoutException:
                print("Loading took too much time!")
            selector_data = driver.find_element(By.CLASS_NAME,'ipd_data-results_series-geo-selector').find_element(By.CLASS_NAME,'ipd_viewby-series-dropdown')
            part_Series = selector_data.find_element(By.CLASS_NAME,'select-by-series__value-container.select-by-series__value-container--has-value.css-1hwfws3')
            part_Series.click()
            time.sleep(3)
            categories = driver.find_element(By.CLASS_NAME,'select-by-series__menu.css-8plzl5-menu').find_elements(By.CLASS_NAME,'select-by-series__option.css-1004i92-option')
    else:
        title = categories[k].text
        title = title.replace('/',' ').replace(':',' ').replace('!',' ').replace('?',' ').replace('[',' ').replace(']',' ').replace("'",' ').replace('"',' ')
        driver.find_elements(By.CLASS_NAME,'select-by-series__option.css-1004i92-option')[k].click()
        time.sleep(5)
        from selenium.common.exceptions import TimeoutException
        delay = 7 # seconds
        try:
            myElem = WebDriverWait(driver, delay).until(EC.presence_of_element_located((By.CLASS_NAME,'ipd_data-results_series-geo-selector')))
        except TimeoutException:
            print("Loading took too much time!")

        try:
            download = driver.find_element(By.CLASS_NAME,'ip_download').find_element(By.CLASS_NAME,'ds-actioned-link.ds-actioned-link--download')
            download.click()
            time.sleep(1)
            # table_data = driver.find_element(By.ID,'Access-To-Local-Markets-0-4--download-options')
            csv_form = driver.find_element(By.CLASS_NAME,'ds__link-list').find_element(By.CLASS_NAME,'ds-navigation-link')
            csv_form.click()
            time.sleep(3)
            def latest_download_file():
                path = base_path
                os.chdir(path)
                files = sorted(os.listdir(os.getcwd()), key=os.path.getmtime)
                newest = files[-1]

                return newest

            fileends = "crdownload"
            while "crdownload" == fileends:
                time.sleep(4) 
                newest_file = latest_download_file()
                if "crdownload" in newest_file:
                    fileends = "crdownload"
                    # time.sleep(5)
                else:
                    fileends = "None"
            latest_download_file() 
            file = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\EIU\\table.csv'
            file_name = tag + ' ' + title
            print(file_name)
            os.rename(file,f'{base_path}\\{file_name}.csv')
            selector_data = driver.find_element(By.CLASS_NAME,'ipd_data-results_series-geo-selector').find_element(By.CLASS_NAME,'ipd_viewby-series-dropdown')
            part_Series = selector_data.find_element(By.CLASS_NAME,'select-by-series__value-container.select-by-series__value-container--has-value.css-1hwfws3')
            part_Series.click()
            time.sleep(2)
            categories = driver.find_element(By.CLASS_NAME,'select-by-series__menu.css-8plzl5-menu').find_elements(By.CLASS_NAME,'select-by-series__option.css-1004i92-option')
        except:
            driver.find_element(By.CLASS_NAME,'ipd_search-no-results').find_element(By.TAG_NAME,'h3')
            driver.find_elements(By.CLASS_NAME,'select-by-series__option.css-1004i92-option')[k].click()
            time.sleep(5)
            from selenium.common.exceptions import TimeoutException
            delay = 5 # seconds
            try:
                myElem = WebDriverWait(driver, delay).until(EC.presence_of_element_located((By.CLASS_NAME,'ip_download')))
            except TimeoutException:
                print("Loading took too much time!")
            selector_data = driver.find_element(By.CLASS_NAME,'ipd_data-results_series-geo-selector').find_element(By.CLASS_NAME,'ipd_viewby-series-dropdown')
            part_Series = selector_data.find_element(By.CLASS_NAME,'select-by-series__value-container.select-by-series__value-container--has-value.css-1hwfws3')
            part_Series.click()
            time.sleep(3)
            categories = driver.find_element(By.CLASS_NAME,'select-by-series__menu.css-8plzl5-menu').find_elements(By.CLASS_NAME,'select-by-series__option.css-1004i92-option')
# Out:
# ---------------------------------------------------------------------------
# ElementNotInteractableException           Traceback (most recent call last)
# c:\Users\10235555\Documents\DataportalCrawlers\UN_Data\EIU.ipynb Cell 6 in 7
#      <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/EIU.ipynb#X41sZmlsZQ%3D%3D?line=72'>73</a> title = categories[k].text
#      <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/EIU.ipynb#X41sZmlsZQ%3D%3D?line=73'>74</a> title = title.replace('/',' ').replace(':',' ').replace('!',' ').replace('?',' ').replace('[',' ').replace(']',' ').replace("'",' ').replace('"',' ')
# ---> <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/EIU.ipynb#X41sZmlsZQ%3D%3D?line=74'>75</a> driver.find_elements(By.CLASS_NAME,'select-by-series__option.css-1004i92-option')[k].click()
#      <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/EIU.ipynb#X41sZmlsZQ%3D%3D?line=75'>76</a> time.sleep(5)
#      <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/EIU.ipynb#X41sZmlsZQ%3D%3D?line=76'>77</a> from selenium.common.exceptions import TimeoutException
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\webelement.py:93, in WebElement.click(self)
#      91 def click(self) -> None:
#      92     """Clicks the element."""
# ---> 93     self._execute(Command.CLICK_ELEMENT)
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\webelement.py:410, in WebElement._execute(self, command, params)
#     408     params = {}
#     409 params["id"] = self._id
# --> 410 return self._parent.execute(command, params)
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\webdriver.py:444, in WebDriver.execute(self, driver_command, params)
#     442 response = self.command_executor.execute(driver_command, params)
#     443 if response:
# --> 444     self.error_handler.check_response(response)
#     445     response["value"] = self._unwrap_value(response.get("value", None))
#     446     return response
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:249, in ErrorHandler.check_response(self, response)
#     247         alert_text = value["alert"].get("text")
#     248     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 249 raise exception_class(message, screen, stacktrace)
#
# ElementNotInteractableException: Message: element not interactable
#   (Session info: chrome=112.0.5615.138)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x0100DCE3+50899]
# 	(No symbol) [0x00F9E111]
# 	(No symbol) [0x00EA5450]
# 	(No symbol) [0x00ED1846]
# 	(No symbol) [0x00EC94A5]
# 	(No symbol) [0x00EEB8FC]
# 	(No symbol) [0x00EC8EC6]
# 	(No symbol) [0x00EEBC54]
# 	(No symbol) [0x00EFE01C]
# 	(No symbol) [0x00EEB6F6]
# 	(No symbol) [0x00EC7708]
# 	(No symbol) [0x00EC886D]
# 	GetHandleVerifier [0x01273EAE+2566302]
# 	GetHandleVerifier [0x012A92B1+2784417]
# 	GetHandleVerifier [0x012A327C+2759788]
# 	GetHandleVerifier [0x010A5740+672048]
# 	(No symbol) [0x00FA8872]
# 	(No symbol) [0x00FA41C8]
# 	(No symbol) [0x00FA42AB]
# 	(No symbol) [0x00F971B7]
# 	BaseThreadInitThunk [0x757D00F9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77327BBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77327B8E+238]

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import ElementNotInteractableException, NoSuchElementException
from selenium.common.exceptions import ElementClickInterceptedException
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from webdriver_manager.firefox import GeckoDriverManager
from selenium.webdriver.firefox.options import Options
from bs4 import BeautifulSoup
import shutil
import time
import os
import pandas as pd
from pyshadow.main import Shadow
from py7zr import unpack_7zarchive
from RequestInferSchemaToJsonAPI.main import TriggerInferShemaToJsonAPI
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\EIU'

# %%
chrome_options = webdriver.ChromeOptions()
base_path = "C:\\Users\\10235555\\Documents\\Dataportal Data\\EIU" # local, gets current working directory
prefs = {'download.default_directory' : base_path}#, "profile.content_settings.exceptions.automatic_downloads.*.setting" : 1}
chrome_options.add_experimental_option('prefs', prefs)
#chrome_options.add_argument('--user-agent="Mozilla/5.0 (Windows Phone 10.0; Android 4.2.1; Microsoft; Lumia 640 XL LTE) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.135 Mobile Safari/537.36 Edge/12.10166"')
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)
driver.maximize_window()

# %%
driver.get('https://viewpoint.eiu.com/data')

# %%
# driver.find_element(By.ID,'sp_message_container_770557')
iframe = driver.find_element(By.XPATH,'//*[@id="sp_message_iframe_770557"]')
driver.switch_to.frame(iframe)

# %%
driver.find_element(By.XPATH,'//*[@id="notice"]/div[4]/div[1]/button').click()

# %%
# driver.switch_to.default_content()

# %%
browse_data = driver.find_element(By.CLASS_NAME,'ip_selections-wrapper')
series = browse_data.find_element(By.CLASS_NAME,'ip-tree-wrapper-column.ip_series-data-tree-container').find_element(By.CLASS_NAME,'root').find_element(By.CLASS_NAME,'infinite-scroll-component').find_elements(By.CLASS_NAME,'node.tree')
for serie in series:
    print(serie.text)
    title = serie.text
    input = serie.find_element(By.CLASS_NAME,'checkbox-item')
    input.click()
    time.sleep(1)
    geographies = browse_data.find_element(By.CLASS_NAME,'ip-tree-wrapper-column.ip_geographies-data-tree-container').find_element(By.CLASS_NAME,'ip_data-tree-container').find_element(By.CLASS_NAME,'header').find_element(By.CLASS_NAME,'ip_select-all-button')
    geographies.click()
    time.sleep(1)
    selection = browse_data.find_element(By.CLASS_NAME,'ip_selections-data-tree-container').find_element(By.CLASS_NAME,'ip_data-tree-wrapper.ip_data-tree-selection').find_element(By.CLASS_NAME,'ip_selections-buttons')
    view_table = selection.find_element(By.CLASS_NAME,'ds-button')
    view_table.click()
    time.sleep(4)
    download = driver.find_element(By.CLASS_NAME,'ip_download').find_element(By.CLASS_NAME,'ds-actioned-link.ds-actioned-link--download')
    download.click()
    time.sleep(1)
    table_data = driver.find_element(By.ID,'Access-To-Local-Markets-0-4--download-options')
    csv_form = table_data.find_element(By.CLASS_NAME,'ds__link-list').find_element(By.CLASS_NAME,'ds-navigation-link')
    csv_form.click()
    start_new = driver.find_element(By.CLASS_NAME,'ipd_search-container').find_element(By.CLASS_NAME,'ds-link-with-arrow-icon')
    start_new.click()
    time.sleep(2)
    browse_data = driver.find_element(By.CLASS_NAME,'ip_selections-wrapper')
    series = browse_data.find_element(By.CLASS_NAME,'ip-tree-wrapper-column ip_series-data-tree-container').find_element(By.CLASS_NAME,'root').find_element(By.CLASS_NAME,'infinite-scroll-component').find_elements(By.CLASS_NAME,'node.tree')
# Out:
# Operational Risk
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# c:\Users\10235555\Documents\DataportalCrawlers\UN_Data\EIU.ipynb Cell 7 in 1
#      <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/EIU.ipynb#W4sZmlsZQ%3D%3D?line=13'>14</a> view_table.click()
#      <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/EIU.ipynb#W4sZmlsZQ%3D%3D?line=14'>15</a> time.sleep(4)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/EIU.ipynb#W4sZmlsZQ%3D%3D?line=15'>16</a> download = driver.find_element(By.CLASS_NAME,'ip_download').find_element(By.CLASS_NAME,'ds-actioned-link ds-actioned-link--download')
#      <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/EIU.ipynb#W4sZmlsZQ%3D%3D?line=16'>17</a> download.click()
#      <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/EIU.ipynb#W4sZmlsZQ%3D%3D?line=17'>18</a> time.sleep(1)
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\webelement.py:433, in WebElement.find_element(self, by, value)
#     430     by = By.CSS_SELECTOR
#     431     value = '[name="%s"]' % value
# --> 433 return self._execute(Command.FIND_CHILD_ELEMENT, {"using": by, "value": value})["value"]
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\webelement.py:410, in WebElement._execute(self, command, params)
#     408     params = {}
#     409 params["id"] = self._id
# --> 410 return self._parent.execute(command, params)
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\webdriver.py:444, in WebDriver.execute(self, driver_command, params)
#     442 response = self.command_executor.execute(driver_command, params)
#     443 if response:
# --> 444     self.error_handler.check_response(response)
#     445     response["value"] = self._unwrap_value(response.get("value", None))
#     446     return response
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:249, in ErrorHandler.check_response(self, response)
#     247         alert_text = value["alert"].get("text")
#     248     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 249 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":".ds-actioned-link ds-actioned-link--download"}
#   (Session info: chrome=112.0.5615.138)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x009DDCE3+50899]
# 	(No symbol) [0x0096E111]
# 	(No symbol) [0x00875588]
# 	(No symbol) [0x008A08F9]
# 	(No symbol) [0x008A0AFB]
# 	(No symbol) [0x00898F71]
# 	(No symbol) [0x008BB944]
# 	(No symbol) [0x00898EC6]
# 	(No symbol) [0x008BBC54]
# 	(No symbol) [0x008CE01C]
# 	(No symbol) [0x008BB6F6]
# 	(No symbol) [0x00897708]
# 	(No symbol) [0x0089886D]
# 	GetHandleVerifier [0x00C43EAE+2566302]
# 	GetHandleVerifier [0x00C792B1+2784417]
# 	GetHandleVerifier [0x00C7327C+2759788]
# 	GetHandleVerifier [0x00A75740+672048]
# 	(No symbol) [0x00978872]
# 	(No symbol) [0x009741C8]
# 	(No symbol) [0x009742AB]
# 	(No symbol) [0x009671B7]
# 	BaseThreadInitThunk [0x757D00F9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77327BBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77327B8E+238]

# %%
selector_data = driver.find_element(By.CLASS_NAME,'ipd_data-results_series-geo-selector').find_element(By.CLASS_NAME,'ipd_viewby-series-dropdown')
part_Series = selector_data.find_element(By.CLASS_NAME,'select-by-series__value-container.select-by-series__value-container--has-value.css-1hwfws3')
part_Series.click()

# %%
driver.find_element(By.CLASS_NAME,'select-by-series__menu.css-8plzl5-menu').click()#.get_attribute('innerHTML')

# %%
selector_data = driver.find_element(By.CLASS_NAME,'ipd_data-results_series-geo-selector').find_element(By.CLASS_NAME,'ipd_viewby-series-dropdown')
part_Series = selector_data.find_element(By.CLASS_NAME,'select-by-series__value-container.select-by-series__value-container--has-value.css-1hwfws3')
part_Series.click()
c = driver.find_elements(By.CLASS_NAME,'select-by-series__option.css-1004i92-option')
for p in c:
    print(p.text)
driver.find_elements(By.CLASS_NAME,'select-by-series__option.css-1004i92-option')[3].text
# Out:
# Access To Local Markets (0-4)
# Accountability Of Public Officials (0-4)
# Air Transport Facilities (0-4)
#
# Banking Sector Health (0-4)
# Capital Account (0-4)
# Capital Controls Risk (0-4)
# Confiscation/Expropriation (0-4)
# Crowding Out (0-4)
# Current Account Convertibility (0-4)
# Cyber Security, Likelihood Of Attacks (0-4)
# Cyber Security, Preparedness (0-4)
# Depth Of Financing (0-4)
# Devaluation Risk (0-4)
# Discrimination Against Foreign Companies (0-4)
# Discriminatory Tariffs (0-4)
# Discriminatory Taxes (0-4)
# Economic Exposure To Natural Disaster Risk (0-4)
# Enforceability Of Contracts (0-4)
# Excessive Bureaucracy/Red-Tape (0-4)
# Excessive Executive Authority (0-4)
# Excessive Protection (0-4)
# Exchange Rate Volatility (0-4)
# Fairness Of Judicial Process (0-4)
# Financial Crisis (0-4)
# Financial Risk Rating (A-E)
# Financial Risk Score (0-100)
# Foreign Trade & Payments Risk Rating (A-E)
# Foreign Trade & Payments Risk Score (0-100)
# Freedom Of Association (0-4)
# Government Effectiveness Risk Rating (A-E)
# Government Effectiveness Risk Score (0-100)
# Hostility To Foreigners/Private Property (0-4)
# Human Rights (0-4)
# Infrastructure Risk Rating (A-E)
# Infrastructure Risk Score (0-100)
# Integrity Of Accounting Practices (0-4)
# Interest Rate Volatility (0-4)
# International Tensions (0-4)
# IT Infrastructure (0-4)
# Kidnapping/Extortion (0-4)
# Labour Laws (0-4)
# Labour Market Risk Rating (A-E)
# Labour Market Risk Score (0-100)
# Labour Strikes (0-4)
# Legal & Regulatory Risk Rating (A-E)
# Legal & Regulatory Risk Score (0-100)
# Level Of Corporate Taxation (0-4)
# Macroeconomic Risk Rating (A-E)
# Macroeconomic Risk Score (0-100)
# Marketable Debt (0-4)
# Meritocratic Remuneration (0-4)
# Opposition Stance (0-4)
# Orderly Transfers (0-4)
# Organised Crime (0-4)
# Overall Rating (A-E)
# Overall Score (0-100)
# Policy Formulation (0-4)
# Political Stability Risk Rating (A-E)
# Political Stability Risk Score (0-100)
# Port Facilities (0-4)
# Power Network (0-4)
# Price Controls (0-4)
# Price Instability (0-4)
# Protection Of Intellectual Property Rights (0-4)
# Protection Of Private Property (0-4)
# Quality Of Bureaucracy (0-4)
# Rail Network (0-4)
# Recession Risk (0-4)
# Retail And Distribution Network (0-4)
# Retroactive Taxation (0-4)
# Road Network (0-4)
# Security Risk Rating (A-E)
# Security Risk Score (0-100)
# Skilled Labour (0-4)
# Social Unrest (0-4)
# Societal Vulnerability To Natural Disaster Risk (0-4)
# Specialised Labour (0-4)
# Speediness Of Judicial Process (0-4)
# Stable Regime (0-4)
# Stockmarket Liquidity (0-4)
# Tax Policy Risk Rating (A-E)
# Tax Policy Risk Score (0-100)
# Telephone Network (0-4)
# Terrorism (0-4)
# Trade Embargo Risk (0-4)
# Trade Unions (0-4)
# Unfair Competitive Practices (0-4)
# Vested Interests/Cronyism (0-4)
# Violent Crime (0-4)
# Violent Demonstrations (0-4)

# %%
# categories = driver.find_element(By.CLASS_NAME,'select-by-series__menu.css-8plzl5-menu')
# categories.click()#.
driver.find_elements(By.CLASS_NAME,'select-by-series__option.css-1004i92-option')[3].text
# Out:
# 'Banking Sector Health (0-4)'

# %%
selector_data = driver.find_element(By.CLASS_NAME,'ipd_data-results_series-geo-selector').find_element(By.CLASS_NAME,'ipd_viewby-series-dropdown')
part_Series = selector_data.find_element(By.CLASS_NAME,'select-by-series__value-container.select-by-series__value-container--has-value.css-1hwfws3')
part_Series.click()
c = driver.find_elements(By.CLASS_NAME,'select-by-series__option.css-1004i92-option')
for p in c:
    print(p.text)
driver.find_elements(By.CLASS_NAME,'select-by-series__option.css-1004i92-option')[3].text

# %%
ip_series-data-tree-0-0_li

# %%
browse_data = driver.find_element(By.CLASS_NAME,'ip_selections-wrapper')
tags = browse_data.find_element(By.CLASS_NAME,'ip-tree-wrapper-column.ip_series-data-tree-container').find_element(By.CLASS_NAME,'root').find_element(By.CLASS_NAME,'infinite-scroll-component').find_elements(By.CSS_SELECTOR,'.node.tree[aria-level="1"]')
for i in range(len(tags)):
    collapse_tag = tags[i].find_element(By.TAG_NAME,'i')
    collapse_tag.click()
    browse_data = driver.find_element(By.CLASS_NAME,'ip_selections-wrapper')
    tags = browse_data.find_element(By.CLASS_NAME,'ip-tree-wrapper-column.ip_series-data-tree-container').find_element(By.CLASS_NAME,'root').find_element(By.CLASS_NAME,'infinite-scroll-component').find_elements(By.CSS_SELECTOR,'.node.tree[aria-level="1"]')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\Users\10235555\Documents\DataportalCrawlers\UN_Data\EIU.ipynb Cell 13 in 4
#       <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/EIU.ipynb#X24sZmlsZQ%3D%3D?line=1'>2</a> tags = browse_data.find_element(By.CLASS_NAME,'ip-tree-wrapper-column.ip_series-data-tree-container').find_element(By.CLASS_NAME,'root').find_element(By.CLASS_NAME,'infinite-scroll-component').find_elements(By.CSS_SELECTOR,'.node.tree[aria-level="1"]')
#       <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/EIU.ipynb#X24sZmlsZQ%3D%3D?line=2'>3</a> for i in range(len(tags)):
# ----> <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/EIU.ipynb#X24sZmlsZQ%3D%3D?line=3'>4</a>     collapse_tag = tags[i].find_element(By.TAG_NAME,'i')
#       <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/EIU.ipynb#X24sZmlsZQ%3D%3D?line=4'>5</a>     collapse_tag.click()
#       <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/EIU.ipynb#X24sZmlsZQ%3D%3D?line=5'>6</a>     browse_data = driver.find_element(By.CLASS_NAME,'ip_selections-wrapper')
#
# IndexError: list index out of range

# %%
browse_data = driver.find_element(By.CLASS_NAME,'ip_selections-wrapper')
tags = browse_data.find_element(By.CLASS_NAME,'ip-tree-wrapper-column.ip_series-data-tree-container').find_element(By.CLASS_NAME,'root').find_element(By.CLASS_NAME,'infinite-scroll-component').find_elements(By.CSS_SELECTOR,'.node.tree[aria-level="1"]')
for tag in tags[0]:
    collapse_tag = tags[i].find_element(By.TAG_NAME,'i')
    collapse_tag.click()
    browse_data = driver.find_element(By.CLASS_NAME,'ip_selections-wrapper')
    tags = browse_data.find_element(By.CLASS_NAME,'ip-tree-wrapper-column.ip_series-data-tree-container').find_element(By.CLASS_NAME,'root').find_element(By.CLASS_NAME,'infinite-scroll-component').find_elements(By.CSS_SELECTOR,'.node.tree[aria-level="1"]')
# time.sleep(2)
# topics = browse_data.find_elements(By.CSS_SELECTOR,'.node.tree[aria-level="2"]')
# for j in range(len(topics)) :
#     collapse_topic = topics[j].find_element(By.TAG_NAME,'i')
#     collapse_topic.click()
#     browse_data = driver.find_element(By.CLASS_NAME,'ip_selections-wrapper')
#     topics = browse_data.find_elements(By.CSS_SELECTOR,'.node.tree[aria-level="2"]')

        
# for serie in series:
#     print(serie.text)
#     title = serie.text
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\Users\10235555\Documents\DataportalCrawlers\UN_Data\EIU.ipynb Cell 13 in 4
#       <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/EIU.ipynb#X15sZmlsZQ%3D%3D?line=1'>2</a> tags = browse_data.find_element(By.CLASS_NAME,'ip-tree-wrapper-column.ip_series-data-tree-container').find_element(By.CLASS_NAME,'root').find_element(By.CLASS_NAME,'infinite-scroll-component').find_elements(By.CSS_SELECTOR,'.node.tree[aria-level="1"]')
#       <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/EIU.ipynb#X15sZmlsZQ%3D%3D?line=2'>3</a> for i in range(len(tags)):
# ----> <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/EIU.ipynb#X15sZmlsZQ%3D%3D?line=3'>4</a>     collapse_tag = tags[i].find_element(By.TAG_NAME,'i')
#       <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/EIU.ipynb#X15sZmlsZQ%3D%3D?line=4'>5</a>     collapse_tag.click()
#       <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/EIU.ipynb#X15sZmlsZQ%3D%3D?line=5'>6</a>     browse_data = driver.find_element(By.CLASS_NAME,'ip_selections-wrapper')
#
# IndexError: list index out of range

# %%
topics = browse_data.find_elements(By.CSS_SELECTOR,'.node.tree[aria-level="2"]')
for j in range(len(topics)) :
    collapse_topic = topics[j].find_element(By.TAG_NAME,'i')
    collapse_topic.click()
    browse_data = driver.find_element(By.CLASS_NAME,'ip_selections-wrapper')
    topics = browse_data.find_elements(By.CSS_SELECTOR,'.node.tree[aria-level="2"]')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\Users\10235555\Documents\DataportalCrawlers\UN_Data\EIU.ipynb Cell 14 in 3
#       <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/EIU.ipynb#X23sZmlsZQ%3D%3D?line=0'>1</a> topics = browse_data.find_elements(By.CSS_SELECTOR,'.node.tree[aria-level="2"]')
#       <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/EIU.ipynb#X23sZmlsZQ%3D%3D?line=1'>2</a> for j in range(len(topics)) :
# ----> <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/EIU.ipynb#X23sZmlsZQ%3D%3D?line=2'>3</a>     collapse_topic = topics[j].find_element(By.TAG_NAME,'i')
#       <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/EIU.ipynb#X23sZmlsZQ%3D%3D?line=3'>4</a>     collapse_topic.click()
#       <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/EIU.ipynb#X23sZmlsZQ%3D%3D?line=4'>5</a>     browse_data = driver.find_element(By.CLASS_NAME,'ip_selections-wrapper')
#
# IndexError: list index out of range

# %%
selector_data = driver.find_element(By.CLASS_NAME,'ipd_data-results_series-geo-selector').find_element(By.CLASS_NAME,'ipd_viewby-series-dropdown')
part_Series = selector_data.find_element(By.CLASS_NAME,'select-by-series__value-container.select-by-series__value-container--has-value.css-1hwfws3')
part_Series.click()
categories = driver.find_elements(By.CLASS_NAME,'select-by-series__option.css-1004i92-option')#.get_attribute('innerHTML')
for k in range(len(categories)) :
    title = categories[k].text
    print(title)
# Out:
# Accountability Of Public Officials (0-4)
# Air Transport Facilities (0-4)
# Armed Conflict (0-4)
# Banking Sector Health (0-4)
# Capital Account (0-4)
# Capital Controls Risk (0-4)
# Corruption (0-4)
# Crowding Out (0-4)
# Current Account Convertibility (0-4)
# Cyber Security, Likelihood Of Attacks (0-4)
# Cyber Security, Preparedness (0-4)
# Depth Of Financing (0-4)
# Devaluation Risk (0-4)
# Discrimination Against Foreign Companies (0-4)
# Discriminatory Tariffs (0-4)
# Discriminatory Taxes (0-4)
# Economic Exposure To Natural Disaster Risk (0-4)
# Enforceability Of Contracts (0-4)
# Excessive Bureaucracy/Red-Tape (0-4)
# Excessive Executive Authority (0-4)
# Excessive Protection (0-4)
# Exchange Rate Volatility (0-4)
# Fairness Of Judicial Process (0-4)
# Financial Crisis (0-4)
# Financial Risk Rating (A-E)
# Financial Risk Score (0-100)
# Foreign Trade & Payments Risk Rating (A-E)
# Foreign Trade & Payments Risk Score (0-100)
# Freedom Of Association (0-4)
# Government Effectiveness Risk Rating (A-E)
# Government Effectiveness Risk Score (0-100)
# Hostility To Foreigners/Private Property (0-4)
# Human Rights (0-4)
# Infrastructure Risk Rating (A-E)
# Infrastructure Risk Score (0-100)
# Integrity Of Accounting Practices (0-4)
# Interest Rate Volatility (0-4)
# International Tensions (0-4)
# IT Infrastructure (0-4)
# Kidnapping/Extortion (0-4)
# Labour Laws (0-4)
# Labour Market Risk Rating (A-E)
# Labour Market Risk Score (0-100)
# Labour Strikes (0-4)
# Legal & Regulatory Risk Rating (A-E)
# Legal & Regulatory Risk Score (0-100)
# Level Of Corporate Taxation (0-4)
# Macroeconomic Risk Rating (A-E)
# Macroeconomic Risk Score (0-100)
# Marketable Debt (0-4)
# Meritocratic Remuneration (0-4)
# Opposition Stance (0-4)
# Orderly Transfers (0-4)
# Organised Crime (0-4)
# Overall Rating (A-E)
# Overall Score (0-100)
# Policy Formulation (0-4)
# Political Stability Risk Rating (A-E)
# Political Stability Risk Score (0-100)
# Port Facilities (0-4)
# Power Network (0-4)
# Price Controls (0-4)
# Price Instability (0-4)
# Protection Of Intellectual Property Rights (0-4)
# Protection Of Private Property (0-4)
# Quality Of Bureaucracy (0-4)
# Rail Network (0-4)
# Recession Risk (0-4)
# Retail And Distribution Network (0-4)
# Retroactive Taxation (0-4)
# Road Network (0-4)
# Security Risk Rating (A-E)
# Security Risk Score (0-100)
# Skilled Labour (0-4)
# Social Unrest (0-4)
# Societal Vulnerability To Natural Disaster Risk (0-4)
# Specialised Labour (0-4)
# Speediness Of Judicial Process (0-4)
# Stable Regime (0-4)
# Stockmarket Liquidity (0-4)
# Tax Policy Risk Rating (A-E)
# Tax Policy Risk Score (0-100)
# Telephone Network (0-4)
# Terrorism (0-4)
# Trade Embargo Risk (0-4)
# Trade Unions (0-4)
# Unfair Competitive Practices (0-4)
# Vested Interests/Cronyism (0-4)
# Violent Crime (0-4)
# Violent Demonstrations (0-4)

# %%
# check
# from selenium.webdriver.common.action_chains import ActionChains
# element = driver.find_element(By.CLASS_NAME,'ipd_data-results_series-geo-selector')
# actions = ActionChains(driver)
# actions.move_to_element(element).perform()
selector_data = driver.find_element(By.CLASS_NAME,'ipd_data-results_series-geo-selector').find_element(By.CLASS_NAME,'ipd_viewby-series-dropdown')
part_Series = selector_data.find_element(By.CLASS_NAME,'select-by-series__value-container.select-by-series__value-container--has-value.css-1hwfws3')
part_Series.click()
time.sleep(1)
categories = driver.find_elements(By.CLASS_NAME,'select-by-series__option.css-1004i92-option')#.get_attribute('innerHTML')
for k in range(len(categories)) :
    title = categories[k].text
    title = title.replace('/',' ').replace(':',' ').replace('!',' ').replace('?',' ').replace('[',' ').replace(']',' ').replace("'",' ').replace('"',' ')
    driver.find_elements(By.CLASS_NAME,'select-by-series__option.css-1004i92-option')[k].click()
    time.sleep(5)
    from selenium.common.exceptions import TimeoutException
    delay = 3 # seconds
    try:
        myElem = WebDriverWait(driver, delay).until(EC.presence_of_element_located((By.CLASS_NAME,'ipd_data-results_series-geo-selector')))
    except TimeoutException:
        print("Loading took too much time!")
    try:
        driver.find_element(By.CLASS_NAME,'ipd_search-no-results').find_element(By.TAG_NAME,'h3')
        driver.find_elements(By.CLASS_NAME,'select-by-series__option.css-1004i92-option')[k].click()
        time.sleep(5)
        from selenium.common.exceptions import TimeoutException
        delay = 5 # seconds
        try:
            myElem = WebDriverWait(driver, delay).until(EC.presence_of_element_located((By.CLASS_NAME,'ip_download')))
        except TimeoutException:
            print("Loading took too much time!")
        selector_data = driver.find_element(By.CLASS_NAME,'ipd_data-results_series-geo-selector').find_element(By.CLASS_NAME,'ipd_viewby-series-dropdown')
        part_Series = selector_data.find_element(By.CLASS_NAME,'select-by-series__value-container.select-by-series__value-container--has-value.css-1hwfws3')
        part_Series.click()
        time.sleep(3)
        categories = driver.find_element(By.CLASS_NAME,'select-by-series__menu.css-8plzl5-menu').find_elements(By.CLASS_NAME,'select-by-series__option.css-1004i92-option')
    except:
        # driver.find_elements(By.CLASS_NAME,'select-by-series__option.css-1004i92-option')[k].click()
        # time.sleep(5)
        # from selenium.common.exceptions import TimeoutException
        # delay = 3 # seconds
        # try:
        #     myElem = WebDriverWait(driver, delay).until(EC.presence_of_element_located((By.CLASS_NAME,'ip_download')))
        # except TimeoutException:
        #     print("Loading took too much time!")
        download = driver.find_element(By.CLASS_NAME,'ip_download').find_element(By.CLASS_NAME,'ds-actioned-link.ds-actioned-link--download')
        download.click()
        time.sleep(1)
        # table_data = driver.find_element(By.ID,'Access-To-Local-Markets-0-4--download-options')
        csv_form = driver.find_element(By.CLASS_NAME,'ds__link-list').find_element(By.CLASS_NAME,'ds-navigation-link')
        csv_form.click()
        time.sleep(3)
        def latest_download_file():
            path = base_path
            os.chdir(path)
            files = sorted(os.listdir(os.getcwd()), key=os.path.getmtime)
            newest = files[-1]

            return newest

        fileends = "crdownload"
        while "crdownload" == fileends:
            time.sleep(4) 
            newest_file = latest_download_file()
            if "crdownload" in newest_file:
                fileends = "crdownload"
                # time.sleep(5)
            else:
                fileends = "None"
        latest_download_file() 
        # file = max([base_path + "\\" + f for f in os.listdir(base_path)],key=os.path.getctime)
        file = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\EIU\\table.csv'
        print(title)
        os.rename(file,f'{base_path}\\{title}.csv')
        selector_data = driver.find_element(By.CLASS_NAME,'ipd_data-results_series-geo-selector').find_element(By.CLASS_NAME,'ipd_viewby-series-dropdown')
        part_Series = selector_data.find_element(By.CLASS_NAME,'select-by-series__value-container.select-by-series__value-container--has-value.css-1hwfws3')
        part_Series.click()
        time.sleep(2)
        categories = driver.find_element(By.CLASS_NAME,'select-by-series__menu.css-8plzl5-menu').find_elements(By.CLASS_NAME,'select-by-series__option.css-1004i92-option')
    

# for categorie in categories:
#     # print(categorie.text)
#     categorie.click()
#     time.sleep(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\10235555\Documents\DataportalCrawlers\UN_Data\EIU.ipynb Cell 24 in 6
#       <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/EIU.ipynb#X24sZmlsZQ%3D%3D?line=0'>1</a> # check
#       <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/EIU.ipynb#X24sZmlsZQ%3D%3D?line=1'>2</a> # from selenium.webdriver.common.action_chains import ActionChains
#       <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/EIU.ipynb#X24sZmlsZQ%3D%3D?line=2'>3</a> # element = driver.find_element(By.CLASS_NAME,'ipd_data-results_series-geo-selector')
#       <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/EIU.ipynb#X24sZmlsZQ%3D%3D?line=3'>4</a> # actions = ActionChains(driver)
#       <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/EIU.ipynb#X24sZmlsZQ%3D%3D?line=4'>5</a> # actions.move_to_element(element).perform()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/EIU.ipynb#X24sZmlsZQ%3D%3D?line=5'>6</a> selector_data = driver.find_element(By.CLASS_NAME,'ipd_data-results_series-geo-selector').find_element(By.CLASS_NAME,'ipd_viewby-series-dropdown')
#       <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/EIU.ipynb#X24sZmlsZQ%3D%3D?line=6'>7</a> part_Series = selector_data.find_element(By.CLASS_NAME,'select-by-series__value-container.select-by-series__value-container--has-value.css-1hwfws3')
#       <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/EIU.ipynb#X24sZmlsZQ%3D%3D?line=7'>8</a> part_Series.click()
#
# NameError: name 'driver' is not defined

# %%
# driver.find_element(By.CLASS_NAME,'expandCollapseController').find_element(By.TAG_NAME,'a').click()
descriptions = []
table_content = driver.find_element(By.CLASS_NAME,'ip_metadata-table.ip_metadata-table-with-link-col').find_element(By.TAG_NAME,'table')#.find_element(By.CLASS_NAME,'ipd_table-container.ip_container')
rows = table_content.find_elements(By.TAG_NAME,'tr')
for row in rows[1:]:
    cells = row.find_elements(By.TAG_NAME,'td')
    cells_text = [cell.text for cell in cells]
    text = 'Country : ' + cells_text[1] + ', Unit : ' + cells_text[2] + ', Description : ' + cells_text[3] + ', Data specific notes : ' + cells_text[4] + ', Source : ' + cells_text[5] + ', Published : ' + cells_text[6]
    descriptions.append(text)
description = [' \n\n '.join(map(str,descriptions))][0]

# %%
description = [' \n\n '.join(map(str,descriptions))][0]

# %%
from selenium.webdriver.common.action_chains import ActionChains
# element = driver.find_element(By.CLASS_NAME,'ip_metadata-table.ip_metadata-table-with-link-col')
# actions = ActionChains(driver)
# actions.move_to_element(element).perform()
reads_desc = driver.find_element(By.CLASS_NAME,'ip_metadata-table.ip_metadata-table-with-link-col').find_elements(By.CLASS_NAME,'ip_read-more-read-less.ds-navigation-link')
for d in reads_desc:
    d.click()
#     reads_desc = driver.find_elements(By.CLASS_NAME,'ip_read-more-read-less.ds-navigation-link')
# reads_desc

# %%
selector_data = driver.find_element(By.CLASS_NAME,'ipd_data-results_series-geo-selector').find_element(By.CLASS_NAME,'ipd_viewby-series-dropdown')
part_Series = selector_data.find_element(By.CLASS_NAME,'select-by-series__value-container.select-by-series__value-container--has-value.css-1hwfws3')
part_Series.click()
time.sleep(2)
categories = driver.find_elements(By.CLASS_NAME,'select-by-series__option.css-1004i92-option')#.get_attribute('innerHTML')
len(categories)
# Out:
# 182

# %%
browse_data = driver.find_element(By.CLASS_NAME,'ip_selections-wrapper')
list_Series = browse_data.find_element(By.CLASS_NAME,'ip-tree-wrapper-column.ip_series-data-tree-container').find_element(By.CLASS_NAME,'root')
series = list_Series.find_element(By.CLASS_NAME,'infinite-scroll-component').find_elements(By.CLASS_NAME,'node.tree')
for serie in series:
    print(serie.text)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# c:\Users\10235555\Documents\DataportalCrawlers\UN_Data\EIU.ipynb Cell 30 in 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/EIU.ipynb#X41sZmlsZQ%3D%3D?line=0'>1</a> browse_data = driver.find_element(By.CLASS_NAME,'ip_selections-wrapper')
#       <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/EIU.ipynb#X41sZmlsZQ%3D%3D?line=1'>2</a> list_Series = browse_data.find_element(By.CLASS_NAME,'ip-tree-wrapper-column.ip_series-data-tree-container').find_element(By.CLASS_NAME,'root')
#       <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/EIU.ipynb#X41sZmlsZQ%3D%3D?line=2'>3</a> series = list_Series.find_element(By.CLASS_NAME,'infinite-scroll-component').find_elements(By.CLASS_NAME,'node.tree')
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\webdriver.py:861, in WebDriver.find_element(self, by, value)
#     858     by = By.CSS_SELECTOR
#     859     value = '[name="%s"]' % value
# --> 861 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\webdriver.py:444, in WebDriver.execute(self, driver_command, params)
#     442 response = self.command_executor.execute(driver_command, params)
#     443 if response:
# --> 444     self.error_handler.check_response(response)
#     445     response["value"] = self._unwrap_value(response.get("value", None))
#     446     return response
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:249, in ErrorHandler.check_response(self, response)
#     247         alert_text = value["alert"].get("text")
#     248     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 249 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":".ip_selections-wrapper"}
#   (Session info: chrome=112.0.5615.138)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00DFDCE3+50899]
# 	(No symbol) [0x00D8E111]
# 	(No symbol) [0x00C95588]
# 	(No symbol) [0x00CC08F9]
# 	(No symbol) [0x00CC0AFB]
# 	(No symbol) [0x00CEF902]
# 	(No symbol) [0x00CDB944]
# 	(No symbol) [0x00CEE01C]
# 	(No symbol) [0x00CDB6F6]
# 	(No symbol) [0x00CB7708]
# 	(No symbol) [0x00CB886D]
# 	GetHandleVerifier [0x01063EAE+2566302]
# 	GetHandleVerifier [0x010992B1+2784417]
# 	GetHandleVerifier [0x0109327C+2759788]
# 	GetHandleVerifier [0x00E95740+672048]
# 	(No symbol) [0x00D98872]
# 	(No symbol) [0x00D941C8]
# 	(No symbol) [0x00D942AB]
# 	(No symbol) [0x00D871B7]
# 	BaseThreadInitThunk [0x75440099+25]
# 	RtlGetAppContainerNamedObjectPath [0x76FA7B6E+286]
# 	RtlGetAppContainerNamedObjectPath [0x76FA7B3E+238]

# %%
file_exis = tag + ' ' + title.replace('/',' ').replace(':',' ').replace('!',' ').replace('?',' ').replace('[',' ').replace(']',' ').replace("'",' ').replace('"',' ') +'.csv'
if file_exis in os.listdir(base_path):
    pass
else:
