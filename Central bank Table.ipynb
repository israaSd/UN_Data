# %%
# core finan filter 7
Table_core = []
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\central_bank'
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('Financial Soundness Indicators ( Core FSIs ) - UAE Banking Sector'):
        Table_core.append(files)
Table_core.sort(key=lambda x: x.split(' 20')[1].split('.')[0],reverse = True)
pdList = []
import pandas as pd
import numpy as np
from pandas import concat
for i in range(len(Table_core)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_core[i]}').reset_index(drop=True)
    globals()[f'df_{i}'].rename(columns={globals()[f'df_{i}'].columns[0]: 'item'},inplace=True)
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_csv('C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\Financial Soundness Indicators ( Core FSIs ) - UAE Banking Sector.csv',index=False)

# %%
# Banking Indicators filter 6
Table_Ind = []
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\central_bank'
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('UAE Banking Indicators - All Banks'):
        Table_Ind.append(files)
Table_Ind.sort(key=lambda x: x.split(' 20')[1].split('.')[0],reverse = True)
pdList = []
import pandas as pd
import numpy as np
from pandas import concat
for i in range(len(Table_Ind)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_Ind[i]}').reset_index(drop=True)
    globals()[f'df_{i}'].rename(columns={globals()[f'df_{i}'].columns[0]: 'item'},inplace=True)
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_csv('C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\UAE Banking Indicators - All Banks.csv',index=False)

# %%
# balance sheet filter  2 & 3 & 4
Table_c = []
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\central_bank'
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('CBUAE Foreign Assets'):
        Table_c.append(files)
Table_c.sort(key=lambda x: x.split(' 20')[1].split('.')[0],reverse = True)
unit = '(End of Period, Figures in Billions of UAE Dirhams)'
pdList = []
import pandas as pd
import numpy as np
from pandas import concat
for i in range(len(Table_c)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_c[i]}').reset_index(drop=True)
    units = pd.DataFrame([f'{unit}']*len(globals()[f'df_{i}']))
    globals()[f'df_{i}'].insert(1, 'Unit', units)
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i}'].to_csv('C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\Central Bank Foreign Assets (Monthly) 1.csv',index=False)

# %%
# Table 1
Table_1 = []
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\central_bank'
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('Table 1 '):
        Table_1.append(files)
Table_1.sort(key=lambda x: x.split(' 20')[1].split('.')[0],reverse = True)
import numpy as np
import pandas as pd
sheets_data = []
xls = pd.ExcelFile('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx')
sheets = xls.sheet_names
df = pd.read_excel('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx',sheets[4])
title = df.iloc[0,1].replace(':','') + ' ' 
unit = df.iloc[2,1]
df.columns = df.iloc[3,:]
df.columns = df.columns.str.replace('*', '')
sum = np.where(pd.isnull(df[df.columns[1]]))[0].tolist()[-1]
df = df.iloc[:sum,:]
df[df.columns[1]] = df[df.columns[1]].ffill(axis = 0)
df[df.columns[2]] = df[df.columns[2]].fillna('')
# df[df.columns[1]] = df[df.columns[1]].str.strip().replace('', np.nan).fillna(df[df.columns[2]])
df[df.columns[1]] = df[df.columns[1]].astype(str) + ' _ ' + df[df.columns[2]]
df = df.dropna(how='all')
df = df.dropna(how='all', axis=1)
df = df.dropna(subset=[df.columns[2]])
df = df.drop(df.columns[1], axis=1)
df = df[1:]
col_0 = df.iloc[:,0]
col_0 = col_0.to_list()
col_0.insert(19, 'Total Number of National Banks and Branches _ of which: Banks operating under digital platform')
pdList = []
import pandas as pd
import numpy as np
from pandas import concat
for i in range(len(Table_1)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_1[i]}').reset_index(drop=True)
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace(' ', '')
    if len(globals()[f'df_{i}']) == 31:
        df1 = pd.DataFrame([[np.nan] * len(globals()[f'df_{i}'].columns)], columns=globals()[f'df_{i}'].columns).fillna('-')
        # globals()[f'df_{i}'] = df1.append(globals()[f'df_{i}'], ignore_index=True)
        globals()[f'df_{i}'] = concat([globals()[f'df_{i}'].iloc[:19,:], df1, globals()[f'df_{i}'].iloc[19:,:]]).reset_index(drop=True)
        globals()[f'df_{i}'].insert(loc=0, column='Indicator', value=col_0)
        units = pd.DataFrame([f'{unit}']*len(globals()[f'df_{i}']))
        globals()[f'df_{i}'].insert(1, 'Unit', units)
        pdList.append(globals()[f'df_{i}'])
    else:
        globals()[f'df_{i}'].insert(loc=0, column='Indicator', value=col_0)
        units = pd.DataFrame([f'{unit}']*len(globals()[f'df_{i}']))
        globals()[f'df_{i}'].insert(1, 'Unit', units)
        pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_csv('C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\Table 1 Selected Monetary and Banking Indicators - statistical bulletin.csv',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\1756477483.py:18: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.columns = df.columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\1756477483.py:39: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\1756477483.py:39: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
# ...

# %%
# Table 2
Table_2 = []
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\central_bank'
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('Table 2 '):
        Table_2.append(files)
Table_2.sort(key=lambda x: x.split(' 20')[1].split('.')[0],reverse = True)
import numpy as np
import pandas as pd
sheets_data = []
xls = pd.ExcelFile('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx')
sheets = xls.sheet_names
df = pd.read_excel('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx',sheets[5])
title = df.iloc[0,1].replace(':','') + ' ' 
unit = df.iloc[2,1]
df.columns = df.iloc[3,:]
df.columns = df.columns.str.replace('*', '')
sum = np.where(pd.isnull(df[df.columns[1]]))[0].tolist()[-1]
df = df.iloc[:sum,:]
df[df.columns[1]] = df[df.columns[1]].ffill(axis = 0)
df[df.columns[2]] = df[df.columns[2]].fillna('')
# df[df.columns[1]] = df[df.columns[1]].str.strip().replace('', np.nan).fillna(df[df.columns[2]])
df[df.columns[1]] = df[df.columns[1]].astype(str) + ' _ ' + df[df.columns[2]]
df = df.dropna(how='all')
df = df.dropna(how='all', axis=1)
df = df.dropna(subset=[df.columns[2]])
df = df.drop(df.columns[1], axis=1)
df = df[1:]
col_0 = df.iloc[:,0]
col_0 = col_0.to_list()
# col_0.insert(19, 'Total Number of National Banks and Branches _ of which: Banks operating under digital platform')
pdList = []
for i in range(len(Table_2)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_2[i]}').reset_index(drop=True)
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace(' ', '')
    globals()[f'df_{i}'].insert(loc=0, column='Indicator', value=col_0)
    units = pd.DataFrame([f'{unit}']*len(globals()[f'df_{i}']))
    globals()[f'df_{i}'].insert(1, 'Unit', units)
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_csv('C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\Table 2  Monetary Survey - statistical bulletin.csv',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\446011977.py:18: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.columns = df.columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\446011977.py:36: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\446011977.py:36: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
# ...

# %%
# Table 3
Table_3 = []
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\central_bank'
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('Table 3 '):
        Table_3.append(files)
Table_3.sort(key=lambda x: x.split(' 20')[1].split('.')[0],reverse = True)
import numpy as np
import pandas as pd
sheets_data = []
xls = pd.ExcelFile('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx')
sheets = xls.sheet_names
df = pd.read_excel('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx',sheets[7])
title = df.iloc[0,1].replace(':','') + ' ' 
unit = df.iloc[2,1]
df.columns = df.iloc[3,:]
df.columns = df.columns.str.replace('*', '')
sum = np.where(pd.isnull(df[df.columns[1]]))[0].tolist()[-1]
df = df.iloc[:sum,:]
df[df.columns[1]] = df[df.columns[1]].ffill(axis = 0)
df[df.columns[2]] = df[df.columns[2]].fillna('')
# df[df.columns[1]] = df[df.columns[1]].str.strip().replace('', np.nan).fillna(df[df.columns[2]])
df[df.columns[1]] = df[df.columns[1]].astype(str) + ' _ ' + df[df.columns[2]]
df = df.dropna(how='all')
df = df.dropna(how='all', axis=1)
df = df.dropna(subset=[df.columns[2]])
df = df.drop(df.columns[1], axis=1)
df = df[1:]
col_0 = df.iloc[:,0]
col_0 = col_0.to_list()
pdList = []
for i in range(len(Table_3)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_3[i]}').reset_index(drop=True)
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace(' ', '')
    globals()[f'df_{i}'].insert(loc=0, column='Indicator', value=col_0)
    units = pd.DataFrame([f'{unit}']*len(globals()[f'df_{i}']))
    globals()[f'df_{i}'].insert(1, 'Unit', units)
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_csv('C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\Table 3  Monthly Changes in Factors Affecting Money Supply 1 - statistical bulletin.csv',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\2272614480.py:18: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.columns = df.columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\2272614480.py:35: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\2272614480.py:35: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
# ...

# %%
# Table 4
Table_4 = []
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\central_bank'
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('Table 4 '):
        Table_4.append(files)
Table_4.sort(key=lambda x: x.split(' 20')[1].split('.')[0],reverse = True)
import numpy as np
import pandas as pd
sheets_data = []
xls = pd.ExcelFile('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx')
sheets = xls.sheet_names
df = pd.read_excel('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx',sheets[9])
title = df.iloc[0,1].replace(':','') + ' ' 
unit = df.iloc[2,1]
df.columns = df.iloc[3,:]
df.columns = df.columns.str.replace('*', '')
sum = np.where(pd.isnull(df[df.columns[1]]))[0].tolist()[-1]
df = df.iloc[:sum,:]
df[df.columns[1]] = df[df.columns[1]].ffill(axis = 0)
df[df.columns[2]] = df[df.columns[2]].fillna('')
# df[df.columns[1]] = df[df.columns[1]].str.strip().replace('', np.nan).fillna(df[df.columns[2]])
df[df.columns[1]] = df[df.columns[1]].astype(str) + ' _ ' + df[df.columns[2]]
df = df.dropna(how='all')
df = df.dropna(how='all', axis=1)
df = df.dropna(subset=[df.columns[2]])
df = df.drop(df.columns[1], axis=1)
df = df[1:]
col_0 = df.iloc[:,0]
col_0 = col_0.to_list()
pdList = []
for i in range(len(Table_4)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_4[i]}').reset_index(drop=True)
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace(' ', '')
    globals()[f'df_{i}'].insert(loc=0, column='Indicator', value=col_0)
    units = pd.DataFrame([f'{unit}']*len(globals()[f'df_{i}']))
    globals()[f'df_{i}'].insert(1, 'Unit', units)
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_csv('C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\Table 4  UAE Monetary Base (Monthly) - statistical bulletin.csv',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\1596231521.py:18: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.columns = df.columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\1596231521.py:35: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\1596231521.py:35: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
# ...

# %%
# Table 5
Table_5 = []
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\central_bank'
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('Table  5 '):
        Table_5.append(files)
Table_5.sort(key=lambda x: x.split(' 20')[1].split('.')[0],reverse = True)
import numpy as np
import pandas as pd
sheets_data = []
xls = pd.ExcelFile('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx')
sheets = xls.sheet_names
df = pd.read_excel('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx',sheets[10])
title = df.iloc[0,1].replace(':','') + ' ' 
unit = df.iloc[2,1]
df.columns = df.iloc[3,:]
df.columns = df.columns.str.replace('*', '')
sum = np.where(pd.isnull(df[df.columns[1]]))[0].tolist()[-1]
df = df.iloc[:sum,:]
df[df.columns[1]] = df[df.columns[1]].ffill(axis = 0)
df[df.columns[2]] = df[df.columns[2]].fillna('')
# df[df.columns[1]] = df[df.columns[1]].str.strip().replace('', np.nan).fillna(df[df.columns[2]])
df[df.columns[1]] = df[df.columns[1]].astype(str) + ' _ ' + df[df.columns[2]]
df = df.dropna(how='all')
df = df.dropna(how='all', axis=1)
df = df.dropna(subset=[df.columns[2]])
df = df.drop(df.columns[1], axis=1)
df = df[1:]
col_0 = df.iloc[:,0]
col_0 = col_0.to_list()
pdList = []
for i in range(len(Table_5)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_5[i]}').reset_index(drop=True)
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace(' ', '')
    globals()[f'df_{i}'].insert(loc=0, column='Indicator', value=col_0)
    units = pd.DataFrame([f'{unit}']*len(globals()[f'df_{i}']))
    globals()[f'df_{i}'].insert(1, 'Unit', units)
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_csv('C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\Table  5  Balance Sheet  - Central Bank of the UAE - statistical bulletin.csv',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\981417061.py:18: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.columns = df.columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\981417061.py:35: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\981417061.py:35: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
# ...

# %%
# Table 6
Table_6 = []
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\central_bank'
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('Table 6 '):
        Table_6.append(files)
Table_6.sort(key=lambda x: x.split(' 20')[1].split('.')[0],reverse = True)
import numpy as np
import pandas as pd
sheets_data = []
xls = pd.ExcelFile('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx')
sheets = xls.sheet_names
df = pd.read_excel('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx',sheets[12])
title = df.iloc[0,1].replace(':','') 
unit = df.iloc[2,1]
df.columns = df.iloc[3,:]
df.columns = df.columns.str.replace('*', '')
sum = np.where(pd.isnull(df[df.columns[1]]))[0].tolist()[-1]
df = df.iloc[:sum,:]
df[df.columns[1]] = df[df.columns[1]].ffill(axis = 0)
df[df.columns[2]] = df[df.columns[2]].fillna('')
# df[df.columns[1]] = df[df.columns[1]].str.strip().replace('', np.nan).fillna(df[df.columns[2]])
df[df.columns[1]] = df[df.columns[1]].astype(str) + ' _ ' + df[df.columns[2]]
df = df.dropna(how='all')
df = df.dropna(how='all', axis=1)
df = df.dropna(subset=[df.columns[2]])
df = df.drop(df.columns[1], axis=1)
df = df[1:]
col_0 = df.iloc[:,0]
col_0 = col_0.to_list()
pdList = []
for i in range(len(Table_6)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_6[i]}').reset_index(drop=True)
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace(' ', '')
    globals()[f'df_{i}'].insert(loc=0, column='Indicator', value=col_0)
    units = pd.DataFrame([f'{unit}']*len(globals()[f'df_{i}']))
    globals()[f'df_{i}'].insert(1, 'Unit', units)
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_csv(f'C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\{title} - statistical bulletin.csv',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\866425729.py:18: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.columns = df.columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\866425729.py:35: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\866425729.py:35: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
# ...

# %%
# Table 7
Table_7 = []
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\central_bank'
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('Table 7 '):
        Table_7.append(files)
Table_7.sort(key=lambda x: x.split(' 20')[1].split('.')[0],reverse = True)
import numpy as np
import pandas as pd
sheets_data = []
xls = pd.ExcelFile('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx')
sheets = xls.sheet_names
df = pd.read_excel('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx',sheets[13])
title = df.iloc[0,1].replace(':','') 
unit = df.iloc[2,1]
df.columns = df.iloc[3,:]
df.columns = df.columns.str.replace('*', '')
sum = np.where(pd.isnull(df[df.columns[1]]))[0].tolist()[-1]
df = df.iloc[:sum,:]
df[df.columns[1]] = df[df.columns[1]].ffill(axis = 0)
df[df.columns[2]] = df[df.columns[2]].fillna('')
# df[df.columns[1]] = df[df.columns[1]].str.strip().replace('', np.nan).fillna(df[df.columns[2]])
df[df.columns[1]] = df[df.columns[1]].astype(str) + ' _ ' + df[df.columns[2]]
df = df.dropna(how='all')
df = df.dropna(how='all', axis=1)
df = df.dropna(subset=[df.columns[2]])
df = df.drop(df.columns[1], axis=1)
df = df[1:]
col_0 = df.iloc[:,0]
col_0 = col_0.to_list()
for i in range(len(col_0)):
    if i in range(16,20):
        col_0[i] = col_0[i].replace('a) Credit Facilities','b) Domestic Investments')
col_0[15] = col_0[15].replace('a) Credit Facilities _ ','')
pdList = []
for i in range(len(Table_7)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_7[i]}').reset_index(drop=True)
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace(' ', '')
    globals()[f'df_{i}'].insert(loc=0, column='Indicator', value=col_0)
    units = pd.DataFrame([f'{unit}']*len(globals()[f'df_{i}']))
    globals()[f'df_{i}'].insert(1, 'Unit', units)
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_csv(f'C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\{title} - statistical bulletin.csv',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\1588630766.py:18: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.columns = df.columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\1588630766.py:39: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\1588630766.py:39: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
# ...

# %%
# Table 8
Table_8 = []
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\central_bank'
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('Table 8 '):
        Table_8.append(files)
Table_8.sort(key=lambda x: x.split(' 20')[1].split('.')[0],reverse = True)
import numpy as np
import pandas as pd
sheets_data = []
xls = pd.ExcelFile('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx')
sheets = xls.sheet_names
df = pd.read_excel('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx',sheets[14])
title = df.iloc[0,1].replace(':','') 
unit = df.iloc[1,1]
df.columns = df.iloc[2,:]
df.columns = df.columns.str.replace('*', '')
sum = np.where(pd.isnull(df[df.columns[1]]))[0].tolist()[-1]
df = df.iloc[:sum,:]
df[df.columns[1]] = df[df.columns[1]].ffill(axis = 0)
df[df.columns[2]] = df[df.columns[2]].fillna('')
# df[df.columns[1]] = df[df.columns[1]].str.strip().replace('', np.nan).fillna(df[df.columns[2]])
df[df.columns[1]] = df[df.columns[1]].astype(str) + ' _ ' + df[df.columns[2]]
df = df.dropna(how='all')
df = df.dropna(how='all', axis=1)
df = df.dropna(subset=[df.columns[2]])
df = df.drop(df.columns[1], axis=1)
df = df[1:]
col_0 = df.iloc[:,0]
col_0 = col_0.to_list()

pdList = []
for i in range(len(Table_8)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_8[i]}').reset_index(drop=True)
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace(' ', '')
    globals()[f'df_{i}'].insert(loc=0, column='Indicator', value=col_0)
    units = pd.DataFrame([f'{unit}']*len(globals()[f'df_{i}']))
    globals()[f'df_{i}'].insert(1, 'Unit', units)
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_csv(f'C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\{title} - statistical bulletin.csv',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\1173073814.py:18: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.columns = df.columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\1173073814.py:36: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\1173073814.py:36: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
# ...

# %%
# Table 9
Table_9 = []
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\central_bank'
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('Table 9 '):
        Table_9.append(files)
Table_9.sort(key=lambda x: x.split(' 20')[1].split('.')[0],reverse = True)
import numpy as np
import pandas as pd
sheets_data = []
xls = pd.ExcelFile('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx')
sheets = xls.sheet_names
df = pd.read_excel('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx',sheets[16])
title = df.iloc[0,1].replace(':','') 
unit = df.iloc[2,1]
df.columns = df.iloc[3,:]
df.columns = df.columns.str.replace('*', '')
sum = np.where(pd.isnull(df[df.columns[1]]))[0].tolist()[-1]
df = df.iloc[:sum,:]
df[df.columns[1]] = df[df.columns[1]].ffill(axis = 0)
df[df.columns[2]] = df[df.columns[2]].fillna('')
# df[df.columns[1]] = df[df.columns[1]].str.strip().replace('', np.nan).fillna(df[df.columns[2]])
df[df.columns[1]] = df[df.columns[1]].astype(str) + ' _ ' + df[df.columns[2]]
df = df.dropna(how='all')
df = df.dropna(how='all', axis=1)
df = df.dropna(subset=[df.columns[2]])
df = df.drop(df.columns[1], axis=1)
df = df[1:]
col_0 = df.iloc[:,0]
col_0 = col_0.to_list()
for i in range(len(col_0)):
    if i in range(16,20):
        col_0[i] = col_0[i].replace('a) Credit Facilities','b) Domestic Investments')
col_0[15] = col_0[15].replace('a) Credit Facilities _ ','')
pdList = []
for i in range(len(Table_9)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_9[i]}').reset_index(drop=True)
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace(' ', '')
    globals()[f'df_{i}'].insert(loc=0, column='Indicator', value=col_0)
    units = pd.DataFrame([f'{unit}']*len(globals()[f'df_{i}']))
    globals()[f'df_{i}'].insert(1, 'Unit', units)
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_csv(f'C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\{title} - statistical bulletin.csv',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\3678770616.py:18: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.columns = df.columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\3678770616.py:39: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\3678770616.py:39: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
# ...

# %%
# Table 10
Table_10 = []
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\central_bank'
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('Table 10 '):
        Table_10.append(files)
Table_10.sort(key=lambda x: x.split(' 20')[1].split('.')[0],reverse = True)
import numpy as np
import pandas as pd
sheets_data = []
xls = pd.ExcelFile('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx')
sheets = xls.sheet_names
df = pd.read_excel('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx',sheets[17])
title = df.iloc[0,1].replace(':','') 
unit = df.iloc[1,1]
df.columns = df.iloc[2,:]
df.columns = df.columns.str.replace('*', '')
sum = np.where(pd.isnull(df[df.columns[1]]))[0].tolist()[-1]
df = df.iloc[:sum,:]
df[df.columns[1]] = df[df.columns[1]].ffill(axis = 0)
df[df.columns[2]] = df[df.columns[2]].fillna('')
# df[df.columns[1]] = df[df.columns[1]].str.strip().replace('', np.nan).fillna(df[df.columns[2]])
df[df.columns[1]] = df[df.columns[1]].astype(str) + ' _ ' + df[df.columns[2]]
df = df.dropna(how='all')
df = df.dropna(how='all', axis=1)
df = df.dropna(subset=[df.columns[2]])
df = df.drop(df.columns[1], axis=1)
df = df[1:]
col_0 = df.iloc[:,0]
col_0 = col_0.to_list()
pdList = []
for i in range(len(Table_10)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_10[i]}').reset_index(drop=True)
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace(' ', '')
    globals()[f'df_{i}'].insert(loc=0, column='Indicator', value=col_0)
    units = pd.DataFrame([f'{unit}']*len(globals()[f'df_{i}']))
    globals()[f'df_{i}'].insert(1, 'Unit', units)
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_csv(f'C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\{title} - statistical bulletin.csv',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\3384460971.py:18: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.columns = df.columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\3384460971.py:35: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\3384460971.py:35: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
# ...

# %%
# Table 11
Table_11 = []
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\central_bank'
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('Table 11 '):
        Table_11.append(files)
Table_11.sort(key=lambda x: x.split(' 20')[1].split('.')[0],reverse = True)
import numpy as np
import pandas as pd
sheets_data = []
xls = pd.ExcelFile('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx')
sheets = xls.sheet_names
df = pd.read_excel('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx',sheets[18])
title = df.iloc[0,1].replace(':','') 
unit = df.iloc[2,1]
df.columns = df.iloc[3,:]
df.columns = df.columns.str.replace('*', '')
sum = np.where(pd.isnull(df[df.columns[1]]))[0].tolist()[-1]
df = df.iloc[:sum,:]
df[df.columns[1]] = df[df.columns[1]].ffill(axis = 0)
df[df.columns[2]] = df[df.columns[2]].fillna('')
# df[df.columns[1]] = df[df.columns[1]].str.strip().replace('', np.nan).fillna(df[df.columns[2]])
df[df.columns[1]] = df[df.columns[1]].astype(str) + ' _ ' + df[df.columns[2]]
df = df.dropna(how='all')
df = df.dropna(how='all', axis=1)
df = df.dropna(subset=[df.columns[2]])
df = df.drop(df.columns[1], axis=1)
df = df[1:]
col_0 = df.iloc[:,0]
col_0 = col_0.to_list()
for i in range(len(col_0)):
    if i in range(16,20):
        col_0[i] = col_0[i].replace('a) Credit Facilities','b) Domestic Investments')
col_0[15] = col_0[15].replace('a) Credit Facilities _ ','')
pdList = []
for i in range(len(Table_11)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_11[i]}').reset_index(drop=True)
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace(' ', '')
    globals()[f'df_{i}'].insert(loc=0, column='Indicator', value=col_0)
    units = pd.DataFrame([f'{unit}']*len(globals()[f'df_{i}']))
    globals()[f'df_{i}'].insert(1, 'Unit', units)
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_csv(f'C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\{title} - statistical bulletin.csv',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\2893248756.py:18: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.columns = df.columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\2893248756.py:39: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\2893248756.py:39: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
# ...

# %%
# Table 12
Table_12 = []
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\central_bank'
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('Table 12 '):
        Table_12.append(files)
Table_12.sort(key=lambda x: x.split(' 20')[1].split('.')[0],reverse = True)
import numpy as np
import pandas as pd
sheets_data = []
xls = pd.ExcelFile('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx')
sheets = xls.sheet_names
df = pd.read_excel('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx',sheets[19])
title = df.iloc[0,1].replace(':','') 
unit = df.iloc[1,1]
df.columns = df.iloc[2,:]
df.columns = df.columns.str.replace('*', '')
sum = np.where(pd.isnull(df[df.columns[1]]))[0].tolist()[-1]
df = df.iloc[:sum,:]
df[df.columns[1]] = df[df.columns[1]].ffill(axis = 0)
df[df.columns[2]] = df[df.columns[2]].fillna('')
# df[df.columns[1]] = df[df.columns[1]].str.strip().replace('', np.nan).fillna(df[df.columns[2]])
df[df.columns[1]] = df[df.columns[1]].astype(str) + ' _ ' + df[df.columns[2]]
df = df.dropna(how='all')
df = df.dropna(how='all', axis=1)
df = df.dropna(subset=[df.columns[2]])
df = df.drop(df.columns[1], axis=1)
df = df[1:]
col_0 = df.iloc[:,0]
col_0 = col_0.to_list()
pdList = []
for i in range(len(Table_12)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_12[i]}').reset_index(drop=True)
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace(' ', '')
    globals()[f'df_{i}'].insert(loc=0, column='Indicator', value=col_0)
    units = pd.DataFrame([f'{unit}']*len(globals()[f'df_{i}']))
    globals()[f'df_{i}'].insert(1, 'Unit', units)
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_csv(f'C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\{title} - statistical bulletin.csv',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\2546298405.py:18: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.columns = df.columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\2546298405.py:35: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\2546298405.py:35: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
# ...

# %%
# Table 13
Table_13 = []
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\central_bank'
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('Table 13 '):
        Table_13.append(files)
Table_13.sort(key=lambda x: x.split(' 20')[1].split('.')[0],reverse = True)
import numpy as np
import pandas as pd
sheets_data = []
xls = pd.ExcelFile('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx')
sheets = xls.sheet_names
df = pd.read_excel('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx',sheets[20])
title = df.iloc[0,1].replace(':','') 
unit = df.iloc[2,1]
df.columns = df.iloc[3,:]
df.columns = df.columns.str.replace('*', '')
sum = np.where(pd.isnull(df[df.columns[1]]))[0].tolist()[-1]
df = df.iloc[:sum,:]
df[df.columns[1]] = df[df.columns[1]].ffill(axis = 0)
df[df.columns[2]] = df[df.columns[2]].fillna('')
# df[df.columns[1]] = df[df.columns[1]].str.strip().replace('', np.nan).fillna(df[df.columns[2]])
df[df.columns[1]] = df[df.columns[1]].astype(str) + ' _ ' + df[df.columns[2]]
df = df.dropna(how='all')
df = df.dropna(how='all', axis=1)
df = df.dropna(subset=[df.columns[2]])
df = df.drop(df.columns[1], axis=1)
df = df[1:]
col_0 = df.iloc[:,0]
col_0 = col_0.to_list()
for i in range(len(col_0)):
    if i in range(16,20):
        col_0[i] = col_0[i].replace('a) Credit Facilities','b) Domestic Investments')
col_0[15] = col_0[15].replace('a) Credit Facilities _ ','')
pdList = []
for i in range(len(Table_13)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_13[i]}').reset_index(drop=True)
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace(' ', '')
    globals()[f'df_{i}'].insert(loc=0, column='Indicator', value=col_0)
    units = pd.DataFrame([f'{unit}']*len(globals()[f'df_{i}']))
    globals()[f'df_{i}'].insert(1, 'Unit', units)
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_csv(f'C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\{title} - statistical bulletin.csv',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\2590458934.py:18: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.columns = df.columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\2590458934.py:39: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\2590458934.py:39: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
# ...

# %%
# Table 14
Table_14 = []
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\central_bank'
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('Table 14 '):
        Table_14.append(files)
Table_14.sort(key=lambda x: x.split(' 20')[1].split('.')[0],reverse = True)
import numpy as np
import pandas as pd
sheets_data = []
xls = pd.ExcelFile('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx')
sheets = xls.sheet_names
df = pd.read_excel('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx',sheets[21])
title = df.iloc[0,1].replace(':','') 
unit = df.iloc[1,1]
df.columns = df.iloc[2,:]
df.columns = df.columns.str.replace('*', '')
sum = np.where(pd.isnull(df[df.columns[1]]))[0].tolist()[-1]
df = df.iloc[:sum,:]
df[df.columns[1]] = df[df.columns[1]].ffill(axis = 0)
df[df.columns[2]] = df[df.columns[2]].fillna('')
# df[df.columns[1]] = df[df.columns[1]].str.strip().replace('', np.nan).fillna(df[df.columns[2]])
df[df.columns[1]] = df[df.columns[1]].astype(str) + ' _ ' + df[df.columns[2]]
df = df.dropna(how='all')
df = df.dropna(how='all', axis=1)
df = df.dropna(subset=[df.columns[2]])
df = df.drop(df.columns[1], axis=1)
df = df[1:]
col_0 = df.iloc[:,0]
col_0 = col_0.to_list()
pdList = []
for i in range(len(Table_14)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_14[i]}').reset_index(drop=True)
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace(' ', '')
    globals()[f'df_{i}'].insert(loc=0, column='Indicator', value=col_0)
    units = pd.DataFrame([f'{unit}']*len(globals()[f'df_{i}']))
    globals()[f'df_{i}'].insert(1, 'Unit', units)
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_csv(f'C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\{title} - statistical bulletin.csv',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\4124644034.py:18: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.columns = df.columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\4124644034.py:35: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\4124644034.py:35: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
# ...

# %%
# Table 15
Table_15 = []
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\central_bank'
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('Table 15 '):
        Table_15.append(files)
Table_15.sort(key=lambda x: x.split(' 20')[1].split('.')[0],reverse = True)
import numpy as np
import pandas as pd
sheets_data = []
xls = pd.ExcelFile('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx')
sheets = xls.sheet_names
df = pd.read_excel('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx',sheets[22])
title = df.iloc[0,1].replace(':','') 
unit = df.iloc[2,1]
df.columns = df.iloc[3,:]
df.columns = df.columns.str.replace('*', '')
sum = np.where(pd.isnull(df[df.columns[1]]))[0].tolist()[-1]
df = df.iloc[:sum,:]
df[df.columns[1]] = df[df.columns[1]].ffill(axis = 0)
df[df.columns[2]] = df[df.columns[2]].fillna('')
# df[df.columns[1]] = df[df.columns[1]].str.strip().replace('', np.nan).fillna(df[df.columns[2]])
df[df.columns[1]] = df[df.columns[1]].astype(str) + ' _ ' + df[df.columns[2]]
df = df.dropna(how='all')
df = df.dropna(how='all', axis=1)
df = df.dropna(subset=[df.columns[2]])
df = df.drop(df.columns[1], axis=1)
df = df[1:]
col_0 = df.iloc[:,0]
col_0 = col_0.to_list()
for i in range(len(col_0)):
    if i in range(16,20):
        col_0[i] = col_0[i].replace('a) Credit Facilities','b) Domestic Investments')
col_0[15] = col_0[15].replace('a) Credit Facilities _ ','')
pdList = []
for i in range(len(Table_15)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_15[i]}').reset_index(drop=True)
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace(' ', '')
    globals()[f'df_{i}'].insert(loc=0, column='Indicator', value=col_0)
    units = pd.DataFrame([f'{unit}']*len(globals()[f'df_{i}']))
    globals()[f'df_{i}'].insert(1, 'Unit', units)
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_csv(f'C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\{title} - statistical bulletin.csv',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\2201217664.py:18: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.columns = df.columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\2201217664.py:39: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\2201217664.py:39: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
# ...

# %%
# Table 16
Table_16 = []
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\central_bank'
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('Table 16 '):
        Table_16.append(files)
Table_16.sort(key=lambda x: x.split(' 20')[1].split('.')[0],reverse = True)
import numpy as np
import pandas as pd
sheets_data = []
xls = pd.ExcelFile('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx')
sheets = xls.sheet_names
df = pd.read_excel('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx',sheets[23])
title = df.iloc[0,1].replace(':','') 
unit = df.iloc[1,1]
df.columns = df.iloc[2,:]
df.columns = df.columns.str.replace('*', '')
sum = np.where(pd.isnull(df[df.columns[1]]))[0].tolist()[-1]
df = df.iloc[:sum,:]
df[df.columns[1]] = df[df.columns[1]].ffill(axis = 0)
df[df.columns[2]] = df[df.columns[2]].fillna('')
# df[df.columns[1]] = df[df.columns[1]].str.strip().replace('', np.nan).fillna(df[df.columns[2]])
df[df.columns[1]] = df[df.columns[1]].astype(str) + ' _ ' + df[df.columns[2]]
df = df.dropna(how='all')
df = df.dropna(how='all', axis=1)
df = df.dropna(subset=[df.columns[2]])
df = df.drop(df.columns[1], axis=1)
df = df[1:]
col_0 = df.iloc[:,0]
col_0 = col_0.to_list()
pdList = []
for i in range(len(Table_16)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_16[i]}').reset_index(drop=True)
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace(' ', '')
    globals()[f'df_{i}'].insert(loc=0, column='Indicator', value=col_0)
    units = pd.DataFrame([f'{unit}']*len(globals()[f'df_{i}']))
    globals()[f'df_{i}'].insert(1, 'Unit', units)
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_csv(f'C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\{title} - statistical bulletin.csv',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\2942770702.py:18: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.columns = df.columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\2942770702.py:35: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\2942770702.py:35: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
# ...

# %%
# Table 17
Table_17 = []
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\central_bank'
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('Table 17 '):
        Table_17.append(files)
Table_17.sort(key=lambda x: x.split(' 20')[1].split('.')[0],reverse = True)
import numpy as np
import pandas as pd
sheets_data = []
xls = pd.ExcelFile('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx')
sheets = xls.sheet_names
df = pd.read_excel('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx',sheets[24])
title = df.iloc[0,1].replace(':','') 
unit = df.iloc[2,1]
df.columns = df.iloc[3,:]
df.columns = df.columns.str.replace('*', '')
sum = np.where(pd.isnull(df[df.columns[1]]))[0].tolist()[-1]
df = df.iloc[:sum,:]
df[df.columns[1]] = df[df.columns[1]].ffill(axis = 0)
df[df.columns[2]] = df[df.columns[2]].fillna('')
# df[df.columns[1]] = df[df.columns[1]].str.strip().replace('', np.nan).fillna(df[df.columns[2]])
df[df.columns[1]] = df[df.columns[1]].astype(str) + ' _ ' + df[df.columns[2]]
df = df.dropna(how='all')
df = df.dropna(how='all', axis=1)
df = df.dropna(subset=[df.columns[2]])
df = df.drop(df.columns[1], axis=1)
df = df[1:]
col_0 = df.iloc[:,0]
col_0 = col_0.to_list()
pdList = []
for i in range(len(Table_17)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_17[i]}').reset_index(drop=True)
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace(' ', '')
    globals()[f'df_{i}'].insert(loc=0, column='Indicator', value=col_0)
    units = pd.DataFrame([f'{unit}']*len(globals()[f'df_{i}']))
    globals()[f'df_{i}'].insert(1, 'Unit', units)
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_csv(f'C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\{title} - statistical bulletin.csv',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\3481645979.py:18: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.columns = df.columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\3481645979.py:35: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\3481645979.py:35: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
# ...

# %%
# Table 18
Table_18 = []
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\central_bank'
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('Table 18 '):
        Table_18.append(files)
Table_18.sort(key=lambda x: x.split(' 20')[1].split('.')[0],reverse = True)
import numpy as np
import pandas as pd
sheets_data = []
xls = pd.ExcelFile('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx')
sheets = xls.sheet_names
df = pd.read_excel('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx',sheets[25])
title = df.iloc[0,1].replace(':','').replace("'","")
unit = df.iloc[2,1]
df.columns = df.iloc[3,:]
df.columns = df.columns.str.replace('*', '')
sum = np.where(pd.isnull(df[df.columns[1]]))[0].tolist()[-1]
df = df.iloc[:sum,:]
# df[df.columns[1]] = df[df.columns[1]].ffill(axis = 0)
# df[df.columns[2]] = df[df.columns[2]].fillna('')
# df[df.columns[1]] = df[df.columns[1]].str.strip().replace('', np.nan).fillna(df[df.columns[2]])
# df[df.columns[1]] = df[df.columns[1]].astype(str) + ' _ ' + df[df.columns[2]]
df = df.dropna(how='all')
df = df.dropna(how='all', axis=1)
# df = df.dropna(subset=[df.columns[2]])
# df = df.drop(df.columns[1], axis=1)
df = df[3:]
col_0 = df.iloc[:,0]
col_0 = col_0.to_list()
pdList = []
for i in range(len(Table_18)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_18[i]}').reset_index(drop=True)
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace(' ', '')
    globals()[f'df_{i}'].insert(loc=0, column='Indicator', value=col_0)
    units = pd.DataFrame([f'{unit}']*len(globals()[f'df_{i}']))
    globals()[f'df_{i}'].insert(1, 'Unit', units)
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_csv(f'C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\{title} - statistical bulletin.csv',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\675908723.py:18: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.columns = df.columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\675908723.py:35: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\675908723.py:35: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
# ...

# %%
# Table 19
Table_19 = []
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\central_bank'
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('Table 19 '):
        Table_19.append(files)
Table_19.sort(key=lambda x: x.split(' 20')[1].split('.')[0],reverse = True)
import numpy as np
import pandas as pd
sheets_data = []
xls = pd.ExcelFile('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx')
sheets = xls.sheet_names
df = pd.read_excel('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx',sheets[27])
title = df.iloc[0,1].replace(':','').replace("'","")
unit = df.iloc[2,1]
df.columns = df.iloc[3,:]
df.columns = df.columns.str.replace('*', '')
sum = np.where(pd.isnull(df[df.columns[1]]))[0].tolist()[-1]
df = df.iloc[:sum,:]
# df[df.columns[1]] = df[df.columns[1]].ffill(axis = 0)
# df[df.columns[2]] = df[df.columns[2]].fillna('')
# df[df.columns[1]] = df[df.columns[1]].str.strip().replace('', np.nan).fillna(df[df.columns[2]])
# df[df.columns[1]] = df[df.columns[1]].astype(str) + ' _ ' + df[df.columns[2]]
df = df.dropna(how='all')
df = df.dropna(how='all', axis=1)
# df = df.dropna(subset=[df.columns[2]])
# df = df.drop(df.columns[1], axis=1)
df = df[3:]
col_0 = df.iloc[:,0]
col_0 = col_0.to_list()
pdList = []
for i in range(len(Table_19)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_19[i]}').reset_index(drop=True)
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace(' ', '')
    globals()[f'df_{i}'].insert(loc=0, column='Indicator', value=col_0)
    units = pd.DataFrame([f'{unit}']*len(globals()[f'df_{i}']))
    globals()[f'df_{i}'].insert(1, 'Unit', units)
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_csv(f'C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\{title} - statistical bulletin.csv',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\1555014055.py:18: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.columns = df.columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\1555014055.py:35: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\1555014055.py:35: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
# ...

# %%
# Table 20
Table_20 = []
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\central_bank'
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('Table 20 '):
        Table_20.append(files)
Table_20.sort(key=lambda x: x.split(' 20')[1].split('.')[0],reverse = True)
import numpy as np
import pandas as pd
sheets_data = []
xls = pd.ExcelFile('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx')
sheets = xls.sheet_names
df = pd.read_excel('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx',sheets[28])
title = df.iloc[0,1].replace(':','').replace("'","")
unit = df.iloc[2,1]
df.columns = df.iloc[3,:]
df.columns = df.columns.str.replace('*', '')
sum = np.where(pd.isnull(df[df.columns[1]]))[0].tolist()[-1]
df = df.iloc[:sum,:]
# df[df.columns[1]] = df[df.columns[1]].ffill(axis = 0)
# df[df.columns[2]] = df[df.columns[2]].fillna('')
# df[df.columns[1]] = df[df.columns[1]].str.strip().replace('', np.nan).fillna(df[df.columns[2]])
# df[df.columns[1]] = df[df.columns[1]].astype(str) + ' _ ' + df[df.columns[2]]
df = df.dropna(how='all')
df = df.dropna(how='all', axis=1)
# df = df.dropna(subset=[df.columns[2]])
# df = df.drop(df.columns[1], axis=1)
df = df[3:]
col_0 = df.iloc[:,0]
col_0 = col_0.to_list()
pdList = []
for i in range(len(Table_20)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_20[i]}').reset_index(drop=True)
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace(' ', '')
    globals()[f'df_{i}'].insert(loc=0, column='Indicator', value=col_0)
    units = pd.DataFrame([f'{unit}']*len(globals()[f'df_{i}']))
    globals()[f'df_{i}'].insert(1, 'Unit', units)
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_csv(f'C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\{title} - statistical bulletin.csv',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\3256722923.py:18: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.columns = df.columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\3256722923.py:35: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\3256722923.py:35: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
# ...

# %%
# Table 21
Table_21 = []
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\central_bank'
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('Table 21 '):
        Table_21.append(files)
Table_21.sort(key=lambda x: x.split(' 20')[1].split('.')[0],reverse = True)
import numpy as np
import pandas as pd
sheets_data = []
xls = pd.ExcelFile('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx')
sheets = xls.sheet_names
df = pd.read_excel('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx',sheets[29])
title = df.iloc[0,1].replace(':','').replace("'","")
unit = df.iloc[2,1]
df.columns = df.iloc[3,:]
df.columns = df.columns.str.replace('*', '')
sum = np.where(pd.isnull(df[df.columns[1]]))[0].tolist()[-1]
df = df.iloc[:sum,:]
# df[df.columns[1]] = df[df.columns[1]].ffill(axis = 0)
# df[df.columns[2]] = df[df.columns[2]].fillna('')
# df[df.columns[1]] = df[df.columns[1]].str.strip().replace('', np.nan).fillna(df[df.columns[2]])
# df[df.columns[1]] = df[df.columns[1]].astype(str) + ' _ ' + df[df.columns[2]]
df = df.dropna(how='all')
df = df.dropna(how='all', axis=1)
# df = df.dropna(subset=[df.columns[2]])
# df = df.drop(df.columns[1], axis=1)
df = df[3:]
col_0 = df.iloc[:,0]
col_0 = col_0.to_list()
pdList = []
for i in range(len(Table_21)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_21[i]}').reset_index(drop=True)
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace(' ', '')
    globals()[f'df_{i}'].insert(loc=0, column='Indicator', value=col_0)
    units = pd.DataFrame([f'{unit}']*len(globals()[f'df_{i}']))
    globals()[f'df_{i}'].insert(1, 'Unit', units)
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_csv(f'C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\{title} - statistical bulletin.csv',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\3758659060.py:18: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.columns = df.columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\3758659060.py:35: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\3758659060.py:35: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
# ...

# %%
# Table 22
Table_22 = []
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\central_bank'
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('Table 22 '):
        Table_22.append(files)
Table_22.sort(key=lambda x: x.split(' 20')[1].split('.')[0],reverse = True)
import numpy as np
import pandas as pd
sheets_data = []
xls = pd.ExcelFile('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx')
sheets = xls.sheet_names
df = pd.read_excel('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx',sheets[30])
title = df.iloc[0,1].replace(':','').replace("'","")
unit = df.iloc[2,1]
df.columns = df.iloc[3,:]
df.columns = df.columns.str.replace('*', '')
sum = np.where(pd.isnull(df[df.columns[1]]))[0].tolist()[-1]
df = df.iloc[:sum,:]
# df[df.columns[1]] = df[df.columns[1]].ffill(axis = 0)
# df[df.columns[2]] = df[df.columns[2]].fillna('')
# df[df.columns[1]] = df[df.columns[1]].str.strip().replace('', np.nan).fillna(df[df.columns[2]])
# df[df.columns[1]] = df[df.columns[1]].astype(str) + ' _ ' + df[df.columns[2]]
df = df.dropna(how='all')
df = df.dropna(how='all', axis=1)
# df = df.dropna(subset=[df.columns[2]])
# df = df.drop(df.columns[1], axis=1)
df = df[3:]
col_0 = df.iloc[:,0]
col_0 = col_0.to_list()
pdList = []
for i in range(len(Table_22)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_22[i]}').reset_index(drop=True)
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace(' ', '')
    globals()[f'df_{i}'].insert(loc=0, column='Indicator', value=col_0)
    units = pd.DataFrame([f'{unit}']*len(globals()[f'df_{i}']))
    globals()[f'df_{i}'].insert(1, 'Unit', units)
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_csv(f'C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\{title} - statistical bulletin.csv',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\1582298207.py:18: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.columns = df.columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\1582298207.py:35: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\1582298207.py:35: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
# ...

# %%
# Table 23
Table_23 = []
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\central_bank'
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('Table 23 '):
        Table_23.append(files)
Table_23.sort(key=lambda x: x.split(' 20')[1].split('.')[0],reverse = True)
import numpy as np
import pandas as pd
sheets_data = []
xls = pd.ExcelFile('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx')
sheets = xls.sheet_names
df = pd.read_excel('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx',sheets[31])
title = df.iloc[1,1].replace(':','').replace("'","")
unit = df.iloc[3,1]
df.columns = df.iloc[4,:]
df.columns = df.columns.str.replace('*', '')
sum = np.where(pd.isnull(df[df.columns[1]]))[0].tolist()[-1]
df = df.iloc[:sum,:]
df = df.dropna(how='all')
df = df.dropna(how='all', axis=1)
df[df.columns[0]] = df[df.columns[0]].ffill(axis = 0)
df[df.columns[1]] = df[df.columns[1]].fillna('')
df[df.columns[0]] = df[df.columns[0]].str.strip().replace('', np.nan).fillna(df[df.columns[1]])
df[df.columns[0]] = df[df.columns[0]].astype(str) + ' _ ' + df[df.columns[1]]
df = df.dropna(how='all')
df = df.dropna(how='all', axis=1)
df = df.dropna(subset=[df.columns[1]])
df = df.drop(df.columns[1], axis=1)
df = df[3:]
col_0 = df.iloc[:,0]
col_0 = col_0.to_list()
pdList = []
for i in range(len(Table_23)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_23[i]}').reset_index(drop=True)
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace(' ', '')
    globals()[f'df_{i}'].insert(loc=0, column='Indicator', value=col_0)
    units = pd.DataFrame([f'{unit}']*len(globals()[f'df_{i}']))
    globals()[f'df_{i}'].insert(1, 'Unit', units)
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_csv(f'C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\{title} - statistical bulletin.csv',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\2305270453.py:18: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.columns = df.columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\2305270453.py:37: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\2305270453.py:37: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
# ...

# %%
# Table 24
Table_24 = []
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\central_bank'
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('Table 24 '):
        Table_24.append(files)
Table_24.sort(key=lambda x: x.split(' 20')[1].split('.')[0],reverse = True)
import numpy as np
import pandas as pd
sheets_data = []
xls = pd.ExcelFile('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx')
sheets = xls.sheet_names
df = pd.read_excel('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx',sheets[33])
title = df.iloc[1,1].replace(':','').replace("'","")
unit = df.iloc[3,1]
df.columns = df.iloc[4,:]
df.columns = df.columns.str.replace('*', '')
sum = np.where(pd.isnull(df[df.columns[1]]))[0].tolist()[-1]
df = df.iloc[:sum,:]
df = df.dropna(how='all')
df = df.dropna(how='all', axis=1)
df[df.columns[0]] = df[df.columns[0]].ffill(axis = 0)
df[df.columns[1]] = df[df.columns[1]].fillna('')
df[df.columns[0]] = df[df.columns[0]].str.strip().replace('', np.nan).fillna(df[df.columns[1]])
df[df.columns[0]] = df[df.columns[0]].astype(str) + ' _ ' + df[df.columns[1]]
df = df.dropna(how='all')
df = df.dropna(how='all', axis=1)
df = df.dropna(subset=[df.columns[1]])
df = df.drop(df.columns[1], axis=1)
df = df[3:]
col_0 = df.iloc[:,0]
col_0 = col_0.to_list()
pdList = []
for i in range(len(Table_24)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_24[i]}').reset_index(drop=True)
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace(' ', '')
    globals()[f'df_{i}'].insert(loc=0, column='Indicator', value=col_0)
    units = pd.DataFrame([f'{unit}']*len(globals()[f'df_{i}']))
    globals()[f'df_{i}'].insert(1, 'Unit', units)
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_csv(f'C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\{title} - statistical bulletin.csv',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\1635894939.py:18: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.columns = df.columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\1635894939.py:37: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\1635894939.py:37: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
# ...

# %%
# Table 25
Table_25 = []
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\central_bank'
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('Table 25 '):
        Table_25.append(files)
Table_24.sort(key=lambda x: x.split(' 20')[1].split('.')[0],reverse = True)
import numpy as np
import pandas as pd
sheets_data = []
xls = pd.ExcelFile('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx')
sheets = xls.sheet_names
df = pd.read_excel('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx',sheets[34])
title = df.iloc[1,1].replace(':','').replace("'","")
unit = df.iloc[3,1]
df.columns = df.iloc[4,:]
df.columns = df.columns.str.replace('*', '')
sum = np.where(pd.isnull(df[df.columns[1]]))[0].tolist()[-1]
df = df.iloc[:sum,:]
df = df.dropna(how='all')
df = df.dropna(how='all', axis=1)
df[df.columns[0]] = df[df.columns[0]].ffill(axis = 0)
df[df.columns[1]] = df[df.columns[1]].fillna('')
df[df.columns[0]] = df[df.columns[0]].str.strip().replace('', np.nan).fillna(df[df.columns[1]])
df[df.columns[0]] = df[df.columns[0]].astype(str) + ' _ ' + df[df.columns[1]]
df = df.dropna(how='all')
df = df.dropna(how='all', axis=1)
df = df.dropna(subset=[df.columns[1]])
df = df.drop(df.columns[1], axis=1)
df = df[3:]
col_0 = df.iloc[:,0]
col_0 = col_0.to_list()
pdList = []
for i in range(len(Table_25)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_25[i]}').reset_index(drop=True)
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace(' ', '')
    globals()[f'df_{i}'].insert(loc=0, column='Indicator', value=col_0)
    units = pd.DataFrame([f'{unit}']*len(globals()[f'df_{i}']))
    globals()[f'df_{i}'].insert(1, 'Unit', units)
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_csv(f'C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\{title} - statistical bulletin.csv',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\3755125222.py:18: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.columns = df.columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\3755125222.py:37: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\3755125222.py:37: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
# ...

# %%
# Table 26
Table_26 = []
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\central_bank'
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('Table 26 '):
        Table_26.append(files)
Table_26.sort(key=lambda x: x.split(' 20')[1].split('.')[0],reverse = True)
import numpy as np
import pandas as pd
sheets_data = []
xls = pd.ExcelFile('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx')
sheets = xls.sheet_names
df = pd.read_excel('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx',sheets[35])
title = df.iloc[1,1].replace(':','').replace("'","")
unit = df.iloc[3,1]
df.columns = df.iloc[4,:]
df.columns = df.columns.str.replace('*', '')
sum = np.where(pd.isnull(df[df.columns[1]]))[0].tolist()[-1]
df = df.iloc[:sum,:]
df = df.dropna(how='all')
df = df.dropna(how='all', axis=1)
df[df.columns[0]] = df[df.columns[0]].ffill(axis = 0)
df[df.columns[1]] = df[df.columns[1]].fillna('')
df[df.columns[0]] = df[df.columns[0]].str.strip().replace('', np.nan).fillna(df[df.columns[1]])
df[df.columns[0]] = df[df.columns[0]].astype(str) + ' _ ' + df[df.columns[1]]
df = df.dropna(how='all')
df = df.dropna(how='all', axis=1)
df = df.dropna(subset=[df.columns[1]])
df = df.drop(df.columns[1], axis=1)
df = df[3:]
col_0 = df.iloc[:,0]
col_0 = col_0.to_list()
pdList = []
for i in range(len(Table_26)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_26[i]}').reset_index(drop=True)
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace(' ', '')
    globals()[f'df_{i}'].insert(loc=0, column='Indicator', value=col_0)
    units = pd.DataFrame([f'{unit}']*len(globals()[f'df_{i}']))
    globals()[f'df_{i}'].insert(1, 'Unit', units)
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_csv(f'C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\{title} - statistical bulletin.csv',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\1653335531.py:18: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.columns = df.columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\1653335531.py:37: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\1653335531.py:37: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
# ...

# %%
# Table 27
Table_27 = []
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\central_bank'
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('Table 27 '):
        Table_27.append(files)
Table_27.sort(key=lambda x: x.split(' 20')[1].split('.')[0],reverse = True)
import numpy as np
import pandas as pd
sheets_data = []
xls = pd.ExcelFile('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx')
sheets = xls.sheet_names
df = pd.read_excel('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx',sheets[36])
title = df.iloc[1,1].replace(':','').replace("'","")
unit = df.iloc[3,1]
df.columns = df.iloc[4,:]
df.columns = df.columns.str.replace('*', '')
sum = np.where(pd.isnull(df[df.columns[1]]))[0].tolist()[-1]
df = df.iloc[:sum,:]
df = df.dropna(how='all')
df = df.dropna(how='all', axis=1)
df[df.columns[0]] = df[df.columns[0]].ffill(axis = 0)
df[df.columns[1]] = df[df.columns[1]].fillna('')
df[df.columns[0]] = df[df.columns[0]].str.strip().replace('', np.nan).fillna(df[df.columns[1]])
df[df.columns[0]] = df[df.columns[0]].astype(str) + ' _ ' + df[df.columns[1]]
df = df.dropna(how='all')
df = df.dropna(how='all', axis=1)
df = df.dropna(subset=[df.columns[1]])
df = df.drop(df.columns[1], axis=1)
df = df[3:]
col_0 = df.iloc[:,0]
col_0 = col_0.to_list()
pdList = []
for i in range(len(Table_27)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_27[i]}').reset_index(drop=True)
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace(' ', '')
    globals()[f'df_{i}'].insert(loc=0, column='Indicator', value=col_0)
    units = pd.DataFrame([f'{unit}']*len(globals()[f'df_{i}']))
    globals()[f'df_{i}'].insert(1, 'Unit', units)
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_csv(f'C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\{title} - statistical bulletin.csv',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\2399300569.py:18: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.columns = df.columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\2399300569.py:37: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\2399300569.py:37: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
# ...

# %%
# Table 28
Table_28 = []
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\central_bank'
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('Table 28 '):
        Table_28.append(files)
Table_28.sort(key=lambda x: x.split(' 20')[1].split('.')[0],reverse = True)
import numpy as np
import pandas as pd
sheets_data = []
xls = pd.ExcelFile('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx')
sheets = xls.sheet_names
df = pd.read_excel('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx',sheets[37])
title = df.iloc[0,1].replace(':','').replace("'","")
unit = df.iloc[2,1]
df.columns = df.iloc[3,:]
df.columns = df.columns.str.replace('*', '')
sum = np.where(pd.isnull(df[df.columns[1]]))[0].tolist()[-1]
df = df.iloc[:sum,:]
df = df.dropna(how='all')
df = df.dropna(how='all', axis=1)
df[df.columns[0]] = df[df.columns[0]].ffill(axis = 0)
# df[df.columns[1]] = df[df.columns[1]].fillna('')
# df[df.columns[2]] = df[df.columns[2]].fillna('')
# df[df.columns[0]] = df[df.columns[0]].str.strip().replace('', np.nan).fillna(df[df.columns[1]])
df[df.columns[0]] = df[df.columns[0]].astype(str) + ' _ ' + df.iloc[:,1].astype(str)
df[df.columns[0]] = df[df.columns[0]].astype(str) + ' _ ' + df.iloc[:,2].astype(str)
df = df.dropna(how='all')
df = df.dropna(how='all', axis=1)
# df = df.dropna(subset=[df.columns[1]])
df = df.drop(df.columns[1], axis=1)
df = df.drop(df.columns[2], axis=1)
df = df[4:]
col_0 = df.iloc[:,0]
col_0 = col_0.to_list()
pdList = []
for i in range(len(Table_28)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_28[i]}').reset_index(drop=True)
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace(' ', '')
    globals()[f'df_{i}'].insert(loc=0, column='Indicator', value=col_0)
    units = pd.DataFrame([f'{unit}']*len(globals()[f'df_{i}']))
    globals()[f'df_{i}'].insert(1, 'Unit', units)
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_csv(f'C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\{title} - statistical bulletin.csv',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\2704021569.py:18: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.columns = df.columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\2704021569.py:40: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\2704021569.py:40: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
# ...

# %%
# Table 29
Table_29 = []
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\central_bank'
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('Table 29 '):
        Table_29.append(files)
Table_29.sort(key=lambda x: x.split(' 20')[1].split('.')[0],reverse = True)
import numpy as np
import pandas as pd
sheets_data = []
xls = pd.ExcelFile('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx')
sheets = xls.sheet_names
df = pd.read_excel('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx',sheets[38])
title = df.iloc[0,1].replace(':','').replace("'","")
unit = df.iloc[2,1]
df.columns = df.iloc[3,:]
df.columns = df.columns.str.replace('*', '')
sum = np.where(pd.isnull(df[df.columns[1]]))[0].tolist()[-1]
df = df.iloc[:sum,:]
df = df.dropna(how='all')
df = df.dropna(how='all', axis=1)
df[df.columns[0]] = df[df.columns[0]].ffill(axis = 0)
# df[df.columns[1]] = df[df.columns[1]].fillna('')
# df[df.columns[2]] = df[df.columns[2]].fillna('')
# df[df.columns[0]] = df[df.columns[0]].str.strip().replace('', np.nan).fillna(df[df.columns[1]])
df[df.columns[0]] = df[df.columns[0]].astype(str) + ' _ ' + df.iloc[:,1].astype(str)
df[df.columns[0]] = df[df.columns[0]].astype(str) + ' _ ' + df.iloc[:,2].astype(str)
df = df.dropna(how='all')
df = df.dropna(how='all', axis=1)
# df = df.dropna(subset=[df.columns[1]])
df = df.drop(df.columns[1], axis=1)
df = df.drop(df.columns[2], axis=1)
df = df[4:]
col_0 = df.iloc[:,0]
col_0 = col_0.to_list()
pdList = []
for i in range(len(Table_29)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_29[i]}').reset_index(drop=True)
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace(' ', '')
    globals()[f'df_{i}'].insert(loc=0, column='Indicator', value=col_0)
    units = pd.DataFrame([f'{unit}']*len(globals()[f'df_{i}']))
    globals()[f'df_{i}'].insert(1, 'Unit', units)
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_csv(f'C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\{title} - statistical bulletin.csv',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\3097307311.py:18: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.columns = df.columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\3097307311.py:40: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\3097307311.py:40: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
# ...

# %%
# Table 30
Table_30 = []
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\central_bank'
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('Table 30 '):
        Table_30.append(files)
Table_30.sort(key=lambda x: x.split(' 20')[1].split('.')[0],reverse = True)
import numpy as np
import pandas as pd
sheets_data = []
xls = pd.ExcelFile('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx')
sheets = xls.sheet_names
df = pd.read_excel('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx',sheets[39])
title = df.iloc[1,1].replace(':','').replace("'","").replace('/','')
unit = df.iloc[3,1]
df.columns = df.iloc[4,:]
df.columns = df.columns.str.replace('*', '')
sum = np.where(pd.isnull(df[df.columns[1]]))[0].tolist()[-1]
df = df.iloc[:sum,:]
df = df.dropna(how='all')
df = df.dropna(how='all', axis=1)
df[df.columns[0]] = df[df.columns[0]].ffill(axis = 0)
# df[df.columns[1]] = df[df.columns[1]].fillna('')
# df[df.columns[2]] = df[df.columns[2]].fillna('')
# df[df.columns[0]] = df[df.columns[0]].str.strip().replace('', np.nan).fillna(df[df.columns[1]])
df[df.columns[0]] = df[df.columns[0]].astype(str) + ' _ ' + df.iloc[:,1].astype(str)
df[df.columns[0]] = df[df.columns[0]].astype(str) + ' _ ' + df.iloc[:,2].astype(str)
df = df.dropna(how='all')
df = df.dropna(how='all', axis=1)
# df = df.dropna(subset=[df.columns[1]])
df = df.drop(df.columns[1], axis=1)
df = df.drop(df.columns[2], axis=1)
df = df[3:]
col_0 = df.iloc[:,0]
col_0 = col_0.to_list()
pdList = []
for i in range(len(Table_30)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_30[i]}').reset_index(drop=True)
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace(' ', '')
    globals()[f'df_{i}'].insert(loc=0, column='Indicator', value=col_0)
    units = pd.DataFrame([f'{unit}']*len(globals()[f'df_{i}']))
    globals()[f'df_{i}'].insert(1, 'Unit', units)
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_csv(f'C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\{title} - statistical bulletin.csv',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\4041908662.py:18: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.columns = df.columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\4041908662.py:40: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\4041908662.py:40: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
# ...

# %%
# Table 31
Table_31 = []
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\central_bank'
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('Table 31 '):
        Table_31.append(files)
Table_31.sort(key=lambda x: x.split(' 20')[1].split('.')[0],reverse = True)
import numpy as np
import pandas as pd
sheets_data = []
xls = pd.ExcelFile('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx')
sheets = xls.sheet_names
df = pd.read_excel('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx',sheets[41])
title = df.iloc[1,1].replace(':','').replace("'","").replace('/','')
unit = df.iloc[3,1]
df.columns = df.iloc[4,:]
df.columns = df.columns.str.replace('*', '')
# sum = np.where(pd.isnull(df[df.columns[1]]))[0].tolist()[-1]
# df = df.iloc[:sum,:]
df = df.dropna(how='all')
df = df.dropna(how='all', axis=1)
df[df.columns[0]] = df[df.columns[0]].ffill(axis = 0)
# df[df.columns[1]] = df[df.columns[1]].fillna('')
# df[df.columns[2]] = df[df.columns[2]].fillna('')
# df[df.columns[0]] = df[df.columns[0]].str.strip().replace('', np.nan).fillna(df[df.columns[1]])
df[df.columns[0]] = df[df.columns[0]].astype(str) + ' _ ' + df.iloc[:,1].astype(str) + ' _ ' + df.iloc[:,2].astype(str)
# df[df.columns[0]] = df[df.columns[0]].astype(str) 
df = df.dropna(how='all')
df = df.dropna(how='all', axis=1)
# df = df.dropna(subset=[df.columns[1]])
df = df.drop(df.columns[1], axis=1)
df = df.drop(df.columns[2], axis=1)
df = df[3:15]
col_0 = df.iloc[:,0]
col_0 = col_0.to_list()
pdList = []
for i in range(len(Table_31)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_31[i]}').reset_index(drop=True)
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace(' ', '')
    globals()[f'df_{i}'].insert(loc=0, column='Indicator', value=col_0)
    units = pd.DataFrame([f'{unit}']*len(globals()[f'df_{i}']))
    globals()[f'df_{i}'].insert(1, 'Unit', units)
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_csv(f'C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\{title} - statistical bulletin.csv',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\1513524416.py:18: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.columns = df.columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\1513524416.py:40: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\1513524416.py:40: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
# ...

# %%
# Table 32
Table_32 = []
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\central_bank'
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('Table 32 '):
        Table_32.append(files)
Table_32.sort(key=lambda x: x.split(' 20')[1].split('.')[0],reverse = True)
import numpy as np
import pandas as pd
sheets_data = []
xls = pd.ExcelFile('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx')
sheets = xls.sheet_names
df = pd.read_excel('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx',sheets[42])
title = df.iloc[1,1].replace(':','').replace("'","").replace('/','')
unit = df.iloc[3,1]
df.columns = df.iloc[4,:]
df.columns = df.columns.str.replace('*', '')
# sum = np.where(pd.isnull(df[df.columns[1]]))[0].tolist()[-1]
# df = df.iloc[:sum,:]
df = df.dropna(how='all')
df = df.dropna(how='all', axis=1)
df[df.columns[0]] = df[df.columns[0]].ffill(axis = 0)
# df[df.columns[1]] = df[df.columns[1]].fillna('')
# df[df.columns[2]] = df[df.columns[2]].fillna('')
# df[df.columns[0]] = df[df.columns[0]].str.strip().replace('', np.nan).fillna(df[df.columns[1]])
df[df.columns[0]] = df[df.columns[0]].astype(str) + ' _ ' + df.iloc[:,1].astype(str) + ' _ ' + df.iloc[:,2].astype(str)
# df[df.columns[0]] = df[df.columns[0]].astype(str) 
df = df.dropna(how='all')
df = df.dropna(how='all', axis=1)
# df = df.dropna(subset=[df.columns[1]])
df = df.drop(df.columns[1], axis=1)
df = df.drop(df.columns[2], axis=1)
df = df[3:15]
col_0 = df.iloc[:,0]
col_0 = col_0.to_list()
pdList = []
for i in range(len(Table_32)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_32[i]}').reset_index(drop=True)
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace(' ', '')
    globals()[f'df_{i}'].insert(loc=0, column='Indicator', value=col_0)
    units = pd.DataFrame([f'{unit}']*len(globals()[f'df_{i}']))
    globals()[f'df_{i}'].insert(1, 'Unit', units)
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_csv(f'C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\{title} - statistical bulletin.csv',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\2840444561.py:18: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.columns = df.columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\2840444561.py:40: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\2840444561.py:40: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
# ...

# %%
# Table 33
Table_33 = []
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\central_bank'
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('Table 33 '):
        Table_33.append(files)
Table_33.sort(key=lambda x: x.split(' 20')[1].split('.')[0],reverse = True)
import numpy as np
import pandas as pd
sheets_data = []
xls = pd.ExcelFile('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx')
sheets = xls.sheet_names
df = pd.read_excel('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx',sheets[43])
title = df.iloc[1,1].replace(':','').replace("'","").replace('/','')
unit = df.iloc[3,1]
df.columns = df.iloc[4,:]
df.columns = df.columns.str.replace('*', '')
# sum = np.where(pd.isnull(df[df.columns[1]]))[0].tolist()[-1]
# df = df.iloc[:sum,:]
df = df.dropna(how='all')
df = df.dropna(how='all', axis=1)
df[df.columns[0]] = df[df.columns[0]].ffill(axis = 0)
# df[df.columns[1]] = df[df.columns[1]].fillna('')
# df[df.columns[2]] = df[df.columns[2]].fillna('')
# df[df.columns[0]] = df[df.columns[0]].str.strip().replace('', np.nan).fillna(df[df.columns[1]])
df[df.columns[0]] = df[df.columns[0]].astype(str) + ' _ ' + df.iloc[:,1].astype(str) + ' _ ' + df.iloc[:,2].astype(str)
# df[df.columns[0]] = df[df.columns[0]].astype(str) 
df = df.dropna(how='all')
df = df.dropna(how='all', axis=1)
# df = df.dropna(subset=[df.columns[1]])
df = df.drop(df.columns[1], axis=1)
df = df.drop(df.columns[2], axis=1)
df = df[3:15]
col_0 = df.iloc[:,0]
col_0 = col_0.to_list()
pdList = []
for i in range(len(Table_33)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_33[i]}').reset_index(drop=True)
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace(' ', '')
    globals()[f'df_{i}'].insert(loc=0, column='Indicator', value=col_0)
    units = pd.DataFrame([f'{unit}']*len(globals()[f'df_{i}']))
    globals()[f'df_{i}'].insert(1, 'Unit', units)
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_csv(f'C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\{title} - statistical bulletin.csv',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\1114590476.py:18: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.columns = df.columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\1114590476.py:40: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\1114590476.py:40: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
# ...

# %%
# Table 34
Table_34 = []
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\central_bank'
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('Table 34 '):
        Table_34.append(files)
Table_34.sort(key=lambda x: x.split(' 20')[1].split('.')[0],reverse = True)
import numpy as np
import pandas as pd
sheets_data = []
xls = pd.ExcelFile('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx')
sheets = xls.sheet_names
df = pd.read_excel('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx',sheets[44])
title = df.iloc[1,1].replace(':','').replace("'","").replace('/','')
unit = df.iloc[3,1]
df.columns = df.iloc[4,:]
df.columns = df.columns.str.replace('*', '')
# sum = np.where(pd.isnull(df[df.columns[1]]))[0].tolist()[-1]
# df = df.iloc[:sum,:]
df = df.dropna(how='all')
df = df.dropna(how='all', axis=1)
df[df.columns[0]] = df[df.columns[0]].ffill(axis = 0)
# df[df.columns[1]] = df[df.columns[1]].fillna('')
# df[df.columns[2]] = df[df.columns[2]].fillna('')
# df[df.columns[0]] = df[df.columns[0]].str.strip().replace('', np.nan).fillna(df[df.columns[1]])
df[df.columns[0]] = df[df.columns[0]].astype(str) + ' _ ' + df.iloc[:,1].astype(str) + ' _ ' + df.iloc[:,2].astype(str)
# df[df.columns[0]] = df[df.columns[0]].astype(str) 
df = df.dropna(how='all')
df = df.dropna(how='all', axis=1)
# df = df.dropna(subset=[df.columns[1]])
df = df.drop(df.columns[1], axis=1)
df = df.drop(df.columns[2], axis=1)
df = df[3:15]
col_0 = df.iloc[:,0]
col_0 = col_0.to_list()
pdList = []
for i in range(len(Table_34)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_34[i]}').reset_index(drop=True)
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace(' ', '')
    globals()[f'df_{i}'].insert(loc=0, column='Indicator', value=col_0)
    units = pd.DataFrame([f'{unit}']*len(globals()[f'df_{i}']))
    globals()[f'df_{i}'].insert(1, 'Unit', units)
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_csv(f'C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\{title} - statistical bulletin.csv',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\4279896470.py:18: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.columns = df.columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\4279896470.py:40: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\4279896470.py:40: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
# ...

# %%
# Table 35
Table_35 = []
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\central_bank'
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('Table 35 '):
        Table_35.append(files)
Table_35.sort(key=lambda x: x.split(' 20')[1].split('.')[0],reverse = True)
import numpy as np
import pandas as pd
sheets_data = []
xls = pd.ExcelFile('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx')
sheets = xls.sheet_names
df = pd.read_excel('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx',sheets[45])
title = df.iloc[1,1].replace(':','').replace("'","")
unit = df.iloc[3,1]
df.columns = df.iloc[4,:]
df.columns = df.columns.str.replace('*', '')
sum = np.where(pd.isnull(df[df.columns[1]]))[0].tolist()[-1]
df = df.iloc[:sum,:]

# df[df.columns[1]] = df[df.columns[1]].ffill(axis = 0)
# df[df.columns[2]] = df[df.columns[2]].fillna('')
# df[df.columns[1]] = df[df.columns[1]].str.strip().replace('', np.nan).fillna(df[df.columns[2]])
# df[df.columns[1]] = df[df.columns[1]].astype(str) + ' _ ' + df[df.columns[2]]

df = df.dropna(how='all')
df = df.dropna(how='all', axis=1)

# df = df.dropna(subset=[df.columns[2]])
# df = df.drop(df.columns[1], axis=1)

df = df[3:]
col_0 = df.iloc[:,0]
col_0 = col_0.to_list()
pdList = []
for i in range(len(Table_35)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_35[i]}').reset_index(drop=True)
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace(' ', '')
    globals()[f'df_{i}'].insert(loc=0, column='Indicator', value=col_0)
    units = pd.DataFrame([f'{unit}']*len(globals()[f'df_{i}']))
    globals()[f'df_{i}'].insert(1, 'Unit', units)
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_csv(f'C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\{title} - statistical bulletin.csv',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\3705224716.py:18: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.columns = df.columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\3705224716.py:39: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\3705224716.py:39: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
# ...

# %%
# Table 36
Table_36 = []
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\central_bank'
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('Table 36 '):
        Table_36.append(files)
Table_36.sort(key=lambda x: x.split(' 20')[1].split('.')[0],reverse = True)
import numpy as np
import pandas as pd
sheets_data = []
xls = pd.ExcelFile('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx')
sheets = xls.sheet_names
df = pd.read_excel('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx',sheets[46])
title = df.iloc[0,1].replace(':','').replace("'","")
unit = df.iloc[2,1]
df.columns = df.iloc[3,:]
df.columns = df.columns.str.replace('*', '')
sum = np.where(pd.isnull(df[df.columns[1]]))[0].tolist()[-1]
df = df.iloc[:sum,:]

# df[df.columns[1]] = df[df.columns[1]].ffill(axis = 0)
# df[df.columns[2]] = df[df.columns[2]].fillna('')
# df[df.columns[1]] = df[df.columns[1]].str.strip().replace('', np.nan).fillna(df[df.columns[2]])
# df[df.columns[1]] = df[df.columns[1]].astype(str) + ' _ ' + df[df.columns[2]]

df = df.dropna(how='all')
df = df.dropna(how='all', axis=1)

# df = df.dropna(subset=[df.columns[2]])
# df = df.drop(df.columns[1], axis=1)

df = df[3:]
col_0 = df.iloc[:,0]
col_0 = col_0.to_list()
pdList = []
for i in range(len(Table_36)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_36[i]}').reset_index(drop=True)
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace(' ', '')
    globals()[f'df_{i}'].insert(loc=0, column='Indicator', value=col_0)
    units = pd.DataFrame([f'{unit}']*len(globals()[f'df_{i}']))
    globals()[f'df_{i}'].insert(1, 'Unit', units)
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_csv(f'C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\{title} - statistical bulletin.csv',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\2272404505.py:18: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.columns = df.columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\2272404505.py:39: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\2272404505.py:39: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
# ...

# %%
# Table 37
Table_37 = []
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\central_bank'
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('Table 37 '):
        Table_37.append(files)
Table_37.sort(key=lambda x: x.split(' 20')[1].split('.')[0],reverse = True)
import numpy as np
import pandas as pd
sheets_data = []
xls = pd.ExcelFile('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx')
sheets = xls.sheet_names
df = pd.read_excel('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx',sheets[47])
title = df.iloc[0,1].replace(':','').replace("'","")
unit = df.iloc[2,1]
df.columns = df.iloc[3,:]
df.columns = df.columns.str.replace('*', '')
sum = np.where(pd.isnull(df[df.columns[1]]))[0].tolist()[-1]
df = df.iloc[:sum,:]

# df[df.columns[1]] = df[df.columns[1]].ffill(axis = 0)
# df[df.columns[2]] = df[df.columns[2]].fillna('')
# df[df.columns[1]] = df[df.columns[1]].str.strip().replace('', np.nan).fillna(df[df.columns[2]])
# df[df.columns[1]] = df[df.columns[1]].astype(str) + ' _ ' + df[df.columns[2]]

df = df.dropna(how='all')
df = df.dropna(how='all', axis=1)

# df = df.dropna(subset=[df.columns[2]])
# df = df.drop(df.columns[1], axis=1)

df = df[3:]
col_0 = df.iloc[:,0]
col_0 = col_0.to_list()
pdList = []
for i in range(len(Table_37)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_37[i]}').reset_index(drop=True)
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace(' ', '')
    globals()[f'df_{i}'].insert(loc=0, column='Indicator', value=col_0)
    units = pd.DataFrame([f'{unit}']*len(globals()[f'df_{i}']))
    globals()[f'df_{i}'].insert(1, 'Unit', units)
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_csv(f'C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\{title} - statistical bulletin.csv',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\941949346.py:18: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.columns = df.columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\941949346.py:39: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\941949346.py:39: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
# ...

# %%
# Table 38
Table_38 = []
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\central_bank'
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('Table 38 '):
        Table_38.append(files)
Table_38.sort(key=lambda x: x.split(' 20')[1].split('.')[0],reverse = True)
import numpy as np
import pandas as pd
sheets_data = []
xls = pd.ExcelFile('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx')
sheets = xls.sheet_names
df = pd.read_excel('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx',sheets[48])
title = df.iloc[0,1].replace(':','').replace("'","")
unit = df.iloc[2,1]
df.columns = df.iloc[3,:]
df.columns = df.columns.str.replace('*', '')
sum = np.where(pd.isnull(df[df.columns[1]]))[0].tolist()[-1]
df = df.iloc[:sum,:]

# df[df.columns[1]] = df[df.columns[1]].ffill(axis = 0)
# df[df.columns[2]] = df[df.columns[2]].fillna('')
# df[df.columns[1]] = df[df.columns[1]].str.strip().replace('', np.nan).fillna(df[df.columns[2]])
# df[df.columns[1]] = df[df.columns[1]].astype(str) + ' _ ' + df[df.columns[2]]

df = df.dropna(how='all')
df = df.dropna(how='all', axis=1)

# df = df.dropna(subset=[df.columns[2]])
# df = df.drop(df.columns[1], axis=1)

df = df[3:]
col_0 = df.iloc[:,0]
col_0 = col_0.to_list()
pdList = []
for i in range(len(Table_38)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_38[i]}').reset_index(drop=True)
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace(' ', '')
    globals()[f'df_{i}'].insert(loc=0, column='Indicator', value=col_0)
    units = pd.DataFrame([f'{unit}']*len(globals()[f'df_{i}']))
    globals()[f'df_{i}'].insert(1, 'Unit', units)
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_csv(f'C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\{title} - statistical bulletin.csv',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\3993401615.py:18: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.columns = df.columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\3993401615.py:39: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\3993401615.py:39: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
# ...

# %%
# Table 39
Table_39 = []
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\central_bank'
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('Table 39 '):
        Table_39.append(files)
Table_39.sort(key=lambda x: x.split(' 20')[1].split('.')[0],reverse = True)
import numpy as np
import pandas as pd
sheets_data = []
xls = pd.ExcelFile('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx')
sheets = xls.sheet_names
df = pd.read_excel('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx',sheets[49])
title = df.iloc[0,1].replace(':','').replace("'","")
unit = df.iloc[2,1]
df.columns = df.iloc[3,:]
df.columns = df.columns.str.replace('*', '')
sum = np.where(pd.isnull(df[df.columns[1]]))[0].tolist()[-1]
df = df.iloc[:sum,:]

# df[df.columns[1]] = df[df.columns[1]].ffill(axis = 0)
# df[df.columns[2]] = df[df.columns[2]].fillna('')
# df[df.columns[1]] = df[df.columns[1]].str.strip().replace('', np.nan).fillna(df[df.columns[2]])
# df[df.columns[1]] = df[df.columns[1]].astype(str) + ' _ ' + df[df.columns[2]]

df = df.dropna(how='all')
df = df.dropna(how='all', axis=1)

# df = df.dropna(subset=[df.columns[2]])
# df = df.drop(df.columns[1], axis=1)

df = df[3:]
col_0 = df.iloc[:,0]
col_0 = col_0.to_list()
pdList = []
for i in range(len(Table_39)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_39[i]}').reset_index(drop=True)
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace(' ', '')
    globals()[f'df_{i}'].insert(loc=0, column='Indicator', value=col_0)
    units = pd.DataFrame([f'{unit}']*len(globals()[f'df_{i}']))
    globals()[f'df_{i}'].insert(1, 'Unit', units)
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_csv(f'C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\{title} - statistical bulletin.csv',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\3806293190.py:18: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.columns = df.columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\3806293190.py:39: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\3806293190.py:39: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
# ...

# %%
# Table 40
Table_40 = []
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\central_bank'
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('Table 40 '):
        Table_40.append(files)
Table_40.sort(key=lambda x: x.split(' 20')[1].split('.')[0],reverse = True)
import numpy as np
import pandas as pd
sheets_data = []
xls = pd.ExcelFile('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx')
sheets = xls.sheet_names
df = pd.read_excel('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx',sheets[50])
title = df.iloc[0,1].replace(':','').replace("'","")
unit = df.iloc[2,1]
df.columns = df.iloc[3,:]
df.columns = df.columns.str.replace('*', '')
sum = np.where(pd.isnull(df[df.columns[1]]))[0].tolist()[-1]
df = df.iloc[:sum,:]

# df[df.columns[1]] = df[df.columns[1]].ffill(axis = 0)
# df[df.columns[2]] = df[df.columns[2]].fillna('')
# df[df.columns[1]] = df[df.columns[1]].str.strip().replace('', np.nan).fillna(df[df.columns[2]])
# df[df.columns[1]] = df[df.columns[1]].astype(str) + ' _ ' + df[df.columns[2]]

df = df.dropna(how='all')
df = df.dropna(how='all', axis=1)

# df = df.dropna(subset=[df.columns[2]])
# df = df.drop(df.columns[1], axis=1)

df = df[3:]
col_0 = df.iloc[:,0]
col_0 = col_0.to_list()
pdList = []
for i in range(len(Table_40)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_40[i]}').reset_index(drop=True)
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace(' ', '')
    globals()[f'df_{i}'].insert(loc=0, column='Indicator', value=col_0)
    units = pd.DataFrame([f'{unit}']*len(globals()[f'df_{i}']))
    globals()[f'df_{i}'].insert(1, 'Unit', units)
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_csv(f'C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\{title} - statistical bulletin.csv',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\565626226.py:18: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.columns = df.columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\565626226.py:39: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\565626226.py:39: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
# ...

# %%
# Table 41
Table_41 = []
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\central_bank'
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('Table 41 '):
        Table_41.append(files)
Table_41.sort(key=lambda x: x.split(' 20')[1].split('.')[0],reverse = True)
import numpy as np
import pandas as pd
sheets_data = []
xls = pd.ExcelFile('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx')
sheets = xls.sheet_names
df = pd.read_excel('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx',sheets[51])
title = df.iloc[1,1].replace(':','').replace("'","")
unit = df.iloc[3,1]
df.columns = df.iloc[4,:]
df.columns = df.columns.str.replace('*', '')
sum = np.where(pd.isnull(df[df.columns[1]]))[0].tolist()[-1]
df = df.iloc[:sum,:]

# # df[df.columns[1]] = df[df.columns[1]].ffill(axis = 0)
# # df[df.columns[2]] = df[df.columns[2]].fillna('')
# # df[df.columns[1]] = df[df.columns[1]].str.strip().replace('', np.nan).fillna(df[df.columns[2]])
# # df[df.columns[1]] = df[df.columns[1]].astype(str) + ' _ ' + df[df.columns[2]]

df = df.dropna(how='all')
df = df.dropna(how='all', axis=1)

# # df = df.dropna(subset=[df.columns[2]])
# # df = df.drop(df.columns[1], axis=1)

df = df[4:]
col_0 = df.iloc[:,0]
col_0 = col_0.to_list()
pdList = []
for i in range(len(Table_41)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_41[i]}').reset_index(drop=True)
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace(' ', '')
    globals()[f'df_{i}'].insert(loc=0, column='Indicator', value=col_0)
    units = pd.DataFrame([f'{unit}']*len(globals()[f'df_{i}']))
    globals()[f'df_{i}'].insert(1, 'Unit', units)
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_csv(f'C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\{title} - statistical bulletin.csv',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\2341820144.py:18: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.columns = df.columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\2341820144.py:39: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\2341820144.py:39: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
# ...

# %%
# Table 42
Table_42 = []
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\central_bank'
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('Table 42 '):
        Table_42.append(files)
Table_42.sort(key=lambda x: x.split(' 20')[1].split('.')[0],reverse = True)
import numpy as np
import pandas as pd
sheets_data = []
xls = pd.ExcelFile('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx')
sheets = xls.sheet_names
df = pd.read_excel('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx',sheets[52])
title = df.iloc[1,1].replace(':','').replace("'","")
unit = df.iloc[3,1]
df.columns = df.iloc[4,:]
df.columns = df.columns.str.replace('*', '')
sum = np.where(pd.isnull(df[df.columns[1]]))[0].tolist()[-1]
df = df.iloc[:sum,:]

# # df[df.columns[1]] = df[df.columns[1]].ffill(axis = 0)
# # df[df.columns[2]] = df[df.columns[2]].fillna('')
# # df[df.columns[1]] = df[df.columns[1]].str.strip().replace('', np.nan).fillna(df[df.columns[2]])
# # df[df.columns[1]] = df[df.columns[1]].astype(str) + ' _ ' + df[df.columns[2]]

df = df.dropna(how='all')
df = df.dropna(how='all', axis=1)

# # df = df.dropna(subset=[df.columns[2]])
# # df = df.drop(df.columns[1], axis=1)

df = df[4:]
col_0 = df.iloc[:,0]
col_0 = col_0.to_list()
pdList = []
for i in range(len(Table_42)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_42[i]}').reset_index(drop=True)
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace(' ', '')
    globals()[f'df_{i}'].insert(loc=0, column='Indicator', value=col_0)
    units = pd.DataFrame([f'{unit}']*len(globals()[f'df_{i}']))
    globals()[f'df_{i}'].insert(1, 'Unit', units)
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_csv(f'C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\{title} - statistical bulletin.csv',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\3538004424.py:18: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.columns = df.columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\3538004424.py:39: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\3538004424.py:39: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
# ...

# %%
# Table 43
Table_43 = []
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\central_bank'
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('Table 43 '):
        Table_43.append(files)
Table_43.sort(key=lambda x: x.split(' 20')[1].split('.')[0],reverse = True)
import numpy as np
import pandas as pd
sheets_data = []
xls = pd.ExcelFile('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx')
sheets = xls.sheet_names
df = pd.read_excel('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx',sheets[53])
title = df.iloc[1,1].replace(':','').replace("'","")
unit = df.iloc[3,1]
df.columns = df.iloc[4,:]
df.columns = df.columns.str.replace('*', '')
sum = np.where(pd.isnull(df[df.columns[1]]))[0].tolist()[-1]
df = df.iloc[:sum,:]

# # df[df.columns[1]] = df[df.columns[1]].ffill(axis = 0)
# # df[df.columns[2]] = df[df.columns[2]].fillna('')
# # df[df.columns[1]] = df[df.columns[1]].str.strip().replace('', np.nan).fillna(df[df.columns[2]])
# # df[df.columns[1]] = df[df.columns[1]].astype(str) + ' _ ' + df[df.columns[2]]

df = df.dropna(how='all')
df = df.dropna(how='all', axis=1)

# # df = df.dropna(subset=[df.columns[2]])
# # df = df.drop(df.columns[1], axis=1)

df = df[4:9]
col_0 = df.iloc[:,0]
col_0 = col_0.to_list()
pdList = []
for i in range(len(Table_43)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_43[i]}').reset_index(drop=True)
    globals()[f'df_{i}'] = globals()[f'df_{i}'].iloc[:-1,:]
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace(' ', '')
    globals()[f'df_{i}'].insert(loc=0, column='Indicator', value=col_0)
    units = pd.DataFrame([f'{unit}']*len(globals()[f'df_{i}']))
    globals()[f'df_{i}'].insert(1, 'Unit', units)
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_csv(f'C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\{title} - statistical bulletin.csv',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\1702552100.py:18: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.columns = df.columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\1702552100.py:40: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\1702552100.py:40: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
# ...

# %%
# Table 44
Table_44 = []
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\central_bank'
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('Table 44 '):
        Table_44.append(files)
Table_44.sort(key=lambda x: x.split(' 20')[1].split('.')[0],reverse = True)
import numpy as np
import pandas as pd
sheets_data = []
xls = pd.ExcelFile('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx')
sheets = xls.sheet_names
df = pd.read_excel('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx',sheets[54])
title = df.iloc[1,1].replace(':','').replace("'","")
unit = df.iloc[3,1]
df.columns = df.iloc[4,:]
df.columns = df.columns.str.replace('*', '')
sum = np.where(pd.isnull(df[df.columns[1]]))[0].tolist()[-1]
df = df.iloc[:sum,:]

# # df[df.columns[1]] = df[df.columns[1]].ffill(axis = 0)
# # df[df.columns[2]] = df[df.columns[2]].fillna('')
# # df[df.columns[1]] = df[df.columns[1]].str.strip().replace('', np.nan).fillna(df[df.columns[2]])
# # df[df.columns[1]] = df[df.columns[1]].astype(str) + ' _ ' + df[df.columns[2]]

df = df.dropna(how='all')
df = df.dropna(how='all', axis=1)

# # df = df.dropna(subset=[df.columns[2]])
# # df = df.drop(df.columns[1], axis=1)

df = df[4:9]
col_0 = df.iloc[:,0]
col_0 = col_0.to_list()
pdList = []
for i in range(len(Table_44)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_44[i]}').reset_index(drop=True)
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace(' ', '')
    globals()[f'df_{i}'].insert(loc=0, column='Indicator', value=col_0)
    units = pd.DataFrame([f'{unit}']*len(globals()[f'df_{i}']))
    globals()[f'df_{i}'].insert(1, 'Unit', units)
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_csv(f'C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\{title} - statistical bulletin.csv',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\2544344961.py:18: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.columns = df.columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\2544344961.py:39: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\2544344961.py:39: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
# ...

# %%
# Table 45
Table_45 = []
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\central_bank'
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('Table 45 '):
        Table_45.append(files)
Table_45.sort(key=lambda x: x.split(' 20')[1].split('.')[0],reverse = True)
import numpy as np
import pandas as pd
sheets_data = []
xls = pd.ExcelFile('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx')
sheets = xls.sheet_names
df = pd.read_excel('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx',sheets[55])
title = df.iloc[1,1].replace(':','').replace("'","")
unit = df.iloc[3,1]
df.columns = df.iloc[4,:]
df.columns = df.columns.str.replace('*', '')
sum = np.where(pd.isnull(df[df.columns[1]]))[0].tolist()[-1]
df = df.iloc[:sum,:]

# # df[df.columns[1]] = df[df.columns[1]].ffill(axis = 0)
# # df[df.columns[2]] = df[df.columns[2]].fillna('')
# # df[df.columns[1]] = df[df.columns[1]].str.strip().replace('', np.nan).fillna(df[df.columns[2]])
# # df[df.columns[1]] = df[df.columns[1]].astype(str) + ' _ ' + df[df.columns[2]]

df = df.dropna(how='all')
df = df.dropna(how='all', axis=1)

# # df = df.dropna(subset=[df.columns[2]])
# # df = df.drop(df.columns[1], axis=1)

df = df[4:9]
col_0 = df.iloc[:,0]
col_0 = col_0.to_list()
pdList = []
for i in range(len(Table_45)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_45[i]}').reset_index(drop=True)
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace(' ', '')
    globals()[f'df_{i}'].insert(loc=0, column='Indicator', value=col_0)
    units = pd.DataFrame([f'{unit}']*len(globals()[f'df_{i}']))
    globals()[f'df_{i}'].insert(1, 'Unit', units)
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_csv(f'C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\{title} - statistical bulletin.csv',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\2690311747.py:18: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.columns = df.columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\2690311747.py:39: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\2690311747.py:39: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
# ...

# %%
# Table 46
Table_46 = []
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\central_bank'
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('Table 46 '):
        Table_46.append(files)
Table_46.sort(key=lambda x: x.split(' 20')[1].split('.')[0],reverse = True)
import numpy as np
import pandas as pd
sheets_data = []
xls = pd.ExcelFile('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx')
sheets = xls.sheet_names
df = pd.read_excel('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx',sheets[56])
title = df.iloc[1,0].replace(':','').replace("'","")
unit = df.iloc[3,1]
df.columns = df.iloc[4,:]
df.columns = df.columns.str.replace('*', '')
df = df.iloc[:,1:]
# sum = np.where(pd.isnull(df[df.columns[1]]))[0].tolist()[-1]
# df = df.iloc[:sum,:]

# # df[df.columns[1]] = df[df.columns[1]].ffill(axis = 0)
# # df[df.columns[2]] = df[df.columns[2]].fillna('')
# # df[df.columns[1]] = df[df.columns[1]].str.strip().replace('', np.nan).fillna(df[df.columns[2]])
# # df[df.columns[1]] = df[df.columns[1]].astype(str) + ' _ ' + df[df.columns[2]]


df[df.columns[0]] = df[df.columns[0]].ffill(axis = 0)
df[df.columns[0]] = df[df.columns[0]].astype(str)
df = df.dropna(how='all')
df = df.dropna(how='all', axis=1)
df = df.drop(df.columns[1], axis=1)
df = df.drop(df.columns[2], axis=1)

# # df = df.dropna(subset=[df.columns[2]])
# # df = df.drop(df.columns[1], axis=1)

df = df[5:8]
col_0 = df.iloc[:,0]
col_0 = col_0.to_list()
pdList = []
for i in range(len(Table_46)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_46[i]}').reset_index(drop=True)
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace(' ', '')
    globals()[f'df_{i}'].insert(loc=0, column='Indicator', value=col_0)
    units = pd.DataFrame([f'{unit}']*len(globals()[f'df_{i}']))
    globals()[f'df_{i}'].insert(1, 'Unit', units)
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_csv(f'C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\{title} - statistical bulletin.csv',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\1115703626.py:18: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.columns = df.columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\1115703626.py:45: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\1115703626.py:45: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
# ...

# %%
# Table 47
Table_47 = []
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\central_bank'
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('Table 47 '):
        Table_47.append(files)
Table_47.sort(key=lambda x: x.split(' 20')[1].split('.')[0],reverse = True)
import numpy as np
import pandas as pd
sheets_data = []
xls = pd.ExcelFile('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx')
sheets = xls.sheet_names
df = pd.read_excel('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx',sheets[57])
title = df.iloc[1,1].replace(':','').replace("'","")
df.columns = df.iloc[4,:]
df.columns = df.columns.str.replace('*', '')
sum = np.where(pd.isnull(df[df.columns[1]]))[0].tolist()[-1]
df = df.iloc[:sum,:]

# # df[df.columns[1]] = df[df.columns[1]].ffill(axis = 0)
# # df[df.columns[2]] = df[df.columns[2]].fillna('')
# # df[df.columns[1]] = df[df.columns[1]].str.strip().replace('', np.nan).fillna(df[df.columns[2]])
# # df[df.columns[1]] = df[df.columns[1]].astype(str) + ' _ ' + df[df.columns[2]]

df = df.dropna(how='all')
df = df.dropna(how='all', axis=1)

# # df = df.dropna(subset=[df.columns[2]])
# # df = df.drop(df.columns[1], axis=1)

df = df[3:]
col_0 = df.iloc[:,0]
col_0 = col_0.to_list()
pdList = []
for i in range(len(Table_47)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_47[i]}').reset_index(drop=True)
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace(' ', '')
    globals()[f'df_{i}'].insert(loc=0, column='Indicator', value=col_0)
    units = pd.DataFrame([f'{unit}']*len(globals()[f'df_{i}']))
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_csv(f'C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\{title} - statistical bulletin.csv',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\3423061027.py:17: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.columns = df.columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\3423061027.py:38: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\3423061027.py:38: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
# ...

# %%
# Table 48
Table_48 = []
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\central_bank'
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('Table 48 '):
        Table_48.append(files)
Table_48.sort(key=lambda x: x.split(' 20')[1].split('.')[0],reverse = True)
import numpy as np
import pandas as pd
sheets_data = []
xls = pd.ExcelFile('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx')
sheets = xls.sheet_names
df = pd.read_excel('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx',sheets[58])
title = df.iloc[1,1].replace(':','').replace("'","")
# df.columns = df.iloc[3,:]
# df.columns = df.columns.str.replace('*', '')
# sum = np.where(pd.isnull(df[df.columns[1]]))[0].tolist()[-1]
# df = df.iloc[:sum,:]

# # df[df.columns[1]] = df[df.columns[1]].ffill(axis = 0)
# # df[df.columns[2]] = df[df.columns[2]].fillna('')
# # df[df.columns[1]] = df[df.columns[1]].str.strip().replace('', np.nan).fillna(df[df.columns[2]])
# # df[df.columns[1]] = df[df.columns[1]].astype(str) + ' _ ' + df[df.columns[2]]

# df = df.dropna(how='all')
# df = df.dropna(how='all', axis=1)

# # df = df.dropna(subset=[df.columns[2]])
# # df = df.drop(df.columns[1], axis=1)

df = df[2:]
# col_0 = df.iloc[:,0]
# col_0 = col_0.to_list()
col_0 = ['Customer to Customer Tranfers _ Number of Transfers','Customer to Customer Tranfers _ Amount ( In Millions of AED )','Bank to Bank Tranfers _ Number of Transfers','Bank to Bank Tranfers _ Amount ( In Millions of AED )','Total Domestic Fund Tranfers _ Number of Transfers','Total Domestic Fund Tranfers _ Amount ( In Millions of AED )']
pdList = []
for i in range(len(Table_48)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_48[i]}').reset_index(drop=True)
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace(' ', '')
    globals()[f'df_{i}'].insert(loc=0, column='Indicator', value=col_0)
    units = pd.DataFrame([f'{unit}']*len(globals()[f'df_{i}']))
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_csv(f'C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\{title} - statistical bulletin.csv',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\3432338237.py:39: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\3432338237.py:39: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns.str.replace('*', '')
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\3432338237.py:39: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
# ...

# %%
# Table 49
Table_49 = []
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\central_bank'
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('Table 49'):
        Table_49.append(files)
Table_49.sort(key=lambda x: x.split(' 20')[1].split('.')[0],reverse = True)
pdList = []
import pandas as pd
import numpy as np
from pandas import concat
for i in range(len(Table_49)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_49[i]}').reset_index(drop=True)
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_csv('C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\Table 49  Banks and Branches Network Statistics ( Quarterly ) - statistical bulletin.csv',index=False)

# %%
Table_7 = []
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\central_bank'
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('Table 7 '):
        Table_7.append(files)
Table_7.sort(key=lambda x: x.split(' 20')[1].split('.')[0],reverse = True)
import numpy as np
import pandas as pd
sheets_data = []
xls = pd.ExcelFile('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx')
sheets = xls.sheet_names
df = pd.read_excel('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx',sheets[13])
title = df.iloc[0,1].replace(':','') 
unit = df.iloc[2,1]
df.columns = df.iloc[3,:]
df.columns = df.columns.str.replace('*', '')
sum = np.where(pd.isnull(df[df.columns[1]]))[0].tolist()[-1]
df = df.iloc[:sum,:]
df[df.columns[1]] = df[df.columns[1]].ffill(axis = 0)
df[df.columns[2]] = df[df.columns[2]].fillna('')
# df[df.columns[1]] = df[df.columns[1]].str.strip().replace('', np.nan).fillna(df[df.columns[2]])
df[df.columns[1]] = df[df.columns[1]].astype(str) + ' _ ' + df[df.columns[2]]
df = df.dropna(how='all')
df = df.dropna(how='all', axis=1)
df = df.dropna(subset=[df.columns[2]])
df = df.drop(df.columns[1], axis=1)
df = df[1:]
col_0 = df.iloc[:,0]
col_0 = col_0.to_list()
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_19388\182860363.py:17: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.columns = df.columns.str.replace('*', '')

# %%
for i in range(len(col_0)):
    if i in range(16,20):
        col_0[i] = col_0[i].replace('a) Credit Facilities','b) Domestic Investments')
col_0[15] = col_0[15].replace('a) Credit Facilities _ ','')

# %%
# Table 23
Table_23 = []
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\central_bank'
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('Table 23 '):
        Table_23.append(files)
Table_23.sort(key=lambda x: x.split(' 20')[1].split('.')[0],reverse = True)
import numpy as np
import pandas as pd
sheets_data = []
xls = pd.ExcelFile('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx')
sheets = xls.sheet_names
df = pd.read_excel('https://www.centralbank.ae/media/badjlgbn/statistical-bulletin-january-2023.xlsx',sheets[31])
title = df.iloc[1,1].replace(':','').replace("'","")
unit = df.iloc[3,1]
df.columns = df.iloc[4,:]
df.columns = df.columns.str.replace('*', '')
sum = np.where(pd.isnull(df[df.columns[1]]))[0].tolist()[-1]
df = df.iloc[:sum,:]
df = df.dropna(how='all')
df = df.dropna(how='all', axis=1)
df[df.columns[0]] = df[df.columns[0]].ffill(axis = 0)
df[df.columns[1]] = df[df.columns[1]].fillna('')
df[df.columns[0]] = df[df.columns[0]].str.strip().replace('', np.nan).fillna(df[df.columns[1]])
df[df.columns[0]] = df[df.columns[0]].astype(str) + ' _ ' + df[df.columns[1]]
df = df.dropna(how='all')
df = df.dropna(how='all', axis=1)
df = df.dropna(subset=[df.columns[1]])
df = df.drop(df.columns[1], axis=1)
df = df[3:]
col_0 = df.iloc[:,0]
col_0 = col_0.to_list()
df
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_19388\187736551.py:18: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.columns = df.columns.str.replace('*', '')
# 4                                                Item Dec 2018 Dec 2019  \
# 6                                       Government _    191498   257383
# 8                                    Public Sector _    167921   185273
# 10                                  Private Sector _   1150018  1149953
# 12               Private Sector _ Private - Corporate   812595   817548
# 13            Private Sector _ Financial Institutions    19951    15338
# 15  Private Sector _ Business and Industrial Secto...   792644   802210
# 17                 Private Sector _ Private - Retail    337423   332405
# 19                                           Total _   1509437  1592609
#
# ...

# %%
df = pd.read_csv(f'{base_path}\\TABLE 1AB Foreign Branches          الشركات الأجنبية Gross Written Premium (2016 - 2021) - Annual Report on the UAE Insurance Sector for 2021.csv')
df[df.columns[0]] = df[df.columns[-1]]
df.columns = [df.columns[-1]] + df.columns[1:].to_list()
df = df.iloc[:,:-1]

# %%
# Table 1A Foreign annual report
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\cb insur sectore'
Table_1af = []
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('1A Share of Foreign Companies Gross Written Premium'):
        Table_1af.append(files)
Table_1af.sort(key=lambda x: x.split('UAE Insurance Sector for ')[1].split('.')[0],reverse = True)
pdList = []
import pandas as pd
import numpy as np
from pandas import concat
for i in range(len(Table_1af)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_1af[i]}').reset_index(drop=True)
    globals()[f'df_{i}'][globals()[f'df_{i}'].columns[0]] = globals()[f'df_{i}'][globals()[f'df_{i}'].columns[-1]]
    globals()[f'df_{i}'].columns = [globals()[f'df_{i}'].columns[-1]] + globals()[f'df_{i}'].columns[1:].to_list()
    globals()[f'df_{i}'] = globals()[f'df_{i}'].iloc[:,:-1]
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_excel('C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\1A Share of Foreign Companies Gross Written Premium - Annual Report on the UAE Insurance Sector for 2017-2021.xlsx',index=False)

# %%
# 1A Share of National Companies Gross Written Premium - Annual Report on the UAE Insurance Sector 
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\cb insur sectore'
Table_1aN = []
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('1A Share of National Companies Gross Written Premium'):
        Table_1aN.append(files)
Table_1aN.sort(key=lambda x: x.split('UAE Insurance Sector for ')[1].split('.')[0],reverse = True)
pdList = []
import pandas as pd
import numpy as np
from pandas import concat
for i in range(len(Table_1aN)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_1aN[i]}').reset_index(drop=True)
    globals()[f'df_{i}'][globals()[f'df_{i}'].columns[0]] = globals()[f'df_{i}'][globals()[f'df_{i}'].columns[-1]]
    globals()[f'df_{i}'].columns = [globals()[f'df_{i}'].columns[-1]] + globals()[f'df_{i}'].columns[1:].to_list()
    globals()[f'df_{i}'] = globals()[f'df_{i}'].iloc[:,:-1]
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_excel('C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\1A Share of National Companies Gross Written Premium - Annual Report on the UAE Insurance Sector for 2017-2021.xlsx',index=False)

# %%
# 1B Share of Takaful Insurance Companies Gross Written Premium - Annual Report on the UAE Insurance Sector
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\cb insur sectore'
Table_1BTk = []
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('1B Share of Takaful Insurance Companies Gross Written Premium'):
        Table_1BTk.append(files)
Table_1BTk.sort(key=lambda x: x.split('UAE Insurance Sector for ')[1].split('.')[0],reverse = True)
pdList = []
import pandas as pd
import numpy as np
from pandas import concat
for i in range(len(Table_1BTk)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_1BTk[i]}').reset_index(drop=True)
    globals()[f'df_{i}'][globals()[f'df_{i}'].columns[0]] = globals()[f'df_{i}'][globals()[f'df_{i}'].columns[-1]]
    globals()[f'df_{i}'].columns = [globals()[f'df_{i}'].columns[-1]] + globals()[f'df_{i}'].columns[1:].to_list()
    globals()[f'df_{i}'] = globals()[f'df_{i}'].iloc[:,:-1]
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_excel('C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\1B Share of Takaful Insurance Companies Gross Written Premium - Annual Report on the UAE Insurance Sector for 2017-2021.xlsx',index=False)

# %%
# 1B Share of Traditional Insurance Companies Gross Written Premium - Annual Report on the UAE Insurance Sector
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\cb insur sectore'
Table_1BTd = []
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('1B Share of Traditional Insurance Companies Gross Written Premium'):
        Table_1BTd.append(files)
Table_1BTd.sort(key=lambda x: x.split('UAE Insurance Sector for ')[1].split('.')[0],reverse = True)
pdList = []
import pandas as pd
import numpy as np
from pandas import concat
for i in range(len(Table_1BTd)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_1BTd[i]}').reset_index(drop=True)
    globals()[f'df_{i}'][globals()[f'df_{i}'].columns[0]] = globals()[f'df_{i}'][globals()[f'df_{i}'].columns[-1]]
    globals()[f'df_{i}'].columns = [globals()[f'df_{i}'].columns[-1]] + globals()[f'df_{i}'].columns[1:].to_list()
    globals()[f'df_{i}'] = globals()[f'df_{i}'].iloc[:,:-1]
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_excel('C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\1B Share of Traditional Insurance Companies Gross Written Premium - Annual Report on the UAE Insurance Sector for 2017-2021.xlsx',index=False)

# %%
# 1C Share of Foreign Companies Gross Written Premium - Annual Report on the UAE Insurance Sector 
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\cb insur sectore'
Table_1CF = []
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('1C Share of Foreign Companies Gross Written Premium'):
        Table_1CF.append(files)
Table_1CF.sort(key=lambda x: x.split('UAE Insurance Sector for ')[1].split('.')[0],reverse = True)
pdList = []
import pandas as pd
import numpy as np
from pandas import concat
for i in range(len(Table_1CF)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_1CF[i]}').reset_index(drop=True)
    globals()[f'df_{i}'][globals()[f'df_{i}'].columns[0]] = globals()[f'df_{i}'][globals()[f'df_{i}'].columns[-1]]
    globals()[f'df_{i}'].columns = [globals()[f'df_{i}'].columns[-1]] + globals()[f'df_{i}'].columns[1:].to_list()
    globals()[f'df_{i}'] = globals()[f'df_{i}'].iloc[:,:-1]
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_excel('C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\1C Share of Foreign Companies Gross Written Premium - Annual Report on the UAE Insurance Sector for 2017-2021.xlsx',index=False)

# %%
# 1C Share of National Companies Gross Written Premium - Annual Report on the UAE Insurance Sector 
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\cb insur sectore'
Table_1CN = []
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('1C Share of National Companies Gross Written Premium'):
        Table_1CN.append(files)
Table_1CN.sort(key=lambda x: x.split('UAE Insurance Sector for ')[1].split('.')[0],reverse = True)
pdList = []
import pandas as pd
import numpy as np
from pandas import concat
for i in range(len(Table_1CN)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_1CN[i]}').reset_index(drop=True)
    globals()[f'df_{i}'][globals()[f'df_{i}'].columns[0]] = globals()[f'df_{i}'][globals()[f'df_{i}'].columns[-1]]
    globals()[f'df_{i}'].columns = [globals()[f'df_{i}'].columns[-1]] + globals()[f'df_{i}'].columns[1:].to_list()
    globals()[f'df_{i}'] = globals()[f'df_{i}'].iloc[:,:-1]
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_excel('C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\1C Share of National Companies Gross Written Premium - Annual Report on the UAE Insurance Sector for 2017-2021.xlsx',index=False)

# %%
# TABLE 1A Gross Written Premium - Annual Report on the UAE Insurance Sector
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\cb insur sectore'
Table_1ag = []
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('TABLE 1A Gross Written Premium'):
        Table_1ag.append(files)
Table_1ag.sort(key=lambda x: x.split('UAE Insurance Sector for ')[1].split('.')[0],reverse = True)
pdList = []
import pandas as pd
import numpy as np
from pandas import concat
for i in range(len(Table_1ag)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_1ag[i]}').reset_index(drop=True)
    globals()[f'df_{i}'][globals()[f'df_{i}'].columns[0]] = globals()[f'df_{i}'][globals()[f'df_{i}'].columns[-1]]
    globals()[f'df_{i}'].columns = [globals()[f'df_{i}'].columns[-1]] + globals()[f'df_{i}'].columns[1:].to_list()
    globals()[f'df_{i}'] = globals()[f'df_{i}'].iloc[:,:-1]
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_excel('C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\TABLE 1A Gross Written Premium - Annual Report on the UAE Insurance Sector for 2017-2021.xlsx',index=False)

# %%
# TABLE 1AA Gross Written Premium - Annual Report on the UAE Insurance Sector
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\cb insur sectore'
Table_1aawp = []
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('TABLE 1AA'):
        Table_1aawp.append(files)
Table_1aawp.sort(key=lambda x: x.split('UAE Insurance Sector for ')[1].split('.')[0],reverse = True)
pdList = []
import pandas as pd
import numpy as np
from pandas import concat
for i in range(len(Table_1aawp)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_1aawp[i]}').reset_index(drop=True)
    globals()[f'df_{i}'][globals()[f'df_{i}'].columns[0]] = globals()[f'df_{i}'][globals()[f'df_{i}'].columns[-1]]
    globals()[f'df_{i}'].columns = [globals()[f'df_{i}'].columns[-1]] + globals()[f'df_{i}'].columns[1:].to_list()
    globals()[f'df_{i}'] = globals()[f'df_{i}'].iloc[:,:-1]
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_excel('C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\TABLE 1AA National Companies Gross Written Premium - Annual Report on the UAE Insurance Sector for 2017-2021.xlsx',index=False)

# %%
# TABLE 1AB Foreign Branches          الشركات الأجنبية Gross Written Premium - Annual Report on the UAE Insurance Sector
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\cb insur sectore'
Table_1abf = []
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('TABLE 1AB'):
        Table_1abf.append(files)
Table_1abf.sort(key=lambda x: x.split('UAE Insurance Sector for ')[1].split('.')[0],reverse = True)
pdList = []
import pandas as pd
import numpy as np
from pandas import concat
for i in range(len(Table_1abf)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_1abf[i]}').reset_index(drop=True)
    globals()[f'df_{i}'][globals()[f'df_{i}'].columns[0]] = globals()[f'df_{i}'][globals()[f'df_{i}'].columns[-1]]
    globals()[f'df_{i}'].columns = [globals()[f'df_{i}'].columns[-1]] + globals()[f'df_{i}'].columns[1:].to_list()
    globals()[f'df_{i}'] = globals()[f'df_{i}'].iloc[:,:-1]
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_excel('C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\TABLE 1AB Foreign Branches Gross Written Premium - Annual Report on the UAE Insurance Sector for 2017-2021.xlsx',index=False)

# %%
# TABLE 1B Gross Written Premium  - Annual Report on the UAE Insurance Sector 
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\cb insur sectore'
Table_1bg = []
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('TABLE 1B Gross Written Premium'):
        Table_1bg.append(files)
Table_1bg.sort(key=lambda x: x.split('UAE Insurance Sector for ')[1].split('.')[0],reverse = True)
pdList = []
import pandas as pd
import numpy as np
from pandas import concat
for i in range(len(Table_1bg)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_1bg[i]}').reset_index(drop=True)
    globals()[f'df_{i}'][globals()[f'df_{i}'].columns[0]] = globals()[f'df_{i}'][globals()[f'df_{i}'].columns[-1]]
    globals()[f'df_{i}'].columns = [globals()[f'df_{i}'].columns[-1]] + globals()[f'df_{i}'].columns[1:].to_list()
    globals()[f'df_{i}'] = globals()[f'df_{i}'].iloc[:,:-1]
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_excel('C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\TABLE 1B Gross Written Premium - Annual Report on the UAE Insurance Sector for 2017-2021.xlsx',index=False)

# %%
# TABLE 1BA National Traditional Insurance Companies شركات التأمين التقليدي الوطنية Gross Written Premium  - Annual Report on the UAE Insurance Sector
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\cb insur sectore'
Table_1ba = []
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('TABLE 1BA'):
        Table_1ba.append(files)
Table_1ba.sort(key=lambda x: x.split('UAE Insurance Sector for ')[1].split('.')[0],reverse = True)
pdList = []
import pandas as pd
import numpy as np
from pandas import concat
for i in range(len(Table_1ba)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_1ba[i]}').reset_index(drop=True)
    globals()[f'df_{i}'][globals()[f'df_{i}'].columns[0]] = globals()[f'df_{i}'][globals()[f'df_{i}'].columns[-1]]
    globals()[f'df_{i}'].columns = [globals()[f'df_{i}'].columns[-1]] + globals()[f'df_{i}'].columns[1:].to_list()
    globals()[f'df_{i}'] = globals()[f'df_{i}'].iloc[:,:-1]
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_excel('C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\TABLE 1BA National Traditional Insurance Companies Gross Written Premium - Annual Report on the UAE Insurance Sector for 2017-2021.xlsx',index=False)

# %%
# TABLE 1BB National Takaful Insurance Companies  شركات التأمين التكافلي الوطنية Gross Written Premium - Annual Report on the UAE Insurance Sector
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\cb insur sectore'
Table_1bb = []
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('TABLE 1BB'):
        Table_1bb.append(files)
Table_1bb.sort(key=lambda x: x.split('UAE Insurance Sector for ')[1].split('.')[0],reverse = True)
pdList = []
import pandas as pd
import numpy as np
from pandas import concat
for i in range(len(Table_1bb)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_1bb[i]}').reset_index(drop=True)
    globals()[f'df_{i}'][globals()[f'df_{i}'].columns[0]] = globals()[f'df_{i}'][globals()[f'df_{i}'].columns[-1]]
    globals()[f'df_{i}'].columns = [globals()[f'df_{i}'].columns[-1]] + globals()[f'df_{i}'].columns[1:].to_list()
    globals()[f'df_{i}'] = globals()[f'df_{i}'].iloc[:,:-1]
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_excel('C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\TABLE 1BB National Takaful Insurance Companies Gross Written Premium - Annual Report on the UAE Insurance Sector for 2017-2021.xlsx',index=False)

# %%
# TABLE 1C Gross Written Premium - Annual Report on the UAE Insurance Sector for 2017
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\cb insur sectore'
Table_1cg = []
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('TABLE 1C Gross Written Premium'):
        Table_1cg.append(files)
Table_1cg.sort(key=lambda x: x.split('UAE Insurance Sector for ')[1].split('.')[0],reverse = True)
pdList = []
import pandas as pd
import numpy as np
from pandas import concat
for i in range(len(Table_1cg)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_1cg[i]}').reset_index(drop=True)
    globals()[f'df_{i}'][globals()[f'df_{i}'].columns[0]] = globals()[f'df_{i}'][globals()[f'df_{i}'].columns[-1]]
    globals()[f'df_{i}'].columns = [globals()[f'df_{i}'].columns[-1]] + globals()[f'df_{i}'].columns[1:].to_list()
    globals()[f'df_{i}'] = globals()[f'df_{i}'].iloc[:,:-1]
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_excel('C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\TABLE 1C Gross Written Premium - Annual Report on the UAE Insurance Sector for 2017-2021.xlsx',index=False)

# %%
# TABLE 1CA National Companies          الشركات الوطنية Gross Written Premium - Annual Report on the UAE Insurance Sector
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\cb insur sectore'
Table_1ca = []
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('TABLE 1CA National Companies'):
        Table_1ca.append(files)
Table_1ca.sort(key=lambda x: x.split('UAE Insurance Sector for ')[1].split('.')[0],reverse = True)
pdList = []
import pandas as pd
import numpy as np
from pandas import concat
for i in range(len(Table_1ca)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_1ca[i]}').reset_index(drop=True)
    globals()[f'df_{i}'][globals()[f'df_{i}'].columns[0]] = globals()[f'df_{i}'][globals()[f'df_{i}'].columns[-1]]
    globals()[f'df_{i}'].columns = [globals()[f'df_{i}'].columns[-1]] + globals()[f'df_{i}'].columns[1:].to_list()
    globals()[f'df_{i}'] = globals()[f'df_{i}'].iloc[:,:-1]
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_excel('C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\TABLE 1CA National Companies Gross Written Premium - Annual Report on the UAE Insurance Sector for 2017-2021.xlsx',index=False)

# %%
# TABLE 1CB Foreign Branches          الشركات الأجنبية Gross Written Premium - Annual Report on the UAE Insurance Sector
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\cb insur sectore'
Table_1cb = []
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('TABLE 1CB Foreign Branches'):
        Table_1cb.append(files)
Table_1cb.sort(key=lambda x: x.split('UAE Insurance Sector for ')[1].split('.')[0],reverse = True)
pdList = []
import pandas as pd
import numpy as np
from pandas import concat
for i in range(len(Table_1cb)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_1cb[i]}').reset_index(drop=True)
    globals()[f'df_{i}'][globals()[f'df_{i}'].columns[0]] = globals()[f'df_{i}'][globals()[f'df_{i}'].columns[-1]]
    globals()[f'df_{i}'].columns = [globals()[f'df_{i}'].columns[-1]] + globals()[f'df_{i}'].columns[1:].to_list()
    globals()[f'df_{i}'] = globals()[f'df_{i}'].iloc[:,:-1]
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_excel('C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\TABLE 1CB Foreign Branches Gross Written Premium - Annual Report on the UAE Insurance Sector for 2017-2021.xlsx',index=False)

# %%
# TABLE 2A Gross Written Premium by Line of Business National & Foreign Companies - Annual Report on the UAE Insurance Sector for 2018
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\cb insur sectore'
Table_2a = []
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('TABLE 2A'):
        Table_2a.append(files)
Table_2a.sort(key=lambda x: x.split('UAE Insurance Sector for ')[1].split('.')[0],reverse = True)
pdList = []
import pandas as pd
import numpy as np
from pandas import concat
for i in range(len(Table_2a)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_2a[i]}').reset_index(drop=True)
    globals()[f'df_{i}_b'] = globals()[f'df_{i}'].iloc[:,2:-1]
    globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
    globals()[f'df_{i}_c'] = globals()[f'df_{i}'].iloc[:,-1:]
    globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns[0:2].to_list() + globals()[f'df_{i}_b'].columns.to_list() + [globals()[f'df_{i}_c'].columns[0]]
    globals()[f'df_{i}'][globals()[f'df_{i}'].columns[0]] = globals()[f'df_{i}'][globals()[f'df_{i}'].columns[-1]]
    globals()[f'df_{i}'].columns = [globals()[f'df_{i}'].columns[-1]] + globals()[f'df_{i}'].columns[1:].to_list()
    globals()[f'df_{i}'] = globals()[f'df_{i}'].iloc[:,:-1]
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_excel('C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\TABLE 2A Gross Written Premium by Line of Business National & Foreign Companies - Annual Report on the UAE Insurance Sector for 2017-2021.xlsx',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_21372\2694623832.py:16: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_21372\2694623832.py:18: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_21372\2694623832.py:16: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
# ...

# %%
# TABLE 2B Gross Written Premium by Line of Business Traditional & Takaful National Companies - Annual Report on the UAE Insurance Sector 
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\cb insur sectore'
Table_2b = []
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('TABLE 2B'):
        Table_2b.append(files)
Table_2b.sort(key=lambda x: x.split('UAE Insurance Sector for ')[1].split('.')[0],reverse = True)
pdList = []
import pandas as pd
import numpy as np
from pandas import concat
for i in range(len(Table_2b)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_2b[i]}').reset_index(drop=True)
    globals()[f'df_{i}_b'] = globals()[f'df_{i}'].iloc[:,2:-1]
    globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
    globals()[f'df_{i}_c'] = globals()[f'df_{i}'].iloc[:,-1:]
    globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns[0:2].to_list() + globals()[f'df_{i}_b'].columns.to_list() + [globals()[f'df_{i}_c'].columns[0]]
    globals()[f'df_{i}'][globals()[f'df_{i}'].columns[0]] = globals()[f'df_{i}'][globals()[f'df_{i}'].columns[-1]]
    globals()[f'df_{i}'].columns = [globals()[f'df_{i}'].columns[-1]] + globals()[f'df_{i}'].columns[1:].to_list()
    globals()[f'df_{i}'] = globals()[f'df_{i}'].iloc[:,:-1]
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_excel('C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\TABLE 2B Gross Written Premium by Line of Business Traditional & Takaful National Companies - Annual Report on the UAE Insurance Sector for 2017-2021.xlsx',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_21372\2069472661.py:16: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_21372\2069472661.py:18: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_21372\2069472661.py:16: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
# ...

# %%
# TABLE 2C Gross Written Premium by Line of Business Life, Non-Life & Composite Companies - Annual Report on the UAE Insurance Sector
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\cb insur sectore'
Table_2c = []
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('TABLE 2C'):
        Table_2c.append(files)
Table_2c.sort(key=lambda x: x.split('UAE Insurance Sector for ')[1].split('.')[0],reverse = True)
pdList = []
import pandas as pd
import numpy as np
from pandas import concat
for i in range(len(Table_2c)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_2c[i]}').reset_index(drop=True)
    globals()[f'df_{i}_b'] = globals()[f'df_{i}'].iloc[:,2:-1]
    globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
    globals()[f'df_{i}_c'] = globals()[f'df_{i}'].iloc[:,-1:]
    globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns[0:2].to_list() + globals()[f'df_{i}_b'].columns.to_list() + [globals()[f'df_{i}_c'].columns[0]]
    globals()[f'df_{i}'][globals()[f'df_{i}'].columns[0]] = globals()[f'df_{i}'][globals()[f'df_{i}'].columns[-1]]
    globals()[f'df_{i}'].columns = [globals()[f'df_{i}'].columns[-1]] + globals()[f'df_{i}'].columns[1:].to_list()
    globals()[f'df_{i}'] = globals()[f'df_{i}'].iloc[:,:-1]
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_excel('C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\TABLE 2C Gross Written Premium by Line of Business Life, Non-Life & Composite Companies - Annual Report on the UAE Insurance Sector for 2017-2021.xlsx',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_21372\1207807250.py:16: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_21372\1207807250.py:18: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_21372\1207807250.py:16: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
# ...

# %%
# TABLE 3A National  & Foreign Companies Net Written Premium by Line of Business - Annual Report on the UAE Insurance Sector 
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\cb insur sectore'
Table_3a = []
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('TABLE 3A'):
        Table_3a.append(files)
Table_3a.sort(key=lambda x: x.split('UAE Insurance Sector for ')[1].split('.')[0],reverse = True)
pdList = []
import pandas as pd
import numpy as np
from pandas import concat
for i in range(len(Table_3a)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_3a[i]}').reset_index(drop=True)
    globals()[f'df_{i}_b'] = globals()[f'df_{i}'].iloc[:,2:-1]
    globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
    globals()[f'df_{i}_c'] = globals()[f'df_{i}'].iloc[:,-1:]
    globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns[0:2].to_list() + globals()[f'df_{i}_b'].columns.to_list() + [globals()[f'df_{i}_c'].columns[0]]
    globals()[f'df_{i}'][globals()[f'df_{i}'].columns[0]] = globals()[f'df_{i}'][globals()[f'df_{i}'].columns[-1]]
    globals()[f'df_{i}'].columns = [globals()[f'df_{i}'].columns[-1]] + globals()[f'df_{i}'].columns[1:].to_list()
    globals()[f'df_{i}'] = globals()[f'df_{i}'].iloc[:,:-1]
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_excel('C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\TABLE 3A National  & Foreign Companies Net Written Premium by Line of Business - Annual Report on the UAE Insurance Sector for 2017-2021.xlsx',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_21372\3182083589.py:16: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_21372\3182083589.py:18: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_21372\3182083589.py:16: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
# ...

# %%
# TABLE 3B Net Written Premium by Line of Business Traditional & Takaful National Companies - Annual Report on the UAE Insurance Sector 
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\cb insur sectore'
Table_3b = []
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('TABLE 3B'):
        Table_3b.append(files)
Table_3b.sort(key=lambda x: x.split('UAE Insurance Sector for ')[1].split('.')[0],reverse = True)
pdList = []
import pandas as pd
import numpy as np
from pandas import concat
for i in range(len(Table_3b)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_3b[i]}').reset_index(drop=True)
    globals()[f'df_{i}_b'] = globals()[f'df_{i}'].iloc[:,2:-1]
    globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
    globals()[f'df_{i}_c'] = globals()[f'df_{i}'].iloc[:,-1:]
    globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns[0:2].to_list() + globals()[f'df_{i}_b'].columns.to_list() + [globals()[f'df_{i}_c'].columns[0]]
    globals()[f'df_{i}'][globals()[f'df_{i}'].columns[0]] = globals()[f'df_{i}'][globals()[f'df_{i}'].columns[-1]]
    globals()[f'df_{i}'].columns = [globals()[f'df_{i}'].columns[-1]] + globals()[f'df_{i}'].columns[1:].to_list()
    globals()[f'df_{i}'] = globals()[f'df_{i}'].iloc[:,:-1]
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_excel('C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\TABLE 3B Net Written Premium by Line of Business Traditional & Takaful National Companies - Annual Report on the UAE Insurance Sector for 2017-2021.xlsx',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_21372\1505135600.py:16: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_21372\1505135600.py:18: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_21372\1505135600.py:16: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
# ...

# %%
# TABLE 4A Retention Ratios of Written Premium by Line of Business (Net Written Premium ÷ Gross Written Premium) - Annual Report on the UAE Insurance Sector 
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\cb insur sectore'
Table_4a = []
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('TABLE 4A'):
        Table_4a.append(files)
Table_4a.sort(key=lambda x: x.split('UAE Insurance Sector for ')[1].split('.')[0],reverse = True)
pdList = []
import pandas as pd
import numpy as np
from pandas import concat
for i in range(len(Table_4a)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_4a[i]}').reset_index(drop=True)
    globals()[f'df_{i}_b'] = globals()[f'df_{i}'].iloc[:,2:-1]
    globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
    globals()[f'df_{i}_c'] = globals()[f'df_{i}'].iloc[:,-1:]
    globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns[0:2].to_list() + globals()[f'df_{i}_b'].columns.to_list() + [globals()[f'df_{i}_c'].columns[0]]
    globals()[f'df_{i}'][globals()[f'df_{i}'].columns[0]] = globals()[f'df_{i}'][globals()[f'df_{i}'].columns[-1]]
    globals()[f'df_{i}'].columns = [globals()[f'df_{i}'].columns[-1]] + globals()[f'df_{i}'].columns[1:].to_list()
    globals()[f'df_{i}'] = globals()[f'df_{i}'].iloc[:,:-1]
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_excel('C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\TABLE 4A Retention Ratios of Written Premium by Line of Business (Net Written Premium ÷ Gross Written Premium) - Annual Report on the UAE Insurance Sector for 2017-2021.xlsx',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_21372\2088145108.py:16: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_21372\2088145108.py:18: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_21372\2088145108.py:16: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
# ...

# %%
# TABLE 4B Retention Ratios of Written Premium by Line of Business (Net Written Premium ÷ Gross Written Premium) - Annual Report on the UAE Insurance Sector
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\cb insur sectore'
Table_4b = []
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('TABLE 4B'):
        Table_4b.append(files)
Table_4b.sort(key=lambda x: x.split('UAE Insurance Sector for ')[1].split('.')[0],reverse = True)
pdList = []
import pandas as pd
import numpy as np
from pandas import concat
for i in range(len(Table_4b)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_4b[i]}').reset_index(drop=True)
    globals()[f'df_{i}_b'] = globals()[f'df_{i}'].iloc[:,2:-1]
    globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
    globals()[f'df_{i}_c'] = globals()[f'df_{i}'].iloc[:,-1:]
    globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns[0:2].to_list() + globals()[f'df_{i}_b'].columns.to_list() + [globals()[f'df_{i}_c'].columns[0]]
    globals()[f'df_{i}'][globals()[f'df_{i}'].columns[0]] = globals()[f'df_{i}'][globals()[f'df_{i}'].columns[-1]]
    globals()[f'df_{i}'].columns = [globals()[f'df_{i}'].columns[-1]] + globals()[f'df_{i}'].columns[1:].to_list()
    globals()[f'df_{i}'] = globals()[f'df_{i}'].iloc[:,:-1]
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_excel('C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\TABLE 4B Retention Ratios of Written Premium by Line of Business (Net Written Premium ÷ Gross Written Premium) - Annual Report on the UAE Insurance Sector for 2017-2021.xlsx',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_21372\1651587861.py:16: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_21372\1651587861.py:18: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_21372\1651587861.py:16: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
# ...

# %%
# TABLE 5A Gross Earned Premium by Line of Business National & Foreign Companies - Annual Report on the UAE Insurance Sector
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\cb insur sectore'
Table_5a = []
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('TABLE 5A'):
        Table_5a.append(files)
Table_5a.sort(key=lambda x: x.split('UAE Insurance Sector for ')[1].split('.')[0],reverse = True)
pdList = []
import pandas as pd
import numpy as np
from pandas import concat
for i in range(len(Table_5a)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_5a[i]}').reset_index(drop=True)
    globals()[f'df_{i}_b'] = globals()[f'df_{i}'].iloc[:,2:-1]
    globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
    globals()[f'df_{i}_c'] = globals()[f'df_{i}'].iloc[:,-1:]
    globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns[0:2].to_list() + globals()[f'df_{i}_b'].columns.to_list() + [globals()[f'df_{i}_c'].columns[0]]
    globals()[f'df_{i}'][globals()[f'df_{i}'].columns[0]] = globals()[f'df_{i}'][globals()[f'df_{i}'].columns[-1]]
    globals()[f'df_{i}'].columns = [globals()[f'df_{i}'].columns[-1]] + globals()[f'df_{i}'].columns[1:].to_list()
    globals()[f'df_{i}'] = globals()[f'df_{i}'].iloc[:,:-1]
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_excel('C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\TABLE 5A Gross Earned Premium by Line of Business National & Foreign Companies - Annual Report on the UAE Insurance Sector for 2017-2021.xlsx',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_21372\3697361339.py:16: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_21372\3697361339.py:18: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_21372\3697361339.py:16: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
# ...

# %%
# TABLE 5B Gross Earned Premium by Line of Business Traditional & Takaful National Companies - Annual Report on the UAE Insurance Sector
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\cb insur sectore'
Table_5b = []
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('TABLE 5B'):
        Table_5b.append(files)
Table_5b.sort(key=lambda x: x.split('UAE Insurance Sector for ')[1].split('.')[0],reverse = True)
pdList = []
import pandas as pd
import numpy as np
from pandas import concat
for i in range(len(Table_5b)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_5b[i]}').reset_index(drop=True)
    globals()[f'df_{i}_b'] = globals()[f'df_{i}'].iloc[:,2:-1]
    globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
    globals()[f'df_{i}_c'] = globals()[f'df_{i}'].iloc[:,-1:]
    globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns[0:2].to_list() + globals()[f'df_{i}_b'].columns.to_list() + [globals()[f'df_{i}_c'].columns[0]]
    globals()[f'df_{i}'][globals()[f'df_{i}'].columns[0]] = globals()[f'df_{i}'][globals()[f'df_{i}'].columns[-1]]
    globals()[f'df_{i}'].columns = [globals()[f'df_{i}'].columns[-1]] + globals()[f'df_{i}'].columns[1:].to_list()
    globals()[f'df_{i}'] = globals()[f'df_{i}'].iloc[:,:-1]
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_excel('C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\TABLE 5B Gross Earned Premium by Line of Business Traditional & Takaful National Companies - Annual Report on the UAE Insurance Sector for 2017-2021.xlsx',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_21372\3664016626.py:16: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_21372\3664016626.py:18: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_21372\3664016626.py:16: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
# ...

# %%
# TABLE 6A Net Earned Premium by Line of Business National & Foreign Companies - Annual Report on the UAE Insurance Sector
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\cb insur sectore'
Table_6a = []
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('TABLE 6A'):
        Table_6a.append(files)
Table_6a.sort(key=lambda x: x.split('UAE Insurance Sector for ')[1].split('.')[0],reverse = True)
pdList = []
import pandas as pd
import numpy as np
from pandas import concat
for i in range(len(Table_6a)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_6a[i]}').reset_index(drop=True)
    globals()[f'df_{i}_b'] = globals()[f'df_{i}'].iloc[:,2:-1]
    globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
    globals()[f'df_{i}_c'] = globals()[f'df_{i}'].iloc[:,-1:]
    globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns[0:2].to_list() + globals()[f'df_{i}_b'].columns.to_list() + [globals()[f'df_{i}_c'].columns[0]]
    globals()[f'df_{i}'][globals()[f'df_{i}'].columns[0]] = globals()[f'df_{i}'][globals()[f'df_{i}'].columns[-1]]
    globals()[f'df_{i}'].columns = [globals()[f'df_{i}'].columns[-1]] + globals()[f'df_{i}'].columns[1:].to_list()
    globals()[f'df_{i}'] = globals()[f'df_{i}'].iloc[:,:-1]
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_excel('C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\TABLE 6A Net Earned Premium by Line of Business National & Foreign Companies - Annual Report on the UAE Insurance Sector for 2017-2021.xlsx',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_21372\2063707780.py:16: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_21372\2063707780.py:18: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_21372\2063707780.py:16: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
# ...

# %%
# TABLE 6B Net Earned Premium by Line of Business Traditional & Takaful National Companies - Annual Report on the UAE Insurance Sector 
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\cb insur sectore'
Table_6b = []
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('TABLE 6B'):
        Table_6b.append(files)
Table_6b.sort(key=lambda x: x.split('UAE Insurance Sector for ')[1].split('.')[0],reverse = True)
pdList = []
import pandas as pd
import numpy as np
from pandas import concat
for i in range(len(Table_6b)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_6b[i]}').reset_index(drop=True)
    globals()[f'df_{i}_b'] = globals()[f'df_{i}'].iloc[:,2:-1]
    globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
    globals()[f'df_{i}_c'] = globals()[f'df_{i}'].iloc[:,-1:]
    globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns[0:2].to_list() + globals()[f'df_{i}_b'].columns.to_list() + [globals()[f'df_{i}_c'].columns[0]]
    globals()[f'df_{i}'][globals()[f'df_{i}'].columns[0]] = globals()[f'df_{i}'][globals()[f'df_{i}'].columns[-1]]
    globals()[f'df_{i}'].columns = [globals()[f'df_{i}'].columns[-1]] + globals()[f'df_{i}'].columns[1:].to_list()
    globals()[f'df_{i}'] = globals()[f'df_{i}'].iloc[:,:-1]
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_excel('C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\TABLE 6B Net Earned Premium by Line of Business Traditional & Takaful National Companies - Annual Report on the UAE Insurance Sector for 2017-2021.xlsx',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_21372\1661920573.py:16: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_21372\1661920573.py:18: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_21372\1661920573.py:16: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
# ...

# %%
# TABLE 7 No. of Policies and Average Gross Written Premium - Annual Report on the UAE Insurance Sector 
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\cb insur sectore'
Table_7 = []
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('TABLE 7'):
        Table_7.append(files)
Table_7.sort(key=lambda x: x.split('UAE Insurance Sector for ')[1].split('.')[0],reverse = True)
pdList = []
import pandas as pd
import numpy as np
from pandas import concat
for i in range(len(Table_7)-1):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_7[i]}').reset_index(drop=True)
    globals()[f'df_{i}_b'] = globals()[f'df_{i}'].iloc[:,1:-1]
    globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
    globals()[f'df_{i}_c'] = globals()[f'df_{i}'].iloc[:,-1:]
    globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns[0:1].to_list() + globals()[f'df_{i}_b'].columns.to_list() + [globals()[f'df_{i}_c'].columns[0]]
    globals()[f'df_{i}'][globals()[f'df_{i}'].columns[0]] = globals()[f'df_{i}'][globals()[f'df_{i}'].columns[-1]]
    globals()[f'df_{i}'].columns = [globals()[f'df_{i}'].columns[-1]] + globals()[f'df_{i}'].columns[1:].to_list()
    globals()[f'df_{i}'] = globals()[f'df_{i}'].iloc[:,:-1]
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_excel('C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\TABLE 7 No. of Policies and Average Gross Written Premium - Annual Report on the UAE Insurance Sector for 2017-2021.xlsx',index=False)

# %%
# TABLE 8 Gross Written Premium & Commission Paid by Distribution Channel - Annual Report on the UAE Insurance Sector
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\cb insur sectore'
Table_8 = []
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('TABLE 8'):
        Table_8.append(files)
Table_8.sort(key=lambda x: x.split('UAE Insurance Sector for ')[1].split('.')[0],reverse = True)
pdList = []
import pandas as pd
import numpy as np
from pandas import concat
for i in range(len(Table_8)-1):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_8[i]}').reset_index(drop=True)
    globals()[f'df_{i}_b'] = globals()[f'df_{i}'].iloc[:,1:-1]
    globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
    globals()[f'df_{i}_c'] = globals()[f'df_{i}'].iloc[:,-1:]
    globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns[0:1].to_list() + globals()[f'df_{i}_b'].columns.to_list() + [globals()[f'df_{i}_c'].columns[0]]
    globals()[f'df_{i}'][globals()[f'df_{i}'].columns[0]] = globals()[f'df_{i}'][globals()[f'df_{i}'].columns[-1]]
    globals()[f'df_{i}'].columns = [globals()[f'df_{i}'].columns[-1]] + globals()[f'df_{i}'].columns[1:].to_list()
    globals()[f'df_{i}'] = globals()[f'df_{i}'].iloc[:,:-1]
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_excel('C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\TABLE 8 Gross Written Premium & Commission Paid by Distribution Channel - Annual Report on the UAE Insurance Sector for 2017-2021.xlsx',index=False)

# %%
# TABLE 9A Gross Technical Provisions by Line of Business National & Foreign Companies - Annual Report on the UAE Insurance Sector
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\cb insur sectore'
Table_9a = []
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('TABLE 9A'):
        Table_9a.append(files)
Table_9a.sort(key=lambda x: x.split('UAE Insurance Sector for ')[1].split('.')[0],reverse = True)
pdList = []
import pandas as pd
import numpy as np
from pandas import concat
for i in range(len(Table_9a)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_9a[i]}').reset_index(drop=True)
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_excel('C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\TABLE 9A Gross Technical Provisions by Line of Business National & Foreign Companies - Annual Report on the UAE Insurance Sector for 2017-2021.xlsx',index=False)

# %%
# TABLE 9B Gross Technical Provisions by Line of Business Traditional & Takaful National Companies - Annual Report on the UAE Insurance Sector 
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\cb insur sectore'
Table_9b = []
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('TABLE 9B'):
        Table_9b.append(files)
Table_9b.sort(key=lambda x: x.split('UAE Insurance Sector for ')[1].split('.')[0],reverse = True)
pdList = []
import pandas as pd
import numpy as np
from pandas import concat
for i in range(len(Table_9b)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_9b[i]}').reset_index(drop=True)
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_excel('C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\TABLE 9B Gross Technical Provisions by Line of Business Traditional & Takaful National Companies - Annual Report on the UAE Insurance Sector for 2017-2021.xlsx',index=False)

# %%
# TABLE 9C Gross Technical Provisions by Line of Business Life, Non-Life & Composite Companies - Annual Report on the UAE Insurance Sector 
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\cb insur sectore'
Table_9c = []
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('TABLE 9C'):
        Table_9c.append(files)
Table_9c.sort(key=lambda x: x.split('UAE Insurance Sector for ')[1].split('.')[0],reverse = True)
pdList = []
import pandas as pd
import numpy as np
from pandas import concat
for i in range(len(Table_9c)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_9c[i]}').reset_index(drop=True)
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_excel('C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\TABLE 9C Gross Technical Provisions by Line of Business Life, Non-Life & Composite Companies - Annual Report on the UAE Insurance Sector for 2017-2021.xlsx',index=False)

# %%
# TABLE 10A Net Technical Provisions by Line of Business National & Foreign Companies - Annual Report on the UAE Insurance Sector 
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\cb insur sectore'
Table_10a = []
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('TABLE 10A'):
        Table_10a.append(files)
Table_10a.sort(key=lambda x: x.split('UAE Insurance Sector for ')[1].split('.')[0],reverse = True)
pdList = []
import pandas as pd
import numpy as np
from pandas import concat
for i in range(len(Table_10a)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_10a[i]}').reset_index(drop=True)
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_excel('C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\TABLE 10A Net Technical Provisions by Line of Business National & Foreign Companies - Annual Report on the UAE Insurance Sector for 2017-2021.xlsx',index=False)

# %%
# TABLE 10B Net Technical Provisions by Line of Business Traditional & Takaful National Companies - Annual Report on the UAE Insurance Sector 
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\cb insur sectore'
Table_10b = []
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('TABLE 10B'):
        Table_10b.append(files)
Table_10b.sort(key=lambda x: x.split('UAE Insurance Sector for ')[1].split('.')[0],reverse = True)
pdList = []
import pandas as pd
import numpy as np
from pandas import concat
for i in range(len(Table_10b)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_10b[i]}').reset_index(drop=True)
    globals()[f'df_{i}_b'] = globals()[f'df_{i}'].iloc[:,1:-1]
    globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
    globals()[f'df_{i}_c'] = globals()[f'df_{i}'].iloc[:,-1:]
    globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns[0:1].to_list() + globals()[f'df_{i}_b'].columns.to_list() + [globals()[f'df_{i}_c'].columns[0]]
    globals()[f'df_{i}'][globals()[f'df_{i}'].columns[0]] = globals()[f'df_{i}'][globals()[f'df_{i}'].columns[-1]]
    globals()[f'df_{i}'].columns = [globals()[f'df_{i}'].columns[-1]] + globals()[f'df_{i}'].columns[1:].to_list()
    globals()[f'df_{i}'] = globals()[f'df_{i}'].iloc[:,:-1]
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_excel('C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\TABLE 10B Net Technical Provisions by Line of Business Traditional & Takaful National Companies - Annual Report on the UAE Insurance Sector for 2017-2021.xlsx',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\3159249556.py:16: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\3159249556.py:18: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\3159249556.py:16: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
# ...

# %%
# TABLE 11A Gross Technical Provisions by Line of Business - Annual Report on the UAE Insurance Sector
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\cb insur sectore'
Table_11a = []
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('TABLE 11A'):
        Table_11a.append(files)
Table_11a.sort(key=lambda x: x.split('UAE Insurance Sector for ')[1].split('.')[0],reverse = True)
pdList = []
import pandas as pd
import numpy as np
from pandas import concat
for i in range(len(Table_11a)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_11a[i]}').reset_index(drop=True)
    globals()[f'df_{i}_b'] = globals()[f'df_{i}'].iloc[:,1:-1]
    globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
    globals()[f'df_{i}_c'] = globals()[f'df_{i}'].iloc[:,-1:]
    globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns[0:1].to_list() + globals()[f'df_{i}_b'].columns.to_list() + [globals()[f'df_{i}_c'].columns[0]]
    globals()[f'df_{i}'][globals()[f'df_{i}'].columns[0]] = globals()[f'df_{i}'][globals()[f'df_{i}'].columns[-1]]
    globals()[f'df_{i}'].columns = [globals()[f'df_{i}'].columns[-1]] + globals()[f'df_{i}'].columns[1:].to_list()
    globals()[f'df_{i}'] = globals()[f'df_{i}'].iloc[:,:-1]
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_excel('C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\TABLE 11A Gross Technical Provisions by Line of Business - Annual Report on the UAE Insurance Sector for 2017-2021.xlsx',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\1944721409.py:16: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\1944721409.py:18: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\1944721409.py:16: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
# ...

# %%
# TABLE 11B Gross Technical Provisions by Line of Business - Annual Report on the UAE Insurance Sector 
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\cb insur sectore'
Table_11b = []
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('TABLE 11B'):
        Table_11b.append(files)
Table_11b.sort(key=lambda x: x.split('UAE Insurance Sector for ')[1].split('.')[0],reverse = True)
pdList = []
import pandas as pd
import numpy as np
from pandas import concat
for i in range(len(Table_11b)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_11b[i]}').reset_index(drop=True)
    globals()[f'df_{i}_b'] = globals()[f'df_{i}'].iloc[:,1:-1]
    globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
    globals()[f'df_{i}_c'] = globals()[f'df_{i}'].iloc[:,-1:]
    globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns[0:1].to_list() + globals()[f'df_{i}_b'].columns.to_list() + [globals()[f'df_{i}_c'].columns[0]]
    globals()[f'df_{i}'][globals()[f'df_{i}'].columns[0]] = globals()[f'df_{i}'][globals()[f'df_{i}'].columns[-1]]
    globals()[f'df_{i}'].columns = [globals()[f'df_{i}'].columns[-1]] + globals()[f'df_{i}'].columns[1:].to_list()
    globals()[f'df_{i}'] = globals()[f'df_{i}'].iloc[:,:-1]
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_excel('C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\TABLE 11B Gross Technical Provisions by Line of Business - Annual Report on the UAE Insurance Sector for 2017-2021.xlsx',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\1996994249.py:16: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\1996994249.py:18: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\1996994249.py:16: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
# ...

# %%
# TABLE 12A Gross Paid and Incurred Claims by Line of Business National & Foreign Companies - Annual Report on the UAE Insurance Sector
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\cb insur sectore'
Table_12a = []
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('TABLE 12A'):
        Table_12a.append(files)
Table_12a.sort(key=lambda x: x.split('UAE Insurance Sector for ')[1].split('.')[0],reverse = True)
pdList = []
import pandas as pd
import numpy as np
from pandas import concat
for i in range(len(Table_12a)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_12a[i]}').reset_index(drop=True)
    globals()[f'df_{i}_b'] = globals()[f'df_{i}'].iloc[:,2:-1]
    globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
    result_colum = globals()[f'df_{i}_b'].columns.to_list() 
    globals()[f'df_{i}_b'].columns = [col.replace(r' - المتكبدة','').replace(r' - المدفوعة','') for col in result_colum]
    globals()[f'df_{i}_c'] = globals()[f'df_{i}'].iloc[:,-1:]
    globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns[0:2].to_list() + globals()[f'df_{i}_b'].columns.to_list() + [globals()[f'df_{i}_c'].columns[0]]
    globals()[f'df_{i}'][globals()[f'df_{i}'].columns[0]] = globals()[f'df_{i}'][globals()[f'df_{i}'].columns[-1]]
    globals()[f'df_{i}'].columns = [globals()[f'df_{i}'].columns[-1]] + globals()[f'df_{i}'].columns[1:].to_list()
    globals()[f'df_{i}'] = globals()[f'df_{i}'].iloc[:,:-1]
    
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_excel('C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\TABLE 12A Gross Paid and Incurred Claims by Line of Business National & Foreign Companies - Annual Report on the UAE Insurance Sector for 2017-2021.xlsx',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\2240741335.py:16: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\2240741335.py:20: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\2240741335.py:16: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
# ...

# %%
# TABLE 12B Gross Paid and Incurred Claims by Line of Business Traditional & Takaful National Companies - Annual Report on the UAE Insurance Sector 
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\cb insur sectore'
Table_12b = []
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('TABLE 12B'):
        Table_12b.append(files)
Table_12b.sort(key=lambda x: x.split('UAE Insurance Sector for ')[1].split('.')[0],reverse = True)
pdList = []
import pandas as pd
import numpy as np
from pandas import concat
for i in range(len(Table_12b)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_12b[i]}').reset_index(drop=True)
    globals()[f'df_{i}_b'] = globals()[f'df_{i}'].iloc[:,2:-1]
    globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
    result_colum = globals()[f'df_{i}_b'].columns.to_list() 
    globals()[f'df_{i}_b'].columns = [col.replace(r' - المتكبدة','').replace(r' - المدفوعة','') for col in result_colum]
    globals()[f'df_{i}_c'] = globals()[f'df_{i}'].iloc[:,-1:]
    globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns[0:2].to_list() + globals()[f'df_{i}_b'].columns.to_list() + [globals()[f'df_{i}_c'].columns[0]]
    globals()[f'df_{i}'][globals()[f'df_{i}'].columns[0]] = globals()[f'df_{i}'][globals()[f'df_{i}'].columns[-1]]
    globals()[f'df_{i}'].columns = [globals()[f'df_{i}'].columns[-1]] + globals()[f'df_{i}'].columns[1:].to_list()
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_excel('C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\TABLE 12B Gross Paid and Incurred Claims by Line of Business Traditional & Takaful National Companies - Annual Report on the UAE Insurance Sector for 2017-2021.xlsx',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\3602066482.py:16: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\3602066482.py:20: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\3602066482.py:16: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
# ...

# %%
# TABLE 13A Net Paid and Incurred Claims by Line of Business National & Foreign Companies - Annual Report on the UAE Insurance Sector
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\cb insur sectore'
Table_13a = []
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('TABLE 13A'):
        Table_13a.append(files)
Table_13a.sort(key=lambda x: x.split('UAE Insurance Sector for ')[1].split('.')[0],reverse = True)
pdList = []
import pandas as pd
import numpy as np
from pandas import concat
for i in range(len(Table_13a)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_13a[i]}',encoding="utf-8").reset_index(drop=True)
    globals()[f'df_{i}_b'] = globals()[f'df_{i}'].iloc[:,2:-1]
    globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
    result_colum = globals()[f'df_{i}_b'].columns.to_list() 
    globals()[f'df_{i}_b'].columns = [col.replace(r' - المتكبدة','').replace(r' - المدفوعة','') for col in result_colum]
    globals()[f'df_{i}_c'] = globals()[f'df_{i}'].iloc[:,-1:]
    globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns[0:2].to_list() + globals()[f'df_{i}_b'].columns.to_list() + [globals()[f'df_{i}_c'].columns[0]]
    globals()[f'df_{i}'][globals()[f'df_{i}'].columns[0]] = globals()[f'df_{i}'][globals()[f'df_{i}'].columns[-1]]
    globals()[f'df_{i}'].columns = [globals()[f'df_{i}'].columns[-1]] + globals()[f'df_{i}'].columns[1:].to_list()
    globals()[f'df_{i}'] = globals()[f'df_{i}'].iloc[:,:-1]
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_excel('C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\TABLE 13A Net Paid and Incurred Claims by Line of Business National & Foreign Companies - Annual Report on the UAE Insurance Sector for 2017-2021.xlsx',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\3429523896.py:16: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\3429523896.py:20: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\3429523896.py:16: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
# ...

# %%
# TABLE 13B Net Paid and Incurred Claims by Line of Business Traditional & Takaful National Companies - Annual Report on the UAE Insurance Sector 
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\cb insur sectore'
Table_13b = []
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('TABLE 13B'):
        Table_13b.append(files)
Table_13b.sort(key=lambda x: x.split('UAE Insurance Sector for ')[1].split('.')[0],reverse = True)
pdList = []
import pandas as pd
import numpy as np
from pandas import concat
for i in range(len(Table_13b)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_13b[i]}',encoding="utf-8").reset_index(drop=True)
    globals()[f'df_{i}_b'] = globals()[f'df_{i}'].iloc[:,2:-1]
    globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
    result_colum = globals()[f'df_{i}_b'].columns.to_list() 
    globals()[f'df_{i}_b'].columns = [col.replace(r' - المتكبدة','').replace(r' - المدفوعة','') for col in result_colum]
    globals()[f'df_{i}_c'] = globals()[f'df_{i}'].iloc[:,-1:]
    globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns[0:2].to_list() + globals()[f'df_{i}_b'].columns.to_list() + [globals()[f'df_{i}_c'].columns[0]]
    globals()[f'df_{i}'][globals()[f'df_{i}'].columns[0]] = globals()[f'df_{i}'][globals()[f'df_{i}'].columns[-1]]
    globals()[f'df_{i}'].columns = [globals()[f'df_{i}'].columns[-1]] + globals()[f'df_{i}'].columns[1:].to_list()
    globals()[f'df_{i}'] = globals()[f'df_{i}'].iloc[:,:-1]
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_excel('C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\TABLE 13B Net Paid and Incurred Claims by Line of Business Traditional & Takaful National Companies - Annual Report on the UAE Insurance Sector for 2017-2021.xlsx',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\2950844848.py:16: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\2950844848.py:20: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\2950844848.py:16: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
# ...

# %%
# TABLE 14A Gross Loss Ratios by Line of Business National & Foreign Companies - Annual Report on the UAE Insurance Sector 
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\cb insur sectore'
Table_14a = []
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('TABLE 14A'):
        Table_14a.append(files)
Table_14a.sort(key=lambda x: x.split('UAE Insurance Sector for ')[1].split('.')[0],reverse = True)
pdList = []
import pandas as pd
import numpy as np
from pandas import concat
for i in range(len(Table_14a)-2):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_14a[i]}',encoding="utf-8").reset_index(drop=True)
    globals()[f'df_{i}_b'] = globals()[f'df_{i}'].iloc[:,2:-1]
    globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
    result_colum = globals()[f'df_{i}_b'].columns.to_list() 
    globals()[f'df_{i}_b'].columns = [col.replace(r' - المتكبدة','').replace(r' - المدفوعة','') for col in result_colum]
    globals()[f'df_{i}_c'] = globals()[f'df_{i}'].iloc[:,-1:]
    globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns[0:2].to_list() + globals()[f'df_{i}_b'].columns.to_list() + [globals()[f'df_{i}_c'].columns[0]]
    globals()[f'df_{i}'][globals()[f'df_{i}'].columns[0]] = globals()[f'df_{i}'][globals()[f'df_{i}'].columns[-1]]
    globals()[f'df_{i}'].columns = [globals()[f'df_{i}'].columns[-1]] + globals()[f'df_{i}'].columns[1:].to_list()
    globals()[f'df_{i}'] = globals()[f'df_{i}'].iloc[:,:-1]
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_excel('C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\TABLE 14A Gross Loss Ratios by Line of Business National & Foreign Companies - Annual Report on the UAE Insurance Sector for 2019-2021.xlsx',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\971280028.py:16: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\971280028.py:20: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\971280028.py:16: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
# ...

# %%
# TABLE 14B Gross Loss Ratios by Line of Business Traditional & Takaful National Companies - Annual Report on the UAE Insurance Sector
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\cb insur sectore'
Table_14b = []
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('TABLE 14A'):
        Table_14b.append(files)
Table_14b.sort(key=lambda x: x.split('UAE Insurance Sector for ')[1].split('.')[0],reverse = True)
pdList = []
import pandas as pd
import numpy as np
from pandas import concat
for i in range(len(Table_14b)-2):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_14b[i]}',encoding="utf-8").reset_index(drop=True)
    globals()[f'df_{i}_b'] = globals()[f'df_{i}'].iloc[:,2:-1]
    globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
    result_colum = globals()[f'df_{i}_b'].columns.to_list() 
    globals()[f'df_{i}_b'].columns = [col.replace(r' - المتكبدة','').replace(r' - المدفوعة','') for col in result_colum]
    globals()[f'df_{i}_c'] = globals()[f'df_{i}'].iloc[:,-1:]
    globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns[0:2].to_list() + globals()[f'df_{i}_b'].columns.to_list() + [globals()[f'df_{i}_c'].columns[0]]
    globals()[f'df_{i}'][globals()[f'df_{i}'].columns[0]] = globals()[f'df_{i}'][globals()[f'df_{i}'].columns[-1]]
    globals()[f'df_{i}'].columns = [globals()[f'df_{i}'].columns[-1]] + globals()[f'df_{i}'].columns[1:].to_list()
    globals()[f'df_{i}'] = globals()[f'df_{i}'].iloc[:,:-1]
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_excel('C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\TABLE 14B Gross Loss Ratios by Line of Business Traditional & Takaful National Companies - Annual Report on the UAE Insurance Sector for 2019-2021.xlsx',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\3133539138.py:16: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\3133539138.py:20: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\3133539138.py:16: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
# ...

# %%
# TABLE 15A Net Loss Ratios by Line of Business National & Foreign Companies - Annual Report on the UAE Insurance Sector
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\cb insur sectore'
Table_15a = []
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('TABLE 15A'):
        Table_15a.append(files)
Table_15a.sort(key=lambda x: x.split('UAE Insurance Sector for ')[1].split('.')[0],reverse = True)
pdList = []
import pandas as pd
import numpy as np
from pandas import concat
for i in range(len(Table_15a)-1):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_15a[i]}').reset_index(drop=True)
    globals()[f'df_{i}_b'] = globals()[f'df_{i}'].iloc[:,2:-1]
    globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
    result_colum = globals()[f'df_{i}_b'].columns.to_list() 
    globals()[f'df_{i}_b'].columns = [col.replace(r' - المتكبدة','').replace(r' - المدفوعة','') for col in result_colum]
    globals()[f'df_{i}_c'] = globals()[f'df_{i}'].iloc[:,-1:]
    globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns[0:2].to_list() + globals()[f'df_{i}_b'].columns.to_list() + [globals()[f'df_{i}_c'].columns[0]]
    globals()[f'df_{i}'][globals()[f'df_{i}'].columns[0]] = globals()[f'df_{i}'][globals()[f'df_{i}'].columns[-1]]
    globals()[f'df_{i}'].columns = [globals()[f'df_{i}'].columns[-1]] + globals()[f'df_{i}'].columns[1:].to_list()
    globals()[f'df_{i}'] = globals()[f'df_{i}'].iloc[:,:-1]
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_excel('C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\TABLE 15A Net Loss Ratios by Line of Business National & Foreign Companies - Annual Report on the UAE Insurance Sector for 2018-2021.xlsx',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\4074786010.py:16: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\4074786010.py:20: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\4074786010.py:16: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
# ...

# %%
# TABLE 15B Net Loss Ratios by Line of Business Traditional & Takaful National Companies - Annual Report on the UAE Insurance Sector 
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\cb insur sectore'
Table_15b = []
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('TABLE 15B'):
        Table_15b.append(files)
Table_15b.sort(key=lambda x: x.split('UAE Insurance Sector for ')[1].split('.')[0],reverse = True)
pdList = []
import pandas as pd
import numpy as np
from pandas import concat
for i in range(len(Table_15b)-1):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_15b[i]}').reset_index(drop=True)
    globals()[f'df_{i}_b'] = globals()[f'df_{i}'].iloc[:,2:-1]
    globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
    result_colum = globals()[f'df_{i}_b'].columns.to_list() 
    globals()[f'df_{i}_b'].columns = [col.replace(r' - المتكبدة','').replace(r' - المدفوعة','') for col in result_colum]
    globals()[f'df_{i}_c'] = globals()[f'df_{i}'].iloc[:,-1:]
    globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns[0:2].to_list() + globals()[f'df_{i}_b'].columns.to_list() + [globals()[f'df_{i}_c'].columns[0]]
    globals()[f'df_{i}'][globals()[f'df_{i}'].columns[0]] = globals()[f'df_{i}'][globals()[f'df_{i}'].columns[-1]]
    globals()[f'df_{i}'].columns = [globals()[f'df_{i}'].columns[-1]] + globals()[f'df_{i}'].columns[1:].to_list()
    globals()[f'df_{i}'] = globals()[f'df_{i}'].iloc[:,:-1]
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_excel('C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\TABLE 15B Net Loss Ratios by Line of Business Traditional & Takaful National Companies - Annual Report on the UAE Insurance Sector for 2018-2021.xlsx',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\3342589122.py:16: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\3342589122.py:20: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\3342589122.py:16: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
# ...

# %%
# TABLE 16A Gross Commission, Expense & Combined Ratios by Line of Business National & Foreign Companies - Annual Report on the UAE Insurance Sector
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\cb insur sectore'
Table_16a = []
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('TABLE 16A'):
        Table_16a.append(files)
Table_16a.sort(key=lambda x: x.split('UAE Insurance Sector for ')[1].split('.')[0],reverse = True)
pdList = []
import pandas as pd
import numpy as np
from pandas import concat
for i in range(len(Table_16a)-1):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_16a[i]}').reset_index(drop=True)
    globals()[f'df_{i}_b'] = globals()[f'df_{i}'].iloc[:,2:-1]
    globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
    result_colum = globals()[f'df_{i}_b'].columns.to_list() 
    globals()[f'df_{i}_b'].columns = [col.replace(r' - نسبة العمولات','').replace(r' - نسبة المصاريف','').replace(r' - النسبة المجمعة','') for col in result_colum]
    globals()[f'df_{i}_c'] = globals()[f'df_{i}'].iloc[:,-1:]
    globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns[0:2].to_list() + globals()[f'df_{i}_b'].columns.to_list() + [globals()[f'df_{i}_c'].columns[0]]
    globals()[f'df_{i}'][globals()[f'df_{i}'].columns[0]] = globals()[f'df_{i}'][globals()[f'df_{i}'].columns[-1]]
    globals()[f'df_{i}'].columns = [globals()[f'df_{i}'].columns[-1]] + globals()[f'df_{i}'].columns[1:].to_list()
    globals()[f'df_{i}'] = globals()[f'df_{i}'].iloc[:,:-1]
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_excel('C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\TABLE 16A Gross Commission, Expense & Combined Ratios by Line of Business National & Foreign Companies - Annual Report on the UAE Insurance Sector for 2018-2021.xlsx',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\2926355384.py:16: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\2926355384.py:20: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\2926355384.py:16: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
# ...

# %%
# TABLE 16B Gross Commission, Expense & Combined Ratios by Line of Business Traditional & Takaful National Companies - Annual Report on the UAE Insurance Sector
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\cb insur sectore'
Table_16b = []
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('TABLE 16B'):
        Table_16b.append(files)
Table_16b.sort(key=lambda x: x.split('UAE Insurance Sector for ')[1].split('.')[0],reverse = True)
pdList = []
import pandas as pd
import numpy as np
from pandas import concat
for i in range(len(Table_16b)-1):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_16b[i]}').reset_index(drop=True)
    globals()[f'df_{i}_b'] = globals()[f'df_{i}'].iloc[:,2:-1]
    globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
    result_colum = globals()[f'df_{i}_b'].columns.to_list() 
    globals()[f'df_{i}_b'].columns = [col.replace(r' - نسبة العمولات','').replace(r' - نسبة المصاريف','').replace(r' - النسبة المجمعة','') for col in result_colum]
    globals()[f'df_{i}_c'] = globals()[f'df_{i}'].iloc[:,-1:]
    globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns[0:2].to_list() + globals()[f'df_{i}_b'].columns.to_list() + [globals()[f'df_{i}_c'].columns[0]]
    globals()[f'df_{i}'][globals()[f'df_{i}'].columns[0]] = globals()[f'df_{i}'][globals()[f'df_{i}'].columns[-1]]
    globals()[f'df_{i}'].columns = [globals()[f'df_{i}'].columns[-1]] + globals()[f'df_{i}'].columns[1:].to_list()
    globals()[f'df_{i}'] = globals()[f'df_{i}'].iloc[:,:-1]
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_excel('C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\TABLE 16B Gross Commission, Expense & Combined Ratios by Line of Business Traditional & Takaful National Companies - Annual Report on the UAE Insurance Sector for 2018-2021.xlsx',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\2702301653.py:16: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\2702301653.py:20: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\2702301653.py:16: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
# ...

# %%
# TABLE 17A Net Commission, Expense & Combined Ratios by Line of Business National & Foreign Companies - Annual Report on the UAE Insurance Sector 
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\cb insur sectore'
Table_17a = []
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('TABLE 17A'):
        Table_17a.append(files)
Table_17a.sort(key=lambda x: x.split('UAE Insurance Sector for ')[1].split('.')[0],reverse = True)
pdList = []
import pandas as pd
import numpy as np
from pandas import concat
for i in range(len(Table_17a)-1):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_17a[i]}').reset_index(drop=True)
    globals()[f'df_{i}_b'] = globals()[f'df_{i}'].iloc[:,2:-1]
    globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
    result_colum = globals()[f'df_{i}_b'].columns.to_list() 
    globals()[f'df_{i}_b'].columns = [col.replace(r' - نسبة العمولات','').replace(r' - نسبة المصاريف','').replace(r' - النسبة المجمعة','') for col in result_colum]
    globals()[f'df_{i}_c'] = globals()[f'df_{i}'].iloc[:,-1:]
    globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns[0:2].to_list() + globals()[f'df_{i}_b'].columns.to_list() + [globals()[f'df_{i}_c'].columns[0]]
    globals()[f'df_{i}'][globals()[f'df_{i}'].columns[0]] = globals()[f'df_{i}'][globals()[f'df_{i}'].columns[-1]]
    globals()[f'df_{i}'].columns = [globals()[f'df_{i}'].columns[-1]] + globals()[f'df_{i}'].columns[1:].to_list()
    globals()[f'df_{i}'] = globals()[f'df_{i}'].iloc[:,:-1]
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_excel('C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\TABLE 17A Net Commission, Expense & Combined Ratios by Line of Business National & Foreign Companies - Annual Report on the UAE Insurance Sector for 2018-2021.xlsx',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\2145577738.py:16: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\2145577738.py:20: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\2145577738.py:16: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
# ...

# %%
# TABLE 17B Net Commission, Expense & Combined Ratios by Line of Business Traditional & Takaful National Companies - Annual Report on the UAE Insurance Sector
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\cb insur sectore'
Table_17b = []
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('TABLE 17B'):
        Table_17b.append(files)
Table_17b.sort(key=lambda x: x.split('UAE Insurance Sector for ')[1].split('.')[0],reverse = True)
pdList = []
import pandas as pd
import numpy as np
from pandas import concat
for i in range(len(Table_17b)-1):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_17b[i]}').reset_index(drop=True)
    globals()[f'df_{i}_b'] = globals()[f'df_{i}'].iloc[:,2:-1]
    globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
    result_colum = globals()[f'df_{i}_b'].columns.to_list() 
    globals()[f'df_{i}_b'].columns = [col.replace(r' - نسبة العمولات','').replace(r' - نسبة المصاريف','').replace(r' - النسبة المجمعة','') for col in result_colum]
    globals()[f'df_{i}_c'] = globals()[f'df_{i}'].iloc[:,-1:]
    globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns[0:2].to_list() + globals()[f'df_{i}_b'].columns.to_list() + [globals()[f'df_{i}_c'].columns[0]]
    globals()[f'df_{i}'][globals()[f'df_{i}'].columns[0]] = globals()[f'df_{i}'][globals()[f'df_{i}'].columns[-1]]
    globals()[f'df_{i}'] = globals()[f'df_{i}'].iloc[:,:-1]
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_excel('C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\TABLE 17B Net Commission, Expense & Combined Ratios by Line of Business Traditional & Takaful National Companies - Annual Report on the UAE Insurance Sector for 2018-2021.xlsx',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\827788395.py:16: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\827788395.py:20: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\827788395.py:16: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
# ...

# %%
# TABLE 18 Motor Insurance Profitability Analysis - Annual Report on the UAE Insurance Sector
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\cb insur sectore'
Table_18 = []
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('TABLE 18'):
        Table_18.append(files)
Table_18.sort(key=lambda x: x.split('UAE Insurance Sector for ')[1].split('.')[0],reverse = True)
pdList = []
import pandas as pd
import numpy as np
from pandas import concat
for i in range(len(Table_18)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_18[i]}').reset_index(drop=True)
    globals()[f'df_{i}_b'] = globals()[f'df_{i}'].iloc[:,1:-1]
    globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
    globals()[f'df_{i}_c'] = globals()[f'df_{i}'].iloc[:,-1:]
    globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns[0:1].to_list() + globals()[f'df_{i}_b'].columns.to_list() + [globals()[f'df_{i}_c'].columns[0]]
    globals()[f'df_{i}'][globals()[f'df_{i}'].columns[0]] = globals()[f'df_{i}'][globals()[f'df_{i}'].columns[-1]]
    globals()[f'df_{i}'].columns = [globals()[f'df_{i}'].columns[-1]] + globals()[f'df_{i}'].columns[1:].to_list()
    globals()[f'df_{i}'] = globals()[f'df_{i}'].iloc[:,:-1]
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_excel('C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\TABLE 18 Motor Insurance Profitability Analysis - Annual Report on the UAE Insurance Sector for 2017-2021.xlsx',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\1810390040.py:16: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\1810390040.py:18: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\1810390040.py:16: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
# ...

# %%
# TABLE 19 Health Profitability Analysis  - Annual Report on the UAE Insurance Sector 
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\cb insur sectore'
Table_19 = []
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('TABLE 19'):
        Table_19.append(files)
Table_19.sort(key=lambda x: x.split('UAE Insurance Sector for ')[1].split('.')[0],reverse = True)
pdList = []
import pandas as pd
import numpy as np
from pandas import concat
for i in range(len(Table_19)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_19[i]}').reset_index(drop=True)
    globals()[f'df_{i}_b'] = globals()[f'df_{i}'].iloc[:,1:-1]
    globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
    globals()[f'df_{i}_c'] = globals()[f'df_{i}'].iloc[:,-1:]
    globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns[0:1].to_list() + globals()[f'df_{i}_b'].columns.to_list() + [globals()[f'df_{i}_c'].columns[0]]
    globals()[f'df_{i}'][globals()[f'df_{i}'].columns[0]] = globals()[f'df_{i}'][globals()[f'df_{i}'].columns[-1]]
    globals()[f'df_{i}'] = globals()[f'df_{i}'].iloc[:,:-1]
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_excel('C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\TABLE 19 Health Profitability Analysis - Annual Report on the UAE Insurance Sector for 2017-2021.xlsx',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\3354158567.py:16: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\3354158567.py:18: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\3354158567.py:16: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
# ...

# %%
# TABLE 20A Invested Assets by Class National & Foreign Companies - Annual Report on the UAE Insurance Sector 
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\cb insur sectore'
Table_20a = []
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('TABLE 20A'):
        Table_20a.append(files)
Table_20a.sort(key=lambda x: x.split('UAE Insurance Sector for ')[1].split('.')[0],reverse = True)
pdList = []
import pandas as pd
import numpy as np
from pandas import concat
for i in range(len(Table_20a)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_20a[i]}').reset_index(drop=True)
    globals()[f'df_{i}_b'] = globals()[f'df_{i}'].iloc[:,1:-1]
    globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
    globals()[f'df_{i}_c'] = globals()[f'df_{i}'].iloc[:,-1:]
    globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns[0:1].to_list() + globals()[f'df_{i}_b'].columns.to_list() + [globals()[f'df_{i}_c'].columns[0]]
    globals()[f'df_{i}'][globals()[f'df_{i}'].columns[0]] = globals()[f'df_{i}'][globals()[f'df_{i}'].columns[-1]]
    globals()[f'df_{i}'] = globals()[f'df_{i}'].iloc[:,:-1]
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_excel('C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\TABLE 20A Invested Assets by Class National & Foreign Companies - Annual Report on the UAE Insurance Sector for 2017-2021.xlsx',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\1812532058.py:16: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\1812532058.py:18: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\1812532058.py:16: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
# ...

# %%
# TABLE 20B Invested Assets by Class Traditional & Takaful National Companies - Annual Report on the UAE Insurance Sector 
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\cb insur sectore'
Table_20bi = []
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('TABLE 20B Invested'):
        Table_20bi.append(files)
Table_20bi.sort(key=lambda x: x.split('UAE Insurance Sector for ')[1].split('.')[0],reverse = True)
pdList = []
import pandas as pd
import numpy as np
from pandas import concat
for i in range(len(Table_20bi)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_20bi[i]}').reset_index(drop=True)
    globals()[f'df_{i}_b'] = globals()[f'df_{i}'].iloc[:,1:-1]
    globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
    globals()[f'df_{i}_c'] = globals()[f'df_{i}'].iloc[:,-1:]
    globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns[0:1].to_list() + globals()[f'df_{i}_b'].columns.to_list() + [globals()[f'df_{i}_c'].columns[0]]
    globals()[f'df_{i}'][globals()[f'df_{i}'].columns[0]] = globals()[f'df_{i}'][globals()[f'df_{i}'].columns[-1]]
    globals()[f'df_{i}'] = globals()[f'df_{i}'].iloc[:,:-1]
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_excel('C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\TABLE 20B Invested Assets by Class Traditional & Takaful National Companies - Annual Report on the UAE Insurance Sector for 2017-2021.xlsx',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\1959489761.py:16: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\1959489761.py:18: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\1959489761.py:16: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
# ...

# %%
# TABLE 20B Percent of Total Invested Assets by Class Traditional & Takaful National Companies - Annual Report on the UAE Insurance Sector
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\cb insur sectore'
Table_20bp = []
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('TABLE 20B Percent'):
        Table_20bp.append(files)
Table_20bp.sort(key=lambda x: x.split('UAE Insurance Sector for ')[1].split('.')[0],reverse = True)
pdList = []
import pandas as pd
import numpy as np
from pandas import concat
for i in range(len(Table_20bp)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_20bp[i]}').reset_index(drop=True)
    globals()[f'df_{i}_b'] = globals()[f'df_{i}'].iloc[:,1:-1]
    globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
    globals()[f'df_{i}_c'] = globals()[f'df_{i}'].iloc[:,-1:]
    globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns[0:1].to_list() + globals()[f'df_{i}_b'].columns.to_list() + [globals()[f'df_{i}_c'].columns[0]]
    globals()[f'df_{i}'][globals()[f'df_{i}'].columns[0]] = globals()[f'df_{i}'][globals()[f'df_{i}'].columns[-1]]
    globals()[f'df_{i}'] = globals()[f'df_{i}'].iloc[:,:-1]
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_excel('C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\TABLE 20B Percent of Total Invested Assets by Class Traditional & Takaful National Companies - Annual Report on the UAE Insurance Sector for 2017-2021.xlsx',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\1526702348.py:16: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\1526702348.py:18: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\1526702348.py:16: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
# ...

# %%
# TABLE 21A Statement of Financial Position National & Foreign Companies - Annual Report on the UAE Insurance Sector
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\cb insur sectore'
Table_21a = []
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('TABLE 21A'):
        Table_21a.append(files)
Table_21a.sort(key=lambda x: x.split('UAE Insurance Sector for ')[1].split('.')[0],reverse = True)
pdList = []
import pandas as pd
import numpy as np
from pandas import concat
for i in range(len(Table_21a)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_21a[i]}').reset_index(drop=True)
    globals()[f'df_{i}_b'] = globals()[f'df_{i}'].iloc[:,1:-1]
    globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
    globals()[f'df_{i}_c'] = globals()[f'df_{i}'].iloc[:,-1:]
    globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns[0:1].to_list() + globals()[f'df_{i}_b'].columns.to_list() + [globals()[f'df_{i}_c'].columns[0]]
    globals()[f'df_{i}'][globals()[f'df_{i}'].columns[0]] = globals()[f'df_{i}'][globals()[f'df_{i}'].columns[-1]]
    globals()[f'df_{i}'] = globals()[f'df_{i}'].iloc[:,:-1]
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_excel('C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\TABLE 21A Statement of Financial Position National & Foreign Companies - Annual Report on the UAE Insurance Sector for 2017-2021.xlsx',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\2538547531.py:16: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\2538547531.py:18: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\2538547531.py:16: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
# ...

# %%
# TABLE 21B Statement of Financial Position Traditional & Takaful National Companies - Annual Report on the UAE Insurance Sector
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\cb insur sectore'
Table_21b = []
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('TABLE 21B'):
        Table_21b.append(files)
Table_21b.sort(key=lambda x: x.split('UAE Insurance Sector for ')[1].split('.')[0],reverse = True)
pdList = []
import pandas as pd
import numpy as np
from pandas import concat
for i in range(len(Table_21b)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_21b[i]}').reset_index(drop=True)
    globals()[f'df_{i}_b'] = globals()[f'df_{i}'].iloc[:,1:-1]
    globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
    globals()[f'df_{i}_c'] = globals()[f'df_{i}'].iloc[:,-1:]
    globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns[0:1].to_list() + globals()[f'df_{i}_b'].columns.to_list() + [globals()[f'df_{i}_c'].columns[0]]
    globals()[f'df_{i}'][globals()[f'df_{i}'].columns[0]] = globals()[f'df_{i}'][globals()[f'df_{i}'].columns[-1]]
    globals()[f'df_{i}'] = globals()[f'df_{i}'].iloc[:,:-1]
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_excel('C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\TABLE 21B Statement of Financial Position Traditional & Takaful National Companies - Annual Report on the UAE Insurance Sector for 2017-2021.xlsx',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\3860728651.py:16: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\3860728651.py:18: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\3860728651.py:16: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
# ...

# %%
# TABLE 22A Income Statement National & Foreign Companies - Annual Report on the UAE Insurance Sector 
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\cb insur sectore'
Table_22a = []
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('TABLE 22A'):
        Table_22a.append(files)
Table_22a.sort(key=lambda x: x.split('UAE Insurance Sector for ')[1].split('.')[0],reverse = True)
pdList = []
import pandas as pd
import numpy as np
from pandas import concat
for i in range(len(Table_22a)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_22a[i]}').reset_index(drop=True)
    globals()[f'df_{i}_b'] = globals()[f'df_{i}'].iloc[:,1:-1]
    globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
    globals()[f'df_{i}_c'] = globals()[f'df_{i}'].iloc[:,-1:]
    globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns[0:1].to_list() + globals()[f'df_{i}_b'].columns.to_list() + [globals()[f'df_{i}_c'].columns[0]]
    globals()[f'df_{i}'][globals()[f'df_{i}'].columns[0]] = globals()[f'df_{i}'][globals()[f'df_{i}'].columns[-1]]
    globals()[f'df_{i}'] = globals()[f'df_{i}'].iloc[:,:-1]
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_excel('C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\TABLE 22A Income Statement National & Foreign Companies - Annual Report on the UAE Insurance Sector for 2017-2021.xlsx',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\92963352.py:16: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\92963352.py:18: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\92963352.py:16: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
# ...

# %%
# TABLE 22B Income Statement Traditional & Takaful National Companies - Annual Report on the UAE Insurance Sector 
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\cb insur sectore'
Table_22b = []
import os
for files in os.listdir(f'{base_path}'):
    if files.startswith('TABLE 22B'):
        Table_22b.append(files)
Table_22b.sort(key=lambda x: x.split('UAE Insurance Sector for ')[1].split('.')[0],reverse = True)
pdList = []
import pandas as pd
import numpy as np
from pandas import concat
for i in range(len(Table_22b)):
    globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_22b[i]}').reset_index(drop=True)
    globals()[f'df_{i}_b'] = globals()[f'df_{i}'].iloc[:,1:-1]
    globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
    globals()[f'df_{i}_c'] = globals()[f'df_{i}'].iloc[:,-1:]
    globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
    globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns[0:1].to_list() + globals()[f'df_{i}_b'].columns.to_list() + [globals()[f'df_{i}_c'].columns[0]]
    globals()[f'df_{i}'][globals()[f'df_{i}'].columns[0]] = globals()[f'df_{i}'][globals()[f'df_{i}'].columns[-1]]
    globals()[f'df_{i}'] = globals()[f'df_{i}'].iloc[:,:-1]
    pdList.append(globals()[f'df_{i}'])

for i in range(len(pdList)-1):
    cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
    globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
globals()[f'df_{i+1}'].to_excel('C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\TABLE 22B Income Statement Traditional & Takaful National Companies - Annual Report on the UAE Insurance Sector for 2017-2021.xlsx',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\1623799873.py:16: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\1623799873.py:18: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\1623799873.py:16: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
# ...

# %%
# 23 >> 34
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\cb insur sectore'
for f in range(25,26):
    Table_k = []
    import os
    for files in os.listdir(f'{base_path}'):
        if files.startswith(f'TABLE {f}'):
            Table_k.append(files)
    Table_k.sort(key=lambda x: x.split('UAE Insurance Sector for ')[1].split('.')[0],reverse = True)
    file_name = Table_k[4].split('-2017')[0]
    pdList = []
    import pandas as pd
    import numpy as np
    from pandas import concat
    for i in range(len(Table_k)):
        globals()[f'df_{i}'] = pd.read_csv(f'{base_path}\\{Table_k[i]}').reset_index(drop=True)
        globals()[f'df_{i}_b'] = globals()[f'df_{i}'].iloc[:,1:-1]
        globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
        globals()[f'df_{i}_c'] = globals()[f'df_{i}'].iloc[:,-1:]
        globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
        globals()[f'df_{i}'].columns = globals()[f'df_{i}'].columns[0:1].to_list() + globals()[f'df_{i}_b'].columns.to_list() + [globals()[f'df_{i}_c'].columns[0]]
        globals()[f'df_{i}'][globals()[f'df_{i}'].columns[0]] = globals()[f'df_{i}'][globals()[f'df_{i}'].columns[-1]]
        globals()[f'df_{i}'] = globals()[f'df_{i}'].iloc[:,:-1]
        pdList.append(globals()[f'df_{i}'])

    for i in range(len(pdList)-1):
        cols_to_use = globals()[f'df_{i+1}'].columns.difference(globals()[f'df_{i}'].columns)
        globals()[f'df_{i+1}'] = pd.merge(globals()[f'df_{i}'], globals()[f'df_{i+1}'][cols_to_use], left_index=True, right_index=True, how='outer')
    globals()[f'df_{i+1}'].to_excel(f'C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank\\{file_name} - Annual Report on the UAE Insurance Sector for 2017-2021.xlsx',index=False)
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\570825972.py:18: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\570825972.py:20: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_c'].columns = globals()[f'df_{i}_c'].columns.str.split('-',1).str[0]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_29348\570825972.py:18: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   globals()[f'df_{i}_b'].columns = globals()[f'df_{i}_b'].columns.str.split('-',1).str[1]
# ...

# %%
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\cb insur sectore'
for f in range(23,35):
    Table_k = []
    import os
    for files in os.listdir(f'{base_path}'):
        if files.startswith(f'TABLE {f}A'):
            Table_k.append(files)
    Table_k.sort(key=lambda x: x.split('UAE Insurance Sector for ')[1].split('.')[0],reverse = True)
Table_k[4].split('-2017')[0]
# Out:
# 'TABLE 34A Gross Results For Fujairah '

# %%
df = pd.read_csv(f'{base_path}\\{Table_7[0]}', encoding="utf-8")
df_2 = df.iloc[:,1:-1]
df_2.columns = df_2.columns.str.split('-',1).str[1]
df_3 = df.iloc[:,-1:]
df_3.columns = df_3.columns.str.split('-',1).str[0]
df.columns = df.columns[0:1].to_list() + df_2.columns.to_list() + [df_3.columns[0]]
df
# Out:
# C:\Users\10235555\AppData\Local\Temp\ipykernel_11660\838767285.py:3: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df_2.columns = df_2.columns.str.split('-',1).str[1]
# C:\Users\10235555\AppData\Local\Temp\ipykernel_11660\838767285.py:5: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df_3.columns = df_3.columns.str.split('-',1).str[0]
#                                      فروع التأمين  \
# 0                                    تأمين الحريق
# 1                         التأمين البحري والطيران
# 2                 تأمين السيارات والمركبات الأخرى
# 3              التأمين الهندسي والانشاءات والطاقة
# 4                                            أخرى
# 5           المجموع - تأمين الممتلكات والمسؤوليات
# 6                             المجموع - تأمين صحي
# 7                               تأمين حياة جماعي
# ...

# %%
# transpose Table in all file C:\Users\10235555\Documents\Dataportal Data\Table Central Bank
import os
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\Table Central Bank'
for file in os.listdir(base_path):
    if file.endswith('.xlsx'):
        df = pd.read_excel(f'C:\\Users\\10235555\\Documents\\Dataportal Data\\central bank\\{file}')
        df = df.transpose()
        df.columns = df.iloc[0,:]
        df = df[1:]
        df.to_excel(f'{base_path}\\{file}')
    elif file.endswith('.csv'):
        df = pd.read_csv(f'C:\\Users\\10235555\\Documents\\Dataportal Data\\central bank\\{file}')
        df = df.transpose()
        df.columns = df.iloc[0,:]
        df = df[1:]
        df.to_csv(f'{base_path}\\{file}')
