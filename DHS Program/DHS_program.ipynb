# %%
import requests
from bs4 import BeautifulSoup
import wget
import logging
from RequestInferSchemaToJsonAPI.main import TriggerInferShemaToJsonAPI
import os
import urllib.request
from urllib import request
import pdfplumber
import tabula 
import csv
import pandas as pd
from unidecode import unidecode
import pandas as pd
base_path='C:\\Users\\10235555\\Documents\\Dataportal Data\\DHS Program'
# logging.basicConfig(handlers=[logging.FileHandler("out.log"),
#                               logging.StreamHandler()], level=logging.INFO)

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import ElementNotInteractableException, NoSuchElementException
from selenium.common.exceptions import ElementClickInterceptedException
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from webdriver_manager.firefox import GeckoDriverManager
from selenium.webdriver.firefox.options import Options
from bs4 import BeautifulSoup
import shutil
import time
import os
from pyshadow.main import Shadow
from py7zr import unpack_7zarchive
from RequestInferSchemaToJsonAPI.main import TriggerInferShemaToJsonAPI

# %%
chrome_options = webdriver.ChromeOptions()
# base_path = "\\\\10.30.31.77\\data_collection_dump\\RawData\\IPU" # local, gets current working directory
# prefs = {'download.default_directory' : base_path}#, "profile.content_settings.exceptions.automatic_downloads.*.setting" : 1}
# chrome_options.add_experimental_option('prefs', prefs)
#chrome_options.add_argument('--user-agent="Mozilla/5.0 (Windows Phone 10.0; Android 4.2.1; Microsoft; Lumia 640 XL LTE) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.135 Mobile Safari/537.36 Edge/12.10166"')
# driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
driver.maximize_window()

# %%
result = requests.get('https://api.dhsprogram.com/#/index.html')
soup = BeautifulSoup(result.content,'html.parser')
url = 'https://api.dhsprogram.com/'
side = soup.find(class_='SideNavDiv')
list_side = side.find(class_='navList')
list_apiRef = list_side.find('ul')
indic_data = list_apiRef.find_all('a')[2]['href']
link_indic_data = url + indic_data
link_indic_data
# Out:
# 'https://api.dhsprogram.com/#/api-data.cfm'

# %%
driver.get(link_indic_data)
time.sleep(2)

# %%
contents = driver.find_elements(By.CLASS_NAME,"apiText")
fields = contents[1].find_element(By.TAG_NAME,'a').get_attribute('href')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\Users\10235555\Documents\DataportalCrawlers\UN_Data\DHS_program.ipynb Cell 6 in 2
#       <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/DHS_program.ipynb#X22sZmlsZQ%3D%3D?line=0'>1</a> contents = driver.find_elements(By.CLASS_NAME,"apiText")
# ----> <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/DHS_program.ipynb#X22sZmlsZQ%3D%3D?line=1'>2</a> fields = contents[1].find_element(By.TAG_NAME,'a').get_attribute('href')
#
# IndexError: list index out of range

# %%
contents = driver.find_elements(By.CLASS_NAME,"apiText")
fields = contents[1].find_element(By.TAG_NAME,'a').get_attribute('href')
res_fields = requests.get(fields)            
soup_fields = BeautifulSoup(res_fields.content, 'html.parser')
rows = soup_fields.find_all('tr')
l = []
for tr in rows[2:]:
    cells = tr.find_all(['td','th'])
    cells_text = [cell.get_text(strip=True) for cell in cells]
    l.append(cells_text)
df = pd.DataFrame(l).iloc[:,1:]
desc = []
for i in range(len(df.index)):
    f = df.iloc[i].to_list()
    f = [' : '.join(map(str,f))]
    desc.append(f[0])
descr = [' , '.join(map(str,desc))]

# %%
desc = []
for i in range(len(df.index)):
    f = df.iloc[i].to_list()
    f = [' : '.join(map(str,f))]
    desc.append(f[0])
# desc = f'{df.columns[0]} : {df.columns[1]} ' + desc[0]
descr = [' , '.join(map(str,desc))]

# %%
descr
# Out:
# ["fieldname : fieldDescription , DataId : A unique numeric record ID corresponding to the data record provided. , Indicator : The name or label of the particular indicator for this data. , Value : The actual value (percentage, rate, number, etc.) of the particular indicator specified. The value can be used to provide statistics to users. , Precision : The number of decimal places that should be presented for value of the indicator. , DHS_CountryCode : Two-letter DHS specific country code. , CountryName : DHS specific country name. , SurveyYear : The principal year in which the survey was conducted. , SurveyId : DHS survey ID. Each survey will always have a unique ID (of the form ccyyyyttt where cc is the DHS country code,\n\t\t\t\t\t\t\t\t\tyyyy is the survey year, and ttt is the survey type) and can be used to obtain national or subnational data for a particular survey. , IndicatorId : Indicator ID for the indicator specified for the particular data. , IndicatorOrder : Indicator Order for the indicator specified for the particular data. , IndicatorType : Indicator Type for the indicator specified for the particular data. , CharacteristicId : DHS has defined a list of characteristics that are used across surveys to make sure the data can be compared across countries\n\t\t\t\t\t\t\t\tvery easily. A characteristic ID gives you the unique ID that represents that particular characteristic. , CharacteristicOrder : Sort order in which to display characteristics. , CharacteristicCategory : DHS has defined a list of characteristic categories that are used across surveys to make sure the data can be compared across\n\t\t\t\t\t\t\t\tcountries very easily. This category can be used to filter data. See also CharacteristicLabel. , CharacteristicLabel : This field provides label of the characteristic within a particular characteristic category. For example, Urban and Rural are the two\n\t\t\t\t\t\t\t\tcharacteristics within the category Residence. , ByVariableId : A characteristic ID identifying a further level of disaggregation, when an indicator is disaggregated in multiple ways. For example,\n\t\t\t\t\t\t\t\tCurrent Use of Contraception is disaggregated by Age, but also for All women, currently married women and sexually active unmarried\n\t\t\t\t\t\t\t\twomen. Age is presented in the characteristic category above; the disaggregation for All women, currently married women and sexually\n\t\t\t\t\t\t\t\tactive unmarried women is captured in the ByVariableId and ByVariableLabel. If this additional level of disaggregation is not used\n\t\t\t\t\t\t\t\tfor the indicator the ByVariableId will be 0 and the ByVariableLabel will be blank. A common use of the ByVariableId and\n\t\t\t\t\t\t\t\tByVariable... , ByVariableLabel : The descriptive label for the level of disaggregation provided in the ByVariableId. , IsTotal : This column will identify if a certain value is a Total value used for national totals. , IsPreferred : If a particular indicator has multiple values because it is disaggregated in multiple ways, this column will identify which is\n\t\t\t\t\t\t\t\tthe preferred value to display by default. , SDRID : ID used in The DHS Program Spatial Data Repository (SDR). , RegionId : Unique ID given to each survey and region. , SurveyYearLabel : The Survey Year Label can provide slightly more details about a survey's year.\n\t\t\t\t\t\t\t\tFor example if a survey started in 1998 and finished in 1999, the survey year\n\t\t\t\t\t\t\t\twould be 1998 while the display would provide 1998-99. This information could be\n\t\t\t\t\t\t\t\tused to make the user interface more intuitive and accurate. , SurveyType : The survey type determines whether the survey was a DHS, AIS, MIS, SPA, RHS or other type of survey. , DenominatorWeighted : The weighted denominator for the indicator data. , DenominatorUnweighted : The unweighted denominator for the indicator data. , CILow : The lower bound of the 95% confidence interval for the indicator. The confidence interval ...

# %%
api_urls = driver.find_elements(By.CLASS_NAME,'apiReferenceURL')
data_DHS = api_urls[10].text
data_DHS
# Out:
# 'https://api.dhsprogram.com/rest/dhs/data/DHS'

# %%
api_urls = driver.find_elements(By.CLASS_NAME,'apiReferenceURL')
for u in api_urls:
    print(u.text)
# indicators_DHS = api_urls[12].text
# indicators_DHS
# Out:
# https://api.dhsprogram.com/rest/dhs/data
# https://api.dhsprogram.com/rest/dhs/data?f=html
# https://api.dhsprogram.com/rest/dhs/data/EG
# https://api.dhsprogram.com/rest/dhs/data/FE_FRTR_W_TFR
# https://api.dhsprogram.com/rest/dhs/data/SN2010DHS
# https://api.dhsprogram.com/rest/dhs/data/SN,all,MIS?selectSurveys=latest
# https://api.dhsprogram.com/rest/dhs/data/SN,all,MIS?selectSurveys=byIndicator&indicatorIds=FE_CEBA_W_CH0
# https://api.dhsprogram.com/rest/dhs/data/2010
# https://api.dhsprogram.com/rest/dhs/data/PK?surveyYearStart=2006
# https://api.dhsprogram.com/rest/dhs/data/PK?surveyYearStart=1991&surveyYearEnd=2006
# https://api.dhsprogram.com/rest/dhs/data/DHS
# https://api.dhsprogram.com/rest/dhs/data?surveyCharacteristicIds=32
# https://api.dhsprogram.com/rest/dhs/data/AL,all?characteristicCategory=wealth%20quintile
# https://api.dhsprogram.com/rest/dhs/data?breakdown=all&countryIds=AZ&characteristicLabel=6%2B
# https://api.dhsprogram.com/rest/dhs/data?tagIds=1
# https://api.dhsprogram.com/rest/dhs/data/2010,national
# https://api.dhsprogram.com/rest/dhs/data/2010,subnational
# https://api.dhsprogram.com/rest/dhs/data/2010,background
# https://api.dhsprogram.com/rest/dhs/data/2010,all
# https://api.dhsprogram.com/rest/dhs/data/KE2014DHS,FE_FRTR_W_TFR?f=geojson&returnGeometry=true
# https://api.dhsprogram.com/rest/dhs/data/NG,2013,FE_FRTR_W_TFR?f=html

# %%
driver.get(data_DHS)
page_source = driver.page_source               
soup_indic_DHS = BeautifulSoup(page_source, 'html.parser')

# %%
#Import libraries.
import json
import urllib.request
 
#Query the API for a list of countries.
 
# ind_DHS_url = r'https://api.dhsprogram.com/rest/dhs/countries'
 
 
#Obtain and Parse the list into a Python Object.
req = urllib.request.urlopen(indicators_DHS)
resp = json.loads(req.read())
resp
my_data = resp['Data']
my_data
# #Display a list of Country Code and names.
# for c in my_data:
#     # print(c['DHS_CountryCode'] + ' : ' + c['CountryName'])
#     print(c['Indicator'])
# Out:
# [{'DataId': 678612,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Age specific fertility rate: 10-14',
#   'IsPreferred': 1,
#   'Value': 0.0,
#   'SDRID': 'FEFRTRWA10',
#   'Precision': 0,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 11763005,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'I',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'FE_FRTR_W_A10',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': '',
#   'DenominatorUnweighted': '',
#   'DenominatorWeighted': '',
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 0,
#   'LevelRank': ''},
#  {'DataId': 678616,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Age specific fertility rate: 15-19',
#   'IsPreferred': 1,
#   'Value': 78.0,
#   'SDRID': 'FEFRTRWA15',
#   'Precision': 0,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 11763010,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'I',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'FE_FRTR_W_A15',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': '',
#   'DenominatorUnweighted': '',
#   'DenominatorWeighted': '',
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 0,
#   'LevelRank': ''},
#  {'DataId': 678608,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Age specific fertility rate: 20-24',
#   'IsPreferred': 1,
#   'Value': 261.0,
#   'SDRID': 'FEFRTRWA20',
#   'Precision': 0,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 11763020,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'I',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'FE_FRTR_W_A20',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': '',
#   'DenominatorUnweighted': '',
#   'DenominatorWeighted': '',
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 0,
#   'LevelRank': ''},
#  {'DataId': 678609,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Age specific fertility rate: 25-29',
#   'IsPreferred': 1,
#   'Value': 271.0,
#   'SDRID': 'FEFRTRWA25',
#   'Precision': 0,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 11763030,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'I',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'FE_FRTR_W_A25',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': '',
#   'DenominatorUnweighted': '',
#   'DenominatorWeighted': '',
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 0,
#   'LevelRank': ''},
#  {'DataId': 678619,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Age specific fertility rate: 30-34',
#   'IsPreferred': 1,
#   'Value': 212.0,
#   'SDRID': 'FEFRTRWA30',
#   'Precision': 0,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 11763040,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'I',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'FE_FRTR_W_A30',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': '',
#   'DenominatorUnweighted': '',
#   'DenominatorWeighted': '',
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 0,
#   'LevelRank': ''},
#  {'DataId': 678620,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Age specific fertility rate: 35-39',
#   'IsPreferred': 1,
#   'Value': 144.0,
#   'SDRID': 'FEFRTRWA35',
#   'Precision': 0,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 11763050,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'I',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'FE_FRTR_W_A35',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': '',
#   'DenominatorUnweighted': '',
#   'DenominatorWeighted': '',
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 0,
#   'LevelRank': ''},
#  {'DataId': 678617,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Age specific fertility rate: 40-44',
#   'IsPreferred': 1,
#   'Value': 64.0,
#   'SDRID': 'FEFRTRWA40',
#   'Precision': 0,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 11763060,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'I',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'FE_FRTR_W_A40',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': '',
#   'DenominatorUnweighted': '',
#   'DenominatorWeighted': '',
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 0,
#   'LevelRank': ''},
#  {'DataId': 678606,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Age specific fertility rate: 45-49',
#   'IsPreferred': 1,
#   'Value': 28.0,
#   'SDRID': 'FEFRTRWA45',
#   'Precision': 0,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 11763070,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'I',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'FE_FRTR_W_A45',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': '',
#   'DenominatorUnweighted': '',
#   'DenominatorWeighted': '',
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 0,
#   'LevelRank': ''},
#  {'DataId': 678618,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Total fertility rate 15-49',
#   'IsPreferred': 1,
#   'Value': 5.3,
#   'SDRID': 'FEFRTRWTFR',
#   'Precision': 1,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 11763080,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'I',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'FE_FRTR_W_TFR',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': '',
#   'DenominatorUnweighted': '',
#   'DenominatorWeighted': '',
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 0,
#   'LevelRank': ''},
#  {'DataId': 678607,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Total fertility rate 15-44',
#   'IsPreferred': 1,
#   'Value': 5.1,
#   'SDRID': 'FEFRTRWTF4',
#   'Precision': 1,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 11763090,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'I',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'FE_FRTR_W_TF4',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': '',
#   'DenominatorUnweighted': '',
#   'DenominatorWeighted': '',
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 0,
#   'LevelRank': ''},
#  {'DataId': 678610,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'General fertility rate',
#   'IsPreferred': 1,
#   'Value': 175.0,
#   'SDRID': 'FEFRTRWGFR',
#   'Precision': 0,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 11763100,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'I',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'FE_FRTR_W_GFR',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': '',
#   'DenominatorUnweighted': '',
#   'DenominatorWeighted': '',
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 0,
#   'LevelRank': ''},
#  {'DataId': 678611,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Crude birth rate',
#   'IsPreferred': 1,
#   'Value': 36.8,
#   'SDRID': 'FEFRTRWCBR',
#   'Precision': 1,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 11763110,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'I',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'FE_FRTR_W_CBR',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': '',
#   'DenominatorUnweighted': '',
#   'DenominatorWeighted': '',
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 0,
#   'LevelRank': ''},
#  {'DataId': 75176,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Percentage of women currently pregnant',
#   'IsPreferred': 1,
#   'Value': 15.2,
#   'SDRID': 'FEFRTYWPRG',
#   'Precision': 1,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 11803020,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'I',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'FE_FRTY_W_PRG',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': '',
#   'DenominatorUnweighted': 41936.0,
#   'DenominatorWeighted': 42221.0,
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 0,
#   'LevelRank': ''},
#  {'DataId': 678643,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Number of women age 15-49',
#   'IsPreferred': 1,
#   'Value': 42221.0,
#   'SDRID': 'FEFRTYWNPG',
#   'Precision': 0,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 11803030,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'D',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'FE_FRTY_W_NPG',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': '',
#   'DenominatorUnweighted': 41936.0,
#   'DenominatorWeighted': '',
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 0,
#   'LevelRank': ''},
#  {'DataId': 75173,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Number of women age 15-49 (unweighted)',
#   'IsPreferred': 1,
#   'Value': 41936.0,
#   'SDRID': 'FEFRTYWUPG',
#   'Precision': 0,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 11803040,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'U',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'FE_FRTY_W_UPG',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': '',
#   'DenominatorUnweighted': '',
#   'DenominatorWeighted': 42221.0,
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 0,
#   'LevelRank': ''},
#  {'DataId': 377059,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Completed fertility of women age 40-49',
#   'IsPreferred': 1,
#   'Value': 7.0,
#   'SDRID': 'FEFRTYWMNC',
#   'Precision': 1,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 11803050,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'I',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'FE_FRTY_W_MNC',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': '',
#   'DenominatorUnweighted': 6324.0,
#   'DenominatorWeighted': 6489.0,
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 0,
#   'LevelRank': ''},
#  {'DataId': 385513,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Number of women age 40-49',
#   'IsPreferred': 1,
#   'Value': 6489.0,
#   'SDRID': 'FEFRTYWN49',
#   'Precision': 0,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 11803060,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'D',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'FE_FRTY_W_N49',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': '',
#   'DenominatorUnweighted': 6324.0,
#   'DenominatorWeighted': '',
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 0,
#   'LevelRank': ''},
#  {'DataId': 124593,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Number of women age 40-49 (unweighted)',
#   'IsPreferred': 1,
#   'Value': 6324.0,
#   'SDRID': 'FEFRTYWU49',
#   'Precision': 0,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 11803070,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'U',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'FE_FRTY_W_U49',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': '',
#   'DenominatorUnweighted': '',
#   'DenominatorWeighted': 6489.0,
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 0,
#   'LevelRank': ''},
#  {'DataId': 678626,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Age specific fertility rate: 10-14 (five year periods)',
#   'IsPreferred': 1,
#   'Value': 1.0,
#   'SDRID': 'FEFRTTWA10',
#   'Precision': 0,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 11833005,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'I',
#   'CharacteristicId': 13000,
#   'CharacteristicCategory': 'Five year periods',
#   'IndicatorId': 'FE_FRTT_W_A10',
#   'CharacteristicOrder': 80000,
#   'CharacteristicLabel': '0-4',
#   'ByVariableLabel': '',
#   'DenominatorUnweighted': '',
#   'DenominatorWeighted': '',
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 0,
#   'LevelRank': ''},
#  {'DataId': 678627,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Age specific fertility rate: 15-19 (five year periods)',
#   'IsPreferred': 1,
#   'Value': 87.0,
#   'SDRID': 'FEFRTTWA15',
#   'Precision': 0,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 11833010,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'I',
#   'CharacteristicId': 13000,
#   'CharacteristicCategory': 'Five year periods',
#   'IndicatorId': 'FE_FRTT_W_A15',
#   'CharacteristicOrder': 80000,
#   'CharacteristicLabel': '0-4',
#   'ByVariableLabel': '',
#   'DenominatorUnweighted': '',
#   'DenominatorWeighted': '',
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 0,
#   'LevelRank': ''},
#  {'DataId': 678628,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Age specific fertility rate: 20-24 (five year periods)',
#   'IsPreferred': 1,
#   'Value': 269.0,
#   'SDRID': 'FEFRTTWA20',
#   'Precision': 0,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 11833020,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'I',
#   'CharacteristicId': 13000,
#   'CharacteristicCategory': 'Five year periods',
#   'IndicatorId': 'FE_FRTT_W_A20',
#   'CharacteristicOrder': 80000,
#   'CharacteristicLabel': '0-4',
#   'ByVariableLabel': '',
#   'DenominatorUnweighted': '',
#   'DenominatorWeighted': '',
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 0,
#   'LevelRank': ''},
#  {'DataId': 678640,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Age specific fertility rate: 25-29 (five year periods)',
#   'IsPreferred': 1,
#   'Value': 280.0,
#   'SDRID': 'FEFRTTWA25',
#   'Precision': 0,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 11833030,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'I',
#   'CharacteristicId': 13000,
#   'CharacteristicCategory': 'Five year periods',
#   'IndicatorId': 'FE_FRTT_W_A25',
#   'CharacteristicOrder': 80000,
#   'CharacteristicLabel': '0-4',
#   'ByVariableLabel': '',
#   'DenominatorUnweighted': '',
#   'DenominatorWeighted': '',
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 0,
#   'LevelRank': ''},
#  {'DataId': 678641,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Age specific fertility rate: 30-34 (five year periods)',
#   'IsPreferred': 1,
#   'Value': 222.0,
#   'SDRID': 'FEFRTTWA30',
#   'Precision': 0,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 11833040,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'I',
#   'CharacteristicId': 13000,
#   'CharacteristicCategory': 'Five year periods',
#   'IndicatorId': 'FE_FRTT_W_A30',
#   'CharacteristicOrder': 80000,
#   'CharacteristicLabel': '0-4',
#   'ByVariableLabel': '',
#   'DenominatorUnweighted': '',
#   'DenominatorWeighted': '',
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 0,
#   'LevelRank': ''},
#  {'DataId': 678629,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Age specific fertility rate: 35-39 (five year periods)',
#   'IsPreferred': 1,
#   'Value': 146.0,
#   'SDRID': 'FEFRTTWA35',
#   'Precision': 0,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 11833050,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'I',
#   'CharacteristicId': 13000,
#   'CharacteristicCategory': 'Five year periods',
#   'IndicatorId': 'FE_FRTT_W_A35',
#   'CharacteristicOrder': 80000,
#   'CharacteristicLabel': '0-4',
#   'ByVariableLabel': '',
#   'DenominatorUnweighted': '',
#   'DenominatorWeighted': '',
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 0,
#   'LevelRank': ''},
#  {'DataId': 678639,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Age specific fertility rate: 40-44 (five year periods)',
#   'IsPreferred': 1,
#   'Value': 69.0,
#   'SDRID': 'FEFRTTWA40',
#   'Precision': 0,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 11833060,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'I',
#   'CharacteristicId': 13000,
#   'CharacteristicCategory': 'Five year periods',
#   'IndicatorId': 'FE_FRTT_W_A40',
#   'CharacteristicOrder': 80000,
#   'CharacteristicLabel': '0-4',
#   'ByVariableLabel': '',
#   'DenominatorUnweighted': '',
#   'DenominatorWeighted': '',
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 0,
#   'LevelRank': ''},
#  {'DataId': 678630,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Age specific fertility rate: 45-49 (five year periods)',
#   'IsPreferred': 1,
#   'Value': 28.0,
#   'SDRID': 'FEFRTTWA45',
#   'Precision': 0,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 11833070,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'I',
#   'CharacteristicId': 13000,
#   'CharacteristicCategory': 'Five year periods',
#   'IndicatorId': 'FE_FRTT_W_A45',
#   'CharacteristicOrder': 80000,
#   'CharacteristicLabel': '0-4',
#   'ByVariableLabel': '',
#   'DenominatorUnweighted': '',
#   'DenominatorWeighted': '',
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 0,
#   'LevelRank': ''},
#  {'DataId': 450098,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Women with no children ever born',
#   'IsPreferred': 1,
#   'Value': 36.9,
#   'SDRID': 'FECEBAWCH0',
#   'Precision': 1,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 11863010,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'I',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'FE_CEBA_W_CH0',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': '',
#   'DenominatorUnweighted': 41936.0,
#   'DenominatorWeighted': 42221.0,
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 0,
#   'LevelRank': ''},
#  {'DataId': 450091,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Women with 1 child ever born',
#   'IsPreferred': 1,
#   'Value': 7.7,
#   'SDRID': 'FECEBAWCH1',
#   'Precision': 1,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 11863020,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'I',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'FE_CEBA_W_CH1',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': '',
#   'DenominatorUnweighted': 41936.0,
#   'DenominatorWeighted': 42221.0,
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 0,
#   'LevelRank': ''},
#  {'DataId': 450092,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Women with 2 children ever born',
#   'IsPreferred': 1,
#   'Value': 8.7,
#   'SDRID': 'FECEBAWCH2',
#   'Precision': 1,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 11863030,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'I',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'FE_CEBA_W_CH2',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': '',
#   'DenominatorUnweighted': 41936.0,
#   'DenominatorWeighted': 42221.0,
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 0,
#   'LevelRank': ''},
#  {'DataId': 450093,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Women with 3 children ever born',
#   'IsPreferred': 1,
#   'Value': 8.4,
#   'SDRID': 'FECEBAWCH3',
#   'Precision': 1,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 11863040,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'I',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'FE_CEBA_W_CH3',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': '',
#   'DenominatorUnweighted': 41936.0,
#   'DenominatorWeighted': 42221.0,
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 0,
#   'LevelRank': ''},
#  {'DataId': 450094,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Women with 4 children ever born',
#   'IsPreferred': 1,
#   'Value': 8.4,
#   'SDRID': 'FECEBAWCH4',
#   'Precision': 1,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 11863050,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'I',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'FE_CEBA_W_CH4',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': '',
#   'DenominatorUnweighted': 41936.0,
#   'DenominatorWeighted': 42221.0,
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 0,
#   'LevelRank': ''},
#  {'DataId': 450099,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Women with 5 children ever born',
#   'IsPreferred': 1,
#   'Value': 7.3,
#   'SDRID': 'FECEBAWCH5',
#   'Precision': 1,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 11863060,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'I',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'FE_CEBA_W_CH5',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': '',
#   'DenominatorUnweighted': 41936.0,
#   'DenominatorWeighted': 42221.0,
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 0,
#   'LevelRank': ''},
#  {'DataId': 450095,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Women with 6 children ever born',
#   'IsPreferred': 1,
#   'Value': 6.8,
#   'SDRID': 'FECEBAWCH6',
#   'Precision': 1,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 11863070,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'I',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'FE_CEBA_W_CH6',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': '',
#   'DenominatorUnweighted': 41936.0,
#   'DenominatorWeighted': 42221.0,
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 0,
#   'LevelRank': ''},
#  {'DataId': 450100,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Women with 7 children ever born',
#   'IsPreferred': 1,
#   'Value': 5.5,
#   'SDRID': 'FECEBAWCH7',
#   'Precision': 1,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 11863080,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'I',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'FE_CEBA_W_CH7',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': '',
#   'DenominatorUnweighted': 41936.0,
#   'DenominatorWeighted': 42221.0,
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 0,
#   'LevelRank': ''},
#  {'DataId': 450096,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Women with 8 children ever born',
#   'IsPreferred': 1,
#   'Value': 4.2,
#   'SDRID': 'FECEBAWCH8',
#   'Precision': 1,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 11863090,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'I',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'FE_CEBA_W_CH8',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': '',
#   'DenominatorUnweighted': 41936.0,
#   'DenominatorWeighted': 42221.0,
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 0,
#   'LevelRank': ''},
#  {'DataId': 450102,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Women with 9 children ever born',
#   'IsPreferred': 1,
#   'Value': 2.8,
#   'SDRID': 'FECEBAWCH9',
#   'Precision': 1,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 11863100,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'I',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'FE_CEBA_W_CH9',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': '',
#   'DenominatorUnweighted': 41936.0,
#   'DenominatorWeighted': 42221.0,
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 0,
#   'LevelRank': ''},
#  {'DataId': 450103,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Women with 10+ children ever born',
#   'IsPreferred': 1,
#   'Value': 3.4,
#   'SDRID': 'FECEBAWC10',
#   'Precision': 1,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 11863110,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'I',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'FE_CEBA_W_C10',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': '',
#   'DenominatorUnweighted': 41936.0,
#   'DenominatorWeighted': 42221.0,
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 0,
#   'LevelRank': ''},
#  {'DataId': 450104,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Women: Total',
#   'IsPreferred': 1,
#   'Value': 100.0,
#   'SDRID': 'FECEBAWTOT',
#   'Precision': 1,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 11863120,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'T',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'FE_CEBA_W_TOT',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': '',
#   'DenominatorUnweighted': 41936.0,
#   'DenominatorWeighted': 42221.0,
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 0,
#   'LevelRank': ''},
#  {'DataId': 450105,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Number of women',
#   'IsPreferred': 1,
#   'Value': 42221.0,
#   'SDRID': 'FECEBAWNUM',
#   'Precision': 0,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 11863130,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'D',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'FE_CEBA_W_NUM',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': '',
#   'DenominatorUnweighted': 41936.0,
#   'DenominatorWeighted': '',
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 0,
#   'LevelRank': ''},
#  {'DataId': 678645,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Number of women (unweighted)',
#   'IsPreferred': 1,
#   'Value': 41936.0,
#   'SDRID': 'FECEBAWUNW',
#   'Precision': 0,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 11863140,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'U',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'FE_CEBA_W_UNW',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': '',
#   'DenominatorUnweighted': '',
#   'DenominatorWeighted': 42221.0,
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 0,
#   'LevelRank': ''},
#  {'DataId': 450101,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Mean number of children ever born',
#   'IsPreferred': 1,
#   'Value': 2.95,
#   'SDRID': 'FECEBAWMNC',
#   'Precision': 2,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 11863150,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'I',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'FE_CEBA_W_MNC',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': '',
#   'DenominatorUnweighted': 41936.0,
#   'DenominatorWeighted': 42221.0,
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 0,
#   'LevelRank': ''},
#  {'DataId': 450097,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Mean number of living children',
#   'IsPreferred': 1,
#   'Value': 2.7,
#   'SDRID': 'FECEBAWMNL',
#   'Precision': 2,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 11863160,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'I',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'FE_CEBA_W_MNL',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': '',
#   'DenominatorUnweighted': 41936.0,
#   'DenominatorWeighted': 42221.0,
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 0,
#   'LevelRank': ''},
#  {'DataId': 39708,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Married women with no children ever born',
#   'IsPreferred': 1,
#   'Value': 9.5,
#   'SDRID': 'FECEBMWCH0',
#   'Precision': 1,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 11903010,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'I',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'FE_CEBM_W_CH0',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': '',
#   'DenominatorUnweighted': 28661.0,
#   'DenominatorWeighted': 28671.0,
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 0,
#   'LevelRank': ''},
#  {'DataId': 39707,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Married women with 1 child ever born',
#   'IsPreferred': 1,
#   'Value': 11.1,
#   'SDRID': 'FECEBMWCH1',
#   'Precision': 1,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 11903020,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'I',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'FE_CEBM_W_CH1',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': '',
#   'DenominatorUnweighted': 28661.0,
#   'DenominatorWeighted': 28671.0,
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 0,
#   'LevelRank': ''},
#  {'DataId': 39704,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Married women with 2 children ever born',
#   'IsPreferred': 1,
#   'Value': 12.5,
#   'SDRID': 'FECEBMWCH2',
#   'Precision': 1,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 11903030,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'I',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'FE_CEBM_W_CH2',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': '',
#   'DenominatorUnweighted': 28661.0,
#   'DenominatorWeighted': 28671.0,
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 0,
#   'LevelRank': ''},
#  {'DataId': 39705,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Married women with 3 children ever born',
#   'IsPreferred': 1,
#   'Value': 12.0,
#   'SDRID': 'FECEBMWCH3',
#   'Precision': 1,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 11903040,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'I',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'FE_CEBM_W_CH3',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': '',
#   'DenominatorUnweighted': 28661.0,
#   'DenominatorWeighted': 28671.0,
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 0,
#   'LevelRank': ''},
#  {'DataId': 39706,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Married women with 4 children ever born',
#   'IsPreferred': 1,
#   'Value': 12.1,
#   'SDRID': 'FECEBMWCH4',
#   'Precision': 1,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 11903050,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'I',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'FE_CEBM_W_CH4',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': '',
#   'DenominatorUnweighted': 28661.0,
#   'DenominatorWeighted': 28671.0,
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 0,
#   'LevelRank': ''},
#  {'DataId': 39709,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Married women with 5 children ever born',
#   'IsPreferred': 1,
#   'Value': 10.4,
#   'SDRID': 'FECEBMWCH5',
#   'Precision': 1,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 11903060,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'I',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'FE_CEBM_W_CH5',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': '',
#   'DenominatorUnweighted': 28661.0,
#   'DenominatorWeighted': 28671.0,
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 0,
#   'LevelRank': ''},
#  {'DataId': 39710,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Married women with 6 children ever born',
#   'IsPreferred': 1,
#   'Value': 9.8,
#   'SDRID': 'FECEBMWCH6',
#   'Precision': 1,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 11903070,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'I',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'FE_CEBM_W_CH6',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': '',
#   'DenominatorUnweighted': 28661.0,
#   'DenominatorWeighted': 28671.0,
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 0,
#   'LevelRank': ''},
#  {'DataId': 39724,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Married women with 7 children ever born',
#   'IsPreferred': 1,
#   'Value': 7.9,
#   'SDRID': 'FECEBMWCH7',
#   'Precision': 1,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 11903080,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'I',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'FE_CEBM_W_CH7',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': '',
#   'DenominatorUnweighted': 28661.0,
#   'DenominatorWeighted': 28671.0,
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 0,
#   'LevelRank': ''},
#  {'DataId': 39711,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Married women with 8 children ever born',
#   'IsPreferred': 1,
#   'Value': 6.0,
#   'SDRID': 'FECEBMWCH8',
#   'Precision': 1,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 11903090,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'I',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'FE_CEBM_W_CH8',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': '',
#   'DenominatorUnweighted': 28661.0,
#   'DenominatorWeighted': 28671.0,
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 0,
#   'LevelRank': ''},
#  {'DataId': 39725,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Married women with 9 children ever born',
#   'IsPreferred': 1,
#   'Value': 4.0,
#   'SDRID': 'FECEBMWCH9',
#   'Precision': 1,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 11903100,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'I',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'FE_CEBM_W_CH9',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': '',
#   'DenominatorUnweighted': 28661.0,
#   'DenominatorWeighted': 28671.0,
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 0,
#   'LevelRank': ''},
#  {'DataId': 39730,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Married women with 10+ children ever born',
#   'IsPreferred': 1,
#   'Value': 4.8,
#   'SDRID': 'FECEBMWC10',
#   'Precision': 1,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 11903110,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'I',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'FE_CEBM_W_C10',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': '',
#   'DenominatorUnweighted': 28661.0,
#   'DenominatorWeighted': 28671.0,
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 0,
#   'LevelRank': ''},
#  {'DataId': 39731,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Married women: Total',
#   'IsPreferred': 1,
#   'Value': 100.0,
#   'SDRID': 'FECEBMWTOT',
#   'Precision': 1,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 11903120,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'T',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'FE_CEBM_W_TOT',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': '',
#   'DenominatorUnweighted': 28661.0,
#   'DenominatorWeighted': 28671.0,
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 0,
#   'LevelRank': ''},
#  {'DataId': 678653,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Number of married women',
#   'IsPreferred': 1,
#   'Value': 28671.0,
#   'SDRID': 'FECEBMWNUM',
#   'Precision': 0,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 11903130,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'D',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'FE_CEBM_W_NUM',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': '',
#   'DenominatorUnweighted': 28661.0,
#   'DenominatorWeighted': '',
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 0,
#   'LevelRank': ''},
#  {'DataId': 39732,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Number of married women (unweighted)',
#   'IsPreferred': 1,
#   'Value': 28661.0,
#   'SDRID': 'FECEBMWUNW',
#   'Precision': 0,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 11903140,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'U',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'FE_CEBM_W_UNW',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': '',
#   'DenominatorUnweighted': '',
#   'DenominatorWeighted': 28671.0,
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 0,
#   'LevelRank': ''},
#  {'DataId': 39726,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Mean number of children ever born to married women',
#   'IsPreferred': 1,
#   'Value': 4.22,
#   'SDRID': 'FECEBMWMNC',
#   'Precision': 2,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 11903150,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'I',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'FE_CEBM_W_MNC',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': '',
#   'DenominatorUnweighted': 28661.0,
#   'DenominatorWeighted': 28671.0,
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 0,
#   'LevelRank': ''},
#  {'DataId': 39729,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Mean number of living children to married women',
#   'IsPreferred': 1,
#   'Value': 3.87,
#   'SDRID': 'FECEBMWMNL',
#   'Precision': 2,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 11903160,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'I',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'FE_CEBM_W_MNL',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': '',
#   'DenominatorUnweighted': 28661.0,
#   'DenominatorWeighted': 28671.0,
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 0,
#   'LevelRank': ''},
#  {'DataId': 53956,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Previous birth interval: 7-17 months',
#   'IsPreferred': 1,
#   'Value': 11.7,
#   'SDRID': 'FEBINTCI07',
#   'Precision': 1,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 11936010,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'I',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'FE_BINT_C_I07',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': '',
#   'DenominatorUnweighted': 26677.0,
#   'DenominatorWeighted': 25693.0,
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 0,
#   'LevelRank': ''},
#  {'DataId': 53955,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Previous birth interval: 18-23 months',
#   'IsPreferred': 1,
#   'Value': 20.7,
#   'SDRID': 'FEBINTCI18',
#   'Precision': 1,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 11936020,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'I',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'FE_BINT_C_I18',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': '',
#   'DenominatorUnweighted': 26677.0,
#   'DenominatorWeighted': 25693.0,
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 0,
#   'LevelRank': ''},
#  {'DataId': 53953,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Previous birth interval: 24-35 months',
#   'IsPreferred': 1,
#   'Value': 35.5,
#   'SDRID': 'FEBINTCI24',
#   'Precision': 1,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 11936030,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'I',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'FE_BINT_C_I24',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': '',
#   'DenominatorUnweighted': 26677.0,
#   'DenominatorWeighted': 25693.0,
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 0,
#   'LevelRank': ''},
#  {'DataId': 53957,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Previous birth interval: 36-47 months',
#   'IsPreferred': 1,
#   'Value': 16.4,
#   'SDRID': 'FEBINTCI36',
#   'Precision': 1,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 11936040,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'I',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'FE_BINT_C_I36',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': '',
#   'DenominatorUnweighted': 26677.0,
#   'DenominatorWeighted': 25693.0,
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 0,
#   'LevelRank': ''},
#  {'DataId': 53958,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Previous birth interval: 48-59 months',
#   'IsPreferred': 1,
#   'Value': 7.9,
#   'SDRID': 'FEBINTCI48',
#   'Precision': 1,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 11936050,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'I',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'FE_BINT_C_I48',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': '',
#   'DenominatorUnweighted': 26677.0,
#   'DenominatorWeighted': 25693.0,
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 0,
#   'LevelRank': ''},
#  {'DataId': 53959,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Previous birth interval: 60+ months',
#   'IsPreferred': 1,
#   'Value': 7.8,
#   'SDRID': 'FEBINTCI60',
#   'Precision': 1,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 11936060,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'I',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'FE_BINT_C_I60',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': '',
#   'DenominatorUnweighted': 26677.0,
#   'DenominatorWeighted': 25693.0,
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 0,
#   'LevelRank': ''},
#  {'DataId': 53960,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Previous birth interval: Total',
#   'IsPreferred': 1,
#   'Value': 100.0,
#   'SDRID': 'FEBINTCTOT',
#   'Precision': 1,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 11936070,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'T',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'FE_BINT_C_TOT',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': '',
#   'DenominatorUnweighted': 26677.0,
#   'DenominatorWeighted': 25693.0,
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 0,
#   'LevelRank': ''},
#  {'DataId': 678647,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Number of non-first births',
#   'IsPreferred': 1,
#   'Value': 25693.0,
#   'SDRID': 'FEBINTCNUM',
#   'Precision': 0,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 11936080,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'D',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'FE_BINT_C_NUM',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': '',
#   'DenominatorUnweighted': 26677.0,
#   'DenominatorWeighted': '',
# ...
#   'Precision': 1,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 83566030,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'I',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'RH_DELP_C_HOM',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': 'Five years preceding the survey',
#   'DenominatorUnweighted': 32712.0,
#   'DenominatorWeighted': 31802.0,
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 14001,
#   'LevelRank': ''},
#  {'DataId': 344343,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Place of delivery: At home',
#   'IsPreferred': 0,
#   'Value': 44.7,
#   'SDRID': 'RHDELPCHOM',
#   'Precision': 1,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 83566030,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'I',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'RH_DELP_C_HOM',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': 'Two years preceding the survey',
#   'DenominatorUnweighted': 12291.0,
#   'DenominatorWeighted': 12068.0,
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 14002,
#   'LevelRank': ''},
#  {'DataId': 397482,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Place of delivery: Other',
#   'IsPreferred': 0,
#   'Value': 0.6,
#   'SDRID': 'RHDELPCOTH',
#   'Precision': 1,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 83566040,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'I',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'RH_DELP_C_OTH',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': 'Three years preceding the survey',
#   'DenominatorUnweighted': 19391.0,
#   'DenominatorWeighted': 19021.0,
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 14000,
#   'LevelRank': ''},
#  {'DataId': 283909,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Place of delivery: Other',
#   'IsPreferred': 1,
#   'Value': 0.6,
#   'SDRID': 'RHDELPCOTH',
#   'Precision': 1,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 83566040,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'I',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'RH_DELP_C_OTH',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': 'Five years preceding the survey',
#   'DenominatorUnweighted': 32712.0,
#   'DenominatorWeighted': 31802.0,
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 14001,
#   'LevelRank': ''},
#  {'DataId': 344344,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Place of delivery: Other',
#   'IsPreferred': 0,
#   'Value': 0.6,
#   'SDRID': 'RHDELPCOTH',
#   'Precision': 1,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 83566040,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'I',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'RH_DELP_C_OTH',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': 'Two years preceding the survey',
#   'DenominatorUnweighted': 12291.0,
#   'DenominatorWeighted': 12068.0,
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 14002,
#   'LevelRank': ''},
#  {'DataId': 397483,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': "Place of delivery: don't know or missing",
#   'IsPreferred': 0,
#   'Value': 0.3,
#   'SDRID': 'RHDELPCDKM',
#   'Precision': 1,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 83566050,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'S',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'RH_DELP_C_DKM',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': 'Three years preceding the survey',
#   'DenominatorUnweighted': 19391.0,
#   'DenominatorWeighted': 19021.0,
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 14000,
#   'LevelRank': ''},
#  {'DataId': 283910,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': "Place of delivery: don't know or missing",
#   'IsPreferred': 1,
#   'Value': 0.4,
#   'SDRID': 'RHDELPCDKM',
#   'Precision': 1,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 83566050,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'S',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'RH_DELP_C_DKM',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': 'Five years preceding the survey',
#   'DenominatorUnweighted': 32712.0,
#   'DenominatorWeighted': 31802.0,
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 14001,
#   'LevelRank': ''},
#  {'DataId': 344348,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': "Place of delivery: don't know or missing",
#   'IsPreferred': 0,
#   'Value': 0.3,
#   'SDRID': 'RHDELPCDKM',
#   'Precision': 1,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 83566050,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'S',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'RH_DELP_C_DKM',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': 'Two years preceding the survey',
#   'DenominatorUnweighted': 12291.0,
#   'DenominatorWeighted': 12068.0,
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 14002,
#   'LevelRank': ''},
#  {'DataId': 397475,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Place of delivery: Total',
#   'IsPreferred': 0,
#   'Value': 100.0,
#   'SDRID': 'RHDELPCTOT',
#   'Precision': 1,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 83566060,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'T',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'RH_DELP_C_TOT',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': 'Three years preceding the survey',
#   'DenominatorUnweighted': 19391.0,
#   'DenominatorWeighted': 19021.0,
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 14000,
#   'LevelRank': ''},
#  {'DataId': 283905,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Place of delivery: Total',
#   'IsPreferred': 1,
#   'Value': 100.0,
#   'SDRID': 'RHDELPCTOT',
#   'Precision': 1,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 83566060,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'T',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'RH_DELP_C_TOT',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': 'Five years preceding the survey',
#   'DenominatorUnweighted': 32712.0,
#   'DenominatorWeighted': 31802.0,
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 14001,
#   'LevelRank': ''},
#  {'DataId': 344346,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Place of delivery: Total',
#   'IsPreferred': 0,
#   'Value': 100.0,
#   'SDRID': 'RHDELPCTOT',
#   'Precision': 1,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 83566060,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'T',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'RH_DELP_C_TOT',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': 'Two years preceding the survey',
#   'DenominatorUnweighted': 12291.0,
#   'DenominatorWeighted': 12068.0,
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 14002,
#   'LevelRank': ''},
#  {'DataId': 397473,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Place of delivery: Health facility',
#   'IsPreferred': 0,
#   'Value': 51.8,
#   'SDRID': 'RHDELPCDHF',
#   'Precision': 1,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 83566070,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'I',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'RH_DELP_C_DHF',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': 'Three years preceding the survey',
#   'DenominatorUnweighted': 19391.0,
#   'DenominatorWeighted': 19021.0,
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 14000,
#   'LevelRank': ''},
#  {'DataId': 283906,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Place of delivery: Health facility',
#   'IsPreferred': 1,
#   'Value': 48.1,
#   'SDRID': 'RHDELPCDHF',
#   'Precision': 1,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 83566070,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'I',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'RH_DELP_C_DHF',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': 'Five years preceding the survey',
#   'DenominatorUnweighted': 32712.0,
#   'DenominatorWeighted': 31802.0,
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 14001,
#   'LevelRank': ''},
#  {'DataId': 344345,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Place of delivery: Health facility',
#   'IsPreferred': 0,
#   'Value': 54.3,
#   'SDRID': 'RHDELPCDHF',
#   'Precision': 1,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 83566070,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'I',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'RH_DELP_C_DHF',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': 'Two years preceding the survey',
#   'DenominatorUnweighted': 12291.0,
#   'DenominatorWeighted': 12068.0,
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 14002,
#   'LevelRank': ''},
#  {'DataId': 395145,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Number of live births in the last five (or three) years',
#   'IsPreferred': 0,
#   'Value': 19021.0,
#   'SDRID': 'RHDELPCNUM',
#   'Precision': 0,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 83566080,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'D',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'RH_DELP_C_NUM',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': 'Three years preceding the survey',
#   'DenominatorUnweighted': 19391.0,
#   'DenominatorWeighted': '',
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 14000,
#   'LevelRank': ''},
#  {'DataId': 292376,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Number of live births in the last five (or three) years',
#   'IsPreferred': 1,
#   'Value': 31802.0,
#   'SDRID': 'RHDELPCNUM',
#   'Precision': 0,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 83566080,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'D',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'RH_DELP_C_NUM',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': 'Five years preceding the survey',
#   'DenominatorUnweighted': 32712.0,
#   'DenominatorWeighted': '',
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 14001,
#   'LevelRank': ''},
#  {'DataId': 344347,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Number of live births in the last five (or three) years',
#   'IsPreferred': 0,
#   'Value': 12068.0,
#   'SDRID': 'RHDELPCNUM',
#   'Precision': 0,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 83566080,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'D',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'RH_DELP_C_NUM',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': 'Two years preceding the survey',
#   'DenominatorUnweighted': 12291.0,
#   'DenominatorWeighted': '',
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 14002,
#   'LevelRank': ''},
#  {'DataId': 174955,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Number of live births in the last five (or three) years (unweighted)',
#   'IsPreferred': 0,
#   'Value': 19391.0,
#   'SDRID': 'RHDELPCUNW',
#   'Precision': 0,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 83566090,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'U',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'RH_DELP_C_UNW',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': 'Three years preceding the survey',
#   'DenominatorUnweighted': '',
#   'DenominatorWeighted': 19021.0,
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 14000,
#   'LevelRank': ''},
#  {'DataId': 95480,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Number of live births in the last five (or three) years (unweighted)',
#   'IsPreferred': 1,
#   'Value': 32712.0,
#   'SDRID': 'RHDELPCUNW',
#   'Precision': 0,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 83566090,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'U',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'RH_DELP_C_UNW',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': 'Five years preceding the survey',
#   'DenominatorUnweighted': '',
#   'DenominatorWeighted': 31802.0,
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 14001,
#   'LevelRank': ''},
#  {'DataId': 679046,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Number of live births in the last five (or three) years (unweighted)',
#   'IsPreferred': 0,
#   'Value': 12291.0,
#   'SDRID': 'RHDELPCUNW',
#   'Precision': 0,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 83566090,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'U',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'RH_DELP_C_UNW',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': 'Two years preceding the survey',
#   'DenominatorUnweighted': '',
#   'DenominatorWeighted': 12068.0,
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 14002,
#   'LevelRank': ''},
#  {'DataId': 32722,
#   'SurveyId': 'AF2015DHS',
#   'Indicator': 'Assistance during delivery: Doctor',
#   'IsPreferred': 0,
#   'Value': 18.5,
#   'SDRID': 'RHDELACDOC',
#   'Precision': 1,
#   'RegionId': '',
#   'SurveyYearLabel': '2015',
#   'SurveyType': 'DHS',
#   'SurveyYear': 2015,
#   'IndicatorOrder': 83606010,
#   'DHS_CountryCode': 'AF',
#   'CILow': '',
#   'CountryName': 'Afghanistan',
#   'IndicatorType': 'I',
#   'CharacteristicId': 1000,
#   'CharacteristicCategory': 'Total',
#   'IndicatorId': 'RH_DELA_C_DOC',
#   'CharacteristicOrder': 0,
#   'CharacteristicLabel': 'Total',
#   'ByVariableLabel': 'Three years preceding the survey',
#   'DenominatorUnweighted': 19391.0,
#   'DenominatorWeighted': 19021.0,
#   'CIHigh': '',
#   'IsTotal': 1,
#   'ByVariableId': 14000,
#   'LevelRank': ''},
#  ...]

# %%
for i in range(4000):#len(dataflows['data']['dataflows'])):
    code = {key: my_data['data'][i][key] for key in my_data['data'][i].keys()
              & {'DataId', 'SurveyId', 'Indicator', 'SDRID','SurveyYearLabel','SurveyType','DHS_CountryCode','CountryName','CharacteristicCategory','IndicatorId'}}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\10235555\Documents\DataportalCrawlers\UN_Data\DHS_program.ipynb Cell 11 in 2
#       <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/DHS_program.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> for i in range(4000):#len(dataflows['data']['dataflows'])):
# ----> <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/DHS_program.ipynb#X15sZmlsZQ%3D%3D?line=1'>2</a>     code = {key: my_data['data'][i][key] for key in my_data['data'][i].keys()
#       <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/DHS_program.ipynb#X15sZmlsZQ%3D%3D?line=2'>3</a>               & {'DataId', 'SurveyId', 'Indicator', 'SDRID','SurveyYearLabel','SurveyType','DHS_CountryCode','CountryName','CharacteristicCategory','IndicatorId'}}
#
# TypeError: list indices must be integers or slices, not str

# %%
df_ind_DHS = pd.DataFrame(my_data)

# %%
df_ind_DHS.to_csv('C:\\Users\\10235555\\Documents\\Dataportal Data\\indicators.csv',index=False)

# %%
import json
import urllib.request
aspects = []
links = []
result = requests.get('https://api.dhsprogram.com/#/index.html')
soup = BeautifulSoup(result.content,'html.parser')
url = 'https://api.dhsprogram.com/'
side = soup.find(class_='SideNavDiv')
list_side = side.find(class_='navList')
list_apiRef = list_side.find('ul')
elems_apiref = list_apiRef.find_all('a')#[2]['href']
for elem in elems_apiref:
    aspect = elem.text
    aspects.append(aspect)
    link = url + elem['href']
    links.append(link)
links = [links[3]] + links[5:7] + links[8:10]
aspects = [aspects[3]] + aspects[5:7] + [aspects[8:10]]
# link_indic_data = url + indic_data
# link_indic_data

# %%
concept = driver.find_element(By.CLASS_NAME,'apiText').text
concept.text
# Out:
# 'Provides a list of surveys characteristics that are provided to facilitate the identification of any non-standard questions or modules which are not included in the core questionnaires. These non-standard questions or modules are developed to address country-specific issues in a survey.'

# %%
links
# Out:
# ['https://api.dhsprogram.com/#/api-indicators.cfm',
#  'https://api.dhsprogram.com/#/api-surveys.cfm',
#  'https://api.dhsprogram.com/#/api-surveycharacteristics.cfm',
#  'https://api.dhsprogram.com/#/api-datasets.cfm',
#  'https://api.dhsprogram.com/#/api-geometry.cfm']

# %%
for i in range(len(links)):
    # link = links[i]
    driver.get(links[i])
    time.sleep(3)
    aspect = aspects[i]
    # cookies = driver.find_element(By.CLASS_NAME,'cc-compliance').find_element(By.TAG_NAME,'a')
    # cookies.click()
    time.sleep(5)
    concept = driver.find_element(By.CLASS_NAME,'apiText').text
    api_urls = driver.find_elements(By.CLASS_NAME,'apiReferenceURL')[0].text
    # data = api_urls[0].text
    print(api_urls)
    # driver.get(data)
    # page_source = driver.page_source               
    # soup_indic_DHS = BeautifulSoup(page_source, 'html.parser')
    req = urllib.request.urlopen(api_urls)
    time.sleep(1)
    resp = json.loads(req.read())
    time.sleep(5)
    my_data = resp['Data']
    df_data = pd.DataFrame(my_data)
    df_data.to_csv(f'{base_path}\\{aspect}.csv',index=False)
    contents = driver.find_elements(By.CLASS_NAME,"apiText")
    fields = contents[1].find_element(By.TAG_NAME,'a').get_attribute('href')
    res_fields = requests.get(fields)            
    soup_fields = BeautifulSoup(res_fields.content, 'html.parser')
    rows = soup_fields.find_all('tr')
    l = []
    for tr in rows[2:]:
        cells = tr.find_all(['td','th'])
        cells_text = [cell.get_text(strip=True) for cell in cells]
        l.append(cells_text)
    df = pd.DataFrame(l).iloc[:,1:]
    desc = []
    for i in range(len(df.index)):
        f = df.iloc[i].to_list()
        f = [' : '.join(map(str,f))]
        desc.append(f[0])
    descr = [' , '.join(map(str,desc))]
    driver.back()
# Out:
# https://api.dhsprogram.com/rest/dhs/indicators
# https://api.dhsprogram.com/rest/dhs/countries
# https://api.dhsprogram.com/rest/dhs/surveys
# https://api.dhsprogram.com/rest/dhs/surveycharacteristics
# https://api.dhsprogram.com/rest/dhs/datasets

# %%
links
# Out:
# ['https://api.dhsprogram.com/#/api-indicators.cfm',
#  'https://api.dhsprogram.com/#/api-countries.cfm',
#  'https://api.dhsprogram.com/#/api-surveys.cfm',
#  'https://api.dhsprogram.com/#/api-surveycharacteristics.cfm',
#  'https://api.dhsprogram.com/#/api-datasets.cfm']

# %%
api_urls = driver.find_elements(By.CLASS_NAME,'apiReferenceURL')
data_DHS = api_urls[0].text
data_DHS
# Out:
# 'https://api.dhsprogram.com/rest/dhs/surveycharacteristics'

# %%
import requests
from bs4 import BeautifulSoup
import wget
import logging
from RequestInferSchemaToJsonAPI.main import TriggerInferShemaToJsonAPI
import os
import urllib.request
from urllib import request
import pdfplumber
import tabula 
import csv
import pandas as pd
from unidecode import unidecode
import pandas as pd
base_path='C:\\Users\\10235555\\Documents\\Dataportal Data\\DHS Program'

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import ElementNotInteractableException, NoSuchElementException
from selenium.common.exceptions import ElementClickInterceptedException
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from webdriver_manager.firefox import GeckoDriverManager
from selenium.webdriver.firefox.options import Options
from bs4 import BeautifulSoup
import shutil
import time
import os
import json
import urllib.request
from pyshadow.main import Shadow
from py7zr import unpack_7zarchive
from RequestInferSchemaToJsonAPI.main import TriggerInferShemaToJsonAPI

chrome_options = webdriver.ChromeOptions()
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
driver.maximize_window()

result = requests.get('https://api.dhsprogram.com/#/index.html')
soup = BeautifulSoup(result.content,'html.parser')
url = 'https://api.dhsprogram.com/'
side = soup.find(class_='SideNavDiv')
list_side = side.find(class_='navList')
list_apiRef = list_side.find('ul')
aspect = list_apiRef.find_all('a')[2].text
indic_data = list_apiRef.find_all('a')[2]['href']
link_indic_data = url + indic_data

driver.get(link_indic_data)
time.sleep(2)

api_urls = driver.find_elements(By.CLASS_NAME,'apiReferenceURL')
data_DHS = api_urls[10].text
req = urllib.request.urlopen(data_DHS)
resp = json.loads(req.read())
my_data = resp['Data']
df_data = pd.DataFrame(my_data)
df_data.dropna(axis='columns', how='all')
df_data.to_csv(f'{base_path}\\{aspect}.csv',index=False)

contents = driver.find_elements(By.CLASS_NAME,"apiText")
concept = contents[0].text
fields = contents[1].find_element(By.TAG_NAME,'a').get_attribute('href')
res_fields = requests.get(fields)            
soup_fields = BeautifulSoup(res_fields.content, 'html.parser')
rows = soup_fields.find_all('tr')
l = []
for tr in rows[2:]:
    cells = tr.find_all(['td','th'])
    cells_text = [cell.get_text(strip=True) for cell in cells]
    l.append(cells_text)
df = pd.DataFrame(l).iloc[:,1:]
desc = []
for i in range(len(df.index)):
    f = df.iloc[i].to_list()
    f = [' : '.join(map(str,f))]
    desc.append(f[0])
descr = [' , '.join(map(str,desc))][0]

try:
    BodyDict = {
    "JobPath":f'C:/Users/10235555/Documents/Dataportal Data/DHS Program/{aspect}.csv', #* Point to downloaded data for conversion 
    "JsonDetails":{
            ## Required
            "organisation": "third-parties",
            "source": "DHSProgram",
            "source_description" : "The Demographic and Health Surveys (DHS) Program has collected, analyzed, and disseminated accurate and representative data on population, health, HIV, and nutrition through more than 300 surveys in over 90 countries.",
            "source_url" : "https://api.dhsprogram.com/#/index.html",
            "table" : aspect,
            "description" : descr, 
            ## Optional
            "JobType": "JSON",
            "CleanPush": True,
            "Server": "str",
            "UseJsonFormatForSQL":  False,
            "CleanReplace":True,
            "MergeSchema": False,
            "tags": [{
                "name": aspect
            }],
            "additional_data_sources": [{
                "name": "",
                "url" : ""
            }],
            "limitations":"",
            "concept": concept,
            "periodicity":  "",
            "topic":  aspect,
            "created": "",                       #* this should follow the following formats %Y-%m-%dT%H:%M:%S" or "%Y-%m-%d"
            "last_modified": "",                #* ""               ""                  ""              ""
            "TriggerTalend" :  False,    #* initialise to True for production
            "SavePathForJsonOutput": "//10.30.31.77/data_collection_dump/TestData" #* initialise as empty string for production.
        }
    }
    TriggerInferShemaToJsonAPIClass = TriggerInferShemaToJsonAPI(BodyDict=BodyDict)
    TriggerInferShemaToJsonAPIClass.TriggerAPI()
    logging.info(f"Conversion successful - {aspect} ")
    print(BodyDict)
except  Exception as err:
    print(err)


aspects = []
links = []
result = requests.get('https://api.dhsprogram.com/#/index.html')
soup = BeautifulSoup(result.content,'html.parser')
url = 'https://api.dhsprogram.com/'
side = soup.find(class_='SideNavDiv')
list_side = side.find(class_='navList')
list_apiRef = list_side.find('ul')
elems_apiref = list_apiRef.find_all('a')#[2]['href']
for elem in elems_apiref:
    aspect = elem.text
    aspects.append(aspect)
    link = url + elem['href']
    links.append(link)
links = [links[3]] + links[5:7] + links[8:10]
aspects = [aspects[3]] + aspects[5:7] + aspects[8:10]

for i in range(len(links)):
    # link = links[i]
    driver.get(links[i])
    time.sleep(3)
    aspect = aspects[i]
    # cookies = driver.find_element(By.CLASS_NAME,'cc-compliance').find_element(By.TAG_NAME,'a')
    # cookies.click()
    time.sleep(5)
    concept = driver.find_element(By.CLASS_NAME,'apiText').text
    api_urls = driver.find_elements(By.CLASS_NAME,'apiReferenceURL')[0].text
    print(api_urls)
    req = urllib.request.urlopen(api_urls)
    time.sleep(1)
    resp = json.loads(req.read())
    time.sleep(5)
    my_data = resp['Data']
    df_data = pd.DataFrame(my_data)
    df_data.dropna(axis='columns', how='all')
    df_data.to_csv(f'{base_path}\\{aspect}.csv',index=False)
    contents = driver.find_elements(By.CLASS_NAME,"apiText")
    fields = contents[1].find_element(By.TAG_NAME,'a').get_attribute('href')
    res_fields = requests.get(fields)            
    soup_fields = BeautifulSoup(res_fields.content, 'html.parser')
    rows = soup_fields.find_all('tr')
    l = []
    for tr in rows[2:]:
        cells = tr.find_all(['td','th'])
        cells_text = [cell.get_text(strip=True) for cell in cells]
        l.append(cells_text)
    df = pd.DataFrame(l).iloc[:,1:]
    desc = []
    for i in range(len(df.index)):
        f = df.iloc[i].to_list()
        f = [' : '.join(map(str,f))]
        desc.append(f[0])
    descr = [' , '.join(map(str,desc))][0]
    try:
        BodyDict = {
        "JobPath":f'//10.30.31.77/data_collection_dump/RawData/DHS_program/{aspect}.csv', #* Point to downloaded data for conversion 
        "JsonDetails":{
                ## Required
                "organisation": "third-parties",
                "source": "DHS Program",
                "source_description" : "The Demographic and Health Surveys (DHS) Program has collected, analyzed, and disseminated accurate and representative data on population, health, HIV, and nutrition through more than 300 surveys in over 90 countries.",
                "source_url" : "https://api.dhsprogram.com/#/index.html",
                "table" : aspect,
                "description" : descr, 
                ## Optional
                "JobType": "JSON",
                "CleanPush": True,
                "Server": "str",
                "UseJsonFormatForSQL":  False,
                "CleanReplace":True,
                "MergeSchema": False,
                "tags": [{
                    "name": aspect
                }],
                "additional_data_sources": [{
                    "name": "",
                    "url" : ""
                }],
                "limitations":"",
                "concept":  concept,
                "periodicity":  "",
                "topic":  aspect,
                "created": "",                       #* this should follow the following formats %Y-%m-%dT%H:%M:%S" or "%Y-%m-%d"
                "last_modified": "",                #* ""               ""                  ""              ""
                "TriggerTalend" :  False,    #* initialise to True for production
                "SavePathForJsonOutput": "//10.30.31.77/data_collection_dump/TestData" #* initialise as empty string for production.
            }
        }
        TriggerInferShemaToJsonAPIClass = TriggerInferShemaToJsonAPI(BodyDict=BodyDict)
        TriggerInferShemaToJsonAPIClass.TriggerAPI()
        logging.info(f"Conversion successful - {aspect} ")
        print(BodyDict)
    except  Exception as err:
        print(err)
# Out:
# {'JobPath': 'C:/Users/10235555/Documents/Dataportal Data/DHS Program/Indicator Data.csv', 'JsonDetails': {'organisation': 'third-parties', 'source': 'DHSProgram', 'source_description': 'The Demographic and Health Surveys (DHS) Program has collected, analyzed, and disseminated accurate and representative data on population, health, HIV, and nutrition through more than 300 surveys in over 90 countries.', 'source_url': 'https://api.dhsprogram.com/#/index.html', 'table': 'Indicator Data', 'description': "fieldname : fieldDescription , DataId : A unique numeric record ID corresponding to the data record provided. , Indicator : The name or label of the particular indicator for this data. , Value : The actual value (percentage, rate, number, etc.) of the particular indicator specified. The value can be used to provide statistics to users. , Precision : The number of decimal places that should be presented for value of the indicator. , DHS_CountryCode : Two-letter DHS specific country code. , CountryName : DHS specific country name. , SurveyYear : The principal year in which the survey was conducted. , SurveyId : DHS survey ID. Each survey will always have a unique ID (of the form ccyyyyttt where cc is the DHS country code,\n\t\t\t\t\t\t\t\t\tyyyy is the survey year, and ttt is the survey type) and can be used to obtain national or subnational data for a particular survey. , IndicatorId : Indicator ID for the indicator specified for the particular data. , IndicatorOrder : Indicator Order for the indicator specified for the particular data. , IndicatorType : Indicator Type for the indicator specified for the particular data. , CharacteristicId : DHS has defined a list of characteristics that are used across surveys to make sure the data can be compared across countries\n\t\t\t\t\t\t\t\tvery easily. A characteristic ID gives you the unique ID that represents that particular characteristic. , CharacteristicOrder : Sort order in which to display characteristics. , CharacteristicCategory : DHS has defined a list of characteristic categories that are used across surveys to make sure the data can be compared across\n\t\t\t\t\t\t\t\tcountries very easily. This category can be used to filter data. See also CharacteristicLabel. , CharacteristicLabel : This field provides label of the characteristic within a particular characteristic category. For example, Urban and Rural are the two\n\t\t\t\t\t\t\t\tcharacteristics within the category Residence. , ByVariableId : A characteristic ID identifying a further level of disaggregation, when an indicator is disaggregated in multiple ways. For example,\n\t\t\t\t\t\t\t\tCurrent Use of Contraception is disaggregated by Age, but also for All women, currently married women and sexually active unmarried\n\t\t\t\t\t\t\t\twomen. Age is presented in the characteristic category above; the disaggregation for All women, currently married women and sexually\n\t\t\t\t\t\t\t\tactive unmarried women is captured in the ByVariableId and ByVariableLabel. If this additional level of disaggregation is not used\n\t\t\t\t\t\t\t\tfor the indicator the ByVariableId will be 0 and the ByVariableLabel will be blank. A common use of the ByVariableId and\n\t\t\t\t\t\t\t\tByVariable... , ByVariableLabel : The descriptive label for the level of disaggregation provided in the ByVariableId. , IsTotal : This column will identify if a certain value is a Total value used for national totals. , IsPreferred : If a particular indicator has multiple values because it is disaggregated in multiple ways, this column will identify which is\n\t\t\t\t\t\t\t\tthe preferred value to display by default. , SDRID : ID used in The DHS Program Spatial Data Repository (SDR). , RegionId : Unique ID given to each survey and region. , SurveyYearLabel : The Survey Year Label can provide slightly more details about a survey's year.\n\t\t\t\t\t\t\t\tFor example if a survey started in 1998 and finished in 1999, the survey year\n\t\t\t\t\t\t\t\twould be 1998 while  ...
# https://api.dhsprogram.com/rest/dhs/indicators
# {'JobPath': '//10.30.31.77/data_collection_dump/RawData/DHS_program/Indicators.csv', 'JsonDetails': {'organisation': 'third-parties', 'source': 'DHSProgram', 'source_description': 'The Demographic and Health Surveys (DHS) Program has collected, analyzed, and disseminated accurate and representative data on population, health, HIV, and nutrition through more than 300 surveys in over 90 countries.', 'source_url': 'https://api.dhsprogram.com/#/index.html', 'table': 'Indicators', 'description': "fieldname : fieldDescription , IndicatorId : Indicator ID for the specified indicator. Each indicator will always have a unique ID and can be used across surveys. , Label : Indicator label describing the specified indicator. , Definition : Provides a definition of the specified indicator. The definition can be used to provide detailed information to your users. , Denominator : Provides a definition of the denominator of the specified indicator. The denominator definition can be used to provide detailed information to your users. , Level1 : Each indicator is grouped in a three level hierarchy. This column provides the top level grouping and is the major subject area. , Level2 : Each indicator is grouped in a three level hierarchy. This column provides the second level grouping and is the topic area within the major subject. , Level3 : Each indicator is grouped in a three level hierarchy. This column provides the third level grouping and is the universe for the topic (typically Women, Men, Both Sexes, Children, Households, Population). , ShortName : Provides a short name for the specified indicator that can be\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tused when displaying the indicator within the hierarchy level if the indicator label is\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\ttoo long. If space is available we recommend using the indicator label. , MeasurementType : Specifies the type of measurement.MeanMedianNumberPercentRate , IndicatorType : Type of indicator:I = IndicatorD = Weighted denominatorU = Unweighted denominatorT = Distribution total (100%)S = Special answers (don't know/missing)E = Sampling errorsC = Confidence interval , NumberScale : Number Scale provides the precision (number of decimal places) that should be presented for the indicator. , IndicatorOrder : Indicator Order is used for ordering indicators within the levels. , TagIds : A list of tag IDs for selecting indicators according to tagged groups.  See the tags list for\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tthe descriptions associated with each ID. , IsQuickStat : This column will display a '1' for DHS Quickstat indicators that are used or viewed most often. The information can be utilized to serve the most common data to users quickly. , QuickStatOrder : This column will provide an integer to help provide a special sort order for all the Quickstat Indicators. These are indicators that display a '1' in the IsQuickStat column and are used or viewed most often. The information can be utilized to serve the most common data to users quickly. , SDRID : This column contains the Spatial Data Repository Indicator ID.", 'JobType': 'JSON', 'CleanPush': True, 'Server': 'str', 'UseJsonFormatForSQL': False, 'CleanReplace': True, 'MergeSchema': False, 'tags': [{'name': 'Indicators'}], 'additional_data_sources': [{'name': '', 'url': ''}], 'limitations': '', 'concept': 'Thousands of indicators are available from each survey. This component provides you a list of these indicators.', 'periodicity': '', 'topic': 'Indicators', 'created': '', 'last_modified': '', 'TriggerTalend': False, 'SavePathForJsonOutput': '//10.30.31.77/data_collection_dump/TestData/IPU'}}
# https://api.dhsprogram.com/rest/dhs/surveys
# {'JobPath': '//10.30.31.77/data_collection_dump/RawData/DHS_program/Surveys.csv', 'JsonDetails': {'organisation': 'third-parties', 'source': 'DHSProgram', 'source_description': 'The Demographic and Health Surveys (DHS) Program has collected, analyzed, and disseminated accurate and representative data on population, health, HIV, and nutrition through more than 300 surveys in over 90 countries.', 'source_url': 'https://api.dhsprogram.com/#/index.html', 'table': 'Surveys', 'description': 'fieldname : fieldDescription , SurveyId : DHS survey ID. Each survey will always have a unique ID (of the form ccyyyyttt where\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tcc is the DHS country code, yyyy is the survey year, and ttt is the survey type) and can\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tbe used to obtain national or subnational data for a particular survey. , DHS_CountryCode : Two-letter DHS specific country code. , CountryName : DHS specific country name. , SurveyYear : The principal year in which the survey was conducted. , SurveyYearLabel : The survey year label provides the range of years in which the fieldwork took place.\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tFor example if a survey started in 1998 and finished in 1999, the survey year would\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tbe 1998 while the survey year label would provide 1998-99. This information could be\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tused to make the user interface more intuitive and accurate. , SurveyType : The survey type determines whether the survey was a DHS, AIS, MIS, SPA, or other (OTH) type of survey. , SurveyStatus : Specifies whether the survey is ongoing or completed. , SurveyNum : Unique numeric id assigned to each survey. , IndicatorData : Whether indicator data is available for this survey (1) or not (0). , RegionName : The region name for the surveys (countries) returned as a result of a specific query.\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tE.g. region name for Egypt is North Africa/West Asia/Europe , SubRegionName : The sub region name for the surveys (countries) returned as a result of a specific query.\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tE.g. Egypt is in the North Africa sub region. , PublicationDate : Date specifying when the survey data was published. , ReleaseDate : Date specifying when the survey data was made available. , SurveyCharacteristicIds : A list of IDs for the survey characteristics that includes additional topics,\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tmodules or features that were included in the survey beyond the standard.\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tSee the survey characteristics for the descriptions associated with each ID. , FieldworkStart : The month and year of the start of fieldwork for the survey (note: day is always returned as 1). , FieldworkEnd : The month and year of the end of fieldwork for the survey (note: day is always returned as 1). , Footnotes : Footnotes about the survey. , ImplementingOrg : The name of the implementing organization(s) for the survey. , NumberOfSamplePoints : The number of sample points (or clusters/enumeration areas) visited in the survey. , NumberOfHouseholds : The total number of households interviewed in the survey. , UniverseOfWomen : The universe of women interviewed: All Women or Ever Married Women. , NumberOfWomen : The total number of women interviewed in the survey. , MinAgeWomen : The minimum age of women included in the survey (typically 15 years). , MaxAgeWomen : The maximum age of women included in the survey (typically 49 years). , UniverseOfMen : The universe of men interviewed: All Men, Ever Married Men, or Husbands. , NumberOfMen : The total number of men interviewed in the survey. , MinAgeMen : The minimum age of men included in the survey (typically 15 years). , MaxAgeMen : The maximum age of men included in the survey (typically 49/54/59/64 years). , NumberOfFacilities : For SPA or service availability surveys, the number of health facilities visi ...
# https://api.dhsprogram.com/rest/dhs/surveycharacteristics
# {'JobPath': '//10.30.31.77/data_collection_dump/RawData/DHS_program/Survey Characteristics.csv', 'JsonDetails': {'organisation': 'third-parties', 'source': 'DHSProgram', 'source_description': 'The Demographic and Health Surveys (DHS) Program has collected, analyzed, and disseminated accurate and representative data on population, health, HIV, and nutrition through more than 300 surveys in over 90 countries.', 'source_url': 'https://api.dhsprogram.com/#/index.html', 'table': 'Survey Characteristics', 'description': 'fieldname : fieldDescription , SurveyCharacteristicID : Numeric survey characteristic ID. , SurveyCharacteristicName : Name of the survey characteristic (topic, module, or feature) , SurveyCharacteristicType : Module (m), Feature (f), Biomarker (b)', 'JobType': 'JSON', 'CleanPush': True, 'Server': 'str', 'UseJsonFormatForSQL': False, 'CleanReplace': True, 'MergeSchema': False, 'tags': [{'name': 'Survey Characteristics'}], 'additional_data_sources': [{'name': '', 'url': ''}], 'limitations': '', 'concept': 'Provides a list of surveys characteristics that are provided to facilitate the identification of any non-standard questions or modules which are not included in the core questionnaires. These non-standard questions or modules are developed to address country-specific issues in a survey.', 'periodicity': '', 'topic': 'Survey Characteristics', 'created': '', 'last_modified': '', 'TriggerTalend': False, 'SavePathForJsonOutput': '//10.30.31.77/data_collection_dump/TestData/IPU'}}
# https://api.dhsprogram.com/rest/dhs/datasets
# {'JobPath': '//10.30.31.77/data_collection_dump/RawData/DHS_program/Datasets.csv', 'JsonDetails': {'organisation': 'third-parties', 'source': 'DHSProgram', 'source_description': 'The Demographic and Health Surveys (DHS) Program has collected, analyzed, and disseminated accurate and representative data on population, health, HIV, and nutrition through more than 300 surveys in over 90 countries.', 'source_url': 'https://api.dhsprogram.com/#/index.html', 'table': 'Datasets', 'description': 'fieldname : fieldDescription , FileName : The name for the download zip file. , DHS_CountryCode : Two-letter DHS specific country code. , CountryName : DHS specific country name. , SurveyYear : The principal year in which the survey was conducted. , SurveyYearLabel : The survey year label provides the range of years in which the fieldwork took place.\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tFor example if a survey started in 1998 and finished in 1999, the survey year would\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tbe 1998 while the survey year label would provide 1998-99. This information could be\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tused to make the user interface more intuitive and accurate. , SurveyType : The survey type determines whether the survey was a DHS, AIS, MIS, SPA, or other (OTH) type of survey. , SurveyId : DHS survey ID. Each survey will always have a unique ID (of the form ccyyyyttt where\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tcc is the DHS country code, yyyy is the survey year, and ttt is the survey type) and can\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tbe used to obtain national or subnational data for a particular survey. , SurveyNum : Unique numeric id assigned to each survey. , DatasetType : The dataset type determines whether the survey is Geographc data or Survey Data. , FileType : The type of dataset generated for the survey. , FileFormat : The available file format for the survey (SAS, Stata, CSPro, SPSS). , FileSize : The size of the file. , FileDateLastModified : Date specifying when the survey data was last modified.', 'JobType': 'JSON', 'CleanPush': True, 'Server': 'str', 'UseJsonFormatForSQL': False, 'CleanReplace': True, 'MergeSchema': False, 'tags': [{'name': 'Datasets'}], 'additional_data_sources': [{'name': '', 'url': ''}], 'limitations': '', 'concept': 'Provides specific Datasets available through The DHS Program.', 'periodicity': '', 'topic': 'Datasets', 'created': '', 'last_modified': '', 'TriggerTalend': False, 'SavePathForJsonOutput': '//10.30.31.77/data_collection_dump/TestData/IPU'}}
# https://api.dhsprogram.com/rest/dhs/geometry
# {'JobPath': '//10.30.31.77/data_collection_dump/RawData/DHS_program/Geometry.csv', 'JsonDetails': {'organisation': 'third-parties', 'source': 'DHSProgram', 'source_description': 'The Demographic and Health Surveys (DHS) Program has collected, analyzed, and disseminated accurate and representative data on population, health, HIV, and nutrition through more than 300 surveys in over 90 countries.', 'source_url': 'https://api.dhsprogram.com/#/index.html', 'table': 'Geometry', 'description': 'fieldname : fieldDescription , SurveyId : DHS survey ID. Each survey will always have a unique ID (of the form ccyyyyttt where\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tcc is the DHS country code, yyyy is the survey year, and ttt is the survey type) and can\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tbe used to obtain national or subnational data for a particular survey. , CountryCode : Two-letter DHS specific country code. , SurveyYear : The principal year in which the survey was conducted. , SurveyType : The survey type determines whether the survey was a DHS, AIS, MIS, SPA, or other (OTH) type of survey. , CountryName : DHS specific country name. , RegionID : ID of the specified region. , LevelRank : Level Ranks determines the administrative boundaries. , Coordinates : Coordinates that make up the polygon of specified region.', 'JobType': 'JSON', 'CleanPush': True, 'Server': 'str', 'UseJsonFormatForSQL': False, 'CleanReplace': True, 'MergeSchema': False, 'tags': [{'name': 'Geometry'}], 'additional_data_sources': [{'name': '', 'url': ''}], 'limitations': '', 'concept': 'Provides a list of coordinates that have geometry data available through The DHS Program.', 'periodicity': '', 'topic': 'Geometry', 'created': '', 'last_modified': '', 'TriggerTalend': False, 'SavePathForJsonOutput': '//10.30.31.77/data_collection_dump/TestData/IPU'}}
