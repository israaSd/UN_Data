# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import ElementNotInteractableException, NoSuchElementException
from selenium.common.exceptions import ElementClickInterceptedException
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from webdriver_manager.firefox import GeckoDriverManager
from selenium.webdriver.firefox.options import Options
from bs4 import BeautifulSoup
import shutil
import time
import os
from pyshadow.main import Shadow
from py7zr import unpack_7zarchive
from RequestInferSchemaToJsonAPI.main import TriggerInferShemaToJsonAPI
base_path = 'C:\\Users\\10235555\\Documents\\Dataportal Data\\ITU Data Hub'

# %%
chrome_options = webdriver.ChromeOptions()
base_path = "C:\\Users\\10235555\\Documents\\Dataportal Data\\ITU Data Hub" # local, gets current working directory
prefs = {'download.default_directory' : base_path}#, "profile.content_settings.exceptions.automatic_downloads.*.setting" : 1}
# prefs = {"download.default_directory": base_path , # pass the variable
#                    "download.prompt_for_download": False,
#                    "directory_upgrade": True,
#                    "safebrowsing.enabled": True }
chrome_options.add_experimental_option('prefs', prefs)
chrome_options.add_argument('--user-agent="Mozilla/5.0 (Windows Phone 10.0; Android 4.2.1; Microsoft; Lumia 640 XL LTE) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.135 Mobile Safari/537.36 Edge/12.10166"')
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)
# driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
driver.maximize_window()

# %%
url = 'https://datahub.itu.int'
driver.get('https://datahub.itu.int/indicators/')

# %%
from selenium.common.exceptions import TimeoutException
content = driver.find_element(By.CLASS_NAME,'styles_root__kuX3t')
indicators = content.find_element(By.TAG_NAME,'ul').find_elements(By.CLASS_NAME,'styles_item__4wcw_')
for indicator in indicators:
    indicator_name = indicator.find_element(By.TAG_NAME,'h2').text
    list_indicators = indicator.find_element(By.CLASS_NAME,'styles_root__KNp6w').find_elements(By.CLASS_NAME,'styles_item__70VBH')
    for list_indicator in list_indicators:
        part_indicator = list_indicator.find_element(By.TAG_NAME,'h3').text
        list_parts_indicator = list_indicator.find_element(By.TAG_NAME,'ul').find_elements(By.TAG_NAME,'li')
        # print(indicator_name)
        # print(part_indicator)
        for elem_part_indicator in list_parts_indicator:
            dataset_name = elem_part_indicator.text
            print(indicator_name)
            print(part_indicator)
            print(dataset_name)
            dataset = elem_part_indicator.find_element(By.TAG_NAME,'a').get_attribute('href')
            driver.get(dataset)
            time.sleep(2)
            timeout = 15
            try:
                element_present = EC.presence_of_element_located((By.CLASS_NAME,'styles_header__N7Zbu'))
                WebDriverWait(driver, timeout).until(element_present)
            except TimeoutException:
                print("Timed out waiting for page to load DOWNLOAD")
            desc =  driver.find_element(By.CLASS_NAME,'styles_header__N7Zbu')
            desc = desc.text.replace('\n',' : ')
            download = driver.find_element(By.CLASS_NAME,'styles_actions__uxvrQ').find_element(By.TAG_NAME,'a')
            download.click()
            try:
                if driver.find_element(By.TAG_NAME,'body').text == '{"message": "Endpoint request timed out"}' :
                    driver.back()
            except:
                pass
            try:
                if driver.find_element(By.TAG_NAME,'body').text == '(intermediate value) is not iterable' :
                    driver.back()
            except:
                pass
            def latest_download_file():
                path = base_path
                os.chdir(path)
                files = sorted(os.listdir(os.getcwd()), key=os.path.getmtime)
                newest = files[-1]

                return newest

            fileends = "crdownload"
            while "crdownload" == fileends:
                time.sleep(5) 
                newest_file = latest_download_file()
                if "crdownload" in newest_file:
                    fileends = "crdownload"
                    # time.sleep(5)
                else:
                    fileends = "None"
            latest_download_file() 
            file = max([base_path + "\\" + f for f in os.listdir(base_path)],key=os.path.getctime)
            filename = os.path.split(file)[1]
            driver.back()
            time.sleep(2)
    # content = driver.find_element(By.CLASS_NAME,'styles_root__kuX3t')
    # indicators = content.find_element(By.TAG_NAME,'ul').find_elements(By.TAG_NAME,'li')
            # content = driver.find_element(By.CLASS_NAME,'styles_root__kuX3t')
            # indicators = content.find_element(By.TAG_NAME,'ul').find_elements(By.TAG_NAME,'li')
            # for indicator in indicators:
            #     indicator_name = indicator.find_element(By.TAG_NAME,'h2').text
            #     list_indicators = indicator.find_element(By.CLASS_NAME,'styles_root__KNp6w').find_elements(By.CLASS_NAME,'styles_item__70VBH')
            #     for list_indicator in list_indicators:
            #         part_indicator = list_indicator.find_element(By.TAG_NAME,'h3').text
            #         list_parts_indicator = list_indicator.find_element(By.TAG_NAME,'ul').find_elements(By.TAG_NAME,'li')
# Out:
# Connectivity
# Access
# Households with a radio
# Connectivity
# Access
# Households with a TV
# Connectivity
# Access
# Households with multichannel television, by type
# Connectivity
# Access
# Households with telephone (fixed or mobile)
# Connectivity
# Access
# Individuals who own a mobile cellular telephone
# Connectivity
# Access
# Individuals who own a smart telephone
# Connectivity
# Access
# Households with a computer
# Connectivity
# Access
# Households with a computer, by type
# Connectivity
# Access
# Households with Internet access at home
# Connectivity
# Access
# Households with access to Internet, by type of service
# Connectivity
# Access
# Reasons for not having Internet access (i.e. Barriers)
# Connectivity
# Access
# Fixed-telephone subscriptions
# Connectivity
# Access
# Fixed-telephone subscriptions that are residential
# Connectivity
# Access
# Mobile-cellular subscriptions
# Connectivity
# Access
# Population coverage, by mobile network technology
# Connectivity
# Access
# M2M mobile-network subscriptions
# Connectivity
# Access
# Mobile-cellular subscriptions: Prepaid
# Connectivity
# Access
# Mobile-cellular numbers ported
# Connectivity
# Access
# Subscriptions to fixed-broadband and fixed-telephone bundles
# Connectivity
# Access
# Subscriptions to fixed-broadband, fixed-telephone and pay-TV bundles
# Connectivity
# Access
# Households covered by fixed wired network
# Connectivity
# Access
# Fixed-broadband subscriptions for organizations
# Connectivity
# Access
# Fixed-broadband subscriptions
# Connectivity
# Access
# Active mobile-broadband subscriptions
# Connectivity
# Access
# Multichannel TV subscriptions
# Connectivity
# Backbone/core infrastructure
# International bandwidth usage
# Connectivity
# Backbone/core infrastructure
# Lit/equipped international bandwidth capacity
# Connectivity
# Emerging technologies
# Internet of Things (IoT)
# Connectivity
# Infrastructure development and sharing
# Regulatory framework for infrastructure sharing
# Connectivity
# Infrastructure development and sharing
# Fixed networks
# Connectivity
# Infrastructure development and sharing
# Mobile networks
# Connectivity
# Infrastructure development and sharing
# Spectrum sharing
# Connectivity
# International connectivity
# Country access to international connectivity
# Connectivity
# International connectivity
# International landing points
# Connectivity
# International connectivity
# National regulation that mandates access to international facilities
# Connectivity
# International connectivity
# Portion of access costs to international connection in retail price
# Connectivity
# International connectivity
# Type of connection to international transit
# Connectivity
# International connectivity
# Steps used to optimize costs of international connectivity
# Connectivity
# International connectivity
# Number of Internet exchange points (IXPs)
# Connectivity
# International connectivity
# Number of Internet service providers (ISPs)
# Connectivity
# International roaming
# International Mobile Roaming (IMR) policies
# Connectivity
# International roaming
# Roaming by home subscribers abroad (outbound roaming on CLRAs)
# Connectivity
# International roaming
# Incoming international traffic to mobile network
# Connectivity
# International roaming
# Roaming by foreign subscribers (inbound roaming)
# Connectivity
# International roaming
# Number of countries with which there is a country-level roaming agreement
# Connectivity
# International roaming
# Number of countries with which there is an operator-level roaming agreement
# Connectivity
# International roaming
# Mobile-broadband Internet traffic (outside the country, roaming out)
# Connectivity
# International roaming
# Mobile-broadband Internet traffic (outside the country, roaming out on CLRAs)
# Connectivity
# Numbering
# Number portability
# Connectivity
# Quality of Service (QoS)
# Quality of Service (QoS) regulatory framework
# Connectivity
# Quality of Service (QoS)
# Mobile-cellular dropped call ratio
# Connectivity
# Quality of Service (QoS)
# Average Download Throughput for Mobile Broadband
# Connectivity
# Quality of Service (QoS)
# Packet Latency for Mobile Broadband
# Connectivity
# Quality of Service (QoS)
# Average Upload Throughput for Mobile Broadband
# Connectivity
# Quality of Service (QoS)
# Mobile-cellular unsuccessful call ratio
# Connectivity
# Quality of Service (QoS)
# Average Download Throughput for Fixed Broadband
# Connectivity
# Quality of Service (QoS)
# Fault Resolution Period for Fixed Broadband Service
# Connectivity
# Quality of Service (QoS)
# Packet Latency for Fixed Broadband
# Connectivity
# Quality of Service (QoS)
# Service activation time for fixed-broadband service
# Connectivity
# Quality of Service (QoS)
# Average upload Throughput for Fixed Broadband
# Connectivity
# Traffic
# Fixed-to-mobile telephone traffic
# Connectivity
# Traffic
# Domestic fixed-to-fixed telephone traffic
# Connectivity
# Traffic
# International outgoing fixed-telephone traffic
# Connectivity
# Traffic
# International incoming and outgoing fixed-telephone traffic
# Connectivity
# Traffic
# International incoming fixed-telephone traffic
# Connectivity
# Traffic
# Total international outgoing telephone traffic
# Connectivity
# Traffic
# Total international telephone traffic
# Connectivity
# Traffic
# Total international incoming telephone traffic
# Connectivity
# Traffic
# Outgoing mobile traffic to fixed networks
# Connectivity
# Traffic
# Outgoing mobile traffic to international
# Connectivity
# Traffic
# SMS sent
# Connectivity
# Traffic
# Domestic mobile-telephone traffic
# Connectivity
# Traffic
# Fixed-broadband Internet traffic
# Connectivity
# Traffic
# Mobile-broadband Internet traffic (within the country)
# Connectivity
# Universal access
# UAS Policy
# Connectivity
# Universal access
# Universal Service Financing
# Connectivity
# Use
# Individuals using a mobile cellular telephone
# Connectivity
# Use
# Individuals using a smart phone
# Connectivity
# Use
# Individuals using a computer
# Connectivity
# Use
# Individuals using a computer, by type of device
# Connectivity
# Use
# Individuals using the Internet
# Connectivity
# Use
# Individuals using the Internet (from any location), by frequency
# Connectivity
# Use
# Individuals using the Internet, by location of use
# Connectivity
# Use
# Individuals using the Internet, by type of portable device and network used to access the Internet
# Connectivity
# Use
# Individuals using the Internet, by type of activity
# Connectivity
# Use
# Individuals not using the Internet, by type of reason
# Connectivity
# Use
# Number of individuals who purchased goods or services online, by type of payment channel
# Connectivity
# Use
# Number of individuals who purchased goods or servies online, by type of goods and services purchased online
# Connectivity
# Use
# Number of individuals who purchased goods or services online, by method of delivery
# Connectivity
# Use
# Number of individuals who did not purchase goods or services online, by reason
# Affordability
# Broadband services pricing
# Subject to price control and type of regulation
# Affordability
# Broadband services pricing
# Broadband services are part of universal service/access scheme
# Affordability
# Broadband services pricing
# Telecom service providers allowed to offer geographically differentiated broadband services
# Affordability
# Functional separation
# Functional separation
# Affordability
# ICT prices
# Household expenditure on ICTs
# Affordability
# ICT prices
# Household expenditure on ICTs, by type
# Affordability
# ICT prices
# Fixed-broadband Internet basket
# Affordability
# ICT prices
# Data-only mobile broadband basket
# Affordability
# ICT prices
# Mobile cellular low usage basket
# Affordability
# ICT prices
# Mobile data and voice low-consumption basket
# Affordability
# ICT prices
# Mobile data and voice high-consumption basket
# Affordability
# Interconnection
# Interconnection charges
# Affordability
# Interconnection
# Regulatory framework for interconnection
# Affordability
# Price regulation
# Fixed services
# Affordability
# Price regulation
# Mobile services
# Affordability
# Price regulation
# Wholesale Telecom/ICT Services
# Affordability
# Price regulation
# Over-the-top (OTT) content services
# Affordability
# Price regulation
# Broadcasting services
# Affordability
# Tariff Policies
# Cost methodology used for calculating fixed service tariffs
# Affordability
# Tariff Policies
# Cost methodology used for calculating mobile service tariffs
# Affordability
# Tariff Policies
# Cost modelling approach used as the basis for calculating fixed service tariffs
# Affordability
# Tariff Policies
# Cost modelling approach used as the basis for calculating mobile service tariffs
# Affordability
# Tariff Policies
# How are regulated service prices determined
# Affordability
# Tariff Policies
# How do operators charge retail prices for voice services?
# Governance
# ICT Regulator
# Regulatory Authority - Institutional structure
# Governance
# ICT Regulator
# Regulatory Authority - Procedures for appointment and removal of Head/Commissioners
# Governance
# ICT Regulator
# Regulatory roadmaps
# Governance
# Dispute resolution
# Dispute resolution mechanisms
# Governance
# Enforcement & Appeals
# Enforcement and appeal mechanisms
# Governance
# Regulatory autonomy
# Regulatory Authority - Decision-making
# Governance
# Regulatory mandates
# Regulatory Functions
# Governance
# Collaborative regulation
# Governance framework - Internet-related issues
# Governance
# Collaborative regulation
# ICT sector Ministry
# Governance
# Collaborative regulation
# Governance framework - Competition authority
# Governance
# Collaborative regulation
# Governance framework - Consumer protection authority
# Governance
# Collaborative regulation
# Governance framework - Data protection authority
# Governance
# Collaborative regulation
# Governance framework - Energy agency
# Governance
# Collaborative regulation
# Governance framework - Media & broadcasting
# Governance
# Collaborative regulation
# Governance framework - Spectrum
# Governance
# Collaborative regulation
# Governance framework - whole-of-government
# Governance
# Collaborative regulation
# Governance framework - Tech ethics
# Governance
# Legal frameworks
# Main laws and regulations
# Governance
# Legal frameworks
# Pandemic policy response
# Governance
# Legal frameworks
# Pandemic policy response
# Governance
# Legal frameworks
# Data policies
# Markets
# Competition
# Competition framework
# Markets
# Competition
# Level of Competition
# Markets
# Market structure
# Foreign participation
# Markets
# Market structure
# Significant Market Power (SMP)
# Markets
# Market structure
# Functional separation
# Markets
# Market structure
# Mergers
# Markets
# Investment
# Annual investment in telecommunication services
# Markets
# Investment
# Annual foreign investment in telecommunications
# Markets
# Emerging technologies
# Internet of Things (IoT)
# Markets
# Policy & operational frameworks
# Digital development strategies
# Markets
# Policy & operational frameworks
# National broadband plans
# Markets
# Policy & operational frameworks
# Emerging technologies
# Markets
# Policy & operational frameworks
# ICT policies
# Markets
# Traffic management
# Net neutrality
# Markets
# Spectrum
# Spectrum licensing
# Markets
# Spectrum
# Spectrum sharing
# Markets
# Spectrum
# Digitial dividend
# Markets
# Spectrum
# Spectrum harmonization
# Markets
# Spectrum
# Amount of spectrum offered for IMT systems, in MHz
# Markets
# Spectrum
# Amount of spectrum licensed for IMT systems, in MHz
# Markets
# Licensing
# Licences & authorizations
# Markets
# Licensing
# Publicly available information
# Markets
# Regulatory incentives
# Regulatory incentives for operators
# Markets
# Regulatory incentives
# Regulatory incentives for operators
# Markets
# Taxation
# Value-added tax (VAT) category
# Markets
# Taxation
# Taxation policies
# Markets
# Taxation
# Taxes and duties applying to telecommunication/ICT sector
# Markets
# Taxation
# Telecommunication/ICT taxation value chain
# Markets
# Revenues
# Revenue from mobile networks
# Markets
# Revenues
# Revenue from all telecommunication services
# Markets
# Workforce
# Full-time equivalent telecommunication employees
# Sustainability
# e-Applications
# Regulatory framework and mandates for e-Applications
# Sustainability
# Emergency telecommunications
# Emergency telecommunications
# Sustainability
# Environment & e-waste
# Environment & e-waste mandates and legal framework
# Sustainability
# Society
# Individuals with ICT skills, by type of skills
# Sustainability
# Society
# Proportion of households with electricity
# Sustainability
# Society
# Total population
# Trust
# Applications and Services
# Over-the-top services (OTT) regulation
# Trust
# Applications and Services
# VoIP policies
# Trust
# Consumer protection
# Consumer protection framework and mandates
# Trust
# Counterfeit
# Counterfeit framework and mandates
# Trust
# Digital identity
# Digital identity framework and mandates
# Trust
# ICT Accessibility for people with disabilities
# ICT accessibility policies
# Trust
# Cybersecurity
# Cybersecurity framework and mandates

# %%
desc =  driver.find_element(By.CLASS_NAME,'styles_header__N7Zbu')
desc.text.replace('\n',' : ')
# Out:
# 'Households with a radio : Connectivity, Access : Refers to the proportion of households that have a radio. A radio is defined as a device capable of receiving broadcast radio signals, using common frequencies. A radio may be a stand-alone device or integrated with another device, e.g. computer or mobile phone.'

# %%
download = driver.find_element(By.CLASS_NAME,'styles_actions__uxvrQ').find_element(By.TAG_NAME,'a')
download.click()

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import ElementNotInteractableException, NoSuchElementException
from selenium.common.exceptions import ElementClickInterceptedException
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from webdriver_manager.firefox import GeckoDriverManager
from selenium.webdriver.firefox.options import Options
from bs4 import BeautifulSoup
import shutil
import time
import os
from pyshadow.main import Shadow
from py7zr import unpack_7zarchive
from RequestInferSchemaToJsonAPI.main import TriggerInferShemaToJsonAPI
import logging
# logging.basicConfig(handlers=[logging.FileHandler("//10.30.31.77/data_collection_dump/TACFolder/ScraperLogs/ITU_DataHub_out.log"),
#                             logging.StreamHandler()], level=logging.INFO)
base_path = '\\\\10.30.31.77\\data_collection_dump\\RawData\\ITU Data Hub'

chrome_options = webdriver.ChromeOptions()
base_path = "\\\\10.30.31.77\\data_collection_dump\\RawData\\ITU Data Hub" # local, gets current working directory
prefs = {'download.default_directory' : base_path}#, "profile.content_settings.exceptions.automatic_downloads.*.setting" : 1}
chrome_options.add_experimental_option('prefs', prefs)
chrome_options.add_argument('--user-agent="Mozilla/5.0 (Windows Phone 10.0; Android 4.2.1; Microsoft; Lumia 640 XL LTE) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.135 Mobile Safari/537.36 Edge/12.10166"')
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)
driver.maximize_window()

driver.get('https://datahub.itu.int/indicators/')

from selenium.common.exceptions import TimeoutException
content = driver.find_element(By.CLASS_NAME,'styles_root__kuX3t')
indicators = content.find_element(By.TAG_NAME,'ul').find_elements(By.CLASS_NAME,'styles_item__4wcw_')
for indicator in indicators[3:]:
    indicator_name = indicator.find_element(By.TAG_NAME,'h2').text
    list_indicators = indicator.find_element(By.CLASS_NAME,'styles_root__KNp6w').find_elements(By.CLASS_NAME,'styles_item__70VBH')
    for list_indicator in list_indicators[5:]:
        part_indicator = list_indicator.find_element(By.TAG_NAME,'h3').text
        list_parts_indicator = list_indicator.find_element(By.TAG_NAME,'ul').find_elements(By.TAG_NAME,'li')
        for elem_part_indicator in list_parts_indicator:
            dataset_name = elem_part_indicator.text
            dataset_name = dataset_name.replace(':','').replace('/',',').replace('?','')#.replace('&','and')
            dataset = elem_part_indicator.find_element(By.TAG_NAME,'a').get_attribute('href')
            driver.get(dataset)
            time.sleep(2)
            timeout = 15
            try:
                element_present = EC.presence_of_element_located((By.CLASS_NAME,'styles_header__N7Zbu'))
                WebDriverWait(driver, timeout).until(element_present)
            except TimeoutException:
                print("Timed out waiting for page to load DOWNLOAD")
            desc =  driver.find_element(By.CLASS_NAME,'styles_header__N7Zbu')
            desc = desc.text.replace('\n','  ')
            download = driver.find_element(By.CLASS_NAME,'styles_actions__uxvrQ').find_element(By.TAG_NAME,'a')
            download.click()
            if driver.find_element(By.TAG_NAME,'body').text == '{"message": "Endpoint request timed out"}' :
                print('{"message": "Endpoint request timed out"}')
                driver.back()
                driver.back()
                time.sleep(2)
            elif driver.find_element(By.TAG_NAME,'body').text == '(intermediate value) is not iterable' :
                print('(intermediate value) is not iterable')
                driver.back()
                driver.back()
                time.sleep(2)
            else:
                def latest_download_file():
                    path = base_path
                    os.chdir(path)
                    files = sorted(os.listdir(os.getcwd()), key=os.path.getmtime)
                    newest = files[-1]

                    return newest

                fileends = "crdownload"
                while "crdownload" == fileends:
                    time.sleep(4) 
                    newest_file = latest_download_file()
                    if "crdownload" in newest_file:
                        fileends = "crdownload"
                        # time.sleep(5)
                    else:
                        fileends = "None"
                latest_download_file() 
                file = max([base_path + "\\" + f for f in os.listdir(base_path)],key=os.path.getctime)
                filename = os.path.split(file)[1]
                os.rename(file,f'{base_path}\\{dataset_name}.csv')
                driver.back()
                time.sleep(2)
                try:
                    BodyDict = {
                        "JobPath":f"//10.30.31.77/data_collection_dump/RawData/ITU Data Hub/{dataset_name}.csv", #* Point to downloaded data for conversion 
                        "JsonDetails":{
                                ## Required
                                "organisation": "third-parties",
                                "source": "ITU",
                                "source_description" : "The International Telecommunication Union (ITU) is the United Nations specialized agency for information and communication technologies - ICTs.",
                                "source_url" : "https://datahub.itu.int/data/",
                                "table" : dataset_name,
                                "description" : desc,
                                ## Optional
                                "JobType": "JSON",
                                "CleanPush": True,
                                "Server": "str",
                                "UseJsonFormatForSQL":  False,
                                "CleanReplace":True,
                                "MergeSchema": False,
                                "tags": [{
                                    "name": part_indicator
                                }],
                                "additional_data_sources": [{
                                    "name": ''
                                }],
                                "limitations":'',
                                "concept":  '',
                                "periodicity":  '',
                                "topic":  indicator_name,
                                "created": '',                       #* this should follow the following formats %Y-%m-%dT%H:%M:%S" or "%Y-%m-%d"
                                "last_modified": '',                #* ""               ""                  ""              ""
                                "TriggerTalend" :  False,    #* initialise to True for production
                                "SavePathForJsonOutput": "//10.30.31.77/data_collection_dump/TestData" #* initialise as empty string for production.
                            }
                        }

                    # TriggerInferShemaToJsonAPIClass = TriggerInferShemaToJsonAPI(BodyDict=BodyDict)
                    # TriggerInferShemaToJsonAPIClass.TriggerAPI()
                    logging.info(f"Conversion successful - {indicator_name} {part_indicator} {dataset_name} ")
                    print(BodyDict)
                except  Exception as err:
                    print(err)
# Out:
# {'JobPath': '//10.30.31.77/data_collection_dump/RawData/ITU Data Hub/Net neutrality.csv', 'JsonDetails': {'organisation': 'third-parties', 'source': 'ITU', 'source_description': 'The International Telecommunication Union (ITU) is the United Nations specialized agency for information and communication technologies - ICTs.', 'source_url': 'https://datahub.itu.int/data/', 'table': 'Net neutrality', 'description': 'Net neutrality  Existing regulations  Markets, Traffic management', 'JobType': 'JSON', 'CleanPush': True, 'Server': 'str', 'UseJsonFormatForSQL': False, 'CleanReplace': True, 'MergeSchema': False, 'tags': [{'name': 'Traffic management'}], 'additional_data_sources': [{'name': ''}], 'limitations': '', 'concept': '', 'periodicity': '', 'topic': 'Markets', 'created': '', 'last_modified': '', 'TriggerTalend': False, 'SavePathForJsonOutput': '//10.30.31.77/data_collection_dump/TestData'}}
# {'JobPath': '//10.30.31.77/data_collection_dump/RawData/ITU Data Hub/Spectrum licensing.csv', 'JsonDetails': {'organisation': 'third-parties', 'source': 'ITU', 'source_description': 'The International Telecommunication Union (ITU) is the United Nations specialized agency for information and communication technologies - ICTs.', 'source_url': 'https://datahub.itu.int/data/', 'table': 'Spectrum licensing', 'description': 'Spectrum licensing  Spectrum licences technology-neutral  Markets, Spectrum', 'JobType': 'JSON', 'CleanPush': True, 'Server': 'str', 'UseJsonFormatForSQL': False, 'CleanReplace': True, 'MergeSchema': False, 'tags': [{'name': 'Spectrum'}], 'additional_data_sources': [{'name': ''}], 'limitations': '', 'concept': '', 'periodicity': '', 'topic': 'Markets', 'created': '', 'last_modified': '', 'TriggerTalend': False, 'SavePathForJsonOutput': '//10.30.31.77/data_collection_dump/TestData'}}
# {'JobPath': '//10.30.31.77/data_collection_dump/RawData/ITU Data Hub/Spectrum sharing.csv', 'JsonDetails': {'organisation': 'third-parties', 'source': 'ITU', 'source_description': 'The International Telecommunication Union (ITU) is the United Nations specialized agency for information and communication technologies - ICTs.', 'source_url': 'https://datahub.itu.int/data/', 'table': 'Spectrum sharing', 'description': 'Spectrum sharing  Secondary spectrum trading  Markets, Spectrum  Secondary Trading is the trading of spectrum rights or licenses directly between original licensed holders and buyers or leasers.', 'JobType': 'JSON', 'CleanPush': True, 'Server': 'str', 'UseJsonFormatForSQL': False, 'CleanReplace': True, 'MergeSchema': False, 'tags': [{'name': 'Spectrum'}], 'additional_data_sources': [{'name': ''}], 'limitations': '', 'concept': '', 'periodicity': '', 'topic': 'Markets', 'created': '', 'last_modified': '', 'TriggerTalend': False, 'SavePathForJsonOutput': '//10.30.31.77/data_collection_dump/TestData'}}
# {'JobPath': '//10.30.31.77/data_collection_dump/RawData/ITU Data Hub/Digitial dividend.csv', 'JsonDetails': {'organisation': 'third-parties', 'source': 'ITU', 'source_description': 'The International Telecommunication Union (ITU) is the United Nations specialized agency for information and communication technologies - ICTs.', 'source_url': 'https://datahub.itu.int/data/', 'table': 'Digitial dividend', 'description': 'Digitial dividend  Digital Dividend spectrum reallocated  Markets, Spectrum  Digital Dividend refers to the spectrum to be released in the process of Analogue to Digital Television transition, and intended to be reallocated to mobile services, and then licensed to mobile operators.', 'JobType': 'JSON', 'CleanPush': True, 'Server': 'str', 'UseJsonFormatForSQL': False, 'CleanReplace': True, 'MergeSchema': False, 'tags': [{'name': 'Spectrum'}], 'additional_data_sources': [{'name': ''}], 'limitations': '', 'concept': '', 'periodicity': '', 'topic': 'Markets', 'created': '', 'last_modified': '', 'TriggerTalend': False, 'SavePathForJsonOutput': '//10.30.31.77/data_collection_dump/TestData'}}
# {'JobPath': '//10.30.31.77/data_collection_dump/RawData/ITU Data Hub/Spectrum harmonization.csv', 'JsonDetails': {'organisation': 'third-parties', 'source': 'ITU', 'source_description': 'The International Telecommunication Union (ITU) is the United Nations specialized agency for information and communication technologies - ICTs.', 'source_url': 'https://datahub.itu.int/data/', 'table': 'Spectrum harmonization', 'description': 'Spectrum harmonization  Information on spectrum publicly available  Markets, Spectrum', 'JobType': 'JSON', 'CleanPush': True, 'Server': 'str', 'UseJsonFormatForSQL': False, 'CleanReplace': True, 'MergeSchema': False, 'tags': [{'name': 'Spectrum'}], 'additional_data_sources': [{'name': ''}], 'limitations': '', 'concept': '', 'periodicity': '', 'topic': 'Markets', 'created': '', 'last_modified': '', 'TriggerTalend': False, 'SavePathForJsonOutput': '//10.30.31.77/data_collection_dump/TestData'}}
# {'JobPath': '//10.30.31.77/data_collection_dump/RawData/ITU Data Hub/Amount of spectrum offered for IMT systems, in MHz.csv', 'JsonDetails': {'organisation': 'third-parties', 'source': 'ITU', 'source_description': 'The International Telecommunication Union (ITU) is the United Nations specialized agency for information and communication technologies - ICTs.', 'source_url': 'https://datahub.itu.int/data/', 'table': 'Amount of spectrum offered for IMT systems, in MHz', 'description': 'Amount of spectrum offered for IMT systems, in MHz  Markets, Spectrum', 'JobType': 'JSON', 'CleanPush': True, 'Server': 'str', 'UseJsonFormatForSQL': False, 'CleanReplace': True, 'MergeSchema': False, 'tags': [{'name': 'Spectrum'}], 'additional_data_sources': [{'name': ''}], 'limitations': '', 'concept': '', 'periodicity': '', 'topic': 'Markets', 'created': '', 'last_modified': '', 'TriggerTalend': False, 'SavePathForJsonOutput': '//10.30.31.77/data_collection_dump/TestData'}}
# {'JobPath': '//10.30.31.77/data_collection_dump/RawData/ITU Data Hub/Amount of spectrum licensed for IMT systems, in MHz.csv', 'JsonDetails': {'organisation': 'third-parties', 'source': 'ITU', 'source_description': 'The International Telecommunication Union (ITU) is the United Nations specialized agency for information and communication technologies - ICTs.', 'source_url': 'https://datahub.itu.int/data/', 'table': 'Amount of spectrum licensed for IMT systems, in MHz', 'description': 'Amount of spectrum licensed for IMT systems, in MHz  Markets, Spectrum', 'JobType': 'JSON', 'CleanPush': True, 'Server': 'str', 'UseJsonFormatForSQL': False, 'CleanReplace': True, 'MergeSchema': False, 'tags': [{'name': 'Spectrum'}], 'additional_data_sources': [{'name': ''}], 'limitations': '', 'concept': '', 'periodicity': '', 'topic': 'Markets', 'created': '', 'last_modified': '', 'TriggerTalend': False, 'SavePathForJsonOutput': '//10.30.31.77/data_collection_dump/TestData'}}
# {'JobPath': '//10.30.31.77/data_collection_dump/RawData/ITU Data Hub/Licences & authorizations.csv', 'JsonDetails': {'organisation': 'third-parties', 'source': 'ITU', 'source_description': 'The International Telecommunication Union (ITU) is the United Nations specialized agency for information and communication technologies - ICTs.', 'source_url': 'https://datahub.itu.int/data/', 'table': 'Licences & authorizations', 'description': 'Licences & authorizations  Types of operating licenses/authorizations provided  Markets, Licensing', 'JobType': 'JSON', 'CleanPush': True, 'Server': 'str', 'UseJsonFormatForSQL': False, 'CleanReplace': True, 'MergeSchema': False, 'tags': [{'name': 'Licensing'}], 'additional_data_sources': [{'name': ''}], 'limitations': '', 'concept': '', 'periodicity': '', 'topic': 'Markets', 'created': '', 'last_modified': '', 'TriggerTalend': False, 'SavePathForJsonOutput': '//10.30.31.77/data_collection_dump/TestData'}}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\10235555\Documents\DataportalCrawlers\UN_Data\ITU_DataHub.ipynb Cell 7 in 6
#      <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/ITU_DataHub.ipynb#W6sZmlsZQ%3D%3D?line=61'>62</a>     driver.back()
#      <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/ITU_DataHub.ipynb#W6sZmlsZQ%3D%3D?line=62'>63</a>     time.sleep(2)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/ITU_DataHub.ipynb#W6sZmlsZQ%3D%3D?line=63'>64</a> elif driver.find_element(By.TAG_NAME,'body').text == '(intermediate value) is not iterable' :
#      <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/ITU_DataHub.ipynb#W6sZmlsZQ%3D%3D?line=64'>65</a>     print('(intermediate value) is not iterable')
#      <a href='vscode-notebook-cell:/c%3A/Users/10235555/Documents/DataportalCrawlers/UN_Data/ITU_DataHub.ipynb#W6sZmlsZQ%3D%3D?line=65'>66</a>     driver.back()
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\webelement.py:89, in WebElement.text(self)
#      86 @property
#      87 def text(self) -> str:
#      88     """The text of the element."""
# ---> 89     return self._execute(Command.GET_ELEMENT_TEXT)["value"]
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\webelement.py:410, in WebElement._execute(self, command, params)
#     408     params = {}
#     409 params["id"] = self._id
# --> 410 return self._parent.execute(command, params)
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\webdriver.py:442, in WebDriver.execute(self, driver_command, params)
#     439     elif "sessionId" not in params:
#     440         params["sessionId"] = self.session_id
# --> 442 response = self.command_executor.execute(driver_command, params)
#     443 if response:
#     444     self.error_handler.check_response(response)
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\remote_connection.py:294, in RemoteConnection.execute(self, command, params)
#     292 data = utils.dump_json(params)
#     293 url = f"{self._url}{path}"
# --> 294 return self._request(command_info[0], url, body=data)
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\remote_connection.py:316, in RemoteConnection._request(self, method, url, body)
#     313     body = None
#     315 if self.keep_alive:
# --> 316     response = self._conn.request(method, url, body=body, headers=headers)
#     317     statuscode = response.status
#     318 else:
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\request.py:74, in RequestMethods.request(self, method, url, fields, headers, **urlopen_kw)
#      71 urlopen_kw["request_url"] = url
#      73 if method in self._encode_url_methods:
# ---> 74     return self.request_encode_url(
#      75         method, url, fields=fields, headers=headers, **urlopen_kw
#      76     )
#      77 else:
#      78     return self.request_encode_body(
#      79         method, url, fields=fields, headers=headers, **urlopen_kw
#      80     )
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\request.py:96, in RequestMethods.request_encode_url(self, method, url, fields, headers, **urlopen_kw)
#      93 if fields:
#      94     url += "?" + urlencode(fields)
# ---> 96 return self.urlopen(method, url, **extra_kw)
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\poolmanager.py:376, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     374     response = conn.urlopen(method, url, **kw)
#     375 else:
# --> 376     response = conn.urlopen(method, u.request_uri, **kw)
#     378 redirect_location = redirect and response.get_redirect_location()
#     379 if not redirect_location:
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\http\client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File c:\Users\10235555\AppData\Local\Programs\Python\Python311\Lib\socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# KeyboardInterrupt:
